# %%
import pandas as pd

data_row=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/transformed/target/after vector/target data.csv")

data_row
# Out:
#       Unnamed: 0         0         1         2         3         4         5  \
# 0              8  0.001959  0.011420  0.087598 -0.028180 -0.031777 -0.073938
# 1            629 -0.000778  0.051204  0.049894  0.005384 -0.015987 -0.054007
# 2            721  0.011526  0.031606  0.037677  0.043493 -0.047457 -0.044487
# 3            370  0.037959  0.019435  0.048267 -0.005821 -0.039560 -0.039283
# 4             21 -0.008401  0.015176  0.085499 -0.043815 -0.042581 -0.060114
# ...          ...       ...       ...       ...       ...       ...       ...
# 1190        1037  0.014927  0.042170  0.086930 -0.010602 -0.007679 -0.042808
# 1191           9 -0.007925  0.052466  0.046144 -0.035355 -0.004603 -0.047827
# 1192        1160  0.004844  0.021066  0.078264 -0.027323 -0.009510 -0.021972
# 1193         853  0.008590  0.027379  0.081873 -0.026565 -0.008348 -0.045456
# 1194         746 -0.039600  0.060860  0.072594 -0.024996 -0.005344 -0.060261
#
# ...

# %%
data_row.drop(columns=['Unnamed: 0'],inplace=True)

# %%
y_test=pd.DataFrame(data=data_row['predict'],columns=['predict'])

# %%
y_test
# Out:
#       predict
# 0           1
# 1           1
# 2           0
# 3           0
# 4           1
# ...       ...
# 1190        1
# 1191        1
# 1192        0
# 1193        0
# 1194        1
#
# [1195 rows x 1 columns]

# %%
data_row.drop(columns=['predict'],inplace=True)

# %%
x_test=data_row

# %%
x_test
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.001959  0.011420  0.087598 -0.028180 -0.031777 -0.073938  0.017819
# 1    -0.000778  0.051204  0.049894  0.005384 -0.015987 -0.054007 -0.008093
# 2     0.011526  0.031606  0.037677  0.043493 -0.047457 -0.044487  0.007500
# 3     0.037959  0.019435  0.048267 -0.005821 -0.039560 -0.039283  0.062943
# 4    -0.008401  0.015176  0.085499 -0.043815 -0.042581 -0.060114  0.011219
# ...        ...       ...       ...       ...       ...       ...       ...
# 1190  0.014927  0.042170  0.086930 -0.010602 -0.007679 -0.042808  0.023162
# 1191 -0.007925  0.052466  0.046144 -0.035355 -0.004603 -0.047827  0.007184
# 1192  0.004844  0.021066  0.078264 -0.027323 -0.009510 -0.021972  0.050431
# 1193  0.008590  0.027379  0.081873 -0.026565 -0.008348 -0.045456  0.029309
# 1194 -0.039600  0.060860  0.072594 -0.024996 -0.005344 -0.060261  0.021857
#
# ...

# %%
x_test.to_csv("x_target.csv")

# %%
y_test.to_csv("y_target.csv")
