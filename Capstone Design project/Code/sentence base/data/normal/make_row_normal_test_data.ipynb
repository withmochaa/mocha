# %%
import pandas as pd

data_row=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/normal/row/df_data_unharmful.csv")

# %%
data_row.drop(columns=['Unnamed: 0'],inplace=True)
#data_row2.drop(columns=['Unnamed: 0'],inplace=True)

# %%
data_row
# Out:
#                                              transcript  confidence  label
# 0     저는 여행 다니는 것을 굉장히 좋아하는데요. 그래가지고 스페인이나 뭐 영국 유럽 아...         NaN      0
# 1     반려동물을 키우고 계신가요? 혹시 안 키우고 계시다면은 어떤 반려동물을 한번 키워보...         NaN      0
# 2      씨는 주로 어떤 음식 좋아하시나요? 저는 근데 가리는 게 거의 없어서 대부분 다 ...         NaN      0
# 3      씨는 반려동물 어~ 좋 뭐 어떤 동물 좋아하세요? 저는 고양이를 정말 좋아하는데요...         NaN      0
# 4     가장 좋아하는 음식이 무엇인가요? 저는 주로 먹는 거를 좋아해서 음식을 가리지 않고...         NaN      0
# ...                                                 ...         ...    ...
# 2227  요새 먹거리에 대해 코로나 때문에 그런지 더 관심이 많아지는 거 같아요. 특히 집에...         NaN      0
# 2228  어~ 중학생 때부터 좋아하던 배우가 있는데 어~ 이제 요즘 영화나 드라마 같은 데는...         NaN      0
# 2229  오늘은 꿈에 대해서 한번 이야기를 나눠 보았으면 좋겠어요. 음~ 나는 어렸을 때부터...         NaN      0
# 2230  저는 여러 계절이 있지만 겨울 이라는 계절을 제일 좋아하는데요. 가장 큰 이유 중의...         NaN      0
# 2231  저는 학교를 졸업한 지 오래되어서 어~ 기억이 쪼금 먼 기리 멀기는 하지만 어~ 저...         NaN      0
#
# [2232 rows x 3 columns]

# %%
data_row.rename(columns={'transcript':'sentence'},inplace=True)

# %%
data_row
# Out:
#                                                sentence  confidence  label
# 0     저는 여행 다니는 것을 굉장히 좋아하는데요. 그래가지고 스페인이나 뭐 영국 유럽 아...         NaN      0
# 1     반려동물을 키우고 계신가요? 혹시 안 키우고 계시다면은 어떤 반려동물을 한번 키워보...         NaN      0
# 2      씨는 주로 어떤 음식 좋아하시나요? 저는 근데 가리는 게 거의 없어서 대부분 다 ...         NaN      0
# 3      씨는 반려동물 어~ 좋 뭐 어떤 동물 좋아하세요? 저는 고양이를 정말 좋아하는데요...         NaN      0
# 4     가장 좋아하는 음식이 무엇인가요? 저는 주로 먹는 거를 좋아해서 음식을 가리지 않고...         NaN      0
# ...                                                 ...         ...    ...
# 2227  요새 먹거리에 대해 코로나 때문에 그런지 더 관심이 많아지는 거 같아요. 특히 집에...         NaN      0
# 2228  어~ 중학생 때부터 좋아하던 배우가 있는데 어~ 이제 요즘 영화나 드라마 같은 데는...         NaN      0
# 2229  오늘은 꿈에 대해서 한번 이야기를 나눠 보았으면 좋겠어요. 음~ 나는 어렸을 때부터...         NaN      0
# 2230  저는 여러 계절이 있지만 겨울 이라는 계절을 제일 좋아하는데요. 가장 큰 이유 중의...         NaN      0
# 2231  저는 학교를 졸업한 지 오래되어서 어~ 기억이 쪼금 먼 기리 멀기는 하지만 어~ 저...         NaN      0
#
# [2232 rows x 3 columns]

# %%
data=pd.DataFrame(index=range(0,data_row.shape[0]),columns=['sentence','predict'])

# %%
data
# Out:
#      sentence predict
# 0         NaN     NaN
# 1         NaN     NaN
# 2         NaN     NaN
# 3         NaN     NaN
# 4         NaN     NaN
# ...       ...     ...
# 2227      NaN     NaN
# 2228      NaN     NaN
# 2229      NaN     NaN
# 2230      NaN     NaN
# 2231      NaN     NaN
#
# [2232 rows x 2 columns]

# %%
for i in range(data_row.shape[0]):
    data.iloc[i,0]=data_row.iloc[i,0]

# %%
data
# Out:
#                                                sentence predict
# 0     저는 여행 다니는 것을 굉장히 좋아하는데요. 그래가지고 스페인이나 뭐 영국 유럽 아...     NaN
# 1     반려동물을 키우고 계신가요? 혹시 안 키우고 계시다면은 어떤 반려동물을 한번 키워보...     NaN
# 2      씨는 주로 어떤 음식 좋아하시나요? 저는 근데 가리는 게 거의 없어서 대부분 다 ...     NaN
# 3      씨는 반려동물 어~ 좋 뭐 어떤 동물 좋아하세요? 저는 고양이를 정말 좋아하는데요...     NaN
# 4     가장 좋아하는 음식이 무엇인가요? 저는 주로 먹는 거를 좋아해서 음식을 가리지 않고...     NaN
# ...                                                 ...     ...
# 2227  요새 먹거리에 대해 코로나 때문에 그런지 더 관심이 많아지는 거 같아요. 특히 집에...     NaN
# 2228  어~ 중학생 때부터 좋아하던 배우가 있는데 어~ 이제 요즘 영화나 드라마 같은 데는...     NaN
# 2229  오늘은 꿈에 대해서 한번 이야기를 나눠 보았으면 좋겠어요. 음~ 나는 어렸을 때부터...     NaN
# 2230  저는 여러 계절이 있지만 겨울 이라는 계절을 제일 좋아하는데요. 가장 큰 이유 중의...     NaN
# 2231  저는 학교를 졸업한 지 오래되어서 어~ 기억이 쪼금 먼 기리 멀기는 하지만 어~ 저...     NaN
#
# [2232 rows x 2 columns]

# %%
data['predict']=pd.DataFrame(data['predict'].fillna('1'))

# %%
data
# Out:
#                                                sentence predict
# 0     저는 여행 다니는 것을 굉장히 좋아하는데요. 그래가지고 스페인이나 뭐 영국 유럽 아...       1
# 1     반려동물을 키우고 계신가요? 혹시 안 키우고 계시다면은 어떤 반려동물을 한번 키워보...       1
# 2      씨는 주로 어떤 음식 좋아하시나요? 저는 근데 가리는 게 거의 없어서 대부분 다 ...       1
# 3      씨는 반려동물 어~ 좋 뭐 어떤 동물 좋아하세요? 저는 고양이를 정말 좋아하는데요...       1
# 4     가장 좋아하는 음식이 무엇인가요? 저는 주로 먹는 거를 좋아해서 음식을 가리지 않고...       1
# ...                                                 ...     ...
# 2227  요새 먹거리에 대해 코로나 때문에 그런지 더 관심이 많아지는 거 같아요. 특히 집에...       1
# 2228  어~ 중학생 때부터 좋아하던 배우가 있는데 어~ 이제 요즘 영화나 드라마 같은 데는...       1
# 2229  오늘은 꿈에 대해서 한번 이야기를 나눠 보았으면 좋겠어요. 음~ 나는 어렸을 때부터...       1
# 2230  저는 여러 계절이 있지만 겨울 이라는 계절을 제일 좋아하는데요. 가장 큰 이유 중의...       1
# 2231  저는 학교를 졸업한 지 오래되어서 어~ 기억이 쪼금 먼 기리 멀기는 하지만 어~ 저...       1
#
# [2232 rows x 2 columns]

# %%
data=data.sample(frac=1)

# %%
data
# Out:
#                                                sentence predict
# 998   아니  씨는 연애 몇 년하고 결혼하셨어요? 아~ 저는 저희 신랑과 연애 기간은 많이...       1
# 254   혹시 어릴 적 부터 즐겨 드시는 음식이 있으신가요? 저는 한식을 좋아해서 밥하고 김...       1
# 2008  지난 주말에 가족들하고 저는 저기 고령 예마을이라는 곳을 다녀왔어요. 고령이라고 하...       1
# 348   아~ 나는 이제 여행을 되게 좋아하잖아. 나는 여행을 되게 좋아하는데 내가 지금까지...       1
# 2089  내 이상형은 어~ 남자가 조금 당 다정하고 듬직한 사람이 좋은데 네 이상형은 어~ ...       1
# ...                                                 ...     ...
# 218   혹시 외모적인 부분에서 콤플렉스가 있나요? 이런 콤플렉스가 있다고 생각하게 된 경험...       1
# 1331  이번에 예체능계 인물들이 일부 봉사 시간을 조작해서 군대 부분을 현역 기피를 하려고...       1
# 1404  나 요 근래에 왼쪽 어깨가 너무 아파가지고 정형외과를 갔는데 정형외과에서 엠알아이를...       1
# 2071  내는 초등학교 때 오형이어서 막 에이형이나 에이비형인 애들이 막 물 한 입 달라 그...       1
# 1120  안녕하세요? 저는 프로야구를 굉장히 좋아합니다. 그~ 프로야구가 탄생한 것은 내가 ...       1
#
# [2232 rows x 2 columns]

# %%
target=pd.DataFrame(index=range(500),columns=['sentence','predict'])

# %%
for i in range(target.shape[0]):
    target.iloc[i,0]=data.iloc[i,0]
    target.iloc[i,1]=data.iloc[i,1]

# %%
target
# Out:
#                                               sentence predict
# 0    아니  씨는 연애 몇 년하고 결혼하셨어요? 아~ 저는 저희 신랑과 연애 기간은 많이...       1
# 1    혹시 어릴 적 부터 즐겨 드시는 음식이 있으신가요? 저는 한식을 좋아해서 밥하고 김...       1
# 2    지난 주말에 가족들하고 저는 저기 고령 예마을이라는 곳을 다녀왔어요. 고령이라고 하...       1
# 3    아~ 나는 이제 여행을 되게 좋아하잖아. 나는 여행을 되게 좋아하는데 내가 지금까지...       1
# 4    내 이상형은 어~ 남자가 조금 당 다정하고 듬직한 사람이 좋은데 네 이상형은 어~ ...       1
# ..                                                 ...     ...
# 495  지금 결혼하셨잖아요? 아 결혼하시면서 직장인이신데 지금 나이가 어떻게 되시고 혹시 ...       1
# 496  혹시 해보신 아르바이트 중에서 조금 재미있는 아르바이트나 조금 특색있는 아르바이트 ...       1
# 497  아~  씨 곧 어머님 생신이라고 그랬죠. 에~ 곧 내려가시겠네요? 네. 저희 엄마가...       1
# 498  최근에 어디 여행 간 데 중에 기억에 남는 장소가 혹시 있어요? 최근에 코로나 때문...       1
# 499  요즘 전복이 가격이 많이 낮아졌대. 1키로 당 원래 67000원 했는데 28000원...       1
#
# [500 rows x 2 columns]

# %%
target.to_csv("target data(nor).csv")
