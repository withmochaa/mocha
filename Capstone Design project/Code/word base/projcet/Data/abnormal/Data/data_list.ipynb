# %%
import os

# %%
path="/Users/withmocha/Desktop/DATA/Capston Design(2024)/Data(24.03.12)/abnormal/Voice fishing Data(row)/"

file_list=os.listdir(path)

print("Voice fishing text file{}".format(file_list))
# Out:
# Voice fishing text file['수사기관 사칭형_74.txt', '수사기관 사칭형_60.txt', '수사기관 사칭형_48.txt', '수사기관 사칭형_222.txt', '수사기관 사칭형_168.txt', '수사기관 사칭형_140.txt', '수사기관 사칭형_154.txt', '수사기관 사칭형_183.txt', '수사기관 사칭형_197.txt', '수사기관 사칭형_196.txt', '수사기관 사칭형_182.txt', '수사기관 사칭형_155.txt', '수사기관 사칭형_141.txt', '수사기관 사칭형_169.txt', '수사기관 사칭형_223.txt', '수사기관 사칭형_49.txt', '수사기관 사칭형_61.txt', '수사기관 사칭형_75.txt', '수사기관 사칭형_63.txt', '수사기관 사칭형_209.txt', '수사기관 사칭형_221.txt', '수사기관 사칭형_88.txt', '수사기관 사칭형_157.txt', '수사기관 사칭형_143.txt', '수사기관 사칭형_194.txt', '수사기관 사칭형_180.txt', '수사기관 사칭형_181.txt', '수사기관 사칭형_195.txt', '수사기관 사칭형_142.txt', '수사기관 사칭형_156.txt', '수사기관 사칭형_89.txt', '수사기관 사칭형_220.txt', '수사기관 사칭형_208.txt', '수사기관 사칭형_76.txt', '수사기관 사칭형_62.txt', '수사기관 사칭형_224.txt', '수사기관 사칭형_218.txt', '수사기관 사칭형_66.txt', '수사기관 사칭형_72.txt', '수사기관 사칭형_99.txt', '수사기관 사칭형_152.txt', '수사기관 사칭형_146.txt', '수사기관 사칭형_191.txt', '수사기관 사칭형_185.txt', '.DS_Store', '수사기관 사칭형_184.txt', '수사기관 사칭형_190.txt', '수사기관 사칭형_147.txt', '수사기관 사칭형_153.txt', '수사기관 사칭형_98.tx
# ...

# %%
file_list
# Out:
# ['수사기관 사칭형_74.txt',
#  '수사기관 사칭형_60.txt',
#  '수사기관 사칭형_48.txt',
#  '수사기관 사칭형_222.txt',
#  '수사기관 사칭형_168.txt',
#  '수사기관 사칭형_140.txt',
#  '수사기관 사칭형_154.txt',
#  '수사기관 사칭형_183.txt',
#  '수사기관 사칭형_197.txt',
#  '수사기관 사칭형_196.txt',
#  '수사기관 사칭형_182.txt',
#  '수사기관 사칭형_155.txt',
#  '수사기관 사칭형_141.txt',
#  '수사기관 사칭형_169.txt',
#  '수사기관 사칭형_223.txt',
#  '수사기관 사칭형_49.txt',
#  '수사기관 사칭형_61.txt',
#  '수사기관 사칭형_75.txt',
#  '수사기관 사칭형_63.txt',
#  '수사기관 사칭형_209.txt',
#  '수사기관 사칭형_221.txt',
#  '수사기관 사칭형_88.txt',
#  '수사기관 사칭형_157.txt',
#  '수사기관 사칭형_143.txt',
#  '수사기관 사칭형_194.txt',
#  '수사기관 사칭형_180.txt',
#  '수사기관 사칭형_181.txt',
#  '수사기관 사칭형_195.txt',
#  '수사기관 사칭형_142.txt',
#  '수사기관 사칭형_156.txt',
#  '수사기관 사칭형_89.txt',
#  '수사기관 사칭형_220.txt',
#  '수사기관 사칭형_208.txt',
#  '수사기관 사칭형_76.txt',
#  '수사기관 사칭형_62.txt',
#  '수사기관 사칭형_224.txt',
#  '수사기관 사칭형_218.txt',
#  '수사기관 사칭형_66.txt',
#  '수사기관 사칭형_72.txt',
#  '수사기관 사칭형_99.txt',
#  '수사기관 사칭형_152.txt',
#  '수사기관 사칭형_146.txt',
#  '수사기관 사칭형_191.txt',
#  '수사기관 사칭형_185.txt',
# ...

# %%
file_list_txt=[file for file in file_list if file.endswith("txt")]

# %%
import pandas as pd

# %%
merge_df=pd.DataFrame(index=range(0,len(file_list)),columns=['sentence'])

# %%
merge_df
# Out:
#     sentence
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# 185      NaN
# 186      NaN
# 187      NaN
# 188      NaN
# 189      NaN
#
# [190 rows x 1 columns]

# %%
i=0
for file in file_list_txt:
    df=pd.read_csv(path+file,dtype='object').columns
    #print(df.columns)
    merge_df.iloc[i,0]=df[0]
    i=i+1

# %%
merge_df
# Out:
#                                               sentence
# 0    지금 전화연락 드렸어요. 지금 통합 안녕하십니까? 네. 지금 본인 명의가 지금 도용...
# 1    여보세요? 없어요. 몇 가지 확인할 사항이 있어서 연락드린 건데요. 보시죠. 말씀하...
# 2    지난주 금요일 마포지역에서 김명철 두목으로 된 금융사기집단이 8 명을 검거했거든요 ...
# 3    그래요. 여보세요. 혹시 맞습니까? 저는 서울중앙지방검찰청이고요 신인 철수세번입니다...
# 4    국가가 없으시기 때문에 그 녹취로서 약식 조사를 할 건데 그리고 이게 휴대폰 아닙니...
# ..                                                 ...
# 185  네 제가 지난 8 월에 금융범죄 불법 사기는 명목으로 김민수 일당을 검거하고 있어요...
# 186  여보세요? 여보세요. 간략하게 이제 지만 드릴게요. 그냥 일단은 검거가 되지 않았습...
# 187  업무보셨나요 해지하신 시간 말씀하시겠어요 한 십삼 시 십다시 한 말씀 해주세요 어떻...
# 188                                                NaN
# 189                                                NaN
#
# [190 rows x 1 columns]

# %%
merge_df.to_csv('abnormal_sentence.csv')

# %%
data=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/Data(24.03.12)/sentence/abnormal/abnormal_sentence.csv")

data
# Out:
#      Unnamed: 0                                           sentence
# 0             0  지금 전화연락 드렸어요. 지금 통합 안녕하십니까? 네. 지금 본인 명의가 지금 도용...
# 1             1  여보세요? 없어요. 몇 가지 확인할 사항이 있어서 연락드린 건데요. 보시죠. 말씀하...
# 2             2  지난주 금요일 마포지역에서 김명철 두목으로 된 금융사기집단이 8 명을 검거했거든요 ...
# 3             3  그래요. 여보세요. 혹시 맞습니까? 저는 서울중앙지방검찰청이고요 신인 철수세번입니다...
# 4             4  국가가 없으시기 때문에 그 녹취로서 약식 조사를 할 건데 그리고 이게 휴대폰 아닙니...
# ..          ...                                                ...
# 185         185  네 제가 지난 8 월에 금융범죄 불법 사기는 명목으로 김민수 일당을 검거하고 있어요...
# 186         186  여보세요? 여보세요. 간략하게 이제 지만 드릴게요. 그냥 일단은 검거가 되지 않았습...
# 187         187  업무보셨나요 해지하신 시간 말씀하시겠어요 한 십삼 시 십다시 한 말씀 해주세요 어떻...
# 188         188                                                NaN
# 189         189                                                NaN
#
# [190 rows x 2 columns]

# %%
data.drop(columns=['Unnamed: 0'],inplace=True)

# %%
print(data.iloc[0,0])
# Out:
# 지금 전화연락 드렸어요. 지금 통합 안녕하십니까? 네. 지금 본인 명의가 지금 도용이 되셔가지고 지금 대표굉장히 금융사기지금 연료가 되셨어요? 혹시 아십니까? 출신이고 삼십 퍼센트 남성이 정말 모르세요? 몰라요. 왜냐하면 저희가 이번에 금융사기 범죄 단을 저희가 이번에 검거를 했는데요. 검거하는 한 현장에서도 지금 명의로 된 하나은행통장하고 농협은행 통장이 발견이 됐어요. 발견된 부분에 대해서 본인께서는 개설된 통장에 대해서 혹시 알고 계신 게 있으신가요? 몰라요. 다음 주 중으로 해서 저희가 이제 소환장을 발부해 드릴 건데요. 검찰도 하셔가지고 조사 받으시길 바라겠습니다.

# %%
import konlpy
from konlpy.tag import Mecab

# %%
nlp_model=Mecab()

# %%
data=pd.DataFrame(index=range(0,data.shape[0]),columns=['sentence'])
