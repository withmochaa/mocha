# %%
import pandas as pd

data=pd.read_csv('/Users/withmocha/Desktop/VisualStudioCode/Capstone Design project/Data/normal/data_word_fine.csv')

data
# Out:
#        Unnamed: 0                                              word1  \
# 0               0                                  ['해결', '남', '부담']
# 1               1            ['이번', '달', '급여', '물가', '월급', '화', '나']
# 2               2              ['회사', '신입', '말투', '애', '생각', '스트레스']
# 3               3           ['직장', '막내', '이유', '나', '심부름', '일', '데']
# 4               4  ['얼마', '전', '입사', '신입', '사원', '나', '무시', '것', ...
# ...           ...                                                ...
# 51625       51625                                  ['나이', '돈', '능력']
# 51626       51626                         ['몸', '전', '일', '것', '짜증']
# 51627       51627                     ['남편', '노후', '준비', '미래', '걱정']
# 51628       51628  ['십', '년', '남편', '이혼', '동안', '세월', '배신감', '화',...
# 51629       51629  ['남편', '결혼', '지', '사', '십', '년', '사람', '것', '사람']
#
#                                                  word2
# 0                                    ['해결', '남', '부담']
# ...

# %%
import konlpy
from konlpy.tag import Mecab
nlp_model = Mecab()

# %%
Y=pd.DataFrame(index=range(0,data.shape[0]),columns=['predict'])
