# %%
import pandas as pd

data_row=pd.read_csv('/Users/withmocha/Desktop/VisualStudioCode/Capstone Design project/Data/normal/preson conversation sentence. data.csv')

# %%
data_row
# Out:
#        Unnamed: 0                                              사람문장1  \
# 0               0                          일은 왜 해도 해도 끝이 없을까? 화가 난다.
# 1               1     이번 달에 또 급여가 깎였어! 물가는 오르는데 월급만 자꾸 깎이니까 너무 화가 나.
# 2               2  회사에 신입이 들어왔는데 말투가 거슬려. 그런 애를 매일 봐야 한다고 생각하니까 스...
# 3               3  직장에서 막내라는 이유로 나에게만 온갖 심부름을 시켜. 일도 많은 데 정말 분하고 ...
# 4               4              얼마 전 입사한 신입사원이 나를 무시하는 것 같아서 너무 화가 나.
# ...           ...                                                ...
# 51625       51625     나이가 먹고 이제 돈도 못 벌어 오니까 어떻게 살아가야 할지 막막해. 능력도 없고.
# 51626       51626        몸이 많이 약해졌나 봐. 이제 전과 같이 일하지 못할 것 같아 너무 짜증 나.
# 51627       51627   이제 어떻게 해야 할지 모르겠어. 남편도 그렇고 노후 준비도 안 되어서 미래가 걱정돼.
# 51628       51628  몇십 년을 함께 살았던 남편과 이혼했어. 그동안의 세월에 배신감을 느끼고 너무 화가 나.
# 51629       51629  남편과 결혼한 지 사십 년이야. 이제 사람 만나는 것도 버겁고 알던 사람도 점점 사라져.
#
#                                                    사람문장2  \
# 0                    그냥 내가 해결하는 게 나아. 남들한테 부담 주고 싶지도 않고.
# ...

# %%
data_row.drop(columns=['Unnamed: 0'],inplace=True)

# %%
data_row
# Out:
#                                                    사람문장1  \
# 0                              일은 왜 해도 해도 끝이 없을까? 화가 난다.
# 1         이번 달에 또 급여가 깎였어! 물가는 오르는데 월급만 자꾸 깎이니까 너무 화가 나.
# 2      회사에 신입이 들어왔는데 말투가 거슬려. 그런 애를 매일 봐야 한다고 생각하니까 스...
# 3      직장에서 막내라는 이유로 나에게만 온갖 심부름을 시켜. 일도 많은 데 정말 분하고 ...
# 4                  얼마 전 입사한 신입사원이 나를 무시하는 것 같아서 너무 화가 나.
# ...                                                  ...
# 51625     나이가 먹고 이제 돈도 못 벌어 오니까 어떻게 살아가야 할지 막막해. 능력도 없고.
# 51626        몸이 많이 약해졌나 봐. 이제 전과 같이 일하지 못할 것 같아 너무 짜증 나.
# 51627   이제 어떻게 해야 할지 모르겠어. 남편도 그렇고 노후 준비도 안 되어서 미래가 걱정돼.
# 51628  몇십 년을 함께 살았던 남편과 이혼했어. 그동안의 세월에 배신감을 느끼고 너무 화가 나.
# 51629  남편과 결혼한 지 사십 년이야. 이제 사람 만나는 것도 버겁고 알던 사람도 점점 사라져.
#
#                                                    사람문장2  \
# 0                    그냥 내가 해결하는 게 나아. 남들한테 부담 주고 싶지도 않고.
# 1       최대한 지출을 억제해야겠어. 월급이 줄어들었으니 고정지출을 줄일 수밖에 없을 것 같아.
# 2      잘 안 맞는 사람이랑 억지로 잘 지내는 것보단 조금은 거리를 두고 예의를 갖춰서 대...
# ...

# %%
data_row.isnull().sum()
# Out:
# 사람문장1       0
# 사람문장2       0
# 사람문장3    8935
# dtype: int64

# %%
data_row.dtypes
# Out:
# 사람문장1    object
# 사람문장2    object
# 사람문장3    object
# dtype: object

# %%
data_x=data_row.drop(columns=['사람문장3'])

# %%
data_x
# Out:
#                                                    사람문장1  \
# 0                              일은 왜 해도 해도 끝이 없을까? 화가 난다.
# 1         이번 달에 또 급여가 깎였어! 물가는 오르는데 월급만 자꾸 깎이니까 너무 화가 나.
# 2      회사에 신입이 들어왔는데 말투가 거슬려. 그런 애를 매일 봐야 한다고 생각하니까 스...
# 3      직장에서 막내라는 이유로 나에게만 온갖 심부름을 시켜. 일도 많은 데 정말 분하고 ...
# 4                  얼마 전 입사한 신입사원이 나를 무시하는 것 같아서 너무 화가 나.
# ...                                                  ...
# 51625     나이가 먹고 이제 돈도 못 벌어 오니까 어떻게 살아가야 할지 막막해. 능력도 없고.
# 51626        몸이 많이 약해졌나 봐. 이제 전과 같이 일하지 못할 것 같아 너무 짜증 나.
# 51627   이제 어떻게 해야 할지 모르겠어. 남편도 그렇고 노후 준비도 안 되어서 미래가 걱정돼.
# 51628  몇십 년을 함께 살았던 남편과 이혼했어. 그동안의 세월에 배신감을 느끼고 너무 화가 나.
# 51629  남편과 결혼한 지 사십 년이야. 이제 사람 만나는 것도 버겁고 알던 사람도 점점 사라져.
#
#                                                    사람문장2
# 0                    그냥 내가 해결하는 게 나아. 남들한테 부담 주고 싶지도 않고.
# 1       최대한 지출을 억제해야겠어. 월급이 줄어들었으니 고정지출을 줄일 수밖에 없을 것 같아.
# 2      잘 안 맞는 사람이랑 억지로 잘 지내는 것보단 조금은 거리를 두고 예의를 갖춰서 대...
# ...

# %%
import konlpy

# %%
from konlpy.tag import Mecab

# %%
nlp_model = Mecab()

# %%
for i in range(100):
    print(f"문장 명사 추출 : {nlp_model.nouns(data_x.iloc[i,0])}")
# Out:
# 문장 명사 추출 : ['일', '끝', '화']
# 문장 명사 추출 : ['이번', '달', '급여', '물가', '월급', '화', '나']
# 문장 명사 추출 : ['회사', '신입', '말투', '애', '생각', '스트레스']
# 문장 명사 추출 : ['직장', '막내', '이유', '나', '심부름', '일', '데']
# 문장 명사 추출 : ['얼마', '전', '입사', '신입', '사원', '나', '무시', '것', '화', '나']
# 문장 명사 추출 : ['직장', '시간', '거', '진로', '고민']
# 문장 명사 추출 : ['성인', '진로', '부모', '나']
# 문장 명사 추출 : ['퇴사', '지', '얼마', '직장']
# 문장 명사 추출 : ['졸업반', '취업', '생각']
# 문장 명사 추출 : ['요즘', '직장', '생활', '것']
# 문장 명사 추출 : ['취업', '나이', '취업']
# 문장 명사 추출 : ['면접', '부모', '직업', '질문']
# 문장 명사 추출 : ['큰일', '부장', '결재', '서류', '시간', '뒤', '제출', '어디']
# 문장 명사 추출 : ['나', '얼마', '전', '면접', '회사', '면접', '합격', '연락', '입사', '취소', '통보', '당혹']
# 문장 명사 추출 : ['길', '동네', '아주머니', '취업', '당황']
# 문장 명사 추출 : ['합격', '통보', '회사', '문자', '발송', '연락', '당혹']
# 문장 명사 추출 : ['나', '출근', '당황']
# 문장 명사 추출 : ['이번', '직장', '이직', '사람', '당황']
# 문장 명사 추출 : ['코로나', '때문', '뭘', '수', '취직', '준비', '시험', '취소', '말', '마비', '말', '때', '것']
# 문장 명사 추출 : ['회사', '실수', '것']
# 문장 명사 추출 : ['취업', '관련', '온몸', '마비', '것']
# ...

# %%
data=pd.DataFrame(index=range(0,data_row.shape[0]),columns=['word1','word2'])

# %%
A=nlp_model.nouns(data_x.iloc[1,0])

# %%
data.iloc[1,0]=nlp_model.nouns(data_x.iloc[1,0])
print(data.iloc[1,0])
# Out:
# ['이번', '달', '급여', '물가', '월급', '화', '나']

# %%
data
# Out:
#                            word1 word2
# 0                            NaN   NaN
# 1      [이번, 달, 급여, 물가, 월급, 화, 나]   NaN
# 2                            NaN   NaN
# 3                            NaN   NaN
# 4                            NaN   NaN
# ...                          ...   ...
# 51625                        NaN   NaN
# 51626                        NaN   NaN
# 51627                        NaN   NaN
# 51628                        NaN   NaN
# 51629                        NaN   NaN
#
# [51630 rows x 2 columns]

# %%
for i in range(data_x.shape[0]):
        A=nlp_model.nouns(data_x.iloc[i,0])
        data.iloc[i][0]=A
# Out:
# /var/folders/gb/hslcbzfs0bvcnj3zxtfrxt_r0000gn/T/ipykernel_74309/1780325728.py:3: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data.iloc[i][0]=A

# %%
data
# Out:
#                                      word1 word2
# 0                                [일, 끝, 화]   NaN
# 1                [이번, 달, 급여, 물가, 월급, 화, 나]   NaN
# 2                [회사, 신입, 말투, 애, 생각, 스트레스]   NaN
# 3               [직장, 막내, 이유, 나, 심부름, 일, 데]   NaN
# 4      [얼마, 전, 입사, 신입, 사원, 나, 무시, 것, 화, 나]   NaN
# ...                                    ...   ...
# 51625                          [나이, 돈, 능력]   NaN
# 51626                     [몸, 전, 일, 것, 짜증]   NaN
# 51627                 [남편, 노후, 준비, 미래, 걱정]   NaN
# 51628    [십, 년, 남편, 이혼, 동안, 세월, 배신감, 화, 나]   NaN
# 51629      [남편, 결혼, 지, 사, 십, 년, 사람, 것, 사람]   NaN
#
# [51630 rows x 2 columns]

# %%
for i in range(data_x.shape[0]):
        A=nlp_model.nouns(data_x.iloc[i,1])
        data.iloc[i,1]=A

# %%
data
# Out:
#                                      word1                            word2
# 0                        [내, 해결, 게, 남, 부담]                [내, 해결, 게, 남, 부담]
# 1                [이번, 달, 급여, 물가, 월급, 화, 나]  [최대한, 지출, 억제, 월급, 고정, 지출, 수, 것]
# 2                [회사, 신입, 말투, 애, 생각, 스트레스]      [사람, 것, 거리, 예의, 게, 스트레스, 것]
# 3               [직장, 막내, 이유, 나, 심부름, 일, 데]          [직장, 사람, 이야기, 일, 데, 방해]
# 4      [얼마, 전, 입사, 신입, 사원, 나, 무시, 것, 화, 나]               [상사, 나, 인사, 내, 인사]
# ...                                    ...                              ...
# 51625                          [나이, 돈, 능력]              [아무것, 수, 내, 가치, 실망]
# 51626                     [몸, 전, 일, 것, 짜증]            [마음, 수, 일, 이젠, 몸, 주니]
# 51627                 [남편, 노후, 준비, 미래, 걱정]              [주변, 사람, 노후, 준비, 난]
# 51628    [십, 년, 남편, 이혼, 동안, 세월, 배신감, 화, 나]                    [수, 일, 게, 불만]
# 51629      [남편, 결혼, 지, 사, 십, 년, 사람, 것, 사람]               [사람, 것, 사람, 의심, 말]
#
# [51630 rows x 2 columns]

# %%
data.to_csv('word data.csv')
