# %%
import pandas as pd

금융_data_row=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0410/fishing/row sentence/대출형 보이스피싱.csv",index_col=0)
기관_data_row=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0410/fishing/row sentence/기관 사칭형 보이스피싱.csv",index_col=0)

# %%
금융_data_row
# Out:
#                                                sentence
# 0                                     '어저께 통화했던 최영환입니다'
# 1      '어떻게 가진행 결과 안내차 오늘 아침에 전화 드린다고 제가 얘기를 했었는데 어떻...
# 2              '일단 최대한도는 고객님 신청하신 최대 한도는 3천만원까지 가능하시고요'
# 3                       '금리는 연 금리 5.5%에 상환 기간 60개월입니다.'
# 4      '매 월 상환하시는 금액은 60개월 기준 원금 이자 포함되신 금액으로 573035...
# ...                                                 ...
# 3472                                        '너무 많아가지고 '
# 3473                              '네 대부업건 어디어디 이용중이세요?'
# 3474                         '얼만지 제가 한번 보고 전화를 한번 드릴게요'
# 3475                                        '아 네 알겠습니다'
# 3476                              '그 바로 연락 한번 좀 부탁드릴게요'
#
# [3477 rows x 1 columns]

# %%
기관_data_row
# Out:
#                                                sentence
# 0                 ['아 서울 중앙 지검 첨단 범죄 수사 일부 이희나 수사관입니다.'
# 1      '본 사건 조사는 법원 증거 제출용으로 이뤄지고 있으신데 녹취 조사 과정에서 허위...
# 2                 형사상 책임이 있으시니 사실에 입각하여 진실로 좀 하셔야 됩니다.'
# 3                          '네 OOO씨 지금 제가 본인 확인 한번 할께요.'
# 4                        '생년월일 앞에 여섯 자리만 말씀 부탁 드리겠습니다.'
# ...                                                 ...
# 8427                   '그 본인 말고도 180명이 넘게 연루된 사건이다 보니까'
# 8428   '찾아오시는 분들이 많기 때문에 저희가 일방적으로 오라고 말씀드릴 수 없기 때문에...
# 8429                   '그러면은 문자로 관련 내용 간단하게 요약해서 보내주세요'
# 8430                           '예 그 본인 자택으로 서류 보내드릴게요.'
# 8431   '그 문자 말고 그 확인하시고 읽어보신 다음에 이해 안 가는 부분 있으시면 다시 ...
#
# [8432 rows x 1 columns]

# %%
y=pd.DataFrame(index=range(금융_data_row.shape[0]),columns=['predict'])

# %%
y=y.fillna('0')

# %%
금융_data=pd.concat([금융_data_row,y],axis=1)

# %%
금융_data
# Out:
#                                                sentence predict
# 0                                     '어저께 통화했던 최영환입니다'       0
# 1      '어떻게 가진행 결과 안내차 오늘 아침에 전화 드린다고 제가 얘기를 했었는데 어떻...       0
# 2              '일단 최대한도는 고객님 신청하신 최대 한도는 3천만원까지 가능하시고요'       0
# 3                       '금리는 연 금리 5.5%에 상환 기간 60개월입니다.'       0
# 4      '매 월 상환하시는 금액은 60개월 기준 원금 이자 포함되신 금액으로 573035...       0
# ...                                                 ...     ...
# 3472                                        '너무 많아가지고 '       0
# 3473                              '네 대부업건 어디어디 이용중이세요?'       0
# 3474                         '얼만지 제가 한번 보고 전화를 한번 드릴게요'       0
# 3475                                        '아 네 알겠습니다'       0
# 3476                              '그 바로 연락 한번 좀 부탁드릴게요'       0
#
# [3477 rows x 2 columns]

# %%
y=pd.DataFrame(index=range(기관_data_row.shape[0]),columns=['predict'])

# %%
y=y.fillna('1')

# %%
기관_data=pd.concat([기관_data_row,y],axis=1)

# %%
기관_data=기관_data.drop(index=range(3500,기관_data.shape[0]))

# %%
기관_data
# Out:
#                                                sentence predict
# 0                 ['아 서울 중앙 지검 첨단 범죄 수사 일부 이희나 수사관입니다.'       1
# 1      '본 사건 조사는 법원 증거 제출용으로 이뤄지고 있으신데 녹취 조사 과정에서 허위...       1
# 2                 형사상 책임이 있으시니 사실에 입각하여 진실로 좀 하셔야 됩니다.'       1
# 3                          '네 OOO씨 지금 제가 본인 확인 한번 할께요.'       1
# 4                        '생년월일 앞에 여섯 자리만 말씀 부탁 드리겠습니다.'       1
# ...                                                 ...     ...
# 3495     '본인이 만약에 그요 부채 정리되면은 한 일주일에 좀 받으셔도 한번 억울하시겠어요'       1
# 3496                     '제가 공문으로 나와 있기 때문에 설명을 드린 거예요'       1
# 3497                              '그 밑에 상세 조회하기가 보이시죠.'       1
# 3498       '아 그러니까 합산해서 다시 한번 제가 상환 좀 이렇게 한 건이 포함이 어차피'       1
# 3499             '그렇쵸 제 우리가 녹취하는 부분에서 본인한테 조사가 다 끝났습니다'       1
#
# [3500 rows x 2 columns]

# %%
data=pd.concat([금융_data,기관_data])

# %%
data
# Out:
#                                                sentence predict
# 0                                     '어저께 통화했던 최영환입니다'       0
# 1      '어떻게 가진행 결과 안내차 오늘 아침에 전화 드린다고 제가 얘기를 했었는데 어떻...       0
# 2              '일단 최대한도는 고객님 신청하신 최대 한도는 3천만원까지 가능하시고요'       0
# 3                       '금리는 연 금리 5.5%에 상환 기간 60개월입니다.'       0
# 4      '매 월 상환하시는 금액은 60개월 기준 원금 이자 포함되신 금액으로 573035...       0
# ...                                                 ...     ...
# 3495     '본인이 만약에 그요 부채 정리되면은 한 일주일에 좀 받으셔도 한번 억울하시겠어요'       1
# 3496                     '제가 공문으로 나와 있기 때문에 설명을 드린 거예요'       1
# 3497                              '그 밑에 상세 조회하기가 보이시죠.'       1
# 3498       '아 그러니까 합산해서 다시 한번 제가 상환 좀 이렇게 한 건이 포함이 어차피'       1
# 3499             '그렇쵸 제 우리가 녹취하는 부분에서 본인한테 조사가 다 끝났습니다'       1
#
# [6977 rows x 2 columns]

# %%
data=data.sample(frac=1)

# %%
data
# Out:
#                                                sentence predict
# 1904                              '지금 기가 막힌다는 생각이 듭니다.'       1
# 1193   'OOO 사건 공문 내용이니 꼼꼼히 읽어 보시고 뭐 이해가 안되시거나 그러시면 저...       1
# 345    '다름이 아니라 본인 개인 정보 유출 사건 관련해서 몇 가지 확인 차 연락 드렸습...       1
# 2204   '제 삼자라는 것은 이번 사건의 그 선생님 개인 정보가 직장 동료로부터 유출 됐는...       1
# 2093                                         '예 예 보냅니다'       0
# ...                                                 ...     ...
# 2375                                     '네 잘 모르는데 그정도'       1
# 2484                                        '유연하게 하시면.'       1
# 2496                        '좀. 제가 지금까지 대출을 받은거 다 아시겠지만       0
# 3315                              '위임 처리하시면 당일로도 가능하시고'       0
# 3018                                 '일단은 그쪽 주변으로 갈게요.'       1
#
# [6977 rows x 2 columns]

# %%
x_train=pd.DataFrame(data['sentence'])

# %%
x_train
# Out:
#                                                sentence
# 1904                              '지금 기가 막힌다는 생각이 듭니다.'
# 1193   'OOO 사건 공문 내용이니 꼼꼼히 읽어 보시고 뭐 이해가 안되시거나 그러시면 저...
# 345    '다름이 아니라 본인 개인 정보 유출 사건 관련해서 몇 가지 확인 차 연락 드렸습...
# 2204   '제 삼자라는 것은 이번 사건의 그 선생님 개인 정보가 직장 동료로부터 유출 됐는...
# 2093                                         '예 예 보냅니다'
# ...                                                 ...
# 2375                                     '네 잘 모르는데 그정도'
# 2484                                        '유연하게 하시면.'
# 2496                        '좀. 제가 지금까지 대출을 받은거 다 아시겠지만
# 3315                              '위임 처리하시면 당일로도 가능하시고'
# 3018                                 '일단은 그쪽 주변으로 갈게요.'
#
# [6977 rows x 1 columns]

# %%
y_train=pd.DataFrame(data['predict'])

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

# %%
A=model.encode(data.iloc[0,0])
list=[]

for i in range(A.shape[0]):
    list.append(i)

# %%
x=pd.DataFrame(index=range(0,x_train.shape[0]),columns=list)

# %%
y=pd.DataFrame(index=range(0,y_train.shape[0]),columns=['predict'])

# %%
y_train
# Out:
#      predict
# 1904       1
# 1193       1
# 345        1
# 2204       1
# 2093       0
# ...      ...
# 2375       1
# 2484       1
# 2496       0
# 3315       0
# 3018       1
#
# [6977 rows x 1 columns]

# %%
for i in range(y_train.shape[0]):
    y.iloc[i,0]=y_train.iloc[i,0]

# %%
#x=pd.read_csv("/Users/withmocha/Desktop/VisualStudioCode/Capstone Design project/Voice Fishing/Team meeting/0417/보이스피싱 라벨별 데이터 분석/x.csv",index_col=0)

# %%
for i in range(x_train.shape[0]):
    vector=[]
    vector=model.encode(x_train.iloc[i,0])
    for j in range(x.shape[1]):
        x.iloc[i,j]=vector[j]

# %%
x
# Out:
#            0         1         2         3         4         5         6    \
# 0    -0.061183   0.10081  0.061214  0.009917 -0.013396  -0.01285  0.147301
# 1     0.018832  0.060418  0.026933  0.015419 -0.016941 -0.107081  0.096329
# 2    -0.014961   0.06885   0.03155  -0.02734 -0.008346 -0.041882  0.059814
# 3     0.017636  0.013094  0.109748 -0.033718 -0.050721 -0.023474  0.100973
# 4    -0.060736  0.056082  0.092356 -0.009645 -0.021811 -0.008148  0.115152
# ...        ...       ...       ...       ...       ...       ...       ...
# 6972 -0.032307   0.10195  0.099347 -0.052167  0.068447 -0.001443  0.162976
# 6973 -0.057625  0.123585  0.026764 -0.023225 -0.024536 -0.089223  0.061513
# 6974 -0.015476  0.093891  0.014191 -0.026245  0.052639  0.028524  0.103107
# 6975 -0.038914  0.099699  0.077106 -0.038491  0.005559 -0.089504  0.065918
# 6976 -0.005061  0.117423  -0.00115 -0.051192 -0.000894 -0.053209  0.125134
#
#            7         8         9    ...       374       375       376  \
# 0      0.00058  0.000231 -0.002955  ...  0.045668  0.061604  0.016196
# 1    -0.001115 -0.016176 -0.083652  ... -0.021181 -0.039896  0.005325
# 2      0.03834 -0.049523   0.01024  ... -0.003933  0.003798  0.027781
# 3     0.015936  0.028173 -0.033284  ... -0.040423  0.070158  0.004682
# 4    -0.040445  0.016166 -0.000389  ...  0.039539  0.032686  0.021231
# ...        ...       ...       ...  ...       ...       ...       ...
# 6972  0.011841  0.008502 -0.069586  ...  0.044111  0.039683  0.037242
# 6973  0.038255 -0.081369 -0.078317  ...  0.049354  0.013594  0.039637
# 6974 -0.001222 -0.045638  -0.04415  ... -0.002193  0.014098 -0.007515
# 6975  0.031805 -0.023265 -0.059792  ...  0.056569  0.069131  0.037577
# 6976  0.023028  -0.05725 -0.063622  ...  0.049748  0.030961  0.014822
#
#            377       378       379       380       381       382       383
# 0     0.022274   0.01188 -0.011912  0.075044  0.095158 -0.106573 -0.105517
# 1     0.000167  0.056236  0.023405  0.030356   0.05546  -0.01418 -0.011396
# 2     0.019212 -0.024139 -0.004355  0.075891  0.066705 -0.086797 -0.027383
# 3     0.110734  0.024958  0.033158   0.06466  0.019756 -0.069465  -0.01959
# 4     0.040172  0.038396  0.023905  0.062547   0.05086  -0.03234 -0.105785
# ...        ...       ...       ...       ...       ...       ...       ...
# 6972  0.015602 -0.012853 -0.037633   0.01399  0.044934  -0.04773 -0.026416
# 6973 -0.060955  0.009941 -0.024636  0.086489  0.101995 -0.068722  0.010277
# 6974  0.006089 -0.011834 -0.021861  0.006799  0.085716 -0.016267 -0.056602
# 6975  0.000395    0.0196 -0.054411  0.100099   0.04848 -0.059081  0.010514
# 6976 -0.048026  0.036437 -0.028328  0.028447  0.066021 -0.049693 -0.049374
#
# [6977 rows x 384 columns]

# %%
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,shuffle=True)

# %%
x_train
# Out:
#            0         1         2         3         4         5         6    \
# 6361 -0.000423  0.060585   0.04927  0.028415   0.00704 -0.138788  0.092926
# 1478 -0.030256  0.103381   0.05033  0.003272  0.003183 -0.055975   0.18667
# 3875 -0.044416  0.076965  0.101107 -0.049185  0.039256 -0.048525  0.219092
# 2318 -0.011495  0.131726  0.015758 -0.087809  -0.02161 -0.071965  0.103739
# 2449  -0.00319  0.114382  0.058631 -0.050333  -0.00984 -0.082817  0.096529
# ...        ...       ...       ...       ...       ...       ...       ...
# 2392 -0.010097  0.088126  0.046297  0.018213 -0.000611 -0.061413  0.110174
# 5458 -0.017928   0.05177  0.032891 -0.025674  0.032176  -0.02717  0.103411
# 2707 -0.041242  0.109372  0.023559  0.009745 -0.028984 -0.084544  0.093418
# 4789 -0.010104  0.065169  0.082837   0.05242  0.017148 -0.007504  0.157916
# 2787 -0.018805  0.051061 -0.002255 -0.038322 -0.034952 -0.093526  0.034297
#
#            7         8         9    ...       374       375       376  \
# 6361  0.040368 -0.012904  -0.11006  ... -0.053662 -0.048563 -0.019292
# 1478 -0.057476 -0.039074 -0.049095  ...  0.035302  0.014343  0.037338
# 3875  0.007696  0.000116 -0.085812  ... -0.007479  0.044711 -0.047607
# 2318  0.023839 -0.006468  -0.05999  ... -0.014677  0.025677  0.013283
# 2449  0.032317 -0.054268 -0.026162  ...   0.04338  0.046236  0.022597
# ...        ...       ...       ...  ...       ...       ...       ...
# 2392  0.023657 -0.034702 -0.026601  ...  -0.00357  0.053031  0.033675
# 5458  0.020683 -0.086223 -0.055252  ...  0.043956  0.000354  0.059429
# 2707 -0.005394  -0.03595 -0.029153  ...  0.055044  0.036926  0.081288
# 4789 -0.029795  0.001347 -0.069736  ...  0.029458  0.092926  0.021515
# 2787   0.06228 -0.043601  -0.04762  ...  0.065253  0.063881  0.008912
#
#            377       378       379       380       381       382       383
# 6361 -0.011565    0.0176 -0.036527 -0.009229  0.043518   0.00216  0.028387
# 1478  0.012931 -0.025215  0.028373  0.065834  0.096108 -0.059825 -0.069056
# 3875  0.034503 -0.022953 -0.022088   0.06903  0.084105 -0.076605 -0.073895
# 2318 -0.004187   0.08047  0.016515  0.024423  0.019288 -0.009866  0.013654
# 2449  0.006626  0.008041 -0.018949   0.07079  0.065466 -0.048537 -0.012897
# ...        ...       ...       ...       ...       ...       ...       ...
# 2392  0.017601 -0.030789 -0.049619  0.112944  0.030124 -0.059591 -0.000309
# 5458  0.006868 -0.027623 -0.063907  0.100622  0.100787 -0.068238 -0.038435
# 2707  0.047133 -0.047144 -0.095867  0.122145  0.097187 -0.082379 -0.003822
# 4789  0.072779  0.013796 -0.014541  0.049365  0.089767  0.052924  -0.07158
# 2787 -0.040187  0.045013  0.006563  0.008184  0.020052 -0.058261 -0.006425
#
# [5581 rows x 384 columns]

# %%
x_train.shape
# Out:
# (5581, 384)

# %%
x_train = x_train.astype(np.float32)
x_test = x_test.astype(np.float32)

# %%
x_train = tf.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
x_test = tf.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))
print('변경된 차원 정보 :',x_train.shape)
# Out:
# 변경된 차원 정보 : (5581, 384, 1)

# %%
y_test
# Out:
#      predict
# 3947       1
# 94         1
# 6850       1
# 2882       0
# 3045       1
# ...      ...
# 929        0
# 5717       1
# 524        1
# 6258       0
# 6962       0
#
# [1396 rows x 1 columns]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dropout, Dense, LSTM, Bidirectional, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf

model = Sequential()
# 입력층 - 1D CNN
model.add(Conv1D(filters=128, kernel_size=3, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(BatchNormalization())  
model.add(tf.keras.layers.Activation('relu'))
model.add(Conv1D(filters=64, kernel_size=3))
model.add(BatchNormalization())  
model.add(tf.keras.layers.Activation('relu'))
model.add(Conv1D(filters=32, kernel_size=3))
model.add(BatchNormalization())  
model.add(tf.keras.layers.Activation('relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.2))
# 추가 CNN 층
#model.add(Conv1D(filters=32, kernel_size=3))
#model.add(BatchNormalization())  
#model.add(tf.keras.layers.Activation('relu'))
#model.add(Conv1D(filters=16, kernel_size=3))
#model.add(BatchNormalization())  
#model.add(tf.keras.layers.Activation('relu'))
#model.add(MaxPooling1D(pool_size=2))
#model.add(Dropout(0.2))
# 중간층 - LSTM
model.add(Bidirectional(LSTM(64, return_sequences=True)))
model.add(Bidirectional(LSTM(32, return_sequences=True)))
model.add(Bidirectional(LSTM(16, return_sequences=False)))
model.add(Dropout(0.2))
# 추가 Dense 층
model.add(Dense(64))
model.add(BatchNormalization())  
model.add(tf.keras.layers.Activation('relu'))
model.add(Dropout(0.2))
# 출력층
model.add(Dense(1, activation='sigmoid'))

# 최적화 알고리즘과 손실 함수 설정
model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Early Stopping과 Model Checkpoint 적용
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True)

model.summary()
# Out:
# 2024-04-16 18:44:04.382769: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-16 18:44:04.383574: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-16 18:44:04.384306: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-04-16 18:44:04.456423: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-04-16 18:44:04.478555: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-16 18:44:04.479996: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-16 18:44:04.480511: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-04-16 18:44:04.563517: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-16 18:44:04.563982: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-16 18:44:04.564376: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-04-16 18:44:04.622356: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-04-16 18:44:05.535140: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-16 18:44:05.535837: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-16 18:44:05.536244: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-04-16 18:44:05.604205: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-16 18:44:05.604620: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-16 18:44:05.605067: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-04-16 18:44:05.652187: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-04-16 18:44:05.668381: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-16 18:44:05.668853: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-16 18:44:05.669298: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Nadam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Nadam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Nadam`.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_6 (Conv1D)           (None, 382, 128)          512
#
#  batch_normalization_4 (Batc  (None, 382, 128)         512
#  hNormalization)
#
#  activation_4 (Activation)   (None, 382, 128)          0
#
#  conv1d_7 (Conv1D)           (None, 380, 64)           24640
#
#  batch_normalization_5 (Batc  (None, 380, 64)          256
#  hNormalization)
#
#  activation_5 (Activation)   (None, 380, 64)           0
#
#  conv1d_8 (Conv1D)           (None, 378, 32)           6176
#
#  batch_normalization_6 (Batc  (None, 378, 32)          128
#  hNormalization)
#
#  activation_6 (Activation)   (None, 378, 32)           0
#
#  max_pooling1d_2 (MaxPooling  (None, 189, 32)          0
#  1D)
#
#  dropout_6 (Dropout)         (None, 189, 32)           0
#
#  bidirectional_6 (Bidirectio  (None, 189, 128)         49664
#  nal)
#
#  bidirectional_7 (Bidirectio  (None, 189, 64)          41216
#  nal)
#
#  bidirectional_8 (Bidirectio  (None, 32)               10368
#  nal)
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 64)                2112
#
#  batch_normalization_7 (Batc  (None, 64)               256
#  hNormalization)
#
#  activation_7 (Activation)   (None, 64)                0
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 135,905
# Trainable params: 135,329
# Non-trainable params: 576
# _________________________________________________________________

# %%
y_train=y_train.astype("float")
y_test=y_test.astype("float")

# %%
y_train
# Out:
#       predict
# 6361      1.0
# 1478      0.0
# 3875      0.0
# 2318      1.0
# 2449      1.0
# ...       ...
# 2392      0.0
# 5458      1.0
# 2707      0.0
# 4789      1.0
# 2787      1.0
#
# [5581 rows x 1 columns]

# %%
training_record = model.fit(x_train, y_train,
                    epochs=50,
                    batch_size
50
# 1116/1116 [==============================] - 70s 63ms/step - loss: 0.2181 - accuracy: 0.9252 - val_loss: 0.2376 - val_accuracy: 0.9266
# Epoch 39/50
# 1116/1116 [==============================] - 70s 63ms/step - loss: 0.1432 - accuracy: 0.9545 - val_loss: 0.1511 - val_accuracy: 0.9481
# Epoch 40/50
# 1116/1116 [==============================] - 76s 68ms/step - loss: 0.1364 - accuracy: 0.9586 - val_loss: 0.1772 - val_accuracy: 0.9346
# Epoch 41/50
# 1116/1116 [==============================] - 75s 67ms/step - loss: 0.1209 - accuracy: 0.9619 - val_loss: 0.2151 - val_accuracy: 0.9382
# Epoch 42/50
# 1116/1116 [==============================] - 76s 68ms/step - loss: 0.1569 - accuracy: 0.9483 - val_loss: 0.2751 - val_accuracy: 0.8809

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
plt.plot(training_record.history["loss"], label="Training Loss")
plt.plot(training_record.history["val_loss"], label="Validation Loss")
plt.legend()
fig.suptitle("Loss")
plt.show()

# %%
pred = model.predict(x_test)
# Out:
# 2024-04-16 19:34:59.667439: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-16 19:34:59.668704: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-16 19:34:59.669632: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-04-16 19:34:59.740280: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-04-16 19:34:59.762472: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-16 19:34:59.763706: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-16 19:34:59.764248: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-04-16 19:34:59.853111: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-16 19:34:59.854107: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-16 19:34:59.854862: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-04-16 19:34:59.926393: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-04-16 19:34:59.947686: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-16 19:34:59.948237: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-16 19:34:59.948788: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-04-16 19:35:00.033133: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-16 19:35:00.033976: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-16 19:35:00.034646: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-04-16 19:35:00.111587: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-04-16 19:35:00.132712: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-16 19:35:00.133579: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-04-16 19:35:00.134344: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 44/44 [==============================] - 2s 29ms/step

# %%
pred
# Out:
# array([[0.9997592 ],
#        [0.9997875 ],
#        [0.9997547 ],
#        ...,
#        [0.99809366],
#        [0.0099799 ],
#        [0.02370726]], dtype=float32)

# %%
y_test
# Out:
#       predict
# 3947      1.0
# 94        1.0
# 6850      1.0
# 2882      0.0
# 3045      1.0
# ...       ...
# 929       0.0
# 5717      1.0
# 524       1.0
# 6258      0.0
# 6962      0.0
#
# [1396 rows x 1 columns]

# %%
predictions=np.array(y_test)
predictions = (predictions > 0.5).astype(bool)
predictions=predictions.reshape(-1,1)

# %%
predictions
# Out:
# array([[ True],
#        [ True],
#        [ True],
#        ...,
#        [ True],
#        [False],
#        [False]])

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve, roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle


# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, predictions)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(10, 5))

# ROC Curve 그리기
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.legend(loc="lower right")

# %%
# Precision-Recall Curve
from sklearn.metrics import average_precision_score
precision, recall, _ = precision_recall_curve(y_test, predictions)
average_precision = average_precision_score(y_test, predictions)

# PR Curve 그리기
plt.subplot(1, 2, 2)
plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve (area = %0.2f)' % average_precision)
plt.fill_between(recall, precision, step='post', alpha=0.2, color='blue')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('PRC')
plt.legend(loc="lower left")

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score
print('CNN-LSTM 2 class Classfication의 정확도는: {0:.4f}'.format(accuracy_score(y_test, predictions)))
# Out:
# CNN-LSTM 2 class Classfication의 정확도는: 1.0000

# %%
from sklearn.metrics import confusion_matrix, classification_report

# 혼동 행렬 및 분류 보고서 출력
print('혼동 행렬:')
print(confusion_matrix(y_test, predictions))
# Out:
# 혼동 행렬:
# [[692   0]
#  [  0 704]]

# %%
print('분류 보고서:')
report=classification_report(y_test, predictions)
print(report)
# Out:
# 분류 보고서:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       692
#          1.0       1.00      1.00      1.00       704
#
#     accuracy                           1.00      1396
#    macro avg       1.00      1.00      1.00      1396
# weighted avg       1.00      1.00      1.00      1396

# %%
model.save('보이스피싱 유형별 탐지 model.h5')

# %%
with open("보이스피싱 유형별 탐지 model output.txt", "w") as text_file:
    print(classification_report(y_test, predictions,digits=4), file=text_file)
