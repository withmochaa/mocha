# %%
import pandas as pd 

data=pd.read_csv('/Users/withmocha/Desktop/DATA/Capston Design(2024)/normal/csv_file/금융/금융보험_가입해지.csv')

data
# Out:
#        Unnamed: 0                          고객질문(요청)                 상담사질문(요청)  \
# 0               0         신용카드를 만들려고 하는데 어떻게 하면 되죠?                       NaN
# 1               1                               NaN  네. 고객님. 현재 나이가 어떻게 되시나요?
# 2               2                               NaN                       NaN
# 3               3                               NaN                       NaN
# 4               4                    발급까지 얼마나 걸리나요?                       NaN
# ...           ...                               ...                       ...
# 87260       87260                               NaN                       NaN
# 87261       87261  그럼 확정만기일 이후에 해지하면 별다른 불이익은 없는거죠?                       NaN
# 87262       87262                               NaN                       NaN
# 87263       87263                               NaN                       NaN
# 87264       87264                               NaN                       NaN
#
# ...

# %%
data.drop(columns=['Unnamed: 0'],inplace=True)

# %%
data
# Out:
#                                고객질문(요청)                 상담사질문(요청)       고객답변  \
# 0             신용카드를 만들려고 하는데 어떻게 하면 되죠?                       NaN        NaN
# 1                                   NaN  네. 고객님. 현재 나이가 어떻게 되시나요?        NaN
# 2                                   NaN                       NaN     20살이예요
# 3                                   NaN                       NaN        NaN
# 4                        발급까지 얼마나 걸리나요?                       NaN        NaN
# ...                                 ...                       ...        ...
# 87260                               NaN                       NaN        NaN
# 87261  그럼 확정만기일 이후에 해지하면 별다른 불이익은 없는거죠?                       NaN        NaN
# 87262                               NaN                       NaN        NaN
# 87263                               NaN                       NaN  네, 감사합니다.
# 87264                               NaN                       NaN        NaN
#
# ...

# %%
data.shape
# Out:
# (87265, 4)
