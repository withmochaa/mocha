# %%
import pandas as pd  

data_row=pd.read_excel('/Users/withmocha/Desktop/TEED/data/mocha/23.12.04/squat/SQUAT2.xlsx')


data_row
# Out:
#      Unnamed: 0  FORCE_A(Big toe)  FORCE_B(Right)  FORCE_C(Left)  \
# 0           NaN                 6             185            276
# 1           NaN                 7             183            278
# 2           NaN                 3             203            291
# 3           NaN                 3             176            279
# 4           NaN                 0             167            259
# ..          ...               ...             ...            ...
# 872         NaN                 0               0             44
# 873         NaN                 0              14             51
# 874         NaN                 0              12             49
# 875         NaN                 0               0             47
# 876         NaN                 0               0             47
#
#      FORCE_D(Heel)  FORCE_E(Little toe)  FORCE_F(Center)  XCOR_A(Big toe)  \
# 0             1344                   12               37         7.750000
# ...

# %%
data_row.isnull().sum()
# Out:
# Unnamed: 0             877
# FORCE_A(Big toe)         0
# FORCE_B(Right)           0
# FORCE_C(Left)            0
# FORCE_D(Heel)            0
# FORCE_E(Little toe)      0
# FORCE_F(Center)          0
# XCOR_A(Big toe)        844
# XCOR_B(Right)          380
# XCOR_C(Left)            19
# XCOR_D(Heel)             0
# XCOR_E(Little toe)     840
# XCOR_F(Center)         117
# YCOR_A(Big toe)        844
# YCOR_B(Right)          380
# YCOR_C(Left)            19
# YCOR_D(Heel)             0
# YCOR_E(Little toe)     840
# YCOR_F(Center)         117
# COPX                     0
# COPY                     0
# FSR_A(Big toe)           0
# FSR_B(Right)             0
# FSR_C(Left)              0
# FSR_D(Heel)              0
# FSR_E(Little toe)        0
# FSR_F(Center)            0
# dtype: int64

# %%
data_row.fillna(method="ffill",inplace=True)
# Out:
# /var/folders/gb/hslcbzfs0bvcnj3zxtfrxt_r0000gn/T/ipykernel_92391/2738689939.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_row.fillna(method="ffill",inplace=True)

# %%
data_row.isnull().sum()
# Out:
# Unnamed: 0             877
# FORCE_A(Big toe)         0
# FORCE_B(Right)           0
# FORCE_C(Left)            0
# FORCE_D(Heel)            0
# FORCE_E(Little toe)      0
# FORCE_F(Center)          0
# XCOR_A(Big toe)          0
# XCOR_B(Right)            0
# XCOR_C(Left)             0
# XCOR_D(Heel)             0
# XCOR_E(Little toe)       0
# XCOR_F(Center)           0
# YCOR_A(Big toe)          0
# YCOR_B(Right)            0
# YCOR_C(Left)             0
# YCOR_D(Heel)             0
# YCOR_E(Little toe)       0
# YCOR_F(Center)           0
# COPX                     0
# COPY                     0
# FSR_A(Big toe)           0
# FSR_B(Right)             0
# FSR_C(Left)              0
# FSR_D(Heel)              0
# FSR_E(Little toe)        0
# FSR_F(Center)            0
# dtype: int64

# %%
data_row.isnull().sum()
# Out:
# Unnamed: 0             877
# FORCE_A(Big toe)         0
# FORCE_B(Right)           0
# FORCE_C(Left)            0
# FORCE_D(Heel)            0
# FORCE_E(Little toe)      0
# FORCE_F(Center)          0
# XCOR_A(Big toe)          0
# XCOR_B(Right)            0
# XCOR_C(Left)             0
# XCOR_D(Heel)             0
# XCOR_E(Little toe)       0
# XCOR_F(Center)           0
# YCOR_A(Big toe)          0
# YCOR_B(Right)            0
# YCOR_C(Left)             0
# YCOR_D(Heel)             0
# YCOR_E(Little toe)       0
# YCOR_F(Center)           0
# COPX                     0
# COPY                     0
# FSR_A(Big toe)           0
# FSR_B(Right)             0
# FSR_C(Left)              0
# FSR_D(Heel)              0
# FSR_E(Little toe)        0
# FSR_F(Center)            0
# dtype: int64

# %%
data_row.drop(columns=["Unnamed: 0"],inplace=True)

# %%
data_row.isnull().sum()
# Out:
# FORCE_A(Big toe)       0
# FORCE_B(Right)         0
# FORCE_C(Left)          0
# FORCE_D(Heel)          0
# FORCE_E(Little toe)    0
# FORCE_F(Center)        0
# XCOR_A(Big toe)        0
# XCOR_B(Right)          0
# XCOR_C(Left)           0
# XCOR_D(Heel)           0
# XCOR_E(Little toe)     0
# XCOR_F(Center)         0
# YCOR_A(Big toe)        0
# YCOR_B(Right)          0
# YCOR_C(Left)           0
# YCOR_D(Heel)           0
# YCOR_E(Little toe)     0
# YCOR_F(Center)         0
# COPX                   0
# COPY                   0
# FSR_A(Big toe)         0
# FSR_B(Right)           0
# FSR_C(Left)            0
# FSR_D(Heel)            0
# FSR_E(Little toe)      0
# FSR_F(Center)          0
# dtype: int64

# %%
data_row.to_excel("squat_data.xlsx")
