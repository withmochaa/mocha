# %%
import pandas as pd  

data=pd.read_excel('/Users/withmocha/Desktop/TEED/data/mocha/23.12.06/squat/squat_data_fit_feature.xlsx')


data
# Out:
#      Unnamed: 0  FORCE_A(Big toe)  FORCE_B(Right)  FORCE_E(Little toe)  \
# 0             0                 6             185                   12
# 1             1                 7             183                   15
# 2             2                 3             203                   15
# 3             3                 3             176                   15
# 4             4                 0             167                   12
# ..          ...               ...             ...                  ...
# 872         872                 0               0                    0
# 873         873                 0              14                    0
# 874         874                 0              12                    0
# 875         875                 0               0                    0
# 876         876                 0               0                    0
#
#      XCOR_A(Big toe)  XCOR_D(Heel)  FSR_B(Right)  FSR_F(Center)  \
# ...

# %%
data.drop(columns=["Unnamed: 0"],inplace=True)

# %%
import matplotlib.pyplot as plt

columns=data.columns
count=0
for i in columns:
    print(columns[count])
    count=count+1
    plt.plot(data[i])
    plt.show()
# Out:
# FORCE_A(Big toe)
# FORCE_B(Right)
# FORCE_E(Little toe)
# XCOR_A(Big toe)
# XCOR_D(Heel)
# FSR_B(Right)
# FSR_F(Center)
# FORCE_C(Left)
# XCOR_C(Left)
# YCOR_C(Left)
# FSR_C(Left)

# %%
data.columns
# Out:
# Index(['FORCE_A(Big toe)', 'FORCE_B(Right)', 'FORCE_E(Little toe)',
#        'XCOR_A(Big toe)', 'XCOR_D(Heel)', 'FSR_B(Right)', 'FSR_F(Center)',
#        'FORCE_C(Left)', 'XCOR_C(Left)', 'YCOR_C(Left)', 'FSR_C(Left)'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
data_scaled=scaler.fit_transform(data)
data2=pd.DataFrame(data=data_scaled)
data2=data2.set_axis(['FORCE_A(Big toe)', 'FORCE_B(Right)', 'FORCE_E(Little toe)',
       'XCOR_A(Big toe)', 'XCOR_D(Heel)', 'FSR_B(Right)', 'FSR_F(Center)',
       'FORCE_C(Left)', 'XCOR_C(Left)', 'YCOR_C(Left)', 'FSR_C(Left)'],axis="columns")

# %%
data2.to_excel("squat_norm.xlsx")
