# %%
import pandas as pd  

data=pd.read_excel('/Users/withmocha/Desktop/TEED/data/mocha/23.12.06/squat/squat_data_target.xlsx')


data
# Out:
#      Unnamed: 0  FORCE_A(Big toe)  FORCE_B(Right)  FORCE_C(Left)  \
# 0             0                 6             185            276
# 1             1                 7             183            278
# 2             2                 3             203            291
# 3             3                 3             176            279
# 4             4                 0             167            259
# ..          ...               ...             ...            ...
# 872         872                 0               0             44
# 873         873                 0              14             51
# 874         874                 0              12             49
# 875         875                 0               0             47
# 876         876                 0               0             47
#
#      FORCE_D(Heel)  FORCE_E(Little toe)  FORCE_F(Center)  XCOR_A(Big toe)  \
# 0             1344                   12               37         7.750000
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0             0
# FORCE_A(Big toe)       0
# FORCE_B(Right)         0
# FORCE_C(Left)          0
# FORCE_D(Heel)          0
# FORCE_E(Little toe)    0
# FORCE_F(Center)        0
# XCOR_A(Big toe)        0
# XCOR_B(Right)          0
# XCOR_C(Left)           0
# XCOR_D(Heel)           0
# XCOR_E(Little toe)     0
# XCOR_F(Center)         0
# YCOR_A(Big toe)        0
# YCOR_B(Right)          0
# YCOR_C(Left)           0
# YCOR_D(Heel)           0
# YCOR_E(Little toe)     0
# YCOR_F(Center)         0
# COPX                   0
# COPY                   0
# FSR_A(Big toe)         0
# FSR_B(Right)           0
# FSR_C(Left)            0
# FSR_D(Heel)            0
# FSR_E(Little toe)      0
# FSR_F(Center)          0
# dtype: int64

# %%
data.drop(columns=["Unnamed: 0"],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/withmocha/Desktop/VisualStudioCode/TEED_LAB/2023/December/week1/1207(model_sum)/squat/correlation/feature_find.ipynb 셀 3 line 1
# ----> <a href='vscode-notebook-cell:/Users/withmocha/Desktop/VisualStudioCode/TEED_LAB/2023/December/week1/1207%28model_sum%29/squat/correlation/feature_find.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> data.drop(columns=["Unnamed: 0"],inplace=True)
#
# File ~/anaconda3/envs/conda/lib/python3.11/site-packages/pandas/core/frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns  

plt.figure(figsize=(35,35))
sns.heatmap(data=data.corr(),annot=True,fmt='.2f',linewidths=.8,cmap='Blues')
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['FORCE_A(Big toe)', 'FORCE_B(Right)', 'FORCE_C(Left)', 'FORCE_D(Heel)',
#        'FORCE_E(Little toe)', 'FORCE_F(Center)', 'XCOR_A(Big toe)',
#        'XCOR_B(Right)', 'XCOR_C(Left)', 'XCOR_D(Heel)', 'XCOR_E(Little toe)',
#        'XCOR_F(Center)', 'YCOR_A(Big toe)', 'YCOR_B(Right)', 'YCOR_C(Left)',
#        'YCOR_D(Heel)', 'YCOR_E(Little toe)', 'YCOR_F(Center)', 'COPX', 'COPY',
#        'FSR_A(Big toe)', 'FSR_B(Right)', 'FSR_C(Left)', 'FSR_D(Heel)',
#        'FSR_E(Little toe)', 'FSR_F(Center)'],
#       dtype='object')

# %%
data.drop(columns=['FORCE_D(Heel)',
        'FORCE_F(Center)', 
       'XCOR_B(Right)', 'XCOR_E(Little toe)',
       'XCOR_F(Center)', 'YCOR_A(Big toe)', 'YCOR_B(Right)',
       'YCOR_D(Heel)', 'YCOR_E(Little toe)', 'YCOR_F(Center)', 'COPX', 'COPY',
       'FSR_A(Big toe)', 'FSR_D(Heel)',
       'FSR_E(Little toe)'],inplace=True)

# %%
plt.figure(figsize=(35,35))
sns.heatmap(data=data.corr(),annot=True,fmt='.2f',linewidths=.8,cmap='Blues')
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['FORCE_A(Big toe)', 'FORCE_B(Right)', 'FORCE_C(Left)',
#        'FORCE_E(Little toe)', 'XCOR_A(Big toe)', 'XCOR_C(Left)',
#        'XCOR_D(Heel)', 'YCOR_C(Left)', 'FSR_B(Right)', 'FSR_C(Left)',
#        'FSR_F(Center)'],
#       dtype='object')

# %%
data_new=data.loc[:,["FORCE_A(Big toe)","FORCE_B(Right)","FORCE_E(Little toe)",'XCOR_A(Big toe)',
                      "XCOR_D(Heel)","FSR_B(Right)","FSR_F(Center)","FORCE_C(Left)","XCOR_C(Left)",
                      "YCOR_C(Left)","FSR_C(Left)"]]

# %%
data_new
# Out:
#      FORCE_A(Big toe)  FORCE_B(Right)  FORCE_E(Little toe)  XCOR_A(Big toe)  \
# 0                   6             185                   12         7.750000
# 1                   7             183                   15         7.714286
# 2                   3             203                   15         7.500000
# 3                   3             176                   15         7.500000
# 4                   0             167                   12         7.500000
# ..                ...             ...                  ...              ...
# 872                 0               0                    0         7.500000
# 873                 0              14                    0         7.500000
# 874                 0              12                    0         7.500000
# 875                 0               0                    0         7.500000
# 876                 0               0                    0         7.500000
#
# ...

# %%
data.columns
# Out:
# Index(['FORCE_A(Big toe)', 'FORCE_B(Right)', 'FORCE_C(Left)',
#        'FORCE_E(Little toe)', 'XCOR_A(Big toe)', 'XCOR_C(Left)',
#        'XCOR_D(Heel)', 'YCOR_C(Left)', 'FSR_B(Right)', 'FSR_C(Left)',
#        'FSR_F(Center)'],
#       dtype='object')

# %%
data_new.isnull().sum()
# Out:
# FORCE_A(Big toe)       0
# FORCE_B(Right)         0
# FORCE_E(Little toe)    0
# XCOR_A(Big toe)        0
# XCOR_D(Heel)           0
# FSR_B(Right)           0
# FSR_F(Center)          0
# FORCE_C(Left)          0
# XCOR_C(Left)           0
# YCOR_C(Left)           0
# FSR_C(Left)            0
# dtype: int64

# %%
data_new.to_excel("squat_data_fit_feature.xlsx")
