# %%
import pandas as pd  

data_row=pd.read_excel('/Users/withmocha/Desktop/TEED/data/mocha/23.12.04/squat/squat_data.xlsx')


data_row
# Out:
#      Unnamed: 0  FORCE_A(Big toe)  FORCE_B(Right)  FORCE_C(Left)  \
# 0             0                 6             185            276
# 1             1                 7             183            278
# 2             2                 3             203            291
# 3             3                 3             176            279
# 4             4                 0             167            259
# ..          ...               ...             ...            ...
# 872         872                 0               0             44
# 873         873                 0              14             51
# 874         874                 0              12             49
# 875         875                 0               0             47
# 876         876                 0               0             47
#
#      FORCE_D(Heel)  FORCE_E(Little toe)  FORCE_F(Center)  XCOR_A(Big toe)  \
# 0             1344                   12               37         7.750000
# ...

# %%
data_row.columns
# Out:
# Index(['Unnamed: 0', 'FORCE_A(Big toe)', 'FORCE_B(Right)', 'FORCE_C(Left)',
#        'FORCE_D(Heel)', 'FORCE_E(Little toe)', 'FORCE_F(Center)',
#        'XCOR_A(Big toe)', 'XCOR_B(Right)', 'XCOR_C(Left)', 'XCOR_D(Heel)',
#        'XCOR_E(Little toe)', 'XCOR_F(Center)', 'YCOR_A(Big toe)',
#        'YCOR_B(Right)', 'YCOR_C(Left)', 'YCOR_D(Heel)', 'YCOR_E(Little toe)',
#        'YCOR_F(Center)', 'COPX', 'COPY', 'FSR_A(Big toe)', 'FSR_B(Right)',
#        'FSR_C(Left)', 'FSR_D(Heel)', 'FSR_E(Little toe)', 'FSR_F(Center)'],
#       dtype='object')

# %%
data_row.drop(columns="Unnamed: 0",inplace=True)

# %%
data_row.isnull().sum()
# Out:
# FORCE_A(Big toe)       0
# FORCE_B(Right)         0
# FORCE_C(Left)          0
# FORCE_D(Heel)          0
# FORCE_E(Little toe)    0
# FORCE_F(Center)        0
# XCOR_A(Big toe)        0
# XCOR_B(Right)          0
# XCOR_C(Left)           0
# XCOR_D(Heel)           0
# XCOR_E(Little toe)     0
# XCOR_F(Center)         0
# YCOR_A(Big toe)        0
# YCOR_B(Right)          0
# YCOR_C(Left)           0
# YCOR_D(Heel)           0
# YCOR_E(Little toe)     0
# YCOR_F(Center)         0
# COPX                   0
# COPY                   0
# FSR_A(Big toe)         0
# FSR_B(Right)           0
# FSR_C(Left)            0
# FSR_D(Heel)            0
# FSR_E(Little toe)      0
# FSR_F(Center)          0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns  

plt.figure(figsize=(35,35))
sns.heatmap(data=data_row.corr(),annot=True,fmt='.2f',linewidths=.8,cmap='Blues')
# Out:
# <Axes: >

# %%
data_row.columns
# Out:
# Index(['FORCE_A(Big toe)', 'FORCE_B(Right)', 'FORCE_C(Left)', 'FORCE_D(Heel)',
#        'FORCE_E(Little toe)', 'FORCE_F(Center)', 'XCOR_A(Big toe)',
#        'XCOR_B(Right)', 'XCOR_C(Left)', 'XCOR_D(Heel)', 'XCOR_E(Little toe)',
#        'XCOR_F(Center)', 'YCOR_A(Big toe)', 'YCOR_B(Right)', 'YCOR_C(Left)',
#        'YCOR_D(Heel)', 'YCOR_E(Little toe)', 'YCOR_F(Center)', 'COPX', 'COPY',
#        'FSR_A(Big toe)', 'FSR_B(Right)', 'FSR_C(Left)', 'FSR_D(Heel)',
#        'FSR_E(Little toe)', 'FSR_F(Center)'],
#       dtype='object')

# %%
data=data_row.drop(columns=["FORCE_A(Big toe)","FORCE_D(Heel)","FORCE_E(Little toe)",
                   "FORCE_F(Center)","XCOR_A(Big toe)","XCOR_D(Heel)","XCOR_E(Little toe)",
                   "XCOR_E(Little toe)","YCOR_A(Big toe)","YCOR_D(Heel)","YCOR_E(Little toe)",
                   "FSR_A(Big toe)","FSR_D(Heel)","FSR_E(Little toe)","FSR_F(Center)"])

# %%
data
# Out:
#      FORCE_B(Right)  FORCE_C(Left)  XCOR_B(Right)  XCOR_C(Left)  \
# 0               185            276       7.408108      3.672101
# 1               183            278       7.401639      3.604317
# 2               203            291       7.463054      3.621993
# 3               176            279       7.491477      3.553763
# 4               167            259       7.425150      3.619691
# ..              ...            ...            ...           ...
# 872               0             44       7.833333      3.090909
# 873              14             51       7.750000      2.950980
# 874              12             49       7.750000      2.959184
# 875               0             47       7.750000      2.968085
# 876               0             47       7.750000      2.968085
#
#      XCOR_F(Center)  YCOR_B(Right)  YCOR_C(Left)  YCOR_F(Center)      COPX  \
# 0          2.851351      11.097297     11.744565       18.648649  5.688195
# ...

# %%
plt.figure(figsize=(35,35))
sns.heatmap(data=data.corr(),annot=True,fmt='.2f',linewidths=.8,cmap='Blues')
# Out:
# <Axes: >

# %%
data_new=data.loc[:,["FORCE_B(Right)","FORCE_C(Left)","FSR_B(Right)","FSR_C(Left)"]]

# %%
data_new.to_excel("squat_data_fit_feature.xlsx")

# %%
data.columns
# Out:
# Index(['FORCE_B(Right)', 'FORCE_C(Left)', 'XCOR_B(Right)', 'XCOR_C(Left)',
#        'XCOR_F(Center)', 'YCOR_B(Right)', 'YCOR_C(Left)', 'YCOR_F(Center)',
#        'COPX', 'COPY', 'FSR_B(Right)', 'FSR_C(Left)'],
#       dtype='object')
