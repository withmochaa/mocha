# %%
import pandas as pd  

data=pd.read_excel('/Users/withmocha/Desktop/TEED/data/mocha/23.12.06/gait/gait_data_target.xlsx')


data
# Out:
#      Unnamed: 0  FORCE_A(Big toe)  FORCE_B(Right)  FORCD_C(Left)  \
# 0             0                 0             117            254
# 1             1                 0             163            287
# 2             2                14             174            326
# 3             3                 0             204            348
# 4             4                35             251            368
# ..          ...               ...             ...            ...
# 887         887                 0              84            258
# 888         888                 0             109            293
# 889         889                 0             108            318
# 890         890                 0             132            352
# 891         891                 0             155            392
#
#      FORCE_D(Heel)  FORCE_E(Little toe)  FORCE_F(Center)  XCOR_A(Big toe)  \
# 0             1794                    0                0         8.250000
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0             0
# FORCE_A(Big toe)       0
# FORCE_B(Right)         0
# FORCD_C(Left)          0
# FORCE_D(Heel)          0
# FORCE_E(Little toe)    0
# FORCE_F(Center)        0
# XCOR_A(Big toe)        0
# XCOR_B(Right)          0
# XCOR_C(Left)           0
# XCOR_D(Heel)           0
# XCOR_E(Little toe)     0
# XCORF(Center)          0
# YCOR_A(Big toe)        0
# YCOR_B(Right)          0
# YCOR_C(Left)           0
# YCOR_D(Heel)           0
# YCOR_E(Little toe)     0
# YCOR_F(Center)         0
# COPX                   0
# COPY                   0
# FSR_A(Big toe)         0
# FSR_B(Right)           0
# FSR_C(Left)            0
# FSR_D(Heel)            0
# FSR_E(Little toe)      0
# FSR_F(Center)          0
# dtype: int64

# %%
data.drop(columns=["Unnamed: 0"],inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns  

plt.figure(figsize=(35,35))
sns.heatmap(data=data.corr(),annot=True,fmt='.2f',linewidths=.8,cmap='Blues')
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['FORCE_A(Big toe)', 'FORCE_B(Right)', 'FORCD_C(Left)', 'FORCE_D(Heel)',
#        'FORCE_E(Little toe)', 'FORCE_F(Center)', 'XCOR_A(Big toe)',
#        'XCOR_B(Right)', 'XCOR_C(Left)', 'XCOR_D(Heel)', 'XCOR_E(Little toe)',
#        'XCORF(Center)', 'YCOR_A(Big toe)', 'YCOR_B(Right)', 'YCOR_C(Left)',
#        'YCOR_D(Heel)', 'YCOR_E(Little toe)', 'YCOR_F(Center)', 'COPX', 'COPY',
#        'FSR_A(Big toe)', 'FSR_B(Right)', 'FSR_C(Left)', 'FSR_D(Heel)',
#        'FSR_E(Little toe)', 'FSR_F(Center)'],
#       dtype='object')

# %%
data.drop(columns=["FORCE_D(Heel)",
                   "XCOR_A(Big toe)","XCOR_D(Heel)","XCOR_E(Little toe)","COPX","COPY","FORCE_D(Heel)",
                   "XCOR_E(Little toe)","YCOR_A(Big toe)","YCOR_D(Heel)","YCOR_E(Little toe)","YCOR_F(Center)",
                   "FSR_D(Heel)","FSR_E(Little toe)","FSR_F(Center)","XCORF(Center)","YCOR_B(Right)"],inplace=True)

# %%
plt.figure(figsize=(35,35))
sns.heatmap(data=data.corr(),annot=True,fmt='.2f',linewidths=.8,cmap='Blues')
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['FORCE_A(Big toe)', 'FORCE_B(Right)', 'FORCD_C(Left)',
#        'FORCE_E(Little toe)', 'FORCE_F(Center)', 'XCOR_B(Right)',
#        'XCOR_C(Left)', 'YCOR_C(Left)', 'FSR_A(Big toe)', 'FSR_B(Right)',
#        'FSR_C(Left)'],
#       dtype='object')

# %%
data_new=data.loc[:,["FORCE_A(Big toe)","FORCE_B(Right)","FORCE_E(Little toe)",
                      "FORCE_F(Center)","XCOR_B(Right)","FSR_A(Big toe)","FSR_B(Right)",
                      "FORCD_C(Left)","XCOR_C(Left)","YCOR_C(Left)","FSR_C(Left)"]]

# %%
data_new
# Out:
#      FORCE_A(Big toe)  FORCE_B(Right)  FORCE_E(Little toe)  FORCE_F(Center)  \
# 0                   0             117                    0                0
# 1                   0             163                    0                5
# 2                  14             174                    0               10
# 3                   0             204                    0               10
# 4                  35             251                    0               10
# ..                ...             ...                  ...              ...
# 887                 0              84                    0                0
# 888                 0             109                    0                6
# 889                 0             108                    0                5
# 890                 0             132                    0                6
# 891                 0             155                    0                9
#
# ...

# %%
data.columns
# Out:
# Index(['FORCE_A(Big toe)', 'FORCE_B(Right)', 'FORCD_C(Left)',
#        'FORCE_E(Little toe)', 'FORCE_F(Center)', 'XCOR_B(Right)',
#        'XCOR_C(Left)', 'YCOR_C(Left)', 'FSR_A(Big toe)', 'FSR_B(Right)',
#        'FSR_C(Left)'],
#       dtype='object')

# %%
data_new.isnull().sum()
# Out:
# FORCE_A(Big toe)       0
# FORCE_B(Right)         0
# FORCE_E(Little toe)    0
# FORCE_F(Center)        0
# XCOR_B(Right)          0
# FSR_A(Big toe)         0
# FSR_B(Right)           0
# FORCD_C(Left)          0
# XCOR_C(Left)           0
# YCOR_C(Left)           0
# FSR_C(Left)            0
# dtype: int64

# %%
data_new.to_excel("gait_data_fit_feature.xlsx")
