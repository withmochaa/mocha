# %%
import pandas as pd  

data=pd.read_excel('/Users/withmocha/Desktop/TEED/data/mocha/23.12.06/gait/gait_data_fit_feature.xlsx')


data
# Out:
#      Unnamed: 0  FORCE_B(Right)  XCOR_B(Right)  YCOR_B(Right)  FSR_B(Right)  \
# 0             0             117       7.081197       11.61538            36
# 1             1             163       7.153374       11.80061            41
# 2             2             174       7.186782       11.74425            47
# 3             3             204       7.186275       11.73775            50
# 4             4             251       7.290837       11.67729            54
# ..          ...             ...            ...            ...           ...
# 887         887              84       6.994048       11.70238            36
# 888         888             109       7.013761       11.67431            38
# 889         889             108       6.916667       11.73611            39
# 890         890             132       6.965909       11.70076            39
# 891         891             155       7.006452       11.75484            41
#
#      FORCD_C(Left)  XCOR_C(Left)  YCOR_C(Left)  FSR_C(Left)
# 0              254      3.996063      12.64764           40
# 1              287      3.982578      12.61672           41
# 2              326      3.927914      12.75767           42
# 3              348      4.033046      12.59195           44
# 4              368      4.048913      12.58967           49
# ..             ...           ...           ...          ...
# 887            258      3.918605      12.75194           42
# 888            293      3.940273      12.76621           45
# 889            318      3.915094      12.82547           47
# 890            352      3.960227      12.84943           47
# 891            392      3.965561      12.76658           49
#
# [892 rows x 9 columns]

# %%
data.drop(columns=["Unnamed: 0"],inplace=True)

# %%
import matplotlib.pyplot as plt

columns=data.columns
count=0
for i in columns:
    print(columns[count])
    count=count+1
    plt.plot(data[i])
    plt.show()
# Out:
# FORCE_B(Right)
# XCOR_B(Right)
# YCOR_B(Right)
# FSR_B(Right)
# FORCD_C(Left)
# XCOR_C(Left)
# YCOR_C(Left)
# FSR_C(Left)

# %%
data.columns
# Out:
# Index(['FORCE_B(Right)', 'XCOR_B(Right)', 'YCOR_B(Right)', 'FSR_B(Right)',
#        'FORCD_C(Left)', 'XCOR_C(Left)', 'YCOR_C(Left)', 'FSR_C(Left)'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
data_scaled=scaler.fit_transform(data)
data2=pd.DataFrame(data=data_scaled)
data2=data2.set_axis(["FORCE_B(Right)","XCOR_B(Right)","YCOR_B(Right)","FSR_B(Right)",
                      "FORCD_C(Left)","XCOR_C(Left)","YCOR_C(Left)","FSR_C(Left)"],axis="columns")

# %%
data2.to_excel("gait_norm.xlsx")
