# %%
import pandas as pd  

data=pd.read_excel('/Users/withmocha/Desktop/TEED/data/mocha/23.11.23/STS/STS_data_main.xlsx')


data
# Out:
#      Unnamed: 0  FORCE_B(Right)  X_COR_C(Left)  FSR_C(Left)
# 0             0               0         3.1250           38
# 1             1               0         3.1250           37
# 2             2               0         3.1250           36
# 3             3               0         3.1250           35
# 4             4               0         3.1250           35
# ..          ...             ...            ...          ...
# 632         632               0         3.1875           36
# 633         633               0         3.1875           37
# 634         634               0         3.1875           37
# 635         635               0         3.1875           37
# 636         636               0         3.1875           37
#
# [637 rows x 4 columns]

# %%
data.drop(columns=["Unnamed: 0"],inplace=True)

# %%
import matplotlib.pyplot as plt

columns=data.columns
count=0
for i in columns:
    print(columns[count])
    count=count+1
    plt.plot(data[i])
    plt.show()
# Out:
# FORCE_B(Right)
# X_COR_C(Left)
# FSR_C(Left)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
data_scaled=scaler.fit_transform(data)
data2=pd.DataFrame(data=data_scaled)
data2=data2.set_axis(["FORCE_B(Right)","X_COR_C(Left)",
                      "FSR_C(Left)"],axis="columns")

# %%
data2.to_excel("STS_norm.xlsx")
