# %%
import pandas as pd  

data=pd.read_excel('/Users/withmocha/Desktop/TEED/data/mocha/23.12.04/squat/squat_data_fit_feature.xlsx')


data
# Out:
#      Unnamed: 0  FORCE_B(Right)  FORCE_C(Left)  FSR_B(Right)  FSR_C(Left)
# 0             0             185            276            38           48
# 1             1             183            278            40           48
# 2             2             203            291            43           47
# 3             3             176            279            44           43
# 4             4             167            259            44           41
# ..          ...             ...            ...           ...          ...
# 872         872               0             44            34           29
# 873         873              14             51            35           27
# 874         874              12             49            35           25
# 875         875               0             47            33           26
# 876         876               0             47            33           26
#
# [877 rows x 5 columns]

# %%
data.drop(columns=["Unnamed: 0"],inplace=True)

# %%
import matplotlib.pyplot as plt

columns=data.columns
count=0
for i in columns:
    print(columns[count])
    count=count+1
    plt.plot(data[i])
    plt.show()
# Out:
# FORCE_B(Right)
# FORCE_C(Left)
# FSR_B(Right)
# FSR_C(Left)

# %%
data.columns
# Out:
# Index(['FORCE_B(Right)', 'FORCE_C(Left)', 'FSR_B(Right)', 'FSR_C(Left)'], dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
data_scaled=scaler.fit_transform(data)
data2=pd.DataFrame(data=data_scaled)
data2=data2.set_axis(["FORCE_B(Right)","FORCE_C(Left)",
                      "FSR_B(Right)","FSR_C(Left)"],axis="columns")

# %%
data2.to_excel("SQUAR_norm.xlsx")
