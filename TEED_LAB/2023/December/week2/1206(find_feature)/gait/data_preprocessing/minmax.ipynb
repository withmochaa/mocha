# %%
import pandas as pd  

data=pd.read_excel('/Users/withmocha/Desktop/TEED/data/mocha/23.12.06/gait/gait_data_fit_feature.xlsx')


data
# Out:
#      Unnamed: 0  FORCE_A(Big toe)  FORCE_B(Right)  FORCE_E(Little toe)  \
# 0             0                 0             117                    0
# 1             1                 0             163                    0
# 2             2                14             174                    0
# 3             3                 0             204                    0
# 4             4                35             251                    0
# ..          ...               ...             ...                  ...
# 887         887                 0              84                    0
# 888         888                 0             109                    0
# 889         889                 0             108                    0
# 890         890                 0             132                    0
# 891         891                 0             155                    0
#
#      FORCE_F(Center)  XCOR_B(Right)  FSR_A(Big toe)  FSR_B(Right)  \
# ...

# %%
data.drop(columns=["Unnamed: 0"],inplace=True)

# %%
import matplotlib.pyplot as plt

columns=data.columns
count=0
for i in columns:
    print(columns[count])
    count=count+1
    plt.plot(data[i])
    plt.show()
# Out:
# FORCE_A(Big toe)
# FORCE_B(Right)
# FORCE_E(Little toe)
# FORCE_F(Center)
# XCOR_B(Right)
# FSR_A(Big toe)
# FSR_B(Right)
# FORCD_C(Left)
# XCOR_C(Left)
# YCOR_C(Left)
# FSR_C(Left)

# %%
data.columns
# Out:
# Index(['FORCE_A(Big toe)', 'FORCE_B(Right)', 'FORCE_E(Little toe)',
#        'FORCE_F(Center)', 'XCOR_B(Right)', 'FSR_A(Big toe)', 'FSR_B(Right)',
#        'FORCD_C(Left)', 'XCOR_C(Left)', 'YCOR_C(Left)', 'FSR_C(Left)'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
data_scaled=scaler.fit_transform(data)
data2=pd.DataFrame(data=data_scaled)
data2=data2.set_axis(['FORCE_A(Big toe)', 'FORCE_B(Right)', 'FORCE_E(Little toe)',
       'FORCE_F(Center)', 'XCOR_B(Right)', 'FSR_A(Big toe)', 'FSR_B(Right)',
       'FORCD_C(Left)', 'XCOR_C(Left)', 'YCOR_C(Left)', 'FSR_C(Left)'],axis="columns")

# %%
data2.to_excel("gait_norm.xlsx")
