# %%
import pandas as pd 

data=pd.read_excel("/Users/withmocha/Desktop/TEED/data/mocha/23.11.01/squart_main.xlsx")

data
# Out:
#      Unnamed: 0  FORCE_B(Right)  FORCE_C(Left)  FORCE_D(Heel)  \
# 0             0              67            260            750
# 1             1              68            263            735
# 2             2              71            275            745
# 3             3              73            261            767
# 4             4              80            252            772
# ..          ...             ...            ...            ...
# 608         608              48            342            214
# 609         609              23            335            208
# 610         610              45            338            244
# 611         611              38            328            247
# 612         612              33            315            290
#
#      FORCE_E(Little toe)  FORCE_F(Center)  X COORDINATE_C(Left)  \
# 0                      0               28              3.325000
# 1                      0               13              3.378327
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                0
# FORCE_B(Right)            0
# FORCE_C(Left)             0
# FORCE_D(Heel)             0
# FORCE_E(Little toe)       0
# FORCE_F(Center)           0
# X COORDINATE_C(Left)      0
# X COORDINATE_D(Heel)      0
# X COORDINATE_F(Center)    0
# Y COORDINATE_C(Left)      0
# Y COORDINATE_D(Heel)      0
# Y COORDINATE_F(Center)    0
# COPX                      0
# COPY                      0
# FSR DATA_A(Big toe)       0
# FSR DATA_B(Right)         0
# FSR DATA_C(Left)          0
# FSR DATA_D(Heel)          0
# FSR DATA_E(Little toe)    0
# FSR DATA_F(Center)        0
# dtype: int64

# %%
data.plot(figsize=(20,20))
# Out:
# <Axes: >

# %%
data.drop(columns="Unnamed: 0",inplace=True)

# %%
data.columns
# Out:
# Index(['FORCE_B(Right)', 'FORCE_C(Left)', 'FORCE_D(Heel)',
#        'FORCE_E(Little toe)', 'FORCE_F(Center)', 'X COORDINATE_C(Left)',
#        'X COORDINATE_D(Heel)', 'X COORDINATE_F(Center)',
#        'Y COORDINATE_C(Left)', 'Y COORDINATE_D(Heel)',
#        'Y COORDINATE_F(Center)', 'COPX', 'COPY', 'FSR DATA_A(Big toe)',
#        'FSR DATA_B(Right)', 'FSR DATA_C(Left)', 'FSR DATA_D(Heel)',
#        'FSR DATA_E(Little toe)', 'FSR DATA_F(Center)'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns  

plt.figure(figsize=(35,35))
sns.heatmap(data=data.corr(),annot=True,fmt='.2f',linewidths=.8,cmap='Blues')
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['FORCE_B(Right)', 'FORCE_C(Left)', 'FORCE_D(Heel)',
#        'FORCE_E(Little toe)', 'FORCE_F(Center)', 'X COORDINATE_C(Left)',
#        'X COORDINATE_D(Heel)', 'X COORDINATE_F(Center)',
#        'Y COORDINATE_C(Left)', 'Y COORDINATE_D(Heel)',
#        'Y COORDINATE_F(Center)', 'COPX', 'COPY', 'FSR DATA_A(Big toe)',
#        'FSR DATA_B(Right)', 'FSR DATA_C(Left)', 'FSR DATA_D(Heel)',
#        'FSR DATA_E(Little toe)', 'FSR DATA_F(Center)'],
#       dtype='object')

# %%
data=data.drop(columns=["FORCE_D(Heel)","FORCE_E(Little toe)","FORCE_F(Center)",
                        "Y COORDINATE_D(Heel)","Y COORDINATE_F(Center)","COPX","COPY",
                        "FSR DATA_A(Big toe)","FSR DATA_D(Heel)","FSR DATA_E(Little toe)","FSR DATA_F(Center)"])

# %%
data.columns
# Out:
# Index(['FORCE_B(Right)', 'FORCE_C(Left)', 'X COORDINATE_C(Left)',
#        'X COORDINATE_D(Heel)', 'X COORDINATE_F(Center)',
#        'Y COORDINATE_C(Left)', 'FSR DATA_B(Right)', 'FSR DATA_C(Left)'],
#       dtype='object')

# %%
data.to_excel("target_data.xlsx")
