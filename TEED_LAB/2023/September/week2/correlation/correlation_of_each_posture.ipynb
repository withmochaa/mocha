# %%
import pandas as pd 

data=pd.read_excel('/Users/withmocha/Desktop/TEED/data/mocha/23.09.06/data_sum.xlsx')
data
# Out:
#      SQUAT_FORCE_L  SQUAT_X_COR_L  SQUAT_Y_COR_L  SQUAT_COPX  SQUAT_COPY  \
# 0              260       3.325000      12.434615    5.519283   21.277130
# 1              263       3.378327      12.311787    5.588154   21.189624
# 2              275       3.378182      12.383636    5.527003   21.112061
# 3              261       3.385057      12.306513    5.551982   21.260793
# 4              252       3.311508      12.388889    5.533654   21.252622
# ..             ...            ...            ...         ...         ...
# 608            342       3.165205      12.741228    4.145478   17.242464
# 609            335       3.165672      12.749254    4.034075   17.324757
# 610            338       3.217456      12.665680    4.198758   17.590062
# 611            328       3.179878      12.681402    4.174745   17.733418
# 612            315       3.165079      12.709524    4.236453   18.237685
#
#      SQUAT_FSR_L  SQUAT_FSRNONOISE_L  SQUAT_FSR_mass_L  SQUAT_FORCE_R  \
# ...

# %%
data.columns
# Out:
# Index(['SQUAT_FORCE_L', 'SQUAT_X_COR_L', 'SQUAT_Y_COR_L', 'SQUAT_COPX',
#        'SQUAT_COPY', 'SQUAT_FSR_L', 'SQUAT_FSRNONOISE_L', 'SQUAT_FSR_mass_L',
#        'SQUAT_FORCE_R', 'SQUAT_X_COR_R', 'SQUAT_Y_COR_R', 'SQUAT_COPX.1',
#        'SQUAT_COPY.1', 'SQUAT_FSR_R', 'SQUAT_FSRNONOISE_R', 'SQUAT_FSR_mass_R',
#        'STS_FORCE_L', 'STS_X_COR_L', 'STS_Y_COR_L', 'STS_COPX', 'STS_COPY',
#        'STS_FSR_L', 'STS_FSRNONOISE_L', 'STS_FSR_mass_L', 'STS_FORCE_R',
#        'STS_X_COR_R', 'STS_Y_COR_R', 'STS_COPX.1', 'STS_COPY.1', 'STS_FSR_R',
#        'STS_FSRNONOISE_R', 'STS_FSR_mass_R', 'GAIT_FORCE_L', 'GAIT_X_COR_L',
#        'GAIT_Y_COR_L', 'GAIT_COPX', 'GAIT_COPY', 'GAIT_FSR_L',
#        'GAIT_FSRNONOISE_L', 'GAIT_FSR_mass_L', 'GAIT_FORCE_R', 'GAIT_X_COR_R',
#        'GAIT_Y_COR_R', 'GAIT_COPX.1', 'GAIT_COPY.1', 'GAIT_FSR_R',
#        'GAIT_FSRNONOISE_R', 'GAIT_FSR_mass_R'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# SQUAT_FORCE_L           0
# SQUAT_X_COR_L          64
# SQUAT_Y_COR_L          64
# SQUAT_COPX              0
# SQUAT_COPY              0
# SQUAT_FSR_L             0
# SQUAT_FSRNONOISE_L      0
# SQUAT_FSR_mass_L        0
# SQUAT_FORCE_R           0
# SQUAT_X_COR_R         420
# SQUAT_Y_COR_R         420
# SQUAT_COPX.1            0
# SQUAT_COPY.1            0
# SQUAT_FSR_R             0
# SQUAT_FSRNONOISE_R      0
# SQUAT_FSR_mass_R        0
# STS_FORCE_L             0
# STS_X_COR_L           149
# STS_Y_COR_L           149
# STS_COPX               20
# STS_COPY               20
# STS_FSR_L               0
# STS_FSRNONOISE_L        0
# STS_FSR_mass_L          0
# STS_FORCE_R             0
# STS_X_COR_R           366
# STS_Y_COR_R           366
# STS_COPX.1             20
# STS_COPY.1             20
# STS_FSR_R               0
# STS_FSRNONOISE_R        0
# STS_FSR_mass_R          0
# GAIT_FORCE_L            0
# GAIT_X_COR_L          329
# GAIT_Y_COR_L          329
# ...

# %%
data.drop(columns=['SQUAT_X_COR_R','SQUAT_Y_COR_R','STS_X_COR_R','STS_Y_COR_R','GAIT_X_COR_L','GAIT_Y_COR_L','GAIT_X_COR_R','GAIT_Y_COR_R'],inplace=True)
data.columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 data.drop(columns=['SQUAT_X_COR_R','SQUAT_Y_COR_R','STS_X_COR_R','STS_Y_COR_R','GAIT_X_COR_L','GAIT_Y_COR_L','GAIT_X_COR_R','GAIT_Y_COR_R'],inplace=True)
#       2 data.columns
#
# File ~/anaconda3/envs/conda/lib/python3.11/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
# ...

# %%
columns=data.columns

for i in columns:
    data[i].fillna(data[i].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# SQUAT_FORCE_L         0
# SQUAT_X_COR_L         0
# SQUAT_Y_COR_L         0
# SQUAT_COPX            0
# SQUAT_COPY            0
# SQUAT_FSR_L           0
# SQUAT_FSRNONOISE_L    0
# SQUAT_FSR_mass_L      0
# SQUAT_FORCE_R         0
# SQUAT_COPX.1          0
# SQUAT_COPY.1          0
# SQUAT_FSR_R           0
# SQUAT_FSRNONOISE_R    0
# SQUAT_FSR_mass_R      0
# STS_FORCE_L           0
# STS_X_COR_L           0
# STS_Y_COR_L           0
# STS_COPX              0
# STS_COPY              0
# STS_FSR_L             0
# STS_FSRNONOISE_L      0
# STS_FSR_mass_L        0
# STS_FORCE_R           0
# STS_COPX.1            0
# STS_COPY.1            0
# STS_FSR_R             0
# STS_FSRNONOISE_R      0
# STS_FSR_mass_R        0
# GAIT_FORCE_L          0
# GAIT_COPX             0
# GAIT_COPY             0
# GAIT_FSR_L            0
# GAIT_FSRNONOISE_L     0
# GAIT_FSR_mass_L       0
# GAIT_FORCE_R          0
# GAIT_COPX.1           0
# GAIT_COPY.1           0
# GAIT_FSR_R            0
# ...

# %%
data_cor=data.corr()

# %%
data.to_excel("data_correlation.xlsx")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(35,35))
sns.heatmap(data=data.corr(),annot=True,fmt='.2f',linewidths=.8,cmap='Blues')
# Out:
# <Axes: >

# %%
squart_data=pd.read_excel("/Users/withmocha/Desktop/TEED/data/mocha/23.09.06/SQUAT.xlsx")
sts_data=pd.read_excel("/Users/withmocha/Desktop/TEED/data/mocha/23.09.06/STS.xlsx")
gait_data=pd.read_excel("/Users/withmocha/Desktop/TEED/data/mocha/23.09.06/GAIT.xlsx")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(25,25))
sns.heatmap(data=squart_data.corr(),annot=True,fmt='.2f',linewidths=.8,cmap='Blues')
# Out:
# <Axes: >

# %%
squart_data.columns
# Out:
# Index(['FORCE_B(Right)', 'FORCE_C(Left)', 'FORCE_D(Heel)',
#        'FORCE_E(Little toe)', 'FORCE_F(Center)', 'X COORDINATE_B(Right)',
#        'X COORDINATE_C(Left)', 'X COORDINATE_D(Heel)',
#        'X COORDINATE_F(Center)', 'Y COORDINATE_B(Right)',
#        'Y COORDINATE_C(Left)', 'Y COORDINATE_D(Heel)',
#        'Y COORDINATE_F(Center)', 'COPX', 'COPY', 'FSR DATA_A(Big toe)',
#        'FSR DATA_B(Right)', 'FSR DATA_C(Left)', 'FSR DATA_D(Heel)',
#        'FSR DATA_E(Little toe)', 'FSR DATA_F(Center)'],
#       dtype='object')

# %%
squart_data.corr()
# Out:
#                         FORCE_B(Right)  FORCE_C(Left)  FORCE_D(Heel)  \
# FORCE_B(Right)                1.000000       0.711373      -0.396874
# FORCE_C(Left)                 0.711373       1.000000      -0.827493
# FORCE_D(Heel)                -0.396874      -0.827493       1.000000
# FORCE_E(Little toe)           0.061685       0.140162      -0.118772
# FORCE_F(Center)               0.163833       0.690229      -0.649274
# X COORDINATE_B(Right)         0.681905      -0.115817       0.134138
# X COORDINATE_C(Left)          0.860273       0.826951      -0.504255
# X COORDINATE_D(Heel)          0.692740       0.829494      -0.716775
# X COORDINATE_F(Center)        0.143817       0.366666      -0.286776
# Y COORDINATE_B(Right)         0.622356       0.104446       0.002515
# Y COORDINATE_C(Left)         -0.431956       0.005027      -0.286509
# Y COORDINATE_D(Heel)         -0.643881      -0.866874       0.719435
# Y COORDINATE_F(Center)       -0.618487      -0.484797       0.260197
# ...

# %%
squart_data.to_excel("squart_correlation.xlsx")

# %%
sts_data.columns
# Out:
# Index(['FORCE_A(Big toe)', 'FORCE_B(Right)', 'FORCE_C(Left)', 'FORCE_D(Heel)',
#        'FORCE_E(Little toe)', 'FORCE_F(Center)', 'X COORDINATE_A(Big toe)',
#        'X COORDINATE_B(Right)', 'X COORDINATE_C(Left)', 'X COORDINATE_D(Heel)',
#        'X COORDINATE_E(Little toe)', 'X COORDINATE_F(Center)',
#        'Y COORDINATE_A(Big toe)', 'Y COORDINATE_B(Right)',
#        'Y COORDINATE_C(Left)', 'Y COORDINATE_D(Heel)',
#        'Y COORDINATE_E(Little toe)', 'Y COORDINATE_F(Center)', 'COPX', 'COPY',
#        'FSR DATA_A(Big toe)', 'FSR DATA_B(Right)', 'FSR DATA_C(Left)',
#        'FSR DATA_D(Heel)', 'FSR DATA_E(Little toe)', 'FSR DATA_F(Center)'],
#       dtype='object')

# %%
plt.figure(figsize=(25,25))
sns.heatmap(data=sts_data.corr(),annot=True,fmt='.2f',linewidths=.8,cmap='Blues')
# Out:
# <Axes: >

# %%
sts_data.columns
# Out:
# Index(['FORCE_A(Big toe)', 'FORCE_B(Right)', 'FORCE_C(Left)', 'FORCE_D(Heel)',
#        'FORCE_E(Little toe)', 'FORCE_F(Center)', 'X COORDINATE_A(Big toe)',
#        'X COORDINATE_B(Right)', 'X COORDINATE_C(Left)', 'X COORDINATE_D(Heel)',
#        'X COORDINATE_E(Little toe)', 'X COORDINATE_F(Center)',
#        'Y COORDINATE_A(Big toe)', 'Y COORDINATE_B(Right)',
#        'Y COORDINATE_C(Left)', 'Y COORDINATE_D(Heel)',
#        'Y COORDINATE_E(Little toe)', 'Y COORDINATE_F(Center)', 'COPX', 'COPY',
#        'FSR DATA_A(Big toe)', 'FSR DATA_B(Right)', 'FSR DATA_C(Left)',
#        'FSR DATA_D(Heel)', 'FSR DATA_E(Little toe)', 'FSR DATA_F(Center)'],
#       dtype='object')

# %%
sts_data.drop(columns=['FORCE_E(Little toe)','X COORDINATE_E(Little toe)','Y COORDINATE_E(Little toe)'],inplace=True)

# %%
plt.figure(figsize=(25,25))
sns.heatmap(data=sts_data.corr(),annot=True,fmt='.2f',linewidths=.8,cmap='Blues')
# Out:
# <Axes: >

# %%
data_cor=sts_data.corr()

# %%
data_cor
# Out:
#                          FORCE_A(Big toe)  FORCE_B(Right)  FORCE_C(Left)  \
# FORCE_A(Big toe)                 1.000000        0.439395       0.098468
# FORCE_B(Right)                   0.439395        1.000000       0.745962
# FORCE_C(Left)                    0.098468        0.745962       1.000000
# FORCE_D(Heel)                   -0.145937       -0.250687      -0.038312
# FORCE_F(Center)                 -0.091129        0.373806       0.732520
# X COORDINATE_A(Big toe)          0.481813       -0.412955      -0.231121
# X COORDINATE_B(Right)            0.156732        0.209502      -0.506852
# X COORDINATE_C(Left)             0.154305        0.649161       0.848661
# X COORDINATE_D(Heel)             0.081675       -0.047631      -0.225125
# X COORDINATE_F(Center)           0.011120        0.331607       0.289216
# Y COORDINATE_A(Big toe)          0.137517       -0.642153      -0.362674
# Y COORDINATE_B(Right)           -0.193171        0.179298      -0.298990
# ...

# %%
data_cor.to_excel("STS_correlation.xlsx")

# %%
plt.figure(figsize=(25,25))
sns.heatmap(data=gait_data.corr(),annot=True,fmt='.2f',linewidths=.8,cmap='Blues')
# Out:
# <Axes: >

# %%
gait_data.columns
# Out:
# Index(['FORCE_A(Big toe)', 'FORCE_B(Right)', 'FORCE_C(Left)', 'FORCE_D(Heel)',
#        'FORCE_E(Little toe)', 'FORCE_F(Center)', 'X COORDINATE_A(Big toe)',
#        'X COORDINATE_B(Right)', 'X COORDINATE_C(Left)', 'X COORDINATE_D(Heel)',
#        'X COORDINATE_E(Little toe)', 'X COORDINATE_F(Center)',
#        'Y COORDINATE_A(Big toe)', 'Y COORDINATE_B(Right)',
#        'Y COORDINATE_C(Left)', 'Y COORDINATE_D(Heel)',
#        'Y COORDINATE_E(Little toe)', 'Y COORDINATE_F(Center)', 'COPX', 'COPY',
#        'FSR DATA_A(Big toe)', 'FSR DATA_B(Right)', 'FSR DATA_C(Left)',
#        'FSR DATA_D(Heel)', 'FSR DATA_E(Little toe)', 'FSR DATA_F(Center)'],
#       dtype='object')

# %%
data_cor=gait_data.corr()
data_cor
# Out:
#                             FORCE_A(Big toe)  FORCE_B(Right)  FORCE_C(Left)  \
# FORCE_A(Big toe)                    1.000000        0.765354       0.759177
# FORCE_B(Right)                      0.765354        1.000000       0.878618
# FORCE_C(Left)                       0.759177        0.878618       1.000000
# FORCE_D(Heel)                      -0.287757       -0.258203      -0.289168
# FORCE_E(Little toe)                 0.717235        0.282996       0.477686
# FORCE_F(Center)                     0.000243        0.206530       0.420161
# X COORDINATE_A(Big toe)            -0.022686        0.563479       0.336423
# X COORDINATE_B(Right)              -0.443192       -0.248512      -0.661952
# X COORDINATE_C(Left)                0.558703        0.794702       0.543922
# X COORDINATE_D(Heel)                0.675560        0.624739       0.430309
# X COORDINATE_E(Little toe)          0.033758        0.451364       0.157464
# ...

# %%
data_cor.to_excel("gait_correlation.xlsx")
