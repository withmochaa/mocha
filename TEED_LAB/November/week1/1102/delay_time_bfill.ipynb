# %%
import pandas as pd 

data=pd.read_excel("/Users/withmocha/Desktop/TEED/data/mocha/23.11.01/target_data_loss113.xlsx.xlsx")

data
# Out:
#      Unnamed: 0  FORCE_B(Right)  FORCE_C(Left)  X COORDINATE_C(Left)  \
# 0             0            67.0          260.0              3.325000
# 1             1            68.0          263.0              3.378327
# 2             2            71.0          275.0              3.378182
# 3             3            73.0          261.0              3.385057
# 4             4            73.0          261.0              3.385057
# ..          ...             ...            ...                   ...
# 608         608            19.0          341.0              3.171554
# 609         609            19.0          341.0              3.171554
# 610         610            45.0          338.0              3.217456
# 611         611            38.0          328.0              3.179878
# 612         612            33.0          315.0              3.165079
#
#      X COORDINATE_D(Heel)  X COORDINATE_F(Center)  Y COORDINATE_C(Left)  \
# 0                6.275333                2.625000             12.434615
# 1                6.325850                2.192308             12.311787
# 2                6.237584                2.250000             12.383636
# 3                6.257497                2.562500             12.306513
# 4                6.257497                2.562500             12.306513
# ..                    ...                     ...                   ...
# 608              6.348837                2.679310             12.739003
# 609              6.348837                2.679310             12.739003
# 610              6.325820                2.706294             12.665680
# 611              6.265182                2.697917             12.681402
# 612              6.237931                2.660584             12.709524
#
#      FSR DATA_B(Right)  FSR DATA_C(Left)
# 0                 33.0              53.0
# 1                 32.0              52.0
# 2                 32.0              51.0
# 3                 31.0              48.0
# 4                 31.0              48.0
# ..                 ...               ...
# 608               25.0              50.0
# 609               25.0              50.0
# 610               27.0              50.0
# 611               30.0              47.0
# 612               33.0              44.0
#
# [613 rows x 9 columns]

# %%
data.plot(figsize=(20,20))
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'FORCE_B(Right)', 'FORCE_C(Left)', 'X COORDINATE_C(Left)',
#        'X COORDINATE_D(Heel)', 'X COORDINATE_F(Center)',
#        'Y COORDINATE_C(Left)', 'FSR DATA_B(Right)', 'FSR DATA_C(Left)'],
#       dtype='object')

# %%
data.drop(columns="Unnamed: 0",inplace=True)

# %%
data.plot(figsize=(20,20))
# Out:
# <Axes: >

# %%
data.isnull().sum()
# Out:
# FORCE_B(Right)            82
# FORCE_C(Left)             82
# X COORDINATE_C(Left)      82
# X COORDINATE_D(Heel)      82
# X COORDINATE_F(Center)    82
# Y COORDINATE_C(Left)      82
# FSR DATA_B(Right)         82
# FSR DATA_C(Left)          82
# dtype: int64

# %%
print((113/613)*100)
# Out:
# 18.43393148450245

# %%
import matplotlib.pyplot as plt

columns=data.columns
count=0
for i in columns:
    print(columns[count])
    count=count+1
    plt.plot(data[i])
    plt.show()
# Out:
# FORCE_B(Right)
# FORCE_C(Left)
# X COORDINATE_C(Left)
# X COORDINATE_D(Heel)
# X COORDINATE_F(Center)
# Y COORDINATE_C(Left)
# FSR DATA_B(Right)
# FSR DATA_C(Left)

# %%
data.fillna(method="ffill",inplace=True)
# Out:
# /var/folders/gb/hslcbzfs0bvcnj3zxtfrxt_r0000gn/T/ipykernel_18375/1830165551.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method="ffill",inplace=True)

# %%
data.isnull().sum()
# Out:
# FORCE_B(Right)            0
# FORCE_C(Left)             0
# X COORDINATE_C(Left)      0
# X COORDINATE_D(Heel)      0
# X COORDINATE_F(Center)    0
# Y COORDINATE_C(Left)      0
# FSR DATA_B(Right)         0
# FSR DATA_C(Left)          0
# dtype: int64

# %%
import matplotlib.pyplot as plt

columns=data.columns
count=0
for i in columns:
    print(columns[count])
    count=count+1
    plt.plot(data[i])
    plt.show()
# Out:
# FORCE_B(Right)
# FORCE_C(Left)
# X COORDINATE_C(Left)
# X COORDINATE_D(Heel)
# X COORDINATE_F(Center)
# Y COORDINATE_C(Left)
# FSR DATA_B(Right)
# FSR DATA_C(Left)

# %%
data.to_excel("data_delay_bfill.xlsx")
