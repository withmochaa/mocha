# %%
import pandas as pd 

data=pd.read_excel("/Users/withmocha/Desktop/TEED/data/mocha/23.11.03/data_target.xlsx")

data
# Out:
#      Unnamed: 0  FORCE_B(Right)  FORCE_C(Left)  FSR DATA_B(Right)  \
# 0             0              67            260                 33
# 1             1              68            263                 32
# 2             2              71            275                 32
# 3             3              73            261                 31
# 4             4              80            252                 31
# ..          ...             ...            ...                ...
# 608         608              48            342                 24
# 609         609              23            335                 25
# 610         610              45            338                 27
# 611         611              38            328                 30
# 612         612              33            315                 33
#
#      FSR DATA_C(Left)
# 0                  53
# 1                  52
# 2                  51
# 3                  48
# 4                  47
# ..                ...
# ...

# %%
data.drop(columns=['Unnamed: 0'],inplace=True)

# %%
import matplotlib.pyplot as plt

columns=data.columns
count=0
for i in columns:
    print(columns[count])
    count=count+1
    plt.plot(data[i])
    plt.show()
# Out:
# FORCE_B(Right)
# FORCE_C(Left)
# FSR DATA_B(Right)
# FSR DATA_C(Left)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
data_scaled=scaler.fit_transform(data)
data2=pd.DataFrame(data=data_scaled)
data2=data2.set_axis(["FORCE_B(Right)","FORCE_C(Left),",
                      "FSR DATA_B(Right)","FSR DATA_C(Left)"],axis="columns")

# %%
data2.to_excel("data_norm.xlsx")
