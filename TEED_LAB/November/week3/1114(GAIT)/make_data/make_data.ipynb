# %%
import pandas as pd 

data_main=pd.read_excel("/Users/withmocha/Desktop/TEED/data/mocha/23.11.14/SBC/gait_main.xlsx")

data_main
# Out:
#      Unnamed: 0       FORCE Unnamed: 2 Unnamed: 3 Unnamed: 4     Unnamed: 5  \
# 0           NaN  A(Big toe)   B(Right)    C(Left)    D(Heel)  E(Little toe)
# 1          14.0           0          0          0         14              0
# 2         112.0           0          0          0        109              0
# 3         358.0           0          0          0        240              0
# 4         324.0           0          0          0        324              0
# ..          ...         ...        ...        ...        ...            ...
# 597       676.0         385         96         36          0            159
# 598       470.0         278         53         22          0            117
# 599       263.0         170         16          0          0             77
# 600       157.0         105          6          0          0             46
# 601       224.0          40          0          0          0             28
#
# ...

# %%
data_row=pd.read_excel("/Users/withmocha/Desktop/TEED/data/mocha/23.11.14/gait_row.xlsx")

data_row
# Out:
#      Force_A(Big toe)  Force_B(Right)  Force_C(Left)  Force_D(Heel)  \
# 0                   0               0              0             14
# 1                   0               0              0            109
# 2                   0               0              0            240
# 3                   0               0              0            324
# 4                   0               0              0            412
# ..                ...             ...            ...            ...
# 596               385              96             36              0
# 597               278              53             22              0
# 598               170              16              0              0
# 599               105               6              0              0
# 600                40               0              0              0
#
#      E(LittleForce_ toe)  Force_F(Center)  X_COR_A(Big toe)  Force_B(Right).1  \
# ...

# %%
g
