# %%
import pandas as pd

data=pd.read_excel("/Users/withmocha/Desktop/TEED/data/mocha/23.10.07/squart/squart_xgb_drop.xlsx")


data
# Out:
#      Unnamed: 0  FORCE_B(Right)  FORCE_C(Left)  FORCE_D(Heel)  \
# 0             0            67.0          260.0          750.0
# 1             1            68.0          263.0          735.0
# 2             2             NaN            NaN            NaN
# 3             3            73.0          261.0          767.0
# 4             4            80.0          252.0          772.0
# ..          ...             ...            ...            ...
# 608         608            48.0          342.0          214.0
# 609         609            23.0          335.0          208.0
# 610         610            45.0          338.0          244.0
# 611         611            38.0          328.0          247.0
# 612         612            33.0          315.0          290.0
#
#      FORCE_E(Little toe)  FORCE_F(Center)  X COORDINATE_C(Left)  \
# 0                    0.0             28.0              3.325000
# 1                    0.0             13.0              3.378327
# 2                    NaN              NaN                   NaN
# 3                    0.0             24.0              3.385057
# 4                    0.0             29.0              3.311508
# ..                   ...              ...                   ...
# 608                  0.0            128.0              3.165205
# 609                  0.0            122.0              3.165672
# 610                  0.0            143.0              3.217456
# 611                  0.0            144.0              3.179878
# 612                  0.0            137.0              3.165079
#
#      X COORDINATE_D(Heel)  X COORDINATE_F(Center)  Y COORDINATE_C(Left)  \
# 0                6.275333                2.625000             12.434615
# 1                6.325850                2.192308             12.311787
# 2                     NaN                     NaN                   NaN
# 3                6.257497                2.562500             12.306513
# 4                6.236399                2.500000             12.388889
# ..                    ...                     ...                   ...
# 608              6.364486                2.667969             12.741228
# 609              6.348558                2.684426             12.749254
# 610              6.325820                2.706294             12.665680
# 611              6.265182                2.697917             12.681402
# 612              6.237931                2.660584             12.709524
#
#      Y COORDINATE_D(Heel)  Y COORDINATE_F(Center)      COPX       COPY  \
# 0               25.482000               17.214286  5.519283  21.277130
# 1               25.461905               16.115385  5.588154  21.189624
# 2                     NaN                     NaN       NaN        NaN
# 3               25.470013               17.166667  5.551982  21.260793
# 4               25.421632               17.327586  5.533654  21.252622
# ..                    ...                     ...       ...        ...
# 608             25.401869               18.511719  4.145478  17.242464
# 609             25.338942               18.127049  4.034075  17.324757
# 610             25.543033               18.307692  4.198758  17.590062
# 611             25.471660               18.399306  4.174745  17.733418
# 612             25.470690               18.328467  4.236453  18.237685
#
#      FSR DATA_A(Big toe)  FSR DATA_B(Right)  FSR DATA_C(Left)  \
# 0                   17.0               33.0              53.0
# 1                   15.0               32.0              52.0
# 2                    NaN                NaN               NaN
# 3                   15.0               31.0              48.0
# 4                   15.0               31.0              47.0
# ..                   ...                ...               ...
# 608                 18.0               24.0              50.0
# 609                 18.0               25.0              51.0
# 610                 18.0               27.0              50.0
# 611                 18.0               30.0              47.0
# 612                 17.0               33.0              44.0
#
#      FSR DATA_D(Heel)  FSR DATA_E(Little toe)  FSR DATA_F(Center)
# 0               114.0                    32.0                42.0
# 1               114.0                    31.0                42.0
# 2                 NaN                     NaN                 NaN
# 3               115.0                    33.0                41.0
# 4               114.0                    33.0                43.0
# ..                ...                     ...                 ...
# 608              55.0                    40.0                44.0
# 609              54.0                    40.0                43.0
# 610              54.0                    40.0                45.0
# 611              55.0                    40.0                48.0
# 612              57.0                    39.0                50.0
#
# [613 rows x 20 columns]

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                  0
# FORCE_B(Right)            170
# FORCE_C(Left)             170
# FORCE_D(Heel)             170
# FORCE_E(Little toe)       170
# FORCE_F(Center)           170
# X COORDINATE_C(Left)      170
# X COORDINATE_D(Heel)      170
# X COORDINATE_F(Center)    170
# Y COORDINATE_C(Left)      170
# Y COORDINATE_D(Heel)      170
# Y COORDINATE_F(Center)    170
# COPX                      170
# COPY                      170
# FSR DATA_A(Big toe)       170
# FSR DATA_B(Right)         170
# FSR DATA_C(Left)          170
# FSR DATA_D(Heel)          170
# FSR DATA_E(Little toe)    170
# FSR DATA_F(Center)        170
# dtype: int64

# %%
data.drop(columns=['Unnamed: 0','COPX','COPY'],inplace=True)

# %%
data.columns
# Out:
# Index(['FORCE_B(Right)', 'FORCE_C(Left)', 'FORCE_D(Heel)',
#        'FORCE_E(Little toe)', 'FORCE_F(Center)', 'X COORDINATE_C(Left)',
#        'X COORDINATE_D(Heel)', 'X COORDINATE_F(Center)',
#        'Y COORDINATE_C(Left)', 'Y COORDINATE_D(Heel)',
#        'Y COORDINATE_F(Center)', 'FSR DATA_A(Big toe)', 'FSR DATA_B(Right)',
#        'FSR DATA_C(Left)', 'FSR DATA_D(Heel)', 'FSR DATA_E(Little toe)',
#        'FSR DATA_F(Center)'],
#       dtype='object')

# %%
data.plot(figsize=(20,20))
# Out:
# <Axes: >

# %%
data.isnull().sum()
# Out:
# FORCE_B(Right)            170
# FORCE_C(Left)             170
# FORCE_D(Heel)             170
# FORCE_E(Little toe)       170
# FORCE_F(Center)           170
# X COORDINATE_C(Left)      170
# X COORDINATE_D(Heel)      170
# X COORDINATE_F(Center)    170
# Y COORDINATE_C(Left)      170
# Y COORDINATE_D(Heel)      170
# Y COORDINATE_F(Center)    170
# FSR DATA_A(Big toe)       170
# FSR DATA_B(Right)         170
# FSR DATA_C(Left)          170
# FSR DATA_D(Heel)          170
# FSR DATA_E(Little toe)    170
# FSR DATA_F(Center)        170
# dtype: int64

# %%
data.shape
# Out:
# (613, 17)

# %%
print(data.shape[0]/170)
# Out:
# 3.6058823529411765

# %%
LR=data.loc[:,['FORCE_B(Right)','FORCE_C(Left)','X COORDINATE_C(Left)','Y COORDINATE_C(Left)',
               'FSR DATA_B(Right)','FSR DATA_C(Left)']]

L=data.loc[:,['FORCE_C(Left)','X COORDINATE_C(Left)','Y COORDINATE_C(Left)','FSR DATA_C(Left)']]

R=data.loc[:,['FORCE_B(Right)','FSR DATA_B(Right)']]

# %%
LR.plot(figsize=(15,15))
# Out:
# <Axes: >

# %%
L.plot(figsize=(15,15))
# Out:
# <Axes: >

# %%
L=data.loc[:,['FORCE_C(Left)','FSR DATA_C(Left)']]
L.plot(figsize=(15,15))
# Out:
# <Axes: >

# %%
R.plot(figsize=(15,15))
# Out:
# <Axes: >

# %%
print(L.columns)
print(R.columns)
# Out:
# Index(['FORCE_C(Left)', 'FSR DATA_C(Left)'], dtype='object')
# Index(['FORCE_B(Right)', 'FSR DATA_B(Right)'], dtype='object')

# %%
print(L.isnull().sum())
print(R.isnull().sum())
# Out:
# FORCE_C(Left)       170
# FSR DATA_C(Left)    170
# dtype: int64
# FORCE_B(Right)       170
# FSR DATA_B(Right)    170
# dtype: int64

# %%
# Out:
# StandardScaler()

# %%
# L 부터 interpolation 

import pandas as pd 

L=pd.DataFrame(data=L)
R=pd.DataFrame(data=R)

# %%
L_FORECE_C=L.iloc[:,0].copy()
L_FSR_C=L.iloc[:,1].copy()

# %%
L_FORECE_C.plot()
# Out:
# <Axes: >

# %%
L_FSR_C.plot()
# Out:
# <Axes: >

# %%
import numpy as np 

index=L.index

loss_index_L_FORECE_C=np.array(L.index).reshape(-1,1)[L.iloc[:,0].isna()]
loss_index_L_FSR_C=np.array(L.index).reshape(-1,1)[L.iloc[:,1].isna()]

normal_index_L_FORECE_C=np.setdiff1d(index,loss_index_L_FORECE_C)
normal_index_L_FSR_C=np.setdiff1d(index,loss_index_L_FSR_C)

# %%
print(loss_index_L_FORECE_C.shape)
print(normal_index_L_FORECE_C.shape)
# Out:
# (170, 1)
# (443,)

# %%
x_train_L_FORECE_C=normal_index_L_FORECE_C.reshape(-1,1)
y_train_L_FORECE_C=L.iloc[normal_index_L_FORECE_C,0]
x_test_L_FORECE_C=loss_index_L_FORECE_C

x_train_L_FSR_C=normal_index_L_FSR_C.reshape(-1,1)
y_train_L_FSR_C=L.iloc[normal_index_L_FSR_C,1]
x_test_L_FSR_C=loss_index_L_FSR_C

# %%
print(x_train_L_FORECE_C.shape)
print(y_train_L_FORECE_C.shape)
print(x_test_L_FORECE_C.shape)
# Out:
# (443, 1)
# (443,)
# (170, 1)

# %%
from xgboost.sklearn import XGBRegressor

reg = XGBRegressor().fit(x_train_L_FORECE_C,y_train_L_FORECE_C)
pred=reg.predict(x_test_L_FORECE_C)
pred=pred.reshape(-1,1)

c=0
for i in loss_index_L_FORECE_C:    
    L_FORECE_C[i]=pred[c]
    c+=1

# %%
import matplotlib.pyplot as plt 
plt.plot(L_FORECE_C,label='imputation_xgb_L_FORECE_C')
plt.plot(L.iloc[:,0],label='original')
plt.legend()

# %%
from xgboost.sklearn import XGBRegressor

reg = XGBRegressor().fit(x_train_L_FSR_C,y_train_L_FSR_C)
pred=reg.predict(x_test_L_FSR_C)
pred=pred.reshape(-1,1)

c=0
for i in loss_index_L_FSR_C:    
    L_FSR_C[i]=pred[c]
    c+=1

# %%
plt.plot(L_FSR_C,label='imputation_xgb_L_FSR_C')
plt.plot(L.iloc[:,1],label='original')
plt.legend()

# %%
L
# Out:
#             0         1
# 0    1.236922  1.360177
# 1    1.266070  1.261896
# 2         NaN       NaN
# 3    1.246638  0.868774
# 4    1.159194  0.770493
# ..        ...       ...
# 608  2.033639  1.065335
# 609  1.965626  1.163615
# 610  1.994775  1.065335
# 611  1.897614  0.770493
# 612  1.771305  0.475651
#
# [613 rows x 2 columns]

# %%
for i in loss_index_L_FORECE_C:    
    L['FORCE_C(Left)'][i]=L_FORECE_C[i]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/withmocha/Desktop/VisualStudioCode/jupyter/TEED/October/week1/precleaning/squart_normalization.ipynb 셀 30 line 2
#       <a href='vscode-notebook-cell:/Users/withmocha/Desktop/VisualStudioCode/jupyter/TEED/October/week1/precleaning/squart_normalization.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> for i in loss_index_L_FORECE_C:
# ----> <a href='vscode-notebook-cell:/Users/withmocha/Desktop/VisualStudioCode/jupyter/TEED/October/week1/precleaning/squart_normalization.ipynb#X36sZmlsZQ%3D%3D?line=1'>2</a>     L['FORCE_C(Left)'][i]=L_FORECE_C[i]
#
# File ~/anaconda3/envs/conda/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/anaconda3/envs/conda/lib/python3.11/site-packages/pandas/core/indexes/range.py:349, in RangeIndex.get_loc(self, key)
#     347         raise KeyError(key) from err
#     348 if isinstance(key, Hashable):
# --> 349     raise KeyError(key)
#     350 self._check_indexing_error(key)
#     351 raise KeyError(key)
#
# KeyError: 'FORCE_C(Left)'

# %%
for i in loss_index_L_FSR_C:    
    L['FSR DATA_C(Left)'][i]=L_FSR_C[i]

# %%
L.isnull().sum()
# Out:
# FORCE_C(Left)       0
# FSR DATA_C(Left)    0
# dtype: int64

# %%
L.plot(figsize=(15,15))
# Out:
# <Axes: >

# %%
print(R.columns)
print(L.columns)
# Out:
# Index(['FORCE_B(Right)', 'FSR DATA_B(Right)'], dtype='object')
# Index(['FORCE_C(Left)', 'FSR DATA_C(Left)'], dtype='object')

# %%
index=R.index

loss_index_R_FORECE_B=np.array(R.index).reshape(-1,1)[R.iloc[:,0].isna()]
loss_index_R_FSR_B=np.array(R.index).reshape(-1,1)[R.iloc[:,1].isna()]

normal_index_R_FORECE_B=np.setdiff1d(index,loss_index_R_FORECE_B)
normal_index_R_FSR_B=np.setdiff1d(index,loss_index_R_FSR_B)

# %%
x_train_R_FORECE_B=normal_index_R_FORECE_B.reshape(-1,1)
y_train_L_FORECE_C=L.iloc[normal_index_R_FORECE_B,0]
x_test_R_FORECE_B=loss_index_R_FORECE_B

x_train_R_FSR_B=normal_index_R_FSR_B.reshape(-1,1)
y_train_L_FSR_C=L.iloc[normal_index_R_FORECE_B,1]
x_test_R_FSR_B=loss_index_R_FSR_B

R_FORCE_B=R.iloc[:,0].copy()
R_FSR_B=R.iloc[:,1].copy()

# %%
reg = XGBRegressor().fit(x_train_R_FORECE_B,y_train_L_FORECE_C)
pred=reg.predict(x_test_R_FORECE_B)
pred=pred.reshape(-1,1)

c=0
for i in loss_index_R_FORECE_B:    
    R_FORCE_B[i]=pred[c]
    c+=1

# %%
import matplotlib.pyplot as plt 
plt.plot(R_FORCE_B,label='imputation_xgb_R_FORCE_B')
plt.plot(R.iloc[:,0],label='original')
plt.legend()

# %%
reg = XGBRegressor().fit(x_train_R_FSR_B,y_train_L_FSR_C)
pred=reg.predict(x_test_R_FSR_B)
pred=pred.reshape(-1,1)

c=0
for i in loss_index_R_FSR_B:    
    R_FSR_B[i]=pred[c]
    c+=1

# %%
import matplotlib.pyplot as plt 
plt.plot(R_FSR_B,label='imputation_xgb_R_FSR_B')
plt.plot(R.iloc[:,1],label='original')
plt.legend()

# %%
print(R.columns)
# Out:
# Index(['FORCE_B(Right)', 'FSR DATA_B(Right)'], dtype='object')

# %%
index=R.index

loss_index_R_FORECE_B=np.array(R.index).reshape(-1,1)[R.iloc[:,0].isna()]
loss_index_R_FSR_B=np.array(R.index).reshape(-1,1)[R.iloc[:,1].isna()]

normal_index_R_FORECE_B=np.setdiff1d(index,loss_index_R_FORECE_B)
normal_index_R_FSR_B=np.setdiff1d(index,loss_index_R_FSR_B)

# %%
x_train_R_FORECE_B=normal_index_R_FORECE_B.reshape(-1,1)
y_train_R_FORECE_B=R.iloc[normal_index_R_FORECE_B,0]
x_test_R_FORECE_B=loss_index_R_FORECE_B

x_train_R_FSR_B=normal_index_R_FSR_B.reshape(-1,1)
y_train_R_FSR_B=R.iloc[normal_index_R_FSR_B,1]
x_test_R_FSR_B=loss_index_R_FSR_B

# %%
R_FORCE_B=R.iloc[:,0].copy()
R_FSR_B=R.iloc[:,1].copy()

# %%
R_FORCE_B.plot()
# Out:
# <Axes: >

# %%
R_FSR_B.plot()
# Out:
# <Axes: >

# %%
reg = XGBRegressor().fit(x_train_R_FORECE_B,y_train_R_FORECE_B)
pred=reg.predict(x_test_R_FORECE_B)
pred=pred.reshape(-1,1)

c=0
for i in loss_index_R_FORECE_B:    
    R_FORCE_B[i]=pred[c]
    c+=1

# %%
import matplotlib.pyplot as plt 
plt.plot(R_FORCE_B,label='imputation_xgb_R_FORCE_B')
plt.plot(R.iloc[:,0],label='original')
plt.legend()

# %%
reg = XGBRegressor().fit(x_train_R_FSR_B,y_train_R_FSR_B)
pred=reg.predict(x_test_R_FSR_B)
pred=pred.reshape(-1,1)

c=0
for i in loss_index_R_FSR_B:    
    R_FSR_B[i]=pred[c]
    c+=1

# %%
import matplotlib.pyplot as plt 
plt.plot(R_FSR_B,label='imputation_xgb_R_FSR_B')
plt.plot(R.iloc[:,1],label='original')
plt.legend()
