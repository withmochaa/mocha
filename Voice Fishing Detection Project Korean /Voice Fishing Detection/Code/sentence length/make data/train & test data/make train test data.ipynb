# %%
import pandas as pd

data=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0426/labeled/normal/일반 민원 data.csv",index_col=0)
data_ab1=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0426/labeled/fishing/4 sentence/대출사기형(4문장).csv",index_col=0)
data_ab2=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0426/labeled/fishing/4 sentence/수사기관형(4문장).csv",index_col=0)

# %%
data
# Out:
#                                              sentence  predict
# 0                                   어떤 은행을 이용하고 계십니까?        0
# 1                                     어느지점으로 안내해드릴까요?        0
# 2                             지금 전화거신 핸드폰이 본인명의 맞습니까?        0
# 3                                    생년월일을 말씀해주시겠습니까?        0
# 4                                     살고계신 주소는 어디입니까?        0
# ...                                               ...      ...
# 22584                                     62400원 입니다.        0
# 22585                                   1423200원 입니다.        0
# 22586  입주신청서와 추천서, 급여내역서 외 기타 서류를 갖고 홈페이지에서 신청하면 됩니다.        0
# 22587                                    1~3순위가 있습니다.        0
# 22588             국가유공자 자녀 및 국민기초생활수급권자를 1순위로 두고있습니다.        0
#
# [22589 rows x 2 columns]

# %%
data=data.sample(frac=1)

# %%
data=data[:6000]

# %%
data
# Out:
#                                                 sentence  predict
# 15012                           우선 00구 통합도서관에 회원가입을 하시구요        0
# 9685                                    씹는 담배는 364원 입니다.        0
# 9881     예 더 궁금한 점 없으시면 상담 종료하겠습니다. 다산콜센터 상담원 OOO 이었습니다.        0
# 10808                  캠핑장은 오토캠핑과 이지캠핑 세미캠핑 세가지 종류가 있습니다        0
# 13315  네. 조회해 보도록 하겠습니다. 잠시만 기다려 주십시오. 자원봉사 관련 사이트명은 ...        0
# ...                                                  ...      ...
# 8364                                매월 1일~27일까지 신청가능합니다.        0
# 4443                               자세한 사항은 말씀드릴수가 없습니다.         0
# 10897                  어플을 사용하셔도 되고, 홈페이지에서도 조회 가능하십니다.         0
# 11881                              ZOOM프로그램을 이용하시면 되십니다.        0
# 5317                     전액 또는 일부금액에 대해 반납 조치 될 수 있습니다.         0
#
# [6000 rows x 2 columns]

# %%
data_ab1
# Out:
#                                                sentence  predict
# 0                        여보세요 네   님 예 예 어저께 통화했던 최영환입니다        1
# 1      아 예 예 어떻게 가진행 결과 안내차 오늘 아침에 전화 드린다고 제가 얘기를 했었...        1
# 2               네 금리는 연 금리 5.5%에 상환 기간 60개월입니다. 5년이고요 네        1
# 3      매 월 상환하시는 금액은 60개월 기준 원금 이자 포함되신 금액으로 573035원...        1
# 4                             금리가 아 예 예 예. 말씀하세요 괜찮으세요?        1
# ...                                                 ...      ...
# 1391   아 그러니까 사장님께서 그 안쓰시는 통장 있으시면 400에서 450까지 선지급 해...        1
# 1392                          네 알겠습니다 네네 네 여보세요 뭐 어디세요?        1
# 1393   아 네 안녕하세요 저희 그 하나캐피탈에서 연락을 드렸습니다 아 그래요? 네네네 고...        1
# 1394   지금 현재 이용중이신 고금리건 채무 러시앤캐시 산와머니 이런 고금리건 채무 이용하...        1
# 1395   네네 어디어디 이용중이십니까? 너무 많아가지고  네 대부업건 어디어디 이용중이세요...        1
#
# [1396 rows x 2 columns]

# %%
data_ab2
# Out:
#                                                sentence  predict
# 0     아 서울 중앙 지검 첨단 범죄 수사 일부 이희나 수사관입니다. 본 사건 조사는 법원...        2
# 1      네 네 OOO씨 지금 제가 본인 확인 한번 할께요. 생년월일 앞에 여섯 자리만 말...        2
# 2        네 성함은 OOO님 맞으시죠? 네 네 본인 김성오 일당 잘 알고 있으십니까? 아니요        2
# 3      전혀 모른다고 진술 하셨는데 맞습니까? 네 네 이천 십 칠년이 월 삼 일 경기도 ...        2
# 4      이 두개 계좌 계설 사실에 대해서 전혀 모르신다는 말씀 이시죠? 네 네 본인은 네...        2
# ...                                                 ...      ...
# 3180   본인이 아시는지 모르시는지 조사를 해봐야 아는 거죠. 그거는 그니까 만약에... ...        2
# 3181   네 네이버 카페 중고나라 사이트를 통해서 그 김용식과 일당들이 고가의 명품 물건을...        2
# 3182   그럼 본인께서 오셔서 대면조사 받으시면 되는겁니다. 간단하게 네 그렇게 할게요. ...        2
# 3183   서울시 서초구로 오시면 됩니다 서울시오? 저희 관할이기 때문에 저희 쪽에서 조사를...        2
# 3184   아 그래요? 찾아오시는 분들이 많기 때문에 저희가 일방적으로 오라고 말씀드릴 수 ...        2
#
# [3185 rows x 2 columns]

# %%
data_ab=pd.concat([data_ab1,data_ab2])

# %%
data_ab
# Out:
#                                                sentence  predict
# 0                        여보세요 네   님 예 예 어저께 통화했던 최영환입니다        1
# 1      아 예 예 어떻게 가진행 결과 안내차 오늘 아침에 전화 드린다고 제가 얘기를 했었...        1
# 2               네 금리는 연 금리 5.5%에 상환 기간 60개월입니다. 5년이고요 네        1
# 3      매 월 상환하시는 금액은 60개월 기준 원금 이자 포함되신 금액으로 573035원...        1
# 4                             금리가 아 예 예 예. 말씀하세요 괜찮으세요?        1
# ...                                                 ...      ...
# 3180   본인이 아시는지 모르시는지 조사를 해봐야 아는 거죠. 그거는 그니까 만약에... ...        2
# 3181   네 네이버 카페 중고나라 사이트를 통해서 그 김용식과 일당들이 고가의 명품 물건을...        2
# 3182   그럼 본인께서 오셔서 대면조사 받으시면 되는겁니다. 간단하게 네 그렇게 할게요. ...        2
# 3183   서울시 서초구로 오시면 됩니다 서울시오? 저희 관할이기 때문에 저희 쪽에서 조사를...        2
# 3184   아 그래요? 찾아오시는 분들이 많기 때문에 저희가 일방적으로 오라고 말씀드릴 수 ...        2
#
# [4581 rows x 2 columns]

# %%
data=pd.concat([data,data_ab])

# %%
data
# Out:
#                                                 sentence  predict
# 15012                           우선 00구 통합도서관에 회원가입을 하시구요        0
# 9685                                    씹는 담배는 364원 입니다.        0
# 9881     예 더 궁금한 점 없으시면 상담 종료하겠습니다. 다산콜센터 상담원 OOO 이었습니다.        0
# 10808                  캠핑장은 오토캠핑과 이지캠핑 세미캠핑 세가지 종류가 있습니다        0
# 13315  네. 조회해 보도록 하겠습니다. 잠시만 기다려 주십시오. 자원봉사 관련 사이트명은 ...        0
# ...                                                  ...      ...
# 3180    본인이 아시는지 모르시는지 조사를 해봐야 아는 거죠. 그거는 그니까 만약에... ...        2
# 3181    네 네이버 카페 중고나라 사이트를 통해서 그 김용식과 일당들이 고가의 명품 물건을...        2
# 3182    그럼 본인께서 오셔서 대면조사 받으시면 되는겁니다. 간단하게 네 그렇게 할게요. ...        2
# 3183    서울시 서초구로 오시면 됩니다 서울시오? 저희 관할이기 때문에 저희 쪽에서 조사를...        2
# 3184    아 그래요? 찾아오시는 분들이 많기 때문에 저희가 일방적으로 오라고 말씀드릴 수 ...        2
#
# [10581 rows x 2 columns]

# %%
data=data.sample(frac=1)

# %%
data
# Out:
#                                                 sentence  predict
# 8686                                           네, 맞습니다.         0
# 4399                                 없으시면 회원가입 하시면 됩니다.         0
# 2984                                 네 바리스타 강좌 말씀하시는 거죠?        0
# 833     근데 뭐 대출 나왔으면은 이거는 선생님이 찾을 수 있는 금액은 백만원밖에 안 된다...        2
# 3158    팔십 몇 만 원 하면 제가 100만 원 기재를 해드리는거에요. 100만 원 선에서...        2
# ...                                                  ...      ...
# 1299    예 뭐 지금 일단 우선 지에스 로부터 한번 드실 텐데요 예 그래서 그게 이제 전화...        2
# 2682                                        다른 문의사항 있나요?        0
# 3726                                       네 무엇을 도와드릴까요?        0
# 376              울산요 지방 같은 경우는 시간이 좀 걸려요. 한 일주일 정도 아 그래요        1
# 13949                                 오전11시부터 오후5시까지입니다.        0
#
# [10581 rows x 2 columns]

# %%
test_data=data[:300]

# %%
train_data=data[300:data.shape[0]]

# %%
train_data
# Out:
#                                                 sentence  predict
# 1272    예 예 그리고 신분증 앞 면 2가지 사진 찍어서 카톡으로 좀 보내 주시구요. 카카...        1
# 1114                                  선생님께서 접종 받으시는 건가요?        0
# 16206                           사업자등록번호및 고객번호만 준비하시면 됩니다        0
# 2642                아 입출금? 체크 카드 발행되신거? 네? 체크 카드 발행이 되신거        2
# 5903                                 10월달에 하는 세종축제가 있습니다        0
# ...                                                  ...      ...
# 1299    예 뭐 지금 일단 우선 지에스 로부터 한번 드실 텐데요 예 그래서 그게 이제 전화...        2
# 2682                                        다른 문의사항 있나요?        0
# 3726                                       네 무엇을 도와드릴까요?        0
# 376              울산요 지방 같은 경우는 시간이 좀 걸려요. 한 일주일 정도 아 그래요        1
# 13949                                 오전11시부터 오후5시까지입니다.        0
#
# [10281 rows x 2 columns]

# %%
train_data.to_csv("train data.csv")
test_data.to_csv("test data.csv")
