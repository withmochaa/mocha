# %%
import pandas as pd



data_row=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0410/0506/train/binary train_data_after_vector(0506).csv",index_col=0)

data_row
# Out:
#               0         1         2         3         4         5         6  \
# 28636  0.057666 -0.048499 -0.015004 -0.008556  0.007480  0.004326 -0.044761
# 5242   0.084339 -0.016759 -0.002239  0.006603  0.034535 -0.000100 -0.025028
# 9597   0.048915 -0.082816 -0.022027 -0.036624 -0.009340  0.005210  0.010473
# 7582   0.044780 -0.074579 -0.025775 -0.022203 -0.012583 -0.003432  0.012088
# 4625   0.046568 -0.084928 -0.012517 -0.023174  0.001471 -0.001228 -0.020728
# ...         ...       ...       ...       ...       ...       ...       ...
# 5680   0.012926 -0.054298 -0.018591  0.020354  0.024776 -0.015096 -0.047258
# 22362  0.083671 -0.068238 -0.024110 -0.003436  0.063956  0.005678 -0.046681
# 26489  0.112500 -0.015669 -0.019522  0.001867  0.014560  0.009811 -0.032503
# 21277  0.063781 -0.045069 -0.021233  0.004045  0.035538  0.013520 -0.060870
# 12871  0.069192  0.002381  0.001885  0.025675  0.030192 -0.010695 -0.005921
#
# ...

# %%
y_train=pd.DataFrame(data=(data_row['predict']))

# %%
y_train
# Out:
#        predict
# 28636        0
# 5242         1
# 9597         0
# 7582         0
# 4625         0
# ...        ...
# 5680         0
# 22362        1
# 26489        1
# 21277        0
# 12871        0
#
# [28842 rows x 1 columns]

# %%
data=data_row

# %%
data_row.drop(columns=['predict'],inplace=True)

# %%
data_row
# Out:
#               0         1         2         3         4         5         6  \
# 28636  0.057666 -0.048499 -0.015004 -0.008556  0.007480  0.004326 -0.044761
# 5242   0.084339 -0.016759 -0.002239  0.006603  0.034535 -0.000100 -0.025028
# 9597   0.048915 -0.082816 -0.022027 -0.036624 -0.009340  0.005210  0.010473
# 7582   0.044780 -0.074579 -0.025775 -0.022203 -0.012583 -0.003432  0.012088
# 4625   0.046568 -0.084928 -0.012517 -0.023174  0.001471 -0.001228 -0.020728
# ...         ...       ...       ...       ...       ...       ...       ...
# 5680   0.012926 -0.054298 -0.018591  0.020354  0.024776 -0.015096 -0.047258
# 22362  0.083671 -0.068238 -0.024110 -0.003436  0.063956  0.005678 -0.046681
# 26489  0.112500 -0.015669 -0.019522  0.001867  0.014560  0.009811 -0.032503
# 21277  0.063781 -0.045069 -0.021233  0.004045  0.035538  0.013520 -0.060870
# 12871  0.069192  0.002381  0.001885  0.025675  0.030192 -0.010695 -0.005921
#
# ...

# %%
x_train=pd.DataFrame(data_row)

# %%
x_train
# Out:
#               0         1         2         3         4         5         6  \
# 28636  0.057666 -0.048499 -0.015004 -0.008556  0.007480  0.004326 -0.044761
# 5242   0.084339 -0.016759 -0.002239  0.006603  0.034535 -0.000100 -0.025028
# 9597   0.048915 -0.082816 -0.022027 -0.036624 -0.009340  0.005210  0.010473
# 7582   0.044780 -0.074579 -0.025775 -0.022203 -0.012583 -0.003432  0.012088
# 4625   0.046568 -0.084928 -0.012517 -0.023174  0.001471 -0.001228 -0.020728
# ...         ...       ...       ...       ...       ...       ...       ...
# 5680   0.012926 -0.054298 -0.018591  0.020354  0.024776 -0.015096 -0.047258
# 22362  0.083671 -0.068238 -0.024110 -0.003436  0.063956  0.005678 -0.046681
# 26489  0.112500 -0.015669 -0.019522  0.001867  0.014560  0.009811 -0.032503
# 21277  0.063781 -0.045069 -0.021233  0.004045  0.035538  0.013520 -0.060870
# 12871  0.069192  0.002381  0.001885  0.025675  0.030192 -0.010695 -0.005921
#
# ...

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (28842, 768)
# (28842, 1)

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
test=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0410/0506/test/binary target_data(0506).csv",index_col=0)

test_y=pd.DataFrame(data=test['predict'],columns=['predict'])
test_x=test.drop(columns=['predict'])
test_x=test_x

# %%
test_x
# Out:
#             0         1         2         3         4         5         6  \
# 114  0.132544 -0.035868 -0.020618  0.011402 -0.011060  0.016346 -0.047212
# 108  0.057914 -0.034599 -0.021505  0.009545  0.021648 -0.002444 -0.053997
# 74   0.106382 -0.019894 -0.019820  0.003348  0.044067  0.004019 -0.031345
# 61   0.099489 -0.063473 -0.022217  0.003446  0.008995  0.006556 -0.036373
# 34   0.074872 -0.011863  0.001483 -0.011409  0.041501  0.018303 -0.059321
# ..        ...       ...       ...       ...       ...       ...       ...
# 97   0.047481 -0.014559 -0.009955  0.019530  0.030867  0.009394 -0.095179
# 191  0.059719 -0.076216 -0.009168 -0.002351  0.008167  0.014102 -0.037567
# 35   0.016940 -0.083818  0.007729  0.000677 -0.009514 -0.020974 -0.028400
# 15   0.074838 -0.024917 -0.013993  0.014806  0.020463 -0.013092 -0.062031
# 290  0.033329 -0.087733 -0.034672 -0.021168  0.016734  0.004777 -0.043377
#
#             7         8         9  ...       758       759       760  \
# ...

# %%
test_y
# Out:
#      predict
# 114        1
# 108        0
# 74         1
# 61         1
# 34         1
# ..       ...
# 97         0
# 191        1
# 35         0
# 15         1
# 290        0
#
# [300 rows x 1 columns]

# %%
import numpy as np 
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras import layers
from tensorflow.keras.models import Model
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split

import os

# %%
x_train
# Out:
#               0         1         2         3         4         5         6  \
# 28636  0.057666 -0.048499 -0.015004 -0.008556  0.007480  0.004326 -0.044761
# 5242   0.084339 -0.016759 -0.002239  0.006603  0.034535 -0.000100 -0.025028
# 9597   0.048915 -0.082816 -0.022027 -0.036624 -0.009340  0.005210  0.010473
# 7582   0.044780 -0.074579 -0.025775 -0.022203 -0.012583 -0.003432  0.012088
# 4625   0.046568 -0.084928 -0.012517 -0.023174  0.001471 -0.001228 -0.020728
# ...         ...       ...       ...       ...       ...       ...       ...
# 5680   0.012926 -0.054298 -0.018591  0.020354  0.024776 -0.015096 -0.047258
# 22362  0.083671 -0.068238 -0.024110 -0.003436  0.063956  0.005678 -0.046681
# 26489  0.112500 -0.015669 -0.019522  0.001867  0.014560  0.009811 -0.032503
# 21277  0.063781 -0.045069 -0.021233  0.004045  0.035538  0.013520 -0.060870
# 12871  0.069192  0.002381  0.001885  0.025675  0.030192 -0.010695 -0.005921
#
# ...

# %%
#from tensorflow.keras.utils import to_categorical

#y_train=to_categorical(y_train,3)

# %%
y_train
# Out:
#        predict
# 28636        0
# 5242         1
# 9597         0
# 7582         0
# 4625         0
# ...        ...
# 5680         0
# 22362        1
# 26489        1
# 21277        0
# 12871        0
#
# [28842 rows x 1 columns]

# %%
#x_train = tf.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
#test_x = tf.reshape(test_x,(test_x.shape[0],test_x.shape[1],1))
#print('변경된 차원 정보 :',x_train.shape)

# %%
print(x_train.shape)
# Out:
# (28842, 768)

# %%
x_train
# Out:
#               0         1         2         3         4         5         6  \
# 28636  0.057666 -0.048499 -0.015004 -0.008556  0.007480  0.004326 -0.044761
# 5242   0.084339 -0.016759 -0.002239  0.006603  0.034535 -0.000100 -0.025028
# 9597   0.048915 -0.082816 -0.022027 -0.036624 -0.009340  0.005210  0.010473
# 7582   0.044780 -0.074579 -0.025775 -0.022203 -0.012583 -0.003432  0.012088
# 4625   0.046568 -0.084928 -0.012517 -0.023174  0.001471 -0.001228 -0.020728
# ...         ...       ...       ...       ...       ...       ...       ...
# 5680   0.012926 -0.054298 -0.018591  0.020354  0.024776 -0.015096 -0.047258
# 22362  0.083671 -0.068238 -0.024110 -0.003436  0.063956  0.005678 -0.046681
# 26489  0.112500 -0.015669 -0.019522  0.001867  0.014560  0.009811 -0.032503
# 21277  0.063781 -0.045069 -0.021233  0.004045  0.035538  0.013520 -0.060870
# 12871  0.069192  0.002381  0.001885  0.025675  0.030192 -0.010695 -0.005921
#
# ...

# %%
print(test_x.shape)
# Out:
# (300, 768)

# %%
test_x
# Out:
#             0         1         2         3         4         5         6  \
# 114  0.132544 -0.035868 -0.020618  0.011402 -0.011060  0.016346 -0.047212
# 108  0.057914 -0.034599 -0.021505  0.009545  0.021648 -0.002444 -0.053997
# 74   0.106382 -0.019894 -0.019820  0.003348  0.044067  0.004019 -0.031345
# 61   0.099489 -0.063473 -0.022217  0.003446  0.008995  0.006556 -0.036373
# 34   0.074872 -0.011863  0.001483 -0.011409  0.041501  0.018303 -0.059321
# ..        ...       ...       ...       ...       ...       ...       ...
# 97   0.047481 -0.014559 -0.009955  0.019530  0.030867  0.009394 -0.095179
# 191  0.059719 -0.076216 -0.009168 -0.002351  0.008167  0.014102 -0.037567
# 35   0.016940 -0.083818  0.007729  0.000677 -0.009514 -0.020974 -0.028400
# 15   0.074838 -0.024917 -0.013993  0.014806  0.020463 -0.013092 -0.062031
# 290  0.033329 -0.087733 -0.034672 -0.021168  0.016734  0.004777 -0.043377
#
#             7         8         9  ...       758       759       760  \
# ...

# %% [markdown]
# ### Ensemble

# %%
import pickle
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn import svm

# %% [markdown]
# #### 분류 score 계산

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.model_selection import KFold

def score(pred, y_test):
    print(' accuracy  : ', accuracy_score(y_test, pred))
    print(' f1-score  : ', f1_score(y_test, pred,average='weighted'))
    print(' recall    : ', recall_score(y_test, pred,average='weighted'))
    print(' precision : ', precision_score(y_test, pred,average='weighted'))
    return accuracy_score(y_test, pred), f1_score(y_test, pred,average='weighted'), recall_score(y_test, pred,average='weighted'), precision_score(y_test, pred,average='weighted')

# %%
def result_append(score_result, scores):
    A=pd.DataFrame(scores, index=score_result.columns)
    print(A)
    for j in range(A.shape[0]):
        score_result.iloc[0,j]=A.iloc[j,0]
        
    
    return score_result

# %%
score_result = pd.DataFrame(index=range(1),columns=['logistic_Acc', 'logistic_F1', 'logistic_Rec', 'logistic_Pre',
                                     'naivebayes_Acc', 'naivebayes_F1', 'naivebayes_Rec', 'naivebayes_Pre',
                                     'Randomforest_Acc', 'Randomforest_F1', 'Randomforest_Rec', 'Randomforest_Pre',
                                     'XGBClassifier_ACC', 'XGBClassifier_F1', 'XGBClassifier_REC','XGBClassifier_Pre',
                                     'SVM_ACC', 'SVM_F1', 'SVM_REC', 'SVM_REC']
                                     
                                     )

# %%
score_result.columns
# Out:
# Index(['logistic_Acc', 'logistic_F1', 'logistic_Rec', 'logistic_Pre',
#        'naivebayes_Acc', 'naivebayes_F1', 'naivebayes_Rec', 'naivebayes_Pre',
#        'Randomforest_Acc', 'Randomforest_F1', 'Randomforest_Rec',
#        'Randomforest_Pre', 'XGBClassifier_ACC', 'XGBClassifier_F1',
#        'XGBClassifier_REC', 'XGBClassifier_Pre', 'SVM_ACC', 'SVM_F1',
#        'SVM_REC', 'SVM_REC'],
#       dtype='object')

# %%
def SVM(x_train, y_train, test_x, test_y):

    # 모델 분류 수행
    reg = svm.SVC(decision_function_shape='ovo')
    reg.fit(x_train, y_train)
    pred = reg.predict(test_x)
    pred

    # 분류 score 계산
    accuracy, f1_score, recall, precision = score(pred, test_y)
    return accuracy, f1_score, recall, precision

# %%
def xgb_clf(x_train, y_train, test_x, test_y):

    # 모델 분류 수행
    reg = XGBClassifier(random_state=42)
    reg.fit(x_train, y_train)
    pred = reg.predict(test_x)
    pred

    # 분류 score 계산
    accuracy, f1_score, recall, precision = score(pred, test_y)
    return accuracy, f1_score, recall, precision

# %%
def logistic_reg(x_train, y_train, test_x, test_y):

    # 모델 분류 수행
    reg = LogisticRegression(random_state=42, max_iter=500)
    reg.fit(x_train, y_train)
    pred = reg.predict(test_x)
    pred

    # 분류 score 계산
    accuracy, f1_score, recall, precision = score(pred, test_y)
    return accuracy, f1_score, recall, precision

# %%
def naivebayes_clf(x_train, y_train, test_x, test_y):

    # 모델 분류 수행
    gnb = GaussianNB()
    gnb.fit(x_train, y_train)
    pred = gnb.predict(test_x)


    # 분류 score 계산
    accuracy, f1_score, recall, precision = score(pred, test_y)
    return accuracy, f1_score, recall, precision

# %%
def randomforest_clf(x_train, y_train, test_x, test_y):

    # 모델 분류 수행
    clf = RandomForestClassifier(max_depth=16, random_state=42)
    clf.fit(x_train, y_train)
    pred = clf.predict(test_x)


    # 분류 score 계산
    accuracy, f1_score, recall, precision = score(pred, test_y)
    return accuracy, f1_score, recall, precision

# %%
def total_model(x_train,y_train,test_x,test_y):

    
    
    score_list = []
    
    

    # Logistic Regression
    print('      ----------    Logistic Regression Result    ----------      ')
    logi1, logi2, logi3, logi4 = logistic_reg(x_train, y_train, test_x,test_y)
    score_list += [logi1, logi2, logi3, logi4]


    # Naive Bayes Classification
    print('      ---------- Naive Bayes Classification Result ----------      ')
    naive1, naive2, naive3, naive4 = naivebayes_clf(x_train, y_train, test_x,test_y)
    score_list += [naive1, naive2, naive3, naive4]


    # RandomForest Classification
    print('      ---------- RandomForest Classifcation Result ----------      ')
    rf1, rf2, rf3, rf4 = randomforest_clf(x_train, y_train, test_x,test_y)
    score_list += [rf1, rf2, rf3, rf4]
    
    
    # XGBoost Classifier
    print('      ----------    XGBoost Classifier Result    ----------      ')
    xgb1, xgb2, xgb3, xgb4 = xgb_clf(x_train, y_train, test_x,test_y)
    score_list += [xgb1, xgb2, xgb3, xgb4]
    
    # SVM Classifier
    print('      ----------    SVM Classifier Result    ----------      ')
    svm1, svm2, svm3, svm4 = SVM(x_train, y_train, test_x,test_y)
    score_list += [svm1, svm2, svm3, svm4 ]


    
    return score_list

# %%
output = total_model(x_train,y_train,test_x,test_y)
score_result = result_append(score_result, output)
score_result=score_result.transpose()
# Out:
#       ----------    Logistic Regression Result    ----------
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  accuracy  :  0.9966666666666667
#  f1-score  :  0.9966644764901845
#  recall    :  0.9966666666666667
#  precision :  0.9966852886405959
#       ---------- Naive Bayes Classification Result ----------
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  accuracy  :  0.97
#  f1-score  :  0.9699386261977138
#  recall    :  0.97
#  precision :  0.970079390872371
#       ---------- RandomForest Classifcation Result ----------
# ...

# %%
score_result=score_result.rename(columns={0:'Score'})

# %%
score_result
# Out:
#                       Score
# logistic_Acc       0.996667
# logistic_F1        0.996664
# logistic_Rec       0.996667
# logistic_Pre       0.996685
# naivebayes_Acc         0.97
# naivebayes_F1      0.969939
# naivebayes_Rec         0.97
# naivebayes_Pre     0.970079
# Randomforest_Acc   0.996667
# Randomforest_F1    0.996664
# Randomforest_Rec   0.996667
# Randomforest_Pre   0.996685
# XGBClassifier_ACC       1.0
# XGBClassifier_F1        1.0
# XGBClassifier_REC       1.0
# XGBClassifier_Pre       1.0
# SVM_ACC            0.996667
# SVM_F1             0.996664
# SVM_REC            0.996667
# SVM_REC            0.996685

# %%
score_result.to_csv("ML Multi classification score.csv")
