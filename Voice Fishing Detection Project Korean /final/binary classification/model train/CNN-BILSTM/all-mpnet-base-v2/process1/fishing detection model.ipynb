# %%
import pandas as pd 

process1_train_row=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0521(final)/data/process/process1/NLP/all-mpnet-base-v2/train/process1 train data after nlp(base).csv")
process1_test_row=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0521(final)/data/process/process1/NLP/all-mpnet-base-v2/test/process1 test data after nlp(base).csv")

# %%
process1_train_row
# Out:
#        Unnamed: 0         0         1         2         3         4         5  \
# 0            8620  0.031141 -0.024905 -0.014686  0.013713  0.048568 -0.000297
# 1            6504  0.042042 -0.058869 -0.021062  0.007940  0.016243 -0.008747
# 2           10213  0.042427 -0.041382 -0.009650 -0.001418  0.035049  0.005404
# 3           16368  0.069545 -0.064686 -0.018986 -0.005506  0.015363 -0.004485
# 4            5504  0.055216 -0.021964 -0.037235  0.004305 -0.008598  0.007816
# ...           ...       ...       ...       ...       ...       ...       ...
# 24077        1629  0.059678 -0.019469 -0.001239  0.033039  0.056483  0.002684
# 24078       18451  0.077545 -0.050442 -0.025179  0.002435  0.020539 -0.005270
# 24079       12722  0.049521 -0.042754  0.012144  0.007339  0.036435  0.009288
# 24080       17958  0.071861 -0.060430 -0.025905 -0.004843  0.014553 -0.009150
# 24081        7067  0.024767 -0.024366 -0.029549  0.003504  0.014644 -0.002221
#
#               6         7         8  ...       759       760       761  \
# 0     -0.076064  0.051279  0.060631  ...  0.008782  0.017730 -0.024913
# 1      0.006296  0.014383  0.058583  ... -0.026977 -0.041494 -0.008822
# 2     -0.017717  0.016439 -0.000525  ... -0.018680 -0.067508  0.011138
# 3     -0.005226  0.002832  0.068258  ... -0.007478  0.000091  0.022763
# 4     -0.008300  0.024681  0.041541  ... -0.016971 -0.038213  0.008892
# ...         ...       ...       ...  ...       ...       ...       ...
# 24077 -0.082536  0.040453  0.076271  ... -0.011296  0.017051 -0.008498
# 24078 -0.021900  0.014242  0.065954  ... -0.004715  0.006110  0.017703
# 24079 -0.070911  0.031703  0.074243  ... -0.019681  0.022712 -0.011637
# 24080 -0.009275  0.013233  0.057288  ... -0.005703  0.003908  0.017028
# 24081 -0.033688  0.010264  0.073428  ... -0.032184 -0.010046 -0.010315
#
#             762       763       764       765       766       767  predict
# 0     -0.055763 -0.053375  0.016780  0.013943  0.040411 -0.031860      0.0
# 1     -0.024273  0.011414  0.013820  0.032365 -0.026040 -0.041349      1.0
# 2     -0.031594  0.002520 -0.013368  0.005618  0.032551 -0.016693      1.0
# 3     -0.045421 -0.068482 -0.002581  0.020759  0.018432 -0.017854      1.0
# 4     -0.032325 -0.026938  0.024946  0.030004  0.009447 -0.043597      1.0
# ...         ...       ...       ...       ...       ...       ...      ...
# 24077 -0.041097 -0.026772 -0.004972  0.023918  0.020927 -0.028353      0.0
# 24078 -0.041473 -0.065994 -0.003259  0.025954  0.034742 -0.018319      1.0
# 24079 -0.070254 -0.055841  0.018464  0.029039  0.016198 -0.034022      0.0
# 24080 -0.037993 -0.064335  0.005273  0.021538  0.028765 -0.023204      1.0
# 24081 -0.041404 -0.034450  0.007475  0.036230  0.015718 -0.029008      0.0
#
# [24082 rows x 770 columns]

# %%
process1_test_row
# Out:
#      Unnamed: 0         0         1         2         3         4         5  \
# 0            14  0.042143 -0.075863 -0.032787 -0.034326  0.003703  0.001564
# 1           192  0.093584 -0.010127 -0.029180  0.001598  0.000396 -0.002416
# 2           185  0.050962 -0.023021 -0.014449  0.000745  0.047686  0.019240
# ...         ...       ...       ...       ...       ...       ...       ...
# 24077  0.059678 -0.019469 -0.001239  0.033039  0.056483  0.002684 -0.082536
# 24078  0.077545 -0.050442 -0.025179  0.002435  0.020539 -0.005270 -0.021900
# 24079  0.049521 -0.042754  0.012144  0.007339  0.036435  0.009288 -0.070911
# 24080  0.071861 -0.060430 -0.025905 -0.004843  0.014553 -0.009150 -0.009275
# 24081  0.024767 -0.024366 -0.029549  0.003504  0.014644 -0.002221 -0.033688
#
#               7         8         9  ...       758       759       760  \
# 0      0.051279  0.060631 -0.002774  ... -0.042202  0.008782  0.017730
# 1      0.014383  0.058583  0.037385  ... -0.038968 -0.026977 -0.041494
# 2      0.016439 -0.000525 -0.030119  ... -0.019957 -0.018680 -0.067508
# 3      0.002832  0.068258 -0.025835  ...  0.001904 -0.007478  0.000091
# 4      0.024681  0.041541 -0.002053  ... -0.040639 -0.016971 -0.038213
# ...         ...       ...       ...  ...       ...       ...       ...
# 24077  0.040453  0.076271 -0.011522  ... -0.029330 -0.011296  0.017051
# 24078  0.014242  0.065954 -0.022793  ...  0.002921 -0.004715  0.006110
# 24079  0.031703  0.074243 -0.018008  ... -0.020254 -0.019681  0.022712
# 24080  0.013233  0.057288 -0.021524  ... -0.005361 -0.005703  0.003908
# 24081  0.010264  0.073428  0.001678  ... -0.049212 -0.032184 -0.010046
#
#             761       762       763       764       765       766       767
# 0     -0.024913 -0.055763 -0.053375  0.016780  0.013943  0.040411 -0.031860
# 1     -0.008822 -0.024273  0.011414  0.013820  0.032365 -0.026040 -0.041349
# 2      0.011138 -0.031594  0.002520 -0.013368  0.005618  0.032551 -0.016693
# 3      0.022763 -0.045421 -0.068482 -0.002581  0.020759  0.018432 -0.017854
# 4      0.008892 -0.032325 -0.026938  0.024946  0.030004  0.009447 -0.043597
# ...         ...       ...       ...       ...       ...       ...       ...
# 24077 -0.008498 -0.041097 -0.026772 -0.004972  0.023918  0.020927 -0.028353
# 24078  0.017703 -0.041473 -0.065994 -0.003259  0.025954  0.034742 -0.018319
# 24079 -0.011637 -0.070254 -0.055841  0.018464  0.029039  0.016198 -0.034022
# 24080  0.017028 -0.037993 -0.064335  0.005273  0.021538  0.028765 -0.023204
# 24081 -0.010315 -0.041404 -0.034450  0.007475  0.036230  0.015718 -0.029008
#
# [24082 rows x 768 columns]

# %%
process1_y_train
# Out:
#        predict
# 0          0.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# ...        ...
# 24077      0.0
# 24078      1.0
# 24079      0.0
# 24080      1.0
# 24081      0.0
#
# [24082 rows x 1 columns]

# %%
process1_x_test=process1_test_row
process1_x_test=process1_x_test.drop(columns=['predict'])
process1_x_test=process1_x_test.drop(columns=['Unnamed: 0'])
process1_y_test=pd.DataFrame(process1_test_row['predict'])

# %%
process1_x_test
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.042143 -0.075863 -0.032787 -0.034326  0.003703  0.001564  0.039880
# 1    0.093584 -0.010127 -0.029180  0.001598  0.000396 -0.002416 -0.017291
# 2    0.050962 -0.023021 -0.014449  0.000745  0.047686  0.019240 -0.090667
# 3    0.040677 -0.095884 -0.025877 -0.012860  0.006696 -0.012739 -0.006766
# 4    0.058986 -0.036946 -0.025480 -0.006198  0.014244  0.001092 -0.048714
# ..        ...       ...       ...       ...       ...       ...       ...
# 295  0.041226 -0.067227 -0.006068 -0.027994  0.037467  0.002795 -0.009585
# 296  0.067222 -0.054213 -0.030217 -0.014232 -0.004994  0.002410  0.036261
# 297  0.086307 -0.040818 -0.026465  0.009861  0.011541 -0.006450 -0.013623
# 298  0.027199 -0.035164 -0.005944  0.001627  0.024499 -0.003586 -0.070054
# 299  0.059343 -0.054728 -0.028986 -0.007379  0.010191 -0.007186 -0.000033
#
#             7         8         9  ...       758       759       760  \
# 0   -0.019157  0.063523 -0.016634  ... -0.044111 -0.055130 -0.023732
# 1    0.017797  0.082248 -0.023267  ...  0.020128 -0.024688 -0.003001
# 2    0.032218  0.092098  0.000602  ... -0.024641 -0.025599  0.024939
# 3   -0.010695  0.060887 -0.001010  ... -0.011329  0.023425 -0.033546
# 4    0.027927  0.056201 -0.013811  ... -0.029304 -0.026212 -0.034943
# ..        ...       ...       ...  ...       ...       ...       ...
# 295  0.007646  0.069293 -0.023132  ... -0.031851 -0.032661  0.026757
# 296 -0.024642  0.055866 -0.004851  ... -0.039482 -0.031071 -0.024941
# 297  0.010029  0.080842 -0.016113  ...  0.016179 -0.020386  0.010085
# 298  0.027453  0.049519 -0.012694  ... -0.051073 -0.041706  0.004206
# 299 -0.012047  0.056827  0.007245  ... -0.023774 -0.037772 -0.004522
#
#           761       762       763       764       765       766       767
# 0    0.026815 -0.030726 -0.047846  0.022260  0.011164  0.014285 -0.006380
# 1   -0.000911 -0.040665 -0.051432 -0.004543  0.049485  0.014501 -0.026474
# 2   -0.019021 -0.055165 -0.041121  0.018082  0.017464  0.031786 -0.027080
# 3    0.013293 -0.010766 -0.018231  0.005803  0.030830 -0.007609 -0.017670
# 4    0.002110 -0.013898 -0.040588  0.017561  0.022851  0.007250 -0.021191
# ..        ...       ...       ...       ...       ...       ...       ...
# 295  0.012142 -0.052688 -0.052194  0.015045  0.022258  0.021265 -0.022555
# 296  0.026737 -0.034270 -0.049872  0.028103  0.003819  0.005779 -0.035805
# 297  0.022582 -0.045778 -0.058397  0.004633  0.029271  0.002256 -0.021711
# 298 -0.017663 -0.041342 -0.057198  0.012646  0.030903  0.042105 -0.014678
# 299  0.006268 -0.046143 -0.037248  0.009444  0.022435  0.019140 -0.033461
#
# [300 rows x 768 columns]

# %%
process1_y_test
# Out:
#      predict
# 0        0.0
# 1        1.0
# 2        0.0
# 3        1.0
# 4        1.0
# ..       ...
# 295      0.0
# 296      0.0
# 297      1.0
# 298      0.0
# 299      0.0
#
# [300 rows x 1 columns]

# %%
print(process1_x_train.shape)
print(process1_y_train.shape)
print(process1_x_test.shape)
print(process1_y_test.shape)
# Out:
# (24082, 768)
# (24082, 1)
# (300, 768)
# (300, 1)

# %%
import tensorflow as tf

x_train = tf.reshape(process1_x_train,(process1_x_train.shape[0],process1_x_train.shape[1],1))
test_x = tf.reshape(process1_x_test,(process1_x_test.shape[0],process1_x_test.shape[1],1))

# %%
print(x_train.shape)
print(process1_y_train.shape)
print(test_x.shape)
print(process1_y_test.shape)
# Out:
# (24082, 768, 1)
# (24082, 1)
# (300, 768, 1)
# (300, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, Bidirectional, Conv1D, MaxPooling1D, Flatten
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint,LearningRateScheduler
import tensorflow as tf
from tensorflow.keras.activations import elu



def lr_schedule(epoch, lr):
    if epoch > 5:
        return float(lr * tf.math.exp(-0.1))  
    return float(lr)  

fishing_detection_model = tf.keras.Sequential()
# 입력층 - 1D CNN
fishing_detection_model.add(Conv1D(filters=128, kernel_size=3, activation='elu', input_shape=(x_train.shape[1], x_train.shape[2])))
fishing_detection_model.add(Conv1D(filters=64, kernel_size=3, activation='elu'))
fishing_detection_model.add(Conv1D(filters=32, kernel_size=3, activation='elu'))
fishing_detection_model.add(MaxPooling1D(pool_size=2))
fishing_detection_model.add(Dropout(0.5))
# 추가 CNN 층
fishing_detection_model.add(Conv1D(filters=64, kernel_size=3, activation='elu'))
fishing_detection_model.add(Conv1D(filters=32, kernel_size=3, activation='elu'))
fishing_detection_model.add(MaxPooling1D(pool_size=2))
fishing_detection_model.add(Dropout(0.5))
# 중간층 - LSTM
fishing_detection_model.add(Bidirectional(LSTM(64, return_sequences=True)))
fishing_detection_model.add(Bidirectional(LSTM(32, return_sequences=True)))
fishing_detection_model.add(Bidirectional(LSTM(16, return_sequences=False)))
fishing_detection_model.add(Dropout(0.5))
# 추가 Dense 층
fishing_detection_model.add(Dense(32, activation='elu'))
fishing_detection_model.add(Dropout(0.5))
# 출력층
fishing_detection_model.add(Dense(1, activation='sigmoid'))

# 최적화 알고리즘과 손실 함수 설정
fishing_detection_model.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Early Stopping과 fishing_detection_model Checkpoint 적용
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('best_fishing_detection_model.keras', save_best_only=True)
lr_scheduler = LearningRateScheduler(lr_schedule)

fishing_detection_model.summary()
# Out:
# /opt/anaconda3/envs/conda_cpu/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_5 (Conv1D)               │ (None, 766, 128)       │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 764, 64)        │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 762, 32)        │         6,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 381, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 381, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 379, 64)        │         6,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_9 (Conv1D)               │ (None, 377, 32)        │         6,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 188, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 188, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_3 (Bidirectional) │ (None, 188, 128)       │        49,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_4 (Bidirectional) │ (None, 188, 64)        │        41,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_5 (Bidirectional) │ (None, 32)             │        10,368 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 146,049 (570.50 KB)
#  Trainable params: 146,049 (570.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
training_record = fishing_detection_model.fit(x_train, process1_y_train,
                    epochs=50,
                    batch_size=250,
                    callbacks=[early_stopping, model_checkpoint,lr_scheduler],
                    validation_split=0.3,
                    shuffle=True)
# Out:
# Epoch 1/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 41s 557ms/step - accuracy: 0.5399 - loss: 0.6808 - val_accuracy: 0.8270 - val_loss: 0.3844
# Epoch 2/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 41s 598ms/step - accuracy: 0.8531 - loss: 0.3415 - val_accuracy: 0.9448 - val_loss: 0.1476
# Epoch 3/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 43s 630ms/step - accuracy: 0.9390 - loss: 0.1805 - val_accuracy: 0.9737 - val_loss: 0.0826
# Epoch 4/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 43s 630ms/step - accuracy: 0.9585 - loss: 0.1261 - val_accuracy: 0.9824 - val_loss: 0.0624
# Epoch 5/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 46s 672ms/step - accuracy: 0.9677 - loss: 0.0995 - val_accuracy: 0.9816 - val_loss: 0.0567
# Epoch 6/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 44s 644ms/step - accuracy: 0.9741 - loss: 0.0852 - val_accuracy: 0.9833 - val_loss: 0.0521
# Epoch 7/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 47s 691ms/step - accuracy: 0.9740 - loss: 0.0787 - val_accuracy: 0.9851 - val_loss: 0.0480
# Epoch 8/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 46s 673ms/step - accuracy: 0.9765 - loss: 0.0743 - val_accuracy: 0.9862 - val_loss: 0.0467
# Epoch 9/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 45s 663ms/step - accuracy: 0.9784 - loss: 0.0708 - val_accuracy: 0.9870 - val_loss: 0.0429
# Epoch 10/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 46s 678ms/step - accuracy: 0.9805 - loss: 0.0647 - val_accuracy: 0.9880 - val_loss: 0.0426
# Epoch 11/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 45s 657ms/step - accuracy: 0.9805 - loss: 0.0598 - val_accuracy: 0.9869 - val_loss: 0.0445
# Epoch 12/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 44s 646ms/step - accuracy: 0.9824 - loss: 0.0588 - val_accuracy: 0.9892 - val_loss: 0.0351
# Epoch 13/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 46s
50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 47s 690ms/step - accuracy: 0.9931 - loss: 0.0229 - val_accuracy: 0.9934 - val_loss: 0.0231
# Epoch 40/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 44s 654ms/step - accuracy: 0.9914 - loss: 0.0252 - val_accuracy: 0.9916 - val_loss: 0.0260
# Epoch 41/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 45s 661ms/step - accuracy: 0.9942 - loss: 0.0172 - val_accuracy: 0.9953 - val_loss: 0.0166
# Epoch 42/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 45s 660ms/step - accuracy: 0.9925 - loss: 0.0239 - val_accuracy: 0.9934 - val_loss: 0.0244
# Epoch 43/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 45s 670ms/step - accuracy: 0.9934 - loss: 0.0208 - val_accuracy: 0.9958 - val_loss: 0.0173
# Epoch 44/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 47s 695ms/step - accuracy: 0.9928 - loss: 0.0214 - val_accuracy: 0.9909 - val_loss: 0.0314
# Epoch 45/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 44s 653ms/step - accuracy: 0.9923 - loss: 0.0234 - val_accuracy: 0.9929 - val_loss: 0.0245
# Epoch 46/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 46s 684ms/step - accuracy: 0.9935 - loss: 0.0191 - val_accuracy: 0.9960 - val_loss: 0.0154
# Epoch 47/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 46s 673ms/step - accuracy: 0.9930 - loss: 0.0222 - val_accuracy: 0.9935 - val_loss: 0.0286
# Epoch 48/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 45s 668ms/step - accuracy: 0.9859 - loss: 0.0418 - val_accuracy: 0.9942 - val_loss: 0.0237
# Epoch 49/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 46s 682ms/step - accuracy: 0.9928 - loss: 0.0209 - val_accuracy: 0.9960 - val_loss: 0.0184
# Epoch 50/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 45s 664ms/step - accuracy: 0.9927 - loss: 0.0209 - val_accuracy: 0.9910 - val_loss: 0.0360

# %%
fishing_detection_model.save('fishing_detection_model(base).keras')

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(8, 6))
plt.plot(training_record.history['loss'], label='train loss')
plt.plot(training_record.history['val_loss'], label='val loss')
plt.title('train and val loss')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
y_pred = fishing_detection_model.predict(test_x).ravel()
fpr, tpr, thresholds = roc_curve(process1_y_test, y_pred)
auc_value = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'AUC = {auc_value:.2f}')
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step

# %%
precision, recall, _ = precision_recall_curve(process1_y_test, y_pred)
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label='precision-recall curve')
plt.title('PRC Curve')
plt.xlabel('Recall')
plt.ylabel('Precisio')
plt.legend(loc='lower left')
plt.show()

# %%
y_pred_binary = np.where(y_pred > 0.5, 1, 0)  
accuracy = accuracy_score(process1_y_test, y_pred_binary)
print(f'accuracy score: {accuracy:.2f}')
# Out:
# accuracy score: 1.00

# %%
cm = confusion_matrix(process1_y_test, y_pred_binary)
fig, ax = plt.subplots(figsize=(6, 6))
cax = ax.matshow(cm, cmap=plt.cm.Blues)
fig.colorbar(cax)
plt.title('confusion matrix')
plt.xlabel('prediction value')
plt.ylabel('real value')
plt.xticks([0, 1], ['0', '1'])
plt.yticks([0, 1], ['0', '1'])
for (i, j), val in np.ndenumerate(cm):
    ax.text(j, i, f'{val}', ha='center', va='center')
plt.show()

# %%
print(classification_report(process1_y_test, y_pred_binary))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       165
#          1.0       1.00      1.00      1.00       135
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300
