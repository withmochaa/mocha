# %%
import pandas as pd

금융_data_row=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0410/fishing/row sentence/대출형 보이스피싱.csv",index_col=0)
기관_data_row=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0410/fishing/row sentence/기관 사칭형 보이스피싱.csv",index_col=0)

# %%
금융_data_row
# Out:
#                                                sentence
# 0                                     '어저께 통화했던 최영환입니다'
# 1      '어떻게 가진행 결과 안내차 오늘 아침에 전화 드린다고 제가 얘기를 했었는데 어떻...
# 2              '일단 최대한도는 고객님 신청하신 최대 한도는 3천만원까지 가능하시고요'
# 3                       '금리는 연 금리 5.5%에 상환 기간 60개월입니다.'
# 4      '매 월 상환하시는 금액은 60개월 기준 원금 이자 포함되신 금액으로 573035...
# ...                                                 ...
# 3472                                        '너무 많아가지고 '
# 3473                              '네 대부업건 어디어디 이용중이세요?'
# 3474                         '얼만지 제가 한번 보고 전화를 한번 드릴게요'
# 3475                                        '아 네 알겠습니다'
# 3476                              '그 바로 연락 한번 좀 부탁드릴게요'
#
# [3477 rows x 1 columns]

# %%
기관_data_row
# Out:
#                                                sentence
# 0                 ['아 서울 중앙 지검 첨단 범죄 수사 일부 이희나 수사관입니다.'
# 1      '본 사건 조사는 법원 증거 제출용으로 이뤄지고 있으신데 녹취 조사 과정에서 허위...
# 2                 형사상 책임이 있으시니 사실에 입각하여 진실로 좀 하셔야 됩니다.'
# 3                          '네 OOO씨 지금 제가 본인 확인 한번 할께요.'
# 4                        '생년월일 앞에 여섯 자리만 말씀 부탁 드리겠습니다.'
# ...                                                 ...
# 8427                   '그 본인 말고도 180명이 넘게 연루된 사건이다 보니까'
# 8428   '찾아오시는 분들이 많기 때문에 저희가 일방적으로 오라고 말씀드릴 수 없기 때문에...
# 8429                   '그러면은 문자로 관련 내용 간단하게 요약해서 보내주세요'
# 8430                           '예 그 본인 자택으로 서류 보내드릴게요.'
# 8431   '그 문자 말고 그 확인하시고 읽어보신 다음에 이해 안 가는 부분 있으시면 다시 ...
#
# [8432 rows x 1 columns]

# %%
y=pd.DataFrame(index=range(금융_data_row.shape[0]),columns=['predict'])

# %%
y=y.fillna('0')

# %%
금융_data=pd.concat([금융_data_row,y],axis=1)

# %%
금융_data
# Out:
#                                                sentence predict
# 0                                     '어저께 통화했던 최영환입니다'       0
# 1      '어떻게 가진행 결과 안내차 오늘 아침에 전화 드린다고 제가 얘기를 했었는데 어떻...       0
# 2              '일단 최대한도는 고객님 신청하신 최대 한도는 3천만원까지 가능하시고요'       0
# 3                       '금리는 연 금리 5.5%에 상환 기간 60개월입니다.'       0
# 4      '매 월 상환하시는 금액은 60개월 기준 원금 이자 포함되신 금액으로 573035...       0
# ...                                                 ...     ...
# 3472                                        '너무 많아가지고 '       0
# 3473                              '네 대부업건 어디어디 이용중이세요?'       0
# 3474                         '얼만지 제가 한번 보고 전화를 한번 드릴게요'       0
# 3475                                        '아 네 알겠습니다'       0
# 3476                              '그 바로 연락 한번 좀 부탁드릴게요'       0
#
# [3477 rows x 2 columns]

# %%
y=pd.DataFrame(index=range(기관_data_row.shape[0]),columns=['predict'])

# %%
y=y.fillna('1')

# %%
기관_data=pd.concat([기관_data_row,y],axis=1)

# %%
기관_data=기관_data.drop(index=range(3500,기관_data.shape[0]))

# %%
기관_data
# Out:
#                                                sentence predict
# 0                 ['아 서울 중앙 지검 첨단 범죄 수사 일부 이희나 수사관입니다.'       1
# 1      '본 사건 조사는 법원 증거 제출용으로 이뤄지고 있으신데 녹취 조사 과정에서 허위...       1
# 2                 형사상 책임이 있으시니 사실에 입각하여 진실로 좀 하셔야 됩니다.'       1
# 3                          '네 OOO씨 지금 제가 본인 확인 한번 할께요.'       1
# 4                        '생년월일 앞에 여섯 자리만 말씀 부탁 드리겠습니다.'       1
# ...                                                 ...     ...
# 3495     '본인이 만약에 그요 부채 정리되면은 한 일주일에 좀 받으셔도 한번 억울하시겠어요'       1
# 3496                     '제가 공문으로 나와 있기 때문에 설명을 드린 거예요'       1
# 3497                              '그 밑에 상세 조회하기가 보이시죠.'       1
# 3498       '아 그러니까 합산해서 다시 한번 제가 상환 좀 이렇게 한 건이 포함이 어차피'       1
# 3499             '그렇쵸 제 우리가 녹취하는 부분에서 본인한테 조사가 다 끝났습니다'       1
#
# [3500 rows x 2 columns]

# %%
data=pd.concat([금융_data,기관_data])

# %%
data
# Out:
#                                                sentence predict
# 0                                     '어저께 통화했던 최영환입니다'       0
# 1      '어떻게 가진행 결과 안내차 오늘 아침에 전화 드린다고 제가 얘기를 했었는데 어떻...       0
# 2              '일단 최대한도는 고객님 신청하신 최대 한도는 3천만원까지 가능하시고요'       0
# 3                       '금리는 연 금리 5.5%에 상환 기간 60개월입니다.'       0
# 4      '매 월 상환하시는 금액은 60개월 기준 원금 이자 포함되신 금액으로 573035...       0
# ...                                                 ...     ...
# 3495     '본인이 만약에 그요 부채 정리되면은 한 일주일에 좀 받으셔도 한번 억울하시겠어요'       1
# 3496                     '제가 공문으로 나와 있기 때문에 설명을 드린 거예요'       1
# 3497                              '그 밑에 상세 조회하기가 보이시죠.'       1
# 3498       '아 그러니까 합산해서 다시 한번 제가 상환 좀 이렇게 한 건이 포함이 어차피'       1
# 3499             '그렇쵸 제 우리가 녹취하는 부분에서 본인한테 조사가 다 끝났습니다'       1
#
# [6977 rows x 2 columns]

# %%
data=data.sample(frac=1)

# %%
data
# Out:
#                                                sentence predict
# 14     '다만 OOO님도 개인 정보 유출로 인해 명의 도용 피해자 일 수 있기 때문에 저...       1
# 2121                                     '아 그렇게는 안되구요.'       0
# 2048                               '방문을 해달라고 하신 거 아니에요'       0
# 1810                        '아 뭐 혹시 온라인에서 가입하신적은 없으세요?'       0
# 1789                                 '고객센터에서 알아보신 건가요?'       0
# ...                                                 ...     ...
# 2900                                       '무슨소리하시는거죠?'       0
# 1281                                  '어저께 통화했던 최영환입니다'       0
# 770                                    마지막에 점은 안 찍습니다.'       1
# 676                                     '아휴 그럼 어떻게 해요.'       0
# 86                        '심사자료 정리를 바로 진행 진행 도와드리겠습니다.'       0
#
# [6977 rows x 2 columns]

# %%
x_train=pd.DataFrame(data['sentence'])

# %%
x_train
# Out:
#                                                sentence
# 14     '다만 OOO님도 개인 정보 유출로 인해 명의 도용 피해자 일 수 있기 때문에 저...
# 2121                                     '아 그렇게는 안되구요.'
# 2048                               '방문을 해달라고 하신 거 아니에요'
# 1810                        '아 뭐 혹시 온라인에서 가입하신적은 없으세요?'
# 1789                                 '고객센터에서 알아보신 건가요?'
# ...                                                 ...
# 2900                                       '무슨소리하시는거죠?'
# 1281                                  '어저께 통화했던 최영환입니다'
# 770                                    마지막에 점은 안 찍습니다.'
# 676                                     '아휴 그럼 어떻게 해요.'
# 86                        '심사자료 정리를 바로 진행 진행 도와드리겠습니다.'
#
# [6977 rows x 1 columns]

# %%
y_train=pd.DataFrame(data['predict'])

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

# %%
A=model.encode(data.iloc[0,0])
list=[]

for i in range(A.shape[0]):
    list.append(i)

# %%
x=pd.DataFrame(index=range(0,x_train.shape[0]),columns=list)

# %%
y=pd.DataFrame(index=range(0,y_train.shape[0]),columns=['predict'])

# %%
y_train
# Out:
#      predict
# 14         1
# 2121       0
# 2048       0
# 1810       0
# 1789       0
# ...      ...
# 2900       0
# 1281       0
# 770        1
# 676        0
# 86         0
#
# [6977 rows x 1 columns]

# %%
for i in range(y_train.shape[0]):
    y.iloc[i,0]=y_train.iloc[i,0]

# %%
#x=pd.read_csv("/Users/withmocha/Desktop/VisualStudioCode/Capstone Design project/Voice Fishing/Team meeting/0417/보이스피싱 라벨별 데이터 분석/x.csv",index_col=0)

# %%
for i in range(x_train.shape[0]):
    vector=[]
    vector=model.encode(x_train.iloc[i,0])
    for j in range(x.shape[1]):
        x.iloc[i,j]=vector[j]

# %%
x
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.021538  0.016558   0.07201  0.024721  -0.01973 -0.055824  0.015536
# 1    -0.026874  0.103987  0.028535 -0.001971  0.000481 -0.047561   0.16753
# 2    -0.028162  0.094818  0.071283 -0.024093 -0.011169 -0.035908  0.168753
# 3    -0.038371  0.076193  0.063185 -0.002009 -0.027921 -0.053045  0.092869
# 4     0.015408  0.093628  0.008939 -0.031333 -0.015152 -0.050496   0.09159
# ...        ...       ...       ...       ...       ...       ...       ...
# 6972 -0.007047  0.080885  0.059929 -0.031884  0.012433  0.017958  0.114592
# 6973   0.02018  0.072283  0.061851  0.062299  0.017337 -0.004081  0.159776
# 6974 -0.027081  0.085688   0.06672 -0.030813  0.026943  0.002418  0.187022
# 6975 -0.012367  0.049841  0.000483 -0.046556 -0.035161 -0.038988  0.076825
# 6976 -0.069183  0.110109 -0.012536 -0.027805  0.014457  -0.07138  0.066368
#
# ...

# %%
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,shuffle=True)

# %%
x_train
# Out:
#            0         1         2         3         4         5         6    \
# 1314  0.035295  0.018444   0.08148  0.002414 -0.064559 -0.043407  0.029145
# 394  -0.036857  0.087197  0.022499 -0.083699   0.03575 -0.043638  0.117997
# 1020 -0.021056   0.12856   0.04216  0.000312  0.054215 -0.041885  0.102134
# 4223 -0.038914  0.099699  0.077106 -0.038491  0.005559 -0.089504  0.065918
# 3420  0.016136  0.048237 -0.007477 -0.049738 -0.029354 -0.063708  0.037175
# ...        ...       ...       ...       ...       ...       ...       ...
# 3327 -0.024207  0.065113  0.083874 -0.048468  0.043529 -0.041132  0.139135
# 5241  0.025296  0.044542  0.036416 -0.000875 -0.058857 -0.097325  0.029026
# 5774 -0.037982  0.081284  0.083076   0.01154 -0.024502 -0.020248  0.146902
# 4130  -0.02066  0.102189 -0.002937 -0.002611 -0.003184 -0.034876   0.07498
# 6597 -0.015997  0.098672  0.056798 -0.010838   0.04547  0.019676  0.166518
#
# ...

# %%
x_train.shape
# Out:
# (5581, 384)

# %%
x_train = x_train.astype(np.float32)
x_test = x_test.astype(np.float32)

# %%
x_train = tf.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
x_test = tf.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))
print('변경된 차원 정보 :',x_train.shape)
# Out:
# 변경된 차원 정보 : (5581, 384, 1)

# %%
y_test
# Out:
#      predict
# 2557       1
# 672        1
# 5810       0
# 4556       1
# 1466       1
# ...      ...
# 2850       1
# 2332       0
# 6732       0
# 3338       1
# 6781       1
#
# [1396 rows x 1 columns]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dropout, Dense, LSTM, Bidirectional, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf

model = Sequential()
# 입력층 - 1D CNN
model.add(Conv1D(filters=128, kernel_size=3, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(BatchNormalization())  
model.add(tf.keras.layers.Activation('relu'))
model.add(Conv1D(filters=64, kernel_size=3))
model.add(BatchNormalization())  
model.add(tf.keras.layers.Activation('relu'))
model.add(Conv1D(filters=32, kernel_size=3))
model.add(BatchNormalization())  
model.add(tf.keras.layers.Activation('relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.2))
# 추가 CNN 층
#model.add(Conv1D(filters=32, kernel_size=3))
#model.add(BatchNormalization())  
#model.add(tf.keras.layers.Activation('relu'))
#model.add(Conv1D(filters=16, kernel_size=3))
#model.add(BatchNormalization())  
#model.add(tf.keras.layers.Activation('relu'))
#model.add(MaxPooling1D(pool_size=2))
#model.add(Dropout(0.2))
# 중간층 - LSTM
model.add(Bidirectional(LSTM(64, return_sequences=True)))
model.add(Bidirectional(LSTM(32, return_sequences=True)))
model.add(Bidirectional(LSTM(16, return_sequences=False)))
model.add(Dropout(0.5))
# 추가 Dense 층
model.add(Dense(64))
model.add(BatchNormalization())  
model.add(tf.keras.layers.Activation('relu'))
model.add(Dropout(0.5))
# 출력층
model.add(Dense(1, activation='sigmoid'))

# 최적화 알고리즘과 손실 함수 설정
model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Early Stopping과 Model Checkpoint 적용
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True)

model.summary()
# Out:
# 2024-04-17 12:42:07.031135: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-17 12:42:07.032922: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# ...

# %%
y_train=y_train.astype("float")
y_test=y_test.astype("float")

# %%
y_train
# Out:
#       predict
# 1314      0.0
# 394       1.0
# 1020      1.0
# 4223      0.0
# 3420      1.0
# ...       ...
# 3327      1.0
# 5241      1.0
# 5774      1.0
# 4130      0.0
# 6597      1.0
#
# [5581 rows x 1 columns]

# %%
training_record = model.fit(x_train, y_train,
                    epochs=50,
                    batch_size=4,
                    callbacks=[early_stopping, model_checkpoint],
                    validation_split=0.2,
                    shuffle=True)
# Out:
# Epoch 1/50
# 2024-04-17 12:42:07.489356: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2024-04-17 12:42:07.672809: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-04-17 12:42:07.673789: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# ...

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
plt.plot(training_record.history["loss"], label="Training Loss")
plt.plot(training_record.history["val_loss"], label="Validation Loss")
plt.legend()
fig.suptitle("Loss")
plt.show()

# %%
pred = model.predict(x_test)
# Out:
# 44/44 [==============================] - 1s 30ms/step

# %%
pred
# Out:
# array([[0.22103477],
#        [0.90034735],
#        [0.08404927],
#        ...,
#        [0.07600437],
#        [0.98716545],
#        [0.43625978]], dtype=float32)

# %%
y_test
# Out:
#       predict
# 2557      1.0
# 672       1.0
# 5810      0.0
# 4556      1.0
# 1466      1.0
# ...       ...
# 2850      1.0
# 2332      0.0
# 6732      0.0
# 3338      1.0
# 6781      1.0
#
# [1396 rows x 1 columns]

# %%
predictions=np.array(pred)
predictions = (predictions > 0.5).astype(float)
predictions=predictions.reshape(-1,1)

# %%
predictions
# Out:
# array([[0.],
#        [1.],
#        [0.],
#        ...,
#        [0.],
#        [1.],
#        [0.]])

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve, roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle


# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, predictions)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(10, 5))

# ROC Curve 그리기
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.legend(loc="lower right")

# %%
# Precision-Recall Curve
from sklearn.metrics import average_precision_score
precision, recall, _ = precision_recall_curve(y_test, predictions)
average_precision = average_precision_score(y_test, predictions)

# PR Curve 그리기
plt.subplot(1, 2, 2)
plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve (area = %0.2f)' % average_precision)
plt.fill_between(recall, precision, step='post', alpha=0.2, color='blue')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('PRC')
plt.legend(loc="lower left")

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score
print('CNN-BiLSTM 2 class Classfication의 정확도는: {0:.4f}'.format(accuracy_score(y_test, predictions)))
# Out:
# CNN-BiLSTM 2 class Classfication의 정확도는: 0.9069

# %%
from sklearn.metrics import confusion_matrix, classification_report

# 혼동 행렬 및 분류 보고서 출력
print('혼동 행렬:')
print(confusion_matrix(y_test, predictions))
# Out:
# 혼동 행렬:
# [[694   9]
#  [121 572]]

# %%
print('분류 보고서:')
report=classification_report(y_test, predictions)
print(report)
# Out:
# 분류 보고서:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.99      0.91       703
#          1.0       0.98      0.83      0.90       693
#
#     accuracy                           0.91      1396
#    macro avg       0.92      0.91      0.91      1396
# weighted avg       0.92      0.91      0.91      1396

# %%
model.save('CNN-BILSTM보이스피싱 유형별 탐지 model.h5')

# %%
with open("CNN-BILSTM보이스피싱 유형별 탐지 model output.txt", "w") as text_file:
    print(classification_report(y_test, predictions,digits=4), file=text_file)
