# %%
import pandas as pd

data_ab1=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0521(final)/data/abnormal/대출사기/대출 사기형 보이스피싱(augmentation).csv",index_col=0)
data_ab2=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0521(final)/data/abnormal/기관사칭/기관 사칭형 보이스피싱(augmentation)).csv",index_col=0)

# %%
data_ab1['predict']=0

# %%
data_ab2['predict']=1

# %%
data_ab=pd.concat([data_ab1,data_ab2])

# %%
data_ab
# Out:
#                                                sentence  predict
# 0                        여보세요 네   님 예 예 어저께 통화했던 최영환입니다        0
# 1      아 예 예 어떻게 가진행 결과 안내차 오늘 아침에 전화 드린다고 제가 얘기를 했었...        0
# 2               네 금리는 연 금리 5.5%에 상환 기간 60개월입니다. 5년이고요 네        0
# 3      매 월 상환하시는 금액은 60개월 기준 원금 이자 포함되신 금액으로 573035원...        0
# 4                             금리가 아 예 예 예. 말씀하세요 괜찮으세요?        0
# ...                                                 ...      ...
# 1495   네. 근데 어딜 가야하나요? 제가? 아 어딜 가는게 아니라 제가 사건도 내용을 좀...        1
# 1496   그때 제가 절차 다 질문 드리면 본인께서는 아시는 대로 진술을 해주시면 되는겁니다...        1
# 1497   사건고지 좀 더 해 드리겠습니다. 또한 이번에 검거된 범인들 다수가 카드사 보험사...        1
# 1498   김태환이란 사람은 농협에서 8년 간 과장으로 근무한 경력이 확인되었어요. 현재 이...        1
# 1499   많게는 1500만까지 받고 통장 판매한 사실이 확인되었습니다. 판매하신 50 여명...        1
#
# [23868 rows x 2 columns]

# %%
data_ab=data_ab.sample(frac=1)

# %%
data_ab
# Out:
#                                                sentence  predict
# 3498   대출 승인 나셨을 경우에 대출금 송금 받아 보실 수 있는 은행 은행 계좌 한번 부...        0
# 855    그냥 전화 누르면 전화 갑니까? 1588 2114 하시고 통화 누르시면 됩니다. ...        1
# 925    무슨소리하시는거죠? 지금 그 입출금 입출금 계좌 제가 신고 해놨거든요? 네 입출금...        0
# 1213   음 재정 입금하기 바로 되고요? 그렇죠. 당일로도 가능하시고 다만 위임 처리하실 ...        0
# 6087   아 뭐 통장 전화숫자는 안 필요한가 그거는 이제 등록하고 뭐 여쭤봐야죠? 지금 다...        0
# ...                                                 ...      ...
# 9303   그럼? 됐습니다 그럼 공증을 지금 저희가 해드릴 수 있는 담보물이 있어요? 아휴 ...        1
# 6268   지금 다짜고짜 여쭤보면 어떡합니까? 고객님 ID도 접수도 안 해줬는데 그냥 아이디...        1
# 2329   위임 처리하시면 당일로도 가능하시고 위임을 하면 어떻게 되요? 위임하실 경우에는 ...        0
# 3763   아 아. 왜냐면 솔직히 이게 보이스속임수 공격 같기도 하고 20만원 큰 자본도 아...        1
# 3298   아 그렇게는 안되구요. 그러면은 저희가 이제 따로 수납 처리 안 받고 공증을 직접...        1
#
# [23868 rows x 2 columns]

# %%
process2_train_data=data_ab[300:]
process2_test_data=data_ab[:300]

# %%
process2_train_data
# Out:
#                                                 sentence  predict
# 1402    아 네 안녕하세요 저희 그 하나캐피탈에서 연락을 드렸습니다 아 그래요? 네네네 고...        0
# 10003   다른거 필요한 건 없나요? 뭐 추가적인 접수는 없으세요 아 뭐 통장 식별숫자는 안...        0
# 339     아 아. 왜냐면 솔직히 이게 보이스보이스피싱 공격 같기도 하고 20만원 큰 자본도...        0
# 6954    아 그래요? 네네네 고객님께서 이제 중개업체쪽에서 필요 자금 부분 신청하신 건 때...        1
# 3939    수납 담당자님 사용자 계정 숫자는 바로 카카오톡으로 보내드릴거구요. 수납 가능하신...        0
# ...                                                  ...      ...
# 9303    그럼? 됐습니다 그럼 공증을 지금 저희가 해드릴 수 있는 담보물이 있어요? 아휴 ...        1
# 6268    지금 다짜고짜 여쭤보면 어떡합니까? 고객님 ID도 접수도 안 해줬는데 그냥 아이디...        1
# 2329    위임 처리하시면 당일로도 가능하시고 위임을 하면 어떻게 되요? 위임하실 경우에는 ...        0
# 3763    아 아. 왜냐면 솔직히 이게 보이스속임수 공격 같기도 하고 20만원 큰 자본도 아...        1
# 3298    아 그렇게는 안되구요. 그러면은 저희가 이제 따로 수납 처리 안 받고 공증을 직접...        1
#
# [23568 rows x 2 columns]

# %%
process2_test_data
# Out:
#                                                 sentence  predict
# 3498    대출 승인 나셨을 경우에 대출금 송금 받아 보실 수 있는 은행 은행 계좌 한번 부...        0
# 855     그냥 전화 누르면 전화 갑니까? 1588 2114 하시고 통화 누르시면 됩니다. ...        1
# 925     무슨소리하시는거죠? 지금 그 입출금 입출금 계좌 제가 신고 해놨거든요? 네 입출금...        0
# 1213    음 재정 입금하기 바로 되고요? 그렇죠. 당일로도 가능하시고 다만 위임 처리하실 ...        0
# 6087    아 뭐 통장 전화숫자는 안 필요한가 그거는 이제 등록하고 뭐 여쭤봐야죠? 지금 다...        0
# ...                                                  ...      ...
# 655     피해자 :\u3000네 본인 입출금으로 이제 해지 보신 거 지금 예금 잔액이 있으...        1
# 5581    다른사람한테 피해주지 마시구요 그러다 벌받아요 무슨소리하시는거죠? 지금 그 로그인...        0
# 549                            보냈거든요 아 예. 아 왔네요. 지금 왔네요.        0
# 10351        네 입출금 입출금 계좌에 금액을 다 빼가셨더라고요 바로?네 여보세요? 여보세요        1
# 4319    네 다름이 아니구요 사장님께서 혹시 안쓰시는 로그인 계정가 있으시면 저희가 월 4...        0
#
# [300 rows x 2 columns]

# %%
process2_train_data.to_csv("process2 train data row.csv")
process2_test_data.to_csv("process2 test data row.csv")
