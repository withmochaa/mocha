# %%
import pandas as pd

data_row=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0504/no gpt/NO gpt train data.csv",index_col=0)

data_row
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.052607 -0.053146 -0.012321 -0.014028  0.006890 -0.004457 -0.028779
# 1     0.065640 -0.056633 -0.012326 -0.016592 -0.000792  0.000747 -0.054616
# 2     0.069203  0.005305 -0.026596  0.008959  0.006379  0.003055 -0.019259
# 3     0.048832 -0.030371 -0.013756 -0.014487  0.036973  0.022373 -0.071002
# 4     0.046536 -0.022251 -0.027004  0.025981  0.022376 -0.013689 -0.050305
# ...        ...       ...       ...       ...       ...       ...       ...
# 2995  0.103314 -0.055173 -0.020592  0.040117  0.033047  0.013462 -0.041553
# 2996  0.067874 -0.063887 -0.029778 -0.007054  0.036702 -0.005829 -0.014136
# 2997  0.050919 -0.081113 -0.025674 -0.021389 -0.005436 -0.005959  0.013455
# 2998  0.033868 -0.028757 -0.018064 -0.003613  0.036243 -0.017056 -0.072555
# 2999  0.048005 -0.016399 -0.032178  0.026566  0.017230  0.020571 -0.026939
#
#              7         8         9  ...       759       760       761  \
# 0     0.008729  0.079076 -0.018651  ... -0.035216 -0.004926  0.002643
# 1     0.016118  0.057677 -0.018877  ... -0.044232 -0.005241  0.006694
# 2     0.008808  0.090986 -0.012824  ...  0.003346  0.024238 -0.002917
# 3     0.022927  0.065173 -0.012395  ... -0.019971  0.005966 -0.027569
# 4     0.025515  0.044787  0.012179  ... -0.000852  0.002012  0.017530
# ...        ...       ...       ...  ...       ...       ...       ...
# 2995  0.026483  0.077640 -0.022566  ... -0.004895 -0.002905  0.013308
# 2996  0.001677  0.047928 -0.010099  ... -0.035204 -0.003959  0.004056
# 2997 -0.004437  0.058308 -0.006634  ... -0.033325 -0.022092  0.022104
# 2998  0.026048  0.054409 -0.012396  ... -0.021542  0.036983 -0.019718
# 2999 -0.005646  0.103374 -0.016679  ...  0.002791 -0.000114  0.010979
#
#            762       763       764       765       766       767  predict
# 0    -0.041705 -0.073804  0.011732  0.023657  0.023674 -0.021644        0
# 1    -0.043336 -0.056174  0.029313  0.019381  0.020676 -0.005578        0
# 2    -0.040966 -0.080141  0.006348  0.023794  0.016556 -0.028141        2
# 3    -0.053896 -0.080093 -0.018758  0.014429  0.037310 -0.016282        0
# 4    -0.016844 -0.010146 -0.008205  0.021647  0.003026 -0.051527        2
# ...        ...       ...       ...       ...       ...       ...      ...
# 2995 -0.044995 -0.075419  0.004471  0.014530  0.021715 -0.006937        1
# 2996 -0.057046 -0.048743 -0.001795  0.026904  0.016072 -0.034152        0
# 2997 -0.035005 -0.049889  0.017549  0.018456  0.006250 -0.027227        0
# 2998 -0.032257 -0.068770  0.019108  0.026003  0.019968 -0.025191        0
# 2999 -0.034349 -0.006738 -0.030371  0.035596  0.028135 -0.023273        2
#
# [3000 rows x 769 columns]

# %%
import torch
if torch.backends.mps.is_available():
    mps_device = torch.device("mps")
    x = torch.ones(1, device=mps_device)
    print (x)
else:
    print ("MPS device not found.")
device = torch.device("mps")  # MPS 장치 사용
# Out:
# tensor([1.], device='mps:0')

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
# 데이터 불러오기 및 전처리
data_row = pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0504/no gpt/NO gpt train data.csv", index_col=0)
y_train = pd.get_dummies(data_row['predict']).values
X_train = data_row.drop(columns=['predict']).values

test = pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0504/no gpt/NO gpt test data.csv", index_col=0)
test_y = pd.get_dummies(test['predict']).values
test_x = test.drop(columns=['predict']).values

# %%
X_train = torch.tensor(X_train, dtype=torch.float).unsqueeze(1).to(device)
y_train = torch.tensor(y_train, dtype=torch.float).to(device)
test_x = torch.tensor(test_x, dtype=torch.float).unsqueeze(1).to(device)
test_y = torch.tensor(test_y, dtype=torch.float).to(device)

# %%
print(X_train.shape)
print(y_train.shape)
print(test_x.shape)
print(test_y.shape)
# Out:
# torch.Size([3000, 1, 768])
# torch.Size([3000, 3])
# torch.Size([300, 1, 768])
# torch.Size([300, 3])

# %%
train_dataset = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=50, shuffle=True)

test_dataset = TensorDataset(test_x, test_y)
test_loader = DataLoader(test_dataset, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

class TextClassifier(nn.Module):
    def __init__(self):
        super(TextClassifier, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=X_train.shape[2], out_channels=128, kernel_size=2, padding=1)  # 채널 수와 커널 사이즈 조정
        self.bn1 = nn.BatchNorm1d(128)  # 배치 정규화 추가
        self.conv2 = nn.Conv1d(in_channels=128, out_channels=64, kernel_size=2, padding=1)
        self.bn2 = nn.BatchNorm1d(64)
        self.conv3 = nn.Conv1d(in_channels=64, out_channels=32, kernel_size=2, padding=1)
        self.bn3 = nn.BatchNorm1d(32)
        self.pool = nn.MaxPool1d(kernel_size=2)
        self.dropout = nn.Dropout(0.25)  # 드롭아웃 비율 조정
        self.lstm = nn.LSTM(input_size=32, hidden_size=128, num_layers=2, batch_first=True, bidirectional=True)  # LSTM 구조 보강
        self.fc1 = nn.Linear(128*2, 32)  # Fully connected 레이어의 크기 조정
        self.fc2 = nn.Linear(32, 3)
        self.activation = nn.ReLU()  # 활성화 함수 변경

    def forward(self, x):
        x = self.bn1(self.activation(self.conv1(x)))
        x = self.pool(x)
        x = self.bn2(self.activation(self.conv2(x)))
        x = self.pool(x)
        x = self.bn3(self.activation(self.conv3(x)))
        x = self.pool(x)
        x = self.dropout(x)
        x = x.permute(0, 2, 1)
        x, _ = self.lstm(x)
        x = self.dropout(x[:, -1, :])
        x = self.activation(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x


model = TextClassifier().to(device)
model.to(device)
# Out:
# TextClassifier(
#   (conv1): Conv1d(768, 128, kernel_size=(2,), stride=(1,), padding=(1,))
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv1d(128, 64, kernel_size=(2,), stride=(1,), padding=(1,))
#   (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv1d(64, 32, kernel_size=(2,), stride=(1,), padding=(1,))
#   (bn3): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout(p=0.25, inplace=False)
#   (lstm): LSTM(32, 128, num_layers=2, batch_first=True, bidirectional=True)
#   (fc1): Linear(in_features=256, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=3, bias=True)
#   (activation): ReLU()
# )

# %%
import torch.optim as optim


criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=0.002,weight_decay=1e-5)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.8, patience=3, verbose=True)
# Out:
# /opt/anaconda3/envs/conda_cpu/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "

# %%
import torch
import torch.optim as optim
import torch.nn as nn
import matplotlib.pyplot as plt

def save_checkpoint(state, filename="my_checkpoint.pt"):
    print("=> Saving checkpoint")
    torch.save(state, filename)

# %%
num_epochs = 500
training_losses = []
validation_losses = []


patience = 20  
counter = 0  
best_loss = None  

for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)  # 데이터를 MPS 장치로 이동
        inputs = inputs.permute(0, 2, 1)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, torch.max(labels, 1)[1])
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
    
    avg_train_loss = train_loss / len(train_loader)
    training_losses.append(avg_train_loss)
    
   
    model.eval()
    validation_loss = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device) 
            inputs = inputs.permute(0, 2, 1)  
            outputs = model(inputs)
            loss = criterion(outputs, torch.max(labels, 1)[1])
            validation_loss += loss.item()
    
    avg_validation_loss = validation_loss / len(test_loader)
    validation_losses.append(avg_validation_loss)

    print(f'Epoch {epoch+1}, Training Loss: {avg_train_loss}, Validation Loss: {avg_validation_loss}')
    
    scheduler.step(avg_validation_loss)
    
    if best_loss is None:
        best_loss = avg_validation_loss
        save_checkpoint({'state_dict': model.state_dict(), 'optimizer': optimizer.state_dict()})
    elif avg_validation_loss < best_loss:
        best_loss = avg_validation_loss
        save_checkpoint({'state_dict': model.state_dict(), 'optimizer': optimizer.state_dict()})
        counter = 0
    else:
        counter += 1
        if counter >= patience:
            print("Early stopping!")
            break

print('Test Fine End')
# Out:
# Epoch 1, Training Loss: 0.5957627192139625, Validation Loss: 0.4272456948893766
# => Saving checkpoint
# Epoch 2, Training Loss: 0.40010895108183225, Validation Loss: 0.5018258666584734
# Epoch 3, Training Loss: 0.3285199455916882, Validation Loss: 0.5424960082462834
# Epoch 4, Training Loss: 0.30412140662471454, Validation Loss: 0.3026208162526988
# => Saving checkpoint
# Epoch 5, Training Loss: 0.2762857752541701, Validation Loss: 0.35849237074609847
# Epoch 6, Training Loss: 0.25438343596955143, Validation Loss: 0.29017908092915606
# => Saving checkpoint
# Epoch 7, Training Loss: 0.23963483224312465, Validation Loss: 0.2254855347601309
# => Saving checkpoint
# Epoch 8, Training Loss: 0.23563579532007375, Validation Loss: 0.6434808437008178
# Epoch 9, Training Loss: 0.2237564644465844, Validation Loss: 0.19304478328330638
# => Saving checkpoint
# Epoch 10, Training Loss: 0.21144367270171643, Validation Loss: 0.31630612559437093
# Epoch 11, Training Loss: 0.19797570047279198, Validation Loss: 0.17945075103064786
# => Saving checkpoint
# Epoch 12, Training Loss: 0.18303365601847568, Validation Loss: 0.17834443685724788
# => Saving checkpoint
# Epoch 13, Training Loss: 0.18356462034086388, Validation Loss: 0.1373263214326774
# => Saving checkpoint
# Epoch 14, Training Loss: 0.1744795383885503, Validation Loss: 0.19494655946354517
# Epoch 15, Training Loss: 0.17437233620633683, Validation Loss: 0.30066275091395556
# Epoch 16, Training Loss: 0.17136078697318832, Validation Loss: 0.154448224807799
# Epoch 17, Training Loss: 0.16218300989518564, Validation Loss: 0.1394962394351084
# Epoch 18, Training Loss: 0.12521794034789005, Validation Loss: 0.09343551980945752
# => Saving checkpoint
# Epoch 19, Training Loss: 0.12153437528759241, Validation Loss: 0.3085264932187298
# Epoch 20, Training Loss: 0.13907265396167834, Validation Loss: 0.09027549547593178
# => Saving checkpoint
# Epoch 21, Training Loss: 0.11622799397446215, Validation Loss: 0.10390929460835953
# Epoch 22, Training Loss: 0.1066339065010349, Validation Loss: 0.18666525559282793
# Epoch 23, Training Loss: 0.11801633642365535, Validation Loss: 0.14237006253982448
# Epoch 24, Training Loss: 0.09863844870900114, Validation Loss: 0.10896964696558523
# Epoch 25, Training Loss: 0.07554731266573071, Validation Loss: 0.10839119540161239
# Epoch 26, Training Loss: 0.0764558515821894, Validation Loss: 0.11678514507979951
# Epoch 27, Training Loss: 0.08937850069875518, Validation Loss: 0.07082141597688557
# => Saving checkpoint
# Epoch 28, Training Loss: 0.06934175562734406, Validation Loss: 0.08308140657837006
# Epoch 29, Training Loss: 0.0661358908051625, Validation Loss: 0.11169291588348339
# Epoch 30, Training Loss: 0.07457407202261189, Validation Loss: 0.08799679490389584
# Epoch 31, Training Loss: 0.0823451024480164, Validation Loss: 0.159629068062715
# Epoch 32, Training Loss: 0.0647793184267357, Validation Loss: 0.03701766298758836
# => Saving checkpoint
# Epoch 33, Training Loss: 0.0545770205091685, Validation Loss: 0.0221999278148769
# => Saving checkpoint
# Epoch 34, Training Loss: 0.04585011807503179, Validation Loss: 0.034559177832136356
# Epoch 35, Training Loss: 0.04248603169301835, Validation Loss: 0.05788016017382385
# Epoch 36, Training Loss: 0.05218377005464087, Validation Loss: 0.09628561952522584
# Epoch 37, Training Loss: 0.04780858848632003, Validation Loss: 0.02241700621231454
# Epoch 38, Training Loss: 0.03177141577277022, Validation Loss: 0.031135329243484194
# Epoch 39, Training Loss: 0.027609674714040012, Validation Loss: 0.053220634062168225
# Epoch 40, Training Loss: 0.06156354985432699, Validation Loss: 0.07065441661479174
# Epoch 41, Training Loss: 0.03585371720449378, Validation Loss: 0.02817661100323903
# Epoch 42, Training Loss: 0.02861735442323455, Validation Loss: 0.010683317358727133
# => Saving checkpoint
# Epoch 43, Training Loss: 0.02414778709547439, Validation Loss: 0.009953707033383429
# => Saving checkpoint
# Epoch 44, Training Loss: 0.024371050370003408, Validation Loss: 0.015780132750730144
# Epoch 45, Training Loss: 0.02202104971705315, Validation Loss: 0.012031827168406532
# Epoch 46, Training Loss: 0.025120503992851203, Validation Loss: 0.014247787885299583
# Epoch 47, Training Loss: 0.03213279654640549, Validation Loss: 0.01832977437664946
# Epoch 48, Training Loss: 0.022929881617892535, Validation Loss: 0.013622724405228154
# Epoch 49, Training Loss: 0.028074163996886153, Validation Loss: 0.011499550535226414
# Epoch 50, Training Loss: 0.013012027908310604, Validation Loss: 0.007344770053581442
# => Saving checkpoint
# Epoch 51, Training Loss: 0.014149707719237388, Validation Loss: 0.00845922200448778
# Epoch 52, Training Loss: 0.018057014459918717, Validation Loss: 0.007006796480422964
# => Saving checkpoint
# Epoch 53, Training Loss: 0.027018123955349437, Validation Loss: 0.006324810129866971
# => Saving checkpoint
# Epoch 54, Training Loss: 0.019520784985797946, Validation Loss: 0.007577555327590062
# Epoch 55, Training Loss: 0.00977916911894378, Validation Loss: 0.0022255671666575457
# => Saving checkpoint
# Epoch 56, Training Loss: 0.022000212592926498, Validation Loss: 0.004477806411572752
# Epoch 57, Training Loss: 0.014211290063879762, Validation Loss: 0.0021189616922621707
# => Saving checkpoint
# Epoch 58, Training Loss: 0.012497090533724987, Validation Loss: 0.014865383258000974
# Epoch 59, Training Loss: 0.03038054800320727, Validation Loss: 0.06448750043550149
# Epoch 60, Training Loss: 0.022754725905057664, Validation Loss: 0.007677018224034858
# Epoch 61, Training Loss: 0.02388112435583025, Validation Loss: 0.017412483534013368
# Epoch 62, Training Loss: 0.03507213143796738, Validation Loss: 0.004596805386896297
# Epoch 63, Training Loss: 0.010182534842169844, Validation Loss: 0.0024397025321350914
# Epoch 64, Training Loss: 0.010357722625485621, Validation Loss: 0.0017115784431848623
# => Saving checkpoint
# Epoch 65, Training Loss: 0.0205349247805619, Validation Loss: 0.003666502748593151
# Epoch 66, Training Loss: 0.012727584199698565, Validation Loss: 0.0024290623319113062
# Epoch 67, Training Loss: 0.01281158906397953, Validation Loss: 0.00147412790816702
# => Saving checkpoint
# Epoch 68, Training Loss: 0.014307220523672488, Validation Loss: 0.009096635643473594
# Epoch 69, Training Loss: 0.012085891478151704, Validation Loss: 0.0015793529657942903
# Epoch 70, Training Loss: 0.011233301310615692, Validation Loss: 0.0010942478761307938
# => Saving checkpoint
# Epoch 71, Training Loss: 0.02152607118623564, Validation Loss: 0.0012446220735841962
# Epoch 72, Training Loss: 0.014512850827304646, Validation Loss: 0.0013420922602995233
# Epoch 73, Training Loss: 0.007154592657267737, Validation Loss: 0.00114506489481073
# Epoch 74, Training Loss: 0.02074345860334385, Validation Loss: 0.0016467699465637982
# Epoch 75, Training Loss: 0.007822207215940579, Validation Loss: 0.0011601260725882412
# Epoch 76, Training Loss: 0.004709737282973947, Validation Loss: 0.0027716754861270942
# Epoch 77, Training Loss: 0.008510967335557023, Validation Loss: 0.0003700617174069028
# => Saving checkpoint
# Epoch 78, Training Loss: 0.00525350150783197, Validation Loss: 0.00024640199308291716
# => Saving checkpoint
# Epoch 79, Training Loss: 0.008371799623394812, Validation Loss: 0.0002888367768687772
# Epoch 80, Training Loss: 0.006275792920011251, Validation Loss: 0.016270263041568946
# Epoch 81, Training Loss: 0.010511101322481408, Validation Loss: 0.006174985480928683
# Epoch 82, Training Loss: 0.014118557875068898, Validation Loss: 0.00032104349964621787
# Epoch 83, Training Loss: 0.0028607540458324364, Validation Loss: 0.00021204367494452944
# => Saving checkpoint
# Epoch 84, Training Loss: 0.009155365357582924, Validation Loss: 0.0028928040083517695
# Epoch 85, Training Loss: 0.009953716194892574, Validation Loss: 0.00033521811060154504
# Epoch 86, Training Loss: 0.004775926674483344, Validation Loss: 8.342191419880388e-05
# => Saving checkpoint
# Epoch 87, Training Loss: 0.01047147714428623, Validation Loss: 0.018514851286801293
# Epoch 88, Training Loss: 0.015641772624318644, Validation Loss: 0.0006353939895289311
# Epoch 89, Training Loss: 0.011862403078824475, Validation Loss: 0.0055603367254212326
# Epoch 90, Training Loss: 0.00877477673990749, Validation Loss: 0.00026555222674827424
# Epoch 91, Training Loss: 0.009468532914373403, Validation Loss: 0.0016242219558422258
# Epoch 92, Training Loss: 0.003114879710240833, Validation Loss: 0.0009604805391406283
# Epoch 93, Training Loss: 0.006047939675954695, Validation Loss: 0.00019151390666254523
# Epoch 94, Training Loss: 0.006689011302417687, Validation Loss: 0.0003310742098044983
# Epoch 95, Training Loss: 0.003197279378825139, Validation Loss: 0.00010033304198387328
# Epoch 96, Training Loss: 0.0030844732834035917, Validation Loss: 8.747144543448826e-05
# Epoch 97, Training Loss: 0.0056345214553706075, Validation Loss: 5.531432883086514e-05
# => Saving checkpoint
# Epoch 98, Training Loss: 0.002606177823508915, Validation Loss: 5.2230318711371144e-05
# => Saving checkpoint
# Epoch 99, Training Loss: 0.003663745447799253, Validation Loss: 4.06353351156478e-05
# => Saving checkpoint
# Epoch 100, Training Loss: 0.004888863151973055, Validation Loss: 4.995411369314695e-05
# Epoch 101, Training Loss: 0.0032918211657791594, Validation Loss: 6.40180541100932e-05
# Epoch 102, Training Loss: 0.0048951095650409115, Validation Loss: 9.407846063747153e-05
# Epoch 103, Training Loss: 0.003056702497300042, Validation Loss: 6.38865750899953e-05
# Epoch 104, Training Loss: 0.004623268096778096, Validation Loss: 4.430261735606678e-05
# Epoch 105, Training Loss: 0.002054282092285575, Validation Loss: 3.8254351421921724e-05
# => Saving checkpoint
# Epoch 106, Training Loss: 0.0035350203629908113, Validation Loss: 2.927092593862331e-05
# => Saving checkpoint
# Epoch 107, Training Loss: 0.0032746225891060023, Validation Loss: 3.419746579275795e-05
# Epoch 108, Training Loss: 0.001652615555455365, Validation Loss: 3.8320252191065644e-05
# Epoch 109, Training Loss: 0.006528240899069715, Validation Loss: 2.9735481323858912e-05
# Epoch 110, Training Loss: 0.0009807746004601844, Validation Loss: 3.4496614300560205e-05
# Epoch 111, Training Loss: 0.0014574044987360443, Validation Loss: 4.519882388047828e-05
# Epoch 112, Training Loss: 0.003869990779367072, Validation Loss: 2.7072089409969636e-05
# => Saving checkpoint
# Epoch 113, Training Loss: 0.001707107684493773, Validation Loss: 0.00043955819156577057
# Epoch 114, Training Loss: 0.005331916893555899, Validation Loss: 0.0009261881506272592
# Epoch 115, Training Loss: 0.003580864911540023, Validation Loss: 5.094193648413163e-05
# Epoch 116, Training Loss: 0.010456623856119526, Validation Loss: 0.00027383264460330753
# Epoch 117, Training Loss: 0.0027470959436868723, Validation Loss: 2.5774713872905865e-05
# => Saving checkpoint
# Epoch 118, Training Loss: 0.0032907812681817936, Validation Loss: 5.245359504890246e-05
# Epoch 119, Training Loss: 0.0033853235609058174, Validation Loss: 2.246722534342401e-05
# => Saving checkpoint
# Epoch 120, Training Loss: 0.0020068777275810135, Validation Loss: 2.383173608907422e-05
# Epoch 121, Training Loss: 0.003380902870230784, Validation Loss: 4.32982575693804e-05
# Epoch 122, Training Loss: 0.0017064826119167265, Validation Loss: 1.9036681619581943e-05
# => Saving checkpoint
# Epoch 123, Training Loss: 0.0007126789617965793, Validation Loss: 1.765211639780754e-05
# => Saving checkpoint
# Epoch 124, Training Loss: 0.00787762476353843, Validation Loss: 3.88478184421596e-05
# Epoch 125, Training Loss: 0.006666254375856321, Validation Loss: 2.7556939781021583e-05
# Epoch 126, Training Loss: 0.001165470849052023, Validation Loss: 2.5327479109951887e-05
# Epoch 127, Training Loss: 0.0009026061869008117, Validation Loss: 2.7781214229705143e-05
# Epoch 128, Training Loss: 0.0017666948257556215, Validation Loss: 3.034681970895292e-05
# Epoch 129, Training Loss: 0.0018055098867383397, Validation Loss: 1.8509222159958465e-05
# Epoch 130, Training Loss: 0.003914668868803043, Validation Loss: 2.1465753481209048e-05
# Epoch 131, Training Loss: 0.0010377434006689631, Validation Loss: 1.86013000823948e-05
# Epoch 132, Training Loss: 0.005632804109071307, Validation Loss: 2.608801259100346e-05
# Epoch 133, Training Loss: 0.0018976753797081377, Validation Loss: 2.3954959357155303e-05
# Epoch 134, Training Loss: 0.001580706772377501, Validation Loss: 2.2475288356744726e-05
# Epoch 135, Training Loss: 0.0025963263049258484, Validation Loss: 3.647110818486491e-05
# Epoch 136, Training Loss: 0.0022535334688048654, Validation Loss: 3.829209569244559e-05
# Epoch 137, Training Loss: 0.0011023983369038129, Validation Loss: 1.7466496494501865e-05
# => Saving checkpoint
# Epoch 138, Training Loss: 0.0011270166610605277, Validation Loss: 2.8325805904406327e-05
# Epoch 139, Training Loss: 0.004961671510909582, Validation Loss: 2.379032066805564e-05
# Epoch 140, Training Loss: 0.007511322972398678, Validation Loss: 4.6151574713656865e-05
# Epoch 141, Training Loss: 0.003861528958229125, Validation Loss: 3.057428339206562e-05
# Epoch 142, Training Loss: 0.0007774325475717584, Validation Loss: 2.7260639383020663e-05
# Epoch 143, Training Loss: 0.0004741132997120682, Validation Loss: 3.814897871137646e-05
# Epoch 144, Training Loss: 0.0011139695781821502, Validation Loss: 2.2653307086078674e-05
# Epoch 145, Training Loss: 0.0009624930725749437, Validation Loss: 2.224507858114085e-05
# Epoch 146, Training Loss: 0.0013945976687106546, Validation Loss: 1.921046513902051e-05
# Epoch 147, Training Loss: 0.0013806378682602372, Validation Loss: 1.737545177974198e-05
# => Saving checkpoint
# Epoch 148, Training Loss: 0.001450585346765365, Validation Loss: 1.9805601178219945e-05
# Epoch 149, Training Loss: 0.004496424446157713, Validation Loss: 7.808839508259761e-05
# Epoch 150, Training Loss: 0.0015330903302735047, Validation Loss: 3.779539628084194e-05
# Epoch 151, Training Loss: 0.0015942080608814043, Validation Loss: 1.4994901353967786e-05
# => Saving checkpoint
# Epoch 152, Training Loss: 0.0005257423818875395, Validation Loss: 1.6403137375201975e-05
# Epoch 153, Training Loss: 0.0008852019788264442, Validation Loss: 1.3313755508690405e-05
# => Saving checkpoint
# Epoch 154, Training Loss: 0.0023458708498916773, Validation Loss: 1.6282906069638633e-05
# Epoch 155, Training Loss: 0.0004868304832295204, Validation Loss: 1.4428796682253164e-05
# Epoch 156, Training Loss: 0.0008250218500658472, Validation Loss: 1.3578865420385e-05
# Epoch 157, Training Loss: 0.0008303506178359991, Validation Loss: 1.9168501978488924e-05
# Epoch 158, Training Loss: 0.0010355583663113066, Validation Loss: 1.1717849106863317e-05
# => Saving checkpoint
# Epoch 159, Training Loss: 0.001211012422057441, Validation Loss: 1.9129376958465134e-05
# Epoch 160, Training Loss: 0.0008759387312693434, Validation Loss: 1.0756968067534938e-05
# => Saving checkpoint
# Epoch 161, Training Loss: 0.0015559813917358648, Validation Loss: 1.2447869264965069e-05
# Epoch 162, Training Loss: 0.0027326416722341187, Validation Loss: 1.364118520645737e-05
# Epoch 163, Training Loss: 0.0009436849961730331, Validation Loss: 2.028710717245493e-05
# Epoch 164, Training Loss: 0.0008657637654854018, Validation Loss: 1.0143683133326438e-05
# => Saving checkpoint
# Epoch 165, Training Loss: 0.002995738022612689, Validation Loss: 1.1854133028326904e-05
# Epoch 166, Training Loss: 0.0026989258227786196, Validation Loss: 1.3120314784439795e-05
# Epoch 167, Training Loss: 0.002900274135587703, Validation Loss: 1.1206700046884065e-05
# Epoch 168, Training Loss: 0.0045305388925498844, Validation Loss: 1.0947263206849318e-05
# Epoch 169, Training Loss: 0.001156081754159762, Validation Loss: 1.056854906688424e-05
# Epoch 170, Training Loss: 0.0010952037674618017, Validation Loss: 1.116290119036023e-05
# Epoch 171, Training Loss: 0.005281541608875766, Validation Loss: 1.2239451393654122e-05
# Epoch 172, Training Loss: 0.0027299287738363396, Validation Loss: 1.0124230044728695e-05
# => Saving checkpoint
# Epoch 173, Training Loss: 0.0014067683497463199, Validation Loss: 1.0103126131468798e-05
# => Saving checkpoint
# Epoch 174, Training Loss: 0.0009566958028472073, Validation Loss: 1.0261359766516876e-05
# Epoch 175, Training Loss: 0.000772916324255372, Validation Loss: 9.851261478317496e-06
# => Saving checkpoint
# Epoch 176, Training Loss: 0.0015472134789130602, Validation Loss: 8.456209236271662e-06
# => Saving checkpoint
# Epoch 177, Training Loss: 0.001638147770654541, Validation Loss: 9.327223487574088e-06
# Epoch 178, Training Loss: 0.0003004045971541321, Validation Loss: 8.05470837664283e-06
# => Saving checkpoint
# Epoch 179, Training Loss: 0.000553284689802543, Validation Loss: 7.888886562833856e-06
# => Saving checkpoint
# Epoch 180, Training Loss: 0.0017339774033795644, Validation Loss: 9.052217272464229e-06
# Epoch 181, Training Loss: 0.0024575075420519474, Validation Loss: 8.029341894418469e-06
# Epoch 182, Training Loss: 0.0006138678999074424, Validation Loss: 8.37270020843069e-06
# Epoch 183, Training Loss: 0.0005061190655624159, Validation Loss: 7.710212473786745e-06
# => Saving checkpoint
# Epoch 184, Training Loss: 0.0030961157778695756, Validation Loss: 1.45275081354157e-05
# Epoch 185, Training Loss: 0.0006566526405852831, Validation Loss: 8.166332016088518e-06
# Epoch 186, Training Loss: 0.0019486881414347106, Validation Loss: 7.983748384864005e-06
# Epoch 187, Training Loss: 0.00029764829074944527, Validation Loss: 7.531707700323409e-06
# => Saving checkpoint
# Epoch 188, Training Loss: 0.0010485389083290406, Validation Loss: 6.998168654751187e-06
# => Saving checkpoint
# Epoch 189, Training Loss: 0.0015456433876427885, Validation Loss: 1.4736246387059282e-05
# Epoch 190, Training Loss: 0.0021821931249784636, Validation Loss: 6.526264520990329e-06
# => Saving checkpoint
# Epoch 191, Training Loss: 0.0006668005772250278, Validation Loss: 8.447374944395846e-06
# Epoch 192, Training Loss: 0.00267496776449813, Validation Loss: 8.360769717820441e-06
# Epoch 193, Training Loss: 0.001005296215165193, Validation Loss: 8.585247281232e-06
# Epoch 194, Training Loss: 0.001302476281610628, Validation Loss: 6.459482636221499e-06
# => Saving checkpoint
# Epoch 195, Training Loss: 0.002507380936837459, Validation Loss: 7.101857460440897e-06
# Epoch 196, Training Loss: 0.0003933374158047324, Validation Loss: 9.566745962175105e-06
# Epoch 197, Training Loss: 0.0005583828711223759, Validation Loss: 7.261705066028412e-06
# Epoch 198, Training Loss: 0.0015823720642553476, Validation Loss: 7.860934300888782e-06
# Epoch 199, Training Loss: 0.00039250968591962495, Validation Loss: 7.284236695094629e-06
# Epoch 200, Training Loss: 0.0011722273378381941, Validation Loss: 7.3164535544615695e-06
# Epoch 201, Training Loss: 0.0003245485581222359, Validation Loss: 5.97774280841179e-06
# => Saving checkpoint
# Epoch 202, Training Loss: 0.0005320799833877269, Validation Loss: 4.9679839548370334e-06
# => Saving checkpoint
# Epoch 203, Training Loss: 0.0025979845468251978, Validation Loss: 2.6625277560725634e-05
# Epoch 204, Training Loss: 0.0029127114868591282, Validation Loss: 8.317871312755187e-06
# Epoch 205, Training Loss: 0.000946823866994843, Validation Loss: 5.3008840676227465e-06
# Epoch 206, Training Loss: 0.0007535009147962531, Validation Loss: 6.1937903853722295e-06
# Epoch 207, Training Loss: 0.0017824521381650507, Validation Loss: 7.749015538630981e-06
# Epoch 208, Training Loss: 0.0027538858062143845, Validation Loss: 7.426953159921368e-06
# Epoch 209, Training Loss: 0.003143076431130491, Validation Loss: 2.1520804443232084e-05
# Epoch 210, Training Loss: 0.0006883111674445293, Validation Loss: 6.09639093217614e-06
# Epoch 211, Training Loss: 0.0008546099823206532, Validation Loss: 3.2686483005430016e-05
# Epoch 212, Training Loss: 0.0007322649946521172, Validation Loss: 5.657402445156852e-06
# Epoch 213, Training Loss: 0.0010927624636754747, Validation Loss: 6.482748540719285e-06
# Epoch 214, Training Loss: 0.0004620477605802383, Validation Loss: 7.1288818073137844e-06
# Epoch 215, Training Loss: 0.000967567407739504, Validation Loss: 6.0679356589332655e-06
# Epoch 216, Training Loss: 0.0015062659700864364, Validation Loss: 7.589529827498609e-06
# Epoch 217, Training Loss: 0.0017680678545730188, Validation Loss: 5.262436160056912e-06
# Epoch 218, Training Loss: 0.001020472185920577, Validation Loss: 7.064571764866893e-06
# Epoch 219, Training Loss: 0.00025831367843238696, Validation Loss: 6.1454337000318064e-06
# Epoch 220, Training Loss: 0.0023257787129561318, Validation Loss: 4.8999258820240735e-06
# => Saving checkpoint
# Epoch 221, Training Loss: 0.0009634027816900926, Validation Loss: 4.292839703078736e-06
# => Saving checkpoint
# Epoch 222, Training Loss: 0.0061537220851581274, Validation Loss: 1.0872035696986396e-05
# Epoch 223, Training Loss: 0.0002845293885305485, Validation Loss: 5.325255361607144e-06
# Epoch 224, Training Loss: 0.0003824076272849197, Validation Loss: 4.85418165358927e-06
# Epoch 225, Training Loss: 0.0017458048924481773, Validation Loss: 1.080005467175719e-05
# Epoch 226, Training Loss: 0.002119259451410471, Validation Loss: 4.75254718030745e-06
# Epoch 227, Training Loss: 0.0003994221769895982, Validation Loss: 4.773893853050973e-06
# Epoch 228, Training Loss: 0.00039154984510787473, Validation Loss: 4.165742728166796e-06
# => Saving checkpoint
# Epoch 229, Training Loss: 0.004096774380271503, Validation Loss: 4.176069402627528e-06
# Epoch 230, Training Loss: 0.0017593604730677726, Validation Loss: 4.915959809324022e-06
# Epoch 231, Training Loss: 0.002939890249316098, Validation Loss: 6.896853094365459e-06
# Epoch 232, Training Loss: 0.002554497533204388, Validation Loss: 8.527959947054834e-06
# Epoch 233, Training Loss: 0.004687095390094479, Validation Loss: 4.039079556577007e-06
# => Saving checkpoint
# Epoch 234, Training Loss: 0.0008653155324812663, Validation Loss: 4.305997259947958e-06
# Epoch 235, Training Loss: 0.0020600444316642096, Validation Loss: 5.376989200011432e-06
# Epoch 236, Training Loss: 0.0006170120348239531, Validation Loss: 4.97538508400434e-06
# Epoch 237, Training Loss: 0.0005435438774535821, Validation Loss: 4.266697004737807e-06
# Epoch 238, Training Loss: 0.0008019800944452981, Validation Loss: 4.609889542924369e-06
# Epoch 239, Training Loss: 0.001775058088711982, Validation Loss: 5.947865339000676e-06
# Epoch 240, Training Loss: 0.0015347507102660529, Validation Loss: 5.6863806666503556e-06
# Epoch 241, Training Loss: 0.0017778430617681807, Validation Loss: 5.7010452171605646e-06
# Epoch 242, Training Loss: 0.00047797212722192246, Validation Loss: 4.727448359957975e-06
# Epoch 243, Training Loss: 0.0019277562616177117, Validation Loss: 4.84986816140065e-06
# Epoch 244, Training Loss: 0.00031896649074572754, Validation Loss: 3.950461352128324e-06
# => Saving checkpoint
# Epoch 245, Training Loss: 0.0007266077516608978, Validation Loss: 6.444954937876446e-06
# Epoch 246, Training Loss: 0.0002705209252250521, Validation Loss: 3.868232287539778e-06
# => Saving checkpoint
# Epoch 247, Training Loss: 0.0028143626819731554, Validation Loss: 4.457799708532662e-06
# Epoch 248, Training Loss: 0.003715896404317694, Validation Loss: 4.9195595313259825e-06
# Epoch 249, Training Loss: 0.0036744143047675, Validation Loss: 8.285115161352034e-06
# Epoch 250, Training Loss: 0.00049848083570699, Validation Loss: 1.309065275291251e-05
# Epoch 251, Training Loss: 0.0004656787655676453, Validation Loss: 4.1585684147804615e-06
# Epoch 252, Training Loss: 0.0012794543532891113, Validation Loss: 4.281039857237563e-06
# Epoch 253, Training Loss: 0.000582888373219248, Validation Loss: 4.7492245611143366e-06
# Epoch 254, Training Loss: 0.0010055754234902755, Validation Loss: 5.938920373888361e-06
# Epoch 255, Training Loss: 0.0006532250610386351, Validation Loss: 9.743016497220461e-06
# Epoch 256, Training Loss: 0.00048555122632478744, Validation Loss: 5.764234639187293e-06
# Epoch 257, Training Loss: 0.00046947988854526555, Validation Loss: 3.9492729141225405e-06
# Epoch 258, Training Loss: 0.0012544315546013725, Validation Loss: 4.694682193052321e-06
# Epoch 259, Training Loss: 0.0036577689164460025, Validation Loss: 4.296465691950857e-06
# Epoch 260, Training Loss: 0.001983667963463631, Validation Loss: 4.311235440752625e-06
# Epoch 261, Training Loss: 0.0005395303724602248, Validation Loss: 4.86368574231714e-06
# Epoch 262, Training Loss: 0.0006159427361808412, Validation Loss: 3.929805785460872e-06
# Epoch 263, Training Loss: 0.002049867822688611, Validation Loss: 4.2317906279976115e-06
# Epoch 264, Training Loss: 0.0017427423634861347, Validation Loss: 4.215746114534606e-06
# Epoch 265, Training Loss: 0.00040596137760834003, Validation Loss: 4.647621567883675e-06
# Epoch 266, Training Loss: 0.00019290741577909404, Validation Loss: 4.379058274845231e-06
# Early stopping!
# Test Fine End

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
import numpy as np
from itertools import cycle
import matplotlib.pyplot as plt
import numpy as np



torch.save(model.state_dict(), 'pytorch cnn-bilstm model_state_dict0424.pt')

# %%
plt.figure(figsize=(10, 5))
plt.plot(training_losses, label='Training Loss')
plt.plot(validation_losses, label='Validation Loss')
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
def plot_multiclass_roc_curve(test_y, y_score, n_classes):
   
    test_y_bin = label_binarize(test_y, classes=[*range(n_classes)])

    
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(test_y_bin[:, i], y_score[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

   
    fpr["micro"], tpr["micro"], _ = roc_curve(test_y_bin.ravel(), y_score.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

   
    plt.figure(figsize=(7, 7))
    plt.plot(fpr["micro"], tpr["micro"],
             label='micro average ROC curve (area = {0:0.2f})'
                   ''.format(roc_auc["micro"]),
             color='deeppink', linestyle=':', linewidth=4)

    colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
    for i, color in zip(range(n_classes), colors):
        plt.plot(fpr[i], tpr[i], color=color, lw=2,
                 label='ROC curve of class {0} (area = {1:0.2f})'
                 ''.format(i, roc_auc[i]))

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC')
    plt.legend(loc="lower right")
    plt.show()





from sklearn.preprocessing import label_binarize

test_x = test_x.permute(0, 2, 1) 
y_score = model(test_x).detach().cpu().numpy()

test_y = test_y.detach().cpu().numpy()

plot_multiclass_roc_curve(test_y, y_score, n_classes=3)

# %%
def plot_precision_recall_curve(test_y, y_score, n_classes):
    
    test_y = label_binarize(test_y, classes=[*range(n_classes)])
    
   
    precision = dict()
    recall = dict()
    average_precision = dict()
    for i in range(n_classes):
        precision[i], recall[i], _ = precision_recall_curve(test_y[:, i], y_score[:, i])
        average_precision[i] = average_precision_score(test_y[:, i], y_score[:, i])

    
    plt.figure(figsize=(7, 7))
    for i in range(n_classes):
        plt.plot(recall[i], precision[i], lw=2, label=f'Class {i} (average precision = {average_precision[i]:0.2f})')

    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
    plt.title('Precision-Recall curve per class')
    plt.legend(loc="best")
    plt.show()
    
plot_precision_recall_curve(test_y, y_score, n_classes=3)

# %%
y_pred = np.argmax(y_score, axis=1)
test_y_labels = np.argmax(test_y, axis=1)  # 실제 레이블

# %%
accuracy = accuracy_score(test_y_labels, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 1.0

# %%
# 혼동 행렬
conf_matrix = confusion_matrix(test_y_labels, y_pred)
print('Confusion Matrix:')
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[165   0   0]
#  [  0  37   0]
#  [  0   0  98]]

# %%
with open("CNN BILSTM confusion matrix.txt", "w") as text_file:
    print(confusion_matrix(test_y_labels, y_pred), file=text_file)

# %%
# 분류 보고서
class_report = classification_report(test_y_labels, y_pred)
print('Classification Report:')
print(class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       165
#            1       1.00      1.00      1.00        37
#            2       1.00      1.00      1.00        98
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300

# %%
with open("CNN-BILSTM output.txt", "w") as text_file:
    print(classification_report(test_y_labels, y_pred,digits=4), file=text_file)
