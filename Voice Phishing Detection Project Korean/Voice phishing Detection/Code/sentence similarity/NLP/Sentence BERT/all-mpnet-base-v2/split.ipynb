# %%
import pandas as pd  

data_row=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0507(report)/sentence 1/train_data_after_vector.csv",index_col=0)

data_row
# Out:
#               0         1         2         3         4         5         6  \
# 6702   0.068081 -0.056239 -0.019021 -0.025090 -0.005837  0.000336  0.019997
# 10656  0.057598 -0.055984  0.001269 -0.032158  0.039640 -0.000089 -0.045828
# 15150  0.043729 -0.057656 -0.034226  0.010653  0.030365 -0.004821 -0.020315
# 19013  0.038672  0.037888  0.003315  0.048451  0.072535  0.029248 -0.095090
# 19856  0.035656 -0.021348 -0.007308  0.019653  0.031415  0.001607 -0.079395
# ...         ...       ...       ...       ...       ...       ...       ...
# 14554  0.030436 -0.013888 -0.023153  0.001383  0.040612  0.008310 -0.055057
# 8909   0.075469 -0.035791 -0.019274  0.034627  0.009696 -0.016320  0.013800
# 12597  0.050968 -0.138988 -0.011835  0.004274  0.029267  0.021201  0.056296
# 12428  0.023058 -0.072633  0.006806  0.008336  0.008375 -0.014838 -0.029651
# 12568  0.041824 -0.026018  0.001510 -0.012775  0.035288  0.037778 -0.053581
#
# ...

# %%
train_data=data_row[300:]
test_data=data_row[:300]

# %%
train_data
# Out:
#               0         1         2         3         4         5         6  \
# 9753   0.026565 -0.003204 -0.019983  0.006303  0.028031  0.014487 -0.072101
# 4459   0.027183 -0.064539 -0.027726 -0.008735 -0.010557 -0.011296  0.010397
# 18089  0.056439 -0.024830 -0.004742  0.012477  0.072107  0.016949 -0.079584
# 996    0.050084 -0.038454 -0.020088  0.017872  0.016645  0.000567 -0.050567
# 3389   0.042280  0.034710 -0.010575  0.039918  0.065134  0.040480 -0.078234
# ...         ...       ...       ...       ...       ...       ...       ...
# 14554  0.030436 -0.013888 -0.023153  0.001383  0.040612  0.008310 -0.055057
# 8909   0.075469 -0.035791 -0.019274  0.034627  0.009696 -0.016320  0.013800
# 12597  0.050968 -0.138988 -0.011835  0.004274  0.029267  0.021201  0.056296
# 12428  0.023058 -0.072633  0.006806  0.008336  0.008375 -0.014838 -0.029651
# 12568  0.041824 -0.026018  0.001510 -0.012775  0.035288  0.037778 -0.053581
#
# ...

# %%
train_data.to_csv("3 class use train data(0507).csv")
test_data.to_csv("3 class use test data(0507).csv")
