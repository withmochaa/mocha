# %%
import pandas as pd 

data=pd.read_excel("/Users/withmocha/Desktop/TEED/data/mocha/23.11.01/data_drop_bfill.xlsx")

data
# Out:
#      Unnamed: 0  FORCE_B(Right)  FORCE_C(Left)  X COORDINATE_C(Left)  \
# 0             0            67.0          260.0              3.325000
# 1             1            68.0          263.0              3.378327
# 2             2            71.0          275.0              3.378182
# 3             3            73.0          261.0              3.385057
# 4             4            73.0          261.0              3.385057
# ..          ...             ...            ...                   ...
# 608         608            19.0          341.0              3.171554
# 609         609            19.0          341.0              3.171554
# 610         610            45.0          338.0              3.217456
# 611         611            38.0          328.0              3.179878
# 612         612            33.0          315.0              3.165079
#
#      X COORDINATE_D(Heel)  X COORDINATE_F(Center)  Y COORDINATE_C(Left)  \
# 0                6.275333                2.625000             12.434615
# 1                6.325850                2.192308             12.311787
# 2                6.237584                2.250000             12.383636
# 3                6.257497                2.562500             12.306513
# 4                6.257497                2.562500             12.306513
# ..                    ...                     ...                   ...
# 608              6.348837                2.679310             12.739003
# 609              6.348837                2.679310             12.739003
# 610              6.325820                2.706294             12.665680
# 611              6.265182                2.697917             12.681402
# 612              6.237931                2.660584             12.709524
#
#      FSR DATA_B(Right)  FSR DATA_C(Left)
# 0                 33.0              53.0
# 1                 32.0              52.0
# 2                 32.0              51.0
# 3                 31.0              48.0
# 4                 31.0              48.0
# ..                 ...               ...
# 608               25.0              50.0
# 609               25.0              50.0
# 610               27.0              50.0
# 611               30.0              47.0
# 612               33.0              44.0
#
# [613 rows x 9 columns]

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                 0
# FORCE_B(Right)            82
# FORCE_C(Left)             82
# X COORDINATE_C(Left)      82
# X COORDINATE_D(Heel)      82
# X COORDINATE_F(Center)    82
# Y COORDINATE_C(Left)      82
# FSR DATA_B(Right)         82
# FSR DATA_C(Left)          82
# dtype: int64

# %%
data.drop(columns="Unnamed: 0",inplace=True)

# %%
import matplotlib.pyplot as plt

columns=data.columns
count=0
for i in columns:
    print(columns[count])
    count=count+1
    plt.plot(data[i])
    plt.show()
# Out:
# FORCE_B(Right)
# FORCE_C(Left)
# X COORDINATE_C(Left)
# X COORDINATE_D(Heel)
# X COORDINATE_F(Center)
# Y COORDINATE_C(Left)
# FSR DATA_B(Right)
# FSR DATA_C(Left)

# %%
data.columns
# Out:
# Index(['FORCE_B(Right)', 'FORCE_C(Left)', 'X COORDINATE_C(Left)',
#        'X COORDINATE_D(Heel)', 'X COORDINATE_F(Center)',
#        'Y COORDINATE_C(Left)', 'FSR DATA_B(Right)', 'FSR DATA_C(Left)'],
#       dtype='object')

# %%
data2=pd.read_excel("/Users/withmocha/Desktop/TEED/data/mocha/23.11.01/data_delay.xlsx")

R2=data2.loc[:,['FORCE_B(Right)','FSR DATA_B(Right)']]

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
R_scaled=scaler.fit_transform(R2)

R3=pd.DataFrame(data=R_scaled)

R_new=R3.set_axis(["FORCE_B(Right)","FSR DATA_B(Right)"],axis="columns")

# %%
R=data.loc[:,['FORCE_B(Right)','FSR DATA_B(Right)']]
L=data.loc[:,['FORCE_C(Left)','FSR DATA_C(Left)']]

# %%
import numpy as np

index=R.index

loss_index_R_FORECE_B=np.array(R.index).reshape(-1,1)[R.iloc[:,0].isna()]
loss_index_R_FSR_B=np.array(R.index).reshape(-1,1)[R.iloc[:,1].isna()]

normal_index_R_FORECE_B=np.setdiff1d(index,loss_index_R_FORECE_B)
normal_index_R_FSR_B=np.setdiff1d(index,loss_index_R_FSR_B)

# %%
index=L.index

loss_index_L_FORECE_C=np.array(L.index).reshape(-1,1)[L.iloc[:,0].isna()]
loss_index_L_FSR_C=np.array(L.index).reshape(-1,1)[L.iloc[:,1].isna()]

normal_index_L_FORECE_C=np.setdiff1d(index,loss_index_L_FORECE_C)
normal_index_L_FSR_C=np.setdiff1d(index,loss_index_L_FSR_C)

# %%
x_train_R_FORECE_B=normal_index_R_FORECE_B.reshape(-1,1)
y_train_L_FORECE_C=L.iloc[normal_index_L_FORECE_C,0]
x_test_L_FORECE_C=loss_index_L_FORECE_C

x_train_R_FSR_B=normal_index_R_FSR_B.reshape(-1,1)
y_train_L_FSR_C=L.iloc[normal_index_L_FSR_C,1]
x_test_L_FSR_C=loss_index_L_FSR_C

L_FORCE_C=L.iloc[:,0].copy()
L_FSR_C=L.iloc[:,1].copy()

# %%
print(x_train_R_FORECE_B.shape)
print(y_train_L_FORECE_C.shape)
# Out:
# (531, 1)
# (531,)

# %%
x_train_R_FORECE_B=x_train_R_FORECE_B.reshape(x_train_R_FORECE_B.shape[0],x_train_R_FORECE_B.shape[1],1)
x_train_R_FSR_B=x_train_R_FSR_B.reshape(x_train_R_FSR_B.shape[0],x_train_R_FSR_B.shape[1],1)
x_test_L_FORECE_C=x_test_L_FORECE_C.reshape(x_test_L_FORECE_C.shape[0],x_test_L_FORECE_C.shape[1],1)
x_test_L_FSR_C=x_test_L_FSR_C.reshape(x_test_L_FSR_C.shape[0],x_test_L_FSR_C.shape[1],1)

# %%
print(x_train_R_FORECE_B.shape)
print(y_train_L_FORECE_C.shape)
# Out:
# (531, 1, 1)
# (531,)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import LSTM
from tensorflow.keras import layers
from keras.layers import Activation, Dense
import tensorflow as tf 
from tensorflow.keras import Model
from keras.layers import Dropout
from keras.layers import Dense, Input, TimeDistributed, Flatten
from keras.layers.convolutional import Conv1D ,MaxPooling1D
from keras.optimizers import adam
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import LSTM

model_cnn_lstm = Sequential()
model_cnn_lstm.add(TimeDistributed(Conv1D(filters=1000, kernel_size=1, activation='relu'), input_shape=(None, x_train_R_FORECE_B.shape[1], x_train_R_FORECE_B.shape[2])))
model_cnn_lstm.add(TimeDistributed(MaxPooling1D(pool_size=1)))
model_cnn_lstm.add(TimeDistributed(Flatten()))
model_cnn_lstm.add(LSTM(400, activation='relu'))
model_cnn_lstm.add(Dense(1))
model_cnn_lstm.compile(loss='mse', optimizer='adam')
model_cnn_lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, None, 1, 1000)    2000
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, None, 1, 1000)    0
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, None, 1000)       0
#  tributed)
#
#  lstm (LSTM)                 (None, 400)               2241600
#
#  dense (Dense)               (None, 1)                 401
#
# =================================================================
# Total params: 2,244,001
# Trainable params: 2,244,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_cnn_lstm.fit(x_train_R_FORECE_B,y_train_L_FORECE_C,epochs=1000,verbose=2,batch_size=1)
pred=model_cnn_lstm.predict(x_test_L_FORECE_C)
pred=pred.reshape(-1,1)
# Out:
# Epoch 1/1000
# 2023-11-01 14:53:22.721813: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 531/531 - 2s - loss: 17253.8281 - 2s/epoch - 4ms/step
# Epoch 2/1000
# 531/531 - 2s - loss: 16594.6387 - 2s/epoch - 3ms/step
# Epoch 3/1000
# 531/531 - 2s - loss: 16789.4297 - 2s/epoch - 3ms/step
# Epoch 4/1000
# 531/531 - 2s - loss: 15952.9434 - 2s/epoch - 3ms/step
# Epoch 5/1000
# 531/531 - 2s - loss: 16058.9619 - 2s/epoch - 3ms/step
# Epoch 6/1000
# 531/531 - 2s - loss: 15545.8271 - 2s/epoch - 3ms/step
# Epoch 7/1000
# 531/531 - 2s - loss: 15401.9385 - 2s/epoch - 3ms/step
# Epoch 8/1000
# 531/531 - 2s - loss: 13270.6270 - 2s/epoch - 3ms/step
# Epoch 9/1000
# 531/531 - 2s - loss: 10187.5254 - 2s/epoch - 3ms/step
# Epoch 10/1000
# 531/531 - 2s - loss: 10049.6631 - 2s/epoch - 3ms/step
# Epoch 11/1000
# 531/531 - 2s - loss: 10267.0361 - 2s/epoch - 3ms/step
# Epoch 12/1000
# 531/531 - 2s - loss: 10231.4580 - 2s/epoch - 3ms/step
# Epoch 13/1000
# 531/531 - 2s - loss: 10178.7842 - 2s/epoch - 3ms/step
# Epoch 14/1000
# 531/531 - 2s - loss: 10207.8281 - 2s/epoch - 3ms/step
# Epoch 15/1000
# 531/531 - 2s - loss: 10081.5381 - 2s/epoch - 3ms/step
# Epoch 16/1000
# 531/531 - 2s - loss: 10119.2119 - 2s/epoch - 3ms/step
# Epoch 17/1000
# 531/531 - 2s - loss: 9927.3252 - 2s/epoch - 3ms/step
# Epoch 18/1000
# 531/531 - 2s - loss: 9912.1729 - 2s/epoch - 3ms/step
# Epoch 19/1000
# 531/531 - 2s - loss: 10186.8496 - 2s/epoch - 3ms/step
# Epoch 20/1000
# 531/531 - 2s - loss: 10046.1592 - 2s/epoch - 3ms/step
# Epoch 21/1000
# 531/531 - 2s - loss: 10024.1504 - 2s/epoch - 3ms/step
# Epoch 22/1000
# 531/531 - 2s - loss: 10116.4980 - 2s/epoch - 3ms/step
# Epoch 23/1000
# 531/531 - 2s - loss: 9761.6016 - 2s/epoch - 3ms/step
# Epoch 24/1000
# 531/531 - 2s - loss: 9962.4912 - 2s/epoch - 3ms/step
# Epoch 25/1000
# 531/531 - 2s - loss: 9985.6514 - 2s/epoch - 3ms/step
# Epoch 26/1000
# 531/531 - 2s - loss: 10089.1270 - 2s/epoch - 3ms/step
# Epoch 27/1000
# 531/531 - 2s - loss: 9939.7764 - 2s/epoch - 3ms/step
# Epoch 28/1000
# 531/531 - 2s - loss: 10051.0938 - 2s/epoch - 3ms/step
# Epoch 29/1000
# 531/531 - 2s - loss: 9830.4541 - 2s/epoch - 3ms/step
# Epoch 30/1000
# 531/531 - 2s - loss: 9668.7227 - 2s/epoch - 3ms/step
# Epoch 31/1000
# 531/531 - 2s - loss: 9923.6680 - 2s/epoch - 3ms/step
# Epoch 32/1000
# 531/531 - 2s - loss: 10010.3555 - 2s/epoch - 3ms/step
# Epoch 33/1000
# 531/531 - 2s - loss: 10036.6816 - 2s/epoch - 3ms/step
# Epoch 34/1000
# 531/531 - 2s - loss: 10087.7217 - 2s/epoch - 3ms/step
# Epoch 35/1000
# 531/531 - 2s - loss: 9788.9883 - 2s/epoch - 3ms/step
# Epoch 36/1000
# 531/531 - 2s - loss: 9877.6875 - 2s/epoch - 3ms/step
# Epoch 37/1000
# 531/531 - 2s - loss: 9797.9727 - 2s/epoch - 3ms/step
# Epoch 38/1000
# 531/531 - 2s - loss: 9983.3008 - 2s/epoch - 3ms/step
# Epoch 39/1000
# 531/531 - 2s - loss: 9814.0859 - 2s/epoch - 3ms/step
# Epoch 40/1000
# 531/531 - 2s - loss: 9936.9736 - 2s/epoch - 3ms/step
# Epoch 41/1000
# 531/531 - 2s - loss: 10370.6914 - 2s/epoch - 3ms/step
# Epoch 42/1000
# 531/531 - 2s - loss: 10464.1113 - 2s/epoch - 3ms/step
# Epoch 43/1000
# 531/531 - 2s - loss: 10143.2012 - 2s/epoch - 3ms/step
# Epoch 44/1000
# 531/531 - 2s - loss: 9864.1133 - 2s/epoch - 3ms/step
# Epoch 45/1000
# 531/531 - 2s - loss: 9835.5234 - 2s/epoch - 3ms/step
# Epoch 46/1000
# 531/531 - 2s - loss: 9688.5732 - 2s/epoch - 3ms/step
# Epoch 47/1000
# 531/531 - 2s - loss: 11929.9561 - 2s/epoch - 3ms/step
# Epoch 48/1000
# 531/531 - 2s - loss: 10127.3994 - 2s/epoch - 3ms/step
# Epoch 49/1000
# 531/531 - 2s - loss: 10176.4326 - 2s/epoch - 3ms/step
# Epoch 50/1000
# 531/531 - 2s - loss: 9725.7549 - 2s/epoch - 3ms/step
# Epoch 51/1000
# 531/531 - 2s - loss: 9854.0801 - 2s/epoch - 3ms/step
# Epoch 52/1000
# 531/531 - 2s - loss: 10119.3271 - 2s/epoch - 3ms/step
# Epoch 53/1000
# 531/531 - 2s - loss: 10100.6230 - 2s/epoch - 3ms/step
# Epoch 54/1000
# 531/531 - 2s - loss: 9972.5449 - 2s/epoch - 3ms/step
# Epoch 55/1000
# 531/531 - 2s - loss: 10197.8555 - 2s/epoch - 3ms/step
# Epoch 56/1000
# 531/531 - 2s - loss: 10042.7559 - 2s/epoch - 4ms/step
# Epoch 57/1000
# 531/531 - 2s - loss: 9861.0117 - 2s/epoch - 3ms/step
# Epoch 58/1000
# 531/531 - 2s - loss: 9936.8398 - 2s/epoch - 3ms/step
# Epoch 59/1000
# 531/531 - 2s - loss: 10022.3145 - 2s/epoch - 3ms/step
# Epoch 60/1000
# 531/531 - 2s - loss: 9750.2451 - 2s/epoch - 3ms/step
# Epoch 61/1000
# 531/531 - 2s - loss: 9809.3916 - 2s/epoch - 3ms/step
# Epoch 62/1000
# 531/531 - 2s - loss: 9820.8936 - 2s/epoch - 3ms/step
# Epoch 63/1000
# 531/531 - 2s - loss: 9840.7002 - 2s/epoch - 3ms/step
# Epoch 64/1000
# 531/531 - 2s - loss: 9872.9873 - 2s/epoch - 3ms/step
# Epoch 65/1000
# 531/531 - 2s - loss: 9819.6514 - 2s/epoch - 3ms/step
# Epoch 66/1000
# 531/531 - 2s - loss: 9675.3818 - 2s/epoch - 4ms/step
# Epoch 67/1000
# 531/531 - 2s - loss: 9819.3145 - 2s/epoch - 3ms/step
# Epoch 68/1000
# 531/531 - 2s - loss: 9796.4258 - 2s/epoch - 3ms/step
# Epoch 69/1000
# 531/531 - 2s - loss: 9626.3506 - 2s/epoch - 3ms/step
# Epoch 70/1000
# 531/531 - 2s - loss: 9773.2871 - 2s/epoch - 3ms/step
# Epoch 71/1000
# 531/531 - 2s - loss: 9764.7324 - 2s/epoch - 3ms/step
# Epoch 72/1000
# 531/531 - 2s - loss: 9557.4365 - 2s/epoch - 4ms/step
# Epoch 73/1000
# 531/531 - 2s - loss: 9636.5264 - 2s/epoch - 4ms/step
# Epoch 74/1000
# 531/531 - 2s - loss: 9712.2354 - 2s/epoch - 4ms/step
# Epoch 75/1000
# 531/531 - 2s - loss: 9602.0068 - 2s/epoch - 3ms/step
# Epoch 76/1000
# 531/531 - 2s - loss: 9734.8115 - 2s/epoch - 3ms/step
# Epoch 77/1000
# 531/531 - 2s - loss: 9745.9697 - 2s/epoch - 3ms/step
# Epoch 78/1000
# 531/531 - 2s - loss: 9579.9346 - 2s/epoch - 3ms/step
# Epoch 79/1000
# 531/531 - 2s - loss: 9700.0820 - 2s/epoch - 3ms/step
# Epoch 80/1000
# 531/531 - 2s - loss: 9640.8047 - 2s/epoch - 3ms/step
# Epoch 81/1000
# 531/531 - 2s - loss: 9612.6846 - 2s/epoch - 3ms/step
# Epoch 82/1000
# 531/531 - 2s - loss: 9571.4756 - 2s/epoch - 4ms/step
# Epoch 83/1000
# 531/531 - 2s - loss: 9827.4902 - 2s/epoch - 3ms/step
# Epoch 84/1000
# 531/531 - 2s - loss: 9796.6758 - 2s/epoch - 3ms/step
# Epoch 85/1000
# 531/531 - 2s - loss: 9732.5732 - 2s/epoch - 3ms/step
# Epoch 86/1000
# 531/531 - 2s - loss: 9583.4688 - 2s/epoch - 3ms/step
# Epoch 87/1000
# 531/531 - 2s - loss: 9744.1338 - 2s/epoch - 3ms/step
# Epoch 88/1000
# 531/531 - 2s - loss: 9615.1709 - 2s/epoch - 3ms/step
# Epoch 89/1000
# 531/531 - 2s - loss: 9495.8047 - 2s/epoch - 4ms/step
# Epoch 90/1000
# 531/531 - 2s - loss: 9383.4541 - 2s/epoch - 3ms/step
# Epoch 91/1000
# 531/531 - 2s - loss: 9402.9648 - 2s/epoch - 3ms/step
# Epoch 92/1000
# 531/531 - 2s - loss: 9745.3311 - 2s/epoch - 3ms/step
# Epoch 93/1000
# 531/531 - 2s - loss: 9276.9785 - 2s/epoch - 3ms/step
# Epoch 94/1000
# 531/531 - 2s - loss: 9624.2354 - 2s/epoch - 3ms/step
# Epoch 95/1000
# 531/531 - 2s - loss: 9548.2812 - 2s/epoch - 3ms/step
# Epoch 96/1000
# 531/531 - 2s - loss: 9311.7998 - 2s/epoch - 3ms/step
# Epoch 97/1000
# 531/531 - 2s - loss: 9579.0117 - 2s/epoch - 3ms/step
# Epoch 98/1000
# 531/531 - 2s - loss: 9514.1924 - 2s/epoch - 3ms/step
# Epoch 99/1000
# 531/531 - 2s - loss: 9437.9180 - 2s/epoch - 3ms/step
# Epoch 100/1000
# 531/531 - 2s - loss: 9328.0830 - 2s/epoch - 3ms/step
# Epoch 101/1000
# 531/531 - 2s - loss: 9605.7627 - 2s/epoch - 3ms/step
# Epoch 102/1000
# 531/531 - 2s - loss: 9495.0020 - 2s/epoch - 3ms/step
# Epoch 103/1000
# 531/531 - 2s - loss: 9491.8047 - 2s/epoch - 3ms/step
# Epoch 104/1000
# 531/531 - 2s - loss: 9295.8779 - 2s/epoch - 3ms/step
# Epoch 105/1000
# 531/531 - 2s - loss: 9554.6611 - 2s/epoch - 3ms/step
# Epoch 106/1000
# 531/531 - 2s - loss: 9821.4980 - 2s/epoch - 3ms/step
# Epoch 107/1000
# 531/531 - 2s - loss: 9320.9443 - 2s/epoch - 3ms/step
# Epoch 108/1000
# 531/531 - 2s - loss: 9553.2500 - 2s/epoch - 3ms/step
# Epoch 109/1000
# 531/531 - 2s - loss: 9359.1523 - 2s/epoch - 3ms/step
# Epoch 110/1000
# 531/531 - 2s - loss: 9494.9121 - 2s/epoch - 3ms/step
# Epoch 111/1000
# 531/531 - 2s - loss: 9601.7500 - 2s/epoch - 4ms/step
# Epoch 112/1000
# 531/531 - 2s - loss: 9635.6865 - 2s/epoch - 3ms/step
# Epoch 113/1000
# 531/531 - 2s - loss: 9446.6377 - 2s/epoch - 3ms/step
# Epoch 114/1000
# 531/531 - 2s - loss: 9528.7891 - 2s/epoch - 3ms/step
# Epoch 115/1000
# 531/531 - 2s - loss: 9553.8877 - 2s/epoch - 3ms/step
# Epoch 116/1000
# 531/531 - 2s - loss: 9300.7754 - 2s/epoch - 3ms/step
# Epoch 117/1000
# 531/531 - 2s - loss: 9503.9863 - 2s/epoch - 3ms/step
# Epoch 118/1000
# 531/531 - 2s - loss: 9324.2061 - 2s/epoch - 3ms/step
# Epoch 119/1000
# 531/531 - 2s - loss: 9569.0088 - 2s/epoch - 3ms/step
# Epoch 120/1000
# 531/531 - 2s - loss: 9575.5078 - 2s/epoch - 3ms/step
# Epoch 121/1000
# 531/531 - 2s - loss: 9349.1768 - 2s/epoch - 3ms/step
# Epoch 122/1000
# 531/531 - 2s - loss: 9404.6807 - 2s/epoch - 3ms/step
# Epoch 123/1000
# 531/531 - 2s - loss: 9351.3320 - 2s/epoch - 3ms/step
# Epoch 124/1000
# 531/531 - 2s - loss: 9409.3799 - 2s/epoch - 3ms/step
# Epoch 125/1000
# 531/531 - 2s - loss: 9102.1016 - 2s/epoch - 3ms/step
# Epoch 126/1000
# 531/531 - 2s - loss: 9281.2178 - 2s/epoch - 3ms/step
# Epoch 127/1000
# 531/531 - 2s - loss: 9206.5166 - 2s/epoch - 3ms/step
# Epoch 128/1000
# 531/531 - 2s - loss: 9666.8389 - 2s/epoch - 3ms/step
# Epoch 129/1000
# 531/531 - 2s - loss: 9458.9209 - 2s/epoch - 3ms/step
# Epoch 130/1000
# 531/531 - 2s - loss: 9502.8564 - 2s/epoch - 3ms/step
# Epoch 131/1000
# 531/531 - 2s - loss: 9231.4248 - 2s/epoch - 3ms/step
# Epoch 132/1000
# 531/531 - 2s - loss: 9801.4189 - 2s/epoch - 3ms/step
# Epoch 133/1000
# 531/531 - 2s - loss: 9621.8564 - 2s/epoch - 3ms/step
# Epoch 134/1000
# 531/531 - 2s - loss: 9598.2842 - 2s/epoch - 3ms/step
# Epoch 135/1000
# 531/531 - 2s - loss: 9516.4873 - 2s/epoch - 3ms/step
# Epoch 136/1000
# 531/531 - 2s - loss: 9581.5879 - 2s/epoch - 3ms/step
# Epoch 137/1000
# 531/531 - 2s - loss: 9300.1250 - 2s/epoch - 3ms/step
# Epoch 138/1000
# 531/531 - 2s - loss: 9478.5107 - 2s/epoch - 3ms/step
# Epoch 139/1000
# 531/531 - 2s - loss: 9404.4922 - 2s/epoch - 3ms/step
# Epoch 140/1000
# 531/531 - 2s - loss: 9568.8789 - 2s/epoch - 3ms/step
# Epoch 141/1000
# 531/531 - 2s - loss: 9594.9863 - 2s/epoch - 3ms/step
# Epoch 142/1000
# 531/531 - 2s - loss: 9272.3926 - 2s/epoch - 3ms/step
# Epoch 143/1000
# 531/531 - 2s - loss: 9359.4785 - 2s/epoch - 3ms/step
# Epoch 144/1000
# 531/531 - 2s - loss: 9110.8242 - 2s/epoch - 3ms/step
# Epoch 145/1000
# 531/531 - 2s - loss: 9263.4268 - 2s/epoch - 3ms/step
# Epoch 146/1000
# 531/531 - 2s - loss: 9199.6709 - 2s/epoch - 3ms/step
# Epoch 147/1000
# 531/531 - 2s - loss: 8991.7598 - 2s/epoch - 3ms/step
# Epoch 148/1000
# 531/531 - 2s - loss: 9160.6904 - 2s/epoch - 3ms/step
# Epoch 149/1000
# 531/531 - 2s - loss: 8828.5156 - 2s/epoch - 3ms/step
# Epoch 150/1000
# 531/531 - 2s - loss: 9045.1826 - 2s/epoch - 3ms/step
# Epoch 151/1000
# 531/531 - 2s - loss: 8693.4316 - 2s/epoch - 3ms/step
# Epoch 152/1000
# 531/531 - 2s - loss: 8877.6475 - 2s/epoch - 3ms/step
# Epoch 153/1000
# 531/531 - 2s - loss: 8790.5508 - 2s/epoch - 3ms/step
# Epoch 154/1000
# 531/531 - 2s - loss: 8896.2480 - 2s/epoch - 3ms/step
# Epoch 155/1000
# 531/531 - 2s - loss: 8763.8252 - 2s/epoch - 3ms/step
# Epoch 156/1000
# 531/531 - 2s - loss: 8997.4102 - 2s/epoch - 3ms/step
# Epoch 157/1000
# 531/531 - 2s - loss: 9290.0488 - 2s/epoch - 3ms/step
# Epoch 158/1000
# 531/531 - 2s - loss: 8980.6650 - 2s/epoch - 3ms/step
# Epoch 159/1000
# 531/531 - 2s - loss: 9148.6406 - 2s/epoch - 3ms/step
# Epoch 160/1000
# 531/531 - 2s - loss: 9036.5654 - 2s/epoch - 3ms/step
# Epoch 161/1000
# 531/531 - 2s - loss: 8710.8506 - 2s/epoch - 3ms/step
# Epoch 162/1000
# 531/531 - 2s - loss: 8442.3779 - 2s/epoch - 3ms/step
# Epoch 163/1000
# 531/531 - 2s - loss: 9394.2539 - 2s/epoch - 3ms/step
# Epoch 164/1000
# 531/531 - 2s - loss: 9318.2637 - 2s/epoch - 3ms/step
# Epoch 165/1000
# 531/531 - 2s - loss: 9267.5283 - 2s/epoch - 3ms/step
# Epoch 166/1000
# 531/531 - 2s - loss: 8840.2139 - 2s/epoch - 3ms/step
# Epoch 167/1000
# 531/531 - 2s - loss: 8954.1260 - 2s/epoch - 3ms/step
# Epoch 168/1000
# 531/531 - 2s - loss: 8761.7461 - 2s/epoch - 3ms/step
# Epoch 169/1000
# 531/531 - 2s - loss: 9709.1504 - 2s/epoch - 3ms/step
# Epoch 170/1000
# 531/531 - 2s - loss: 9046.0459 - 2s/epoch - 3ms/step
# Epoch 171/1000
# 531/531 - 2s - loss: 9221.1152 - 2s/epoch - 3ms/step
# Epoch 172/1000
# 531/531 - 2s - loss: 8747.8291 - 2s/epoch - 3ms/step
# Epoch 173/1000
# 531/531 - 2s - loss: 8391.5049 - 2s/epoch - 3ms/step
# Epoch 174/1000
# 531/531 - 2s - loss: 8380.7510 - 2s/epoch - 3ms/step
# Epoch 175/1000
# 531/531 - 2s - loss: 8488.8203 - 2s/epoch - 3ms/step
# Epoch 176/1000
# 531/531 - 2s - loss: 8303.6865 - 2s/epoch - 3ms/step
# Epoch 177/1000
# 531/531 - 2s - loss: 8737.6016 - 2s/epoch - 3ms/step
# Epoch 178/1000
# 531/531 - 2s - loss: 8365.8242 - 2s/epoch - 3ms/step
# Epoch 179/1000
# 531/531 - 2s - loss: 8320.0381 - 2s/epoch - 3ms/step
# Epoch 180/1000
# 531/531 - 2s - loss: 8039.7026 - 2s/epoch - 3ms/step
# Epoch 181/1000
# 531/531 - 2s - loss: 8367.4990 - 2s/epoch - 3ms/step
# Epoch 182/1000
# 531/531 - 2s - loss: 8283.7754 - 2s/epoch - 3ms/step
# Epoch 183/1000
# 531/531 - 2s - loss: 8180.2920 - 2s/epoch - 3ms/step
# Epoch 184/1000
# 531/531 - 2s - loss: 8418.3613 - 2s/epoch - 3ms/step
# Epoch 185/1000
# 531/531 - 2s - loss: 8052.8267 - 2s/epoch - 3ms/step
# Epoch 186/1000
# 531/531 - 2s - loss: 8381.8945 - 2s/epoch - 3ms/step
# Epoch 187/1000
# 531/531 - 2s - loss: 9555.6660 - 2s/epoch - 3ms/step
# Epoch 188/1000
# 531/531 - 2s - loss: 9099.7314 - 2s/epoch - 3ms/step
# Epoch 189/1000
# 531/531 - 2s - loss: 8982.1660 - 2s/epoch - 3ms/step
# Epoch 190/1000
# 531/531 - 2s - loss: 8793.6533 - 2s/epoch - 3ms/step
# Epoch 191/1000
# 531/531 - 2s - loss: 8623.0996 - 2s/epoch - 3ms/step
# Epoch 192/1000
# 531/531 - 2s - loss: 8585.1924 - 2s/epoch - 3ms/step
# Epoch 193/1000
# 531/531 - 2s - loss: 8641.1338 - 2s/epoch - 3ms/step
# Epoch 194/1000
# 531/531 - 2s - loss: 8831.3789 - 2s/epoch - 3ms/step
# Epoch 195/1000
# 531/531 - 2s - loss: 9168.2559 - 2s/epoch - 3ms/step
# Epoch 196/1000
# 531/531 - 2s - loss: 9189.4980 - 2s/epoch - 3ms/step
# Epoch 197/1000
# 531/531 - 2s - loss: 8627.3604 - 2s/epoch - 3ms/step
# Epoch 198/1000
# 531/531 - 2s - loss: 8131.8105 - 2s/epoch - 3ms/step
# Epoch 199/1000
# 531/531 - 2s - loss: 8434.2695 - 2s/epoch - 3ms/step
# Epoch 200/1000
# 531/531 - 2s - loss: 8313.7861 - 2s/epoch - 3ms/step
# Epoch 201/1000
# 531/531 - 2s - loss: 8356.9561 - 2s/epoch - 3ms/step
# Epoch 202/1000
# 531/531 - 2s - loss: 8152.5952 - 2s/epoch - 3ms/step
# Epoch 203/1000
# 531/531 - 2s - loss: 8080.9331 - 2s/epoch - 3ms/step
# Epoch 204/1000
# 531/531 - 2s - loss: 8253.0479 - 2s/epoch - 3ms/step
# Epoch 205/1000
# 531/531 - 2s - loss: 8138.8315 - 2s/epoch - 3ms/step
# Epoch 206/1000
# 531/531 - 2s - loss: 7985.8652 - 2s/epoch - 3ms/step
# Epoch 207/1000
# 531/531 - 2s - loss: 9260.9863 - 2s/epoch - 3ms/step
# Epoch 208/1000
# 531/531 - 2s - loss: 8700.5127 - 2s/epoch - 3ms/step
# Epoch 209/1000
# 531/531 - 2s - loss: 8750.3975 - 2s/epoch - 3ms/step
# Epoch 210/1000
# 531/531 - 2s - loss: 8403.1973 - 2s/epoch - 3ms/step
# Epoch 211/1000
# 531/531 - 2s - loss: 8571.9854 - 2s/epoch - 3ms/step
# Epoch 212/1000
# 531/531 - 2s - loss: 8067.5312 - 2s/epoch - 3ms/step
# Epoch 213/1000
# 531/531 - 2s - loss: 8072.6064 - 2s/epoch - 3ms/step
# Epoch 214/1000
# 531/531 - 2s - loss: 8358.0068 - 2s/epoch - 3ms/step
# Epoch 215/1000
# 531/531 - 2s - loss: 8214.6807 - 2s/epoch - 3ms/step
# Epoch 216/1000
# 531/531 - 2s - loss: 8298.5879 - 2s/epoch - 4ms/step
# Epoch 217/1000
# 531/531 - 2s - loss: 7978.6318 - 2s/epoch - 3ms/step
# Epoch 218/1000
# 531/531 - 2s - loss: 7960.0459 - 2s/epoch - 3ms/step
# Epoch 219/1000
# 531/531 - 2s - loss: 7816.8105 - 2s/epoch - 3ms/step
# Epoch 220/1000
# 531/531 - 2s - loss: 8091.5557 - 2s/epoch - 3ms/step
# Epoch 221/1000
# 531/531 - 2s - loss: 7887.9487 - 2s/epoch - 3ms/step
# Epoch 222/1000
# 531/531 - 2s - loss: 8439.8740 - 2s/epoch - 3ms/step
# Epoch 223/1000
# 531/531 - 2s - loss: 8121.1646 - 2s/epoch - 3ms/step
# Epoch 224/1000
# 531/531 - 2s - loss: 8075.2183 - 2s/epoch - 3ms/step
# Epoch 225/1000
# 531/531 - 2s - loss: 7783.9634 - 2s/epoch - 3ms/step
# Epoch 226/1000
# 531/531 - 2s - loss: 8280.5918 - 2s/epoch - 3ms/step
# Epoch 227/1000
# 531/531 - 2s - loss: 7748.8184 - 2s/epoch - 3ms/step
# Epoch 228/1000
# 531/531 - 2s - loss: 8191.3540 - 2s/epoch - 3ms/step
# Epoch 229/1000
# 531/531 - 2s - loss: 7531.7588 - 2s/epoch - 3ms/step
# Epoch 230/1000
# 531/531 - 2s - loss: 7700.9233 - 2s/epoch - 3ms/step
# Epoch 231/1000
# 531/531 - 2s - loss: 7893.1553 - 2s/epoch - 3ms/step
# Epoch 232/1000
# 531/531 - 2s - loss: 7623.0483 - 2s/epoch - 4ms/step
# Epoch 233/1000
# 531/531 - 2s - loss: 8741.0078 - 2s/epoch - 4ms/step
# Epoch 234/1000
# 531/531 - 2s - loss: 7958.7617 - 2s/epoch - 3ms/step
# Epoch 235/1000
# 531/531 - 2s - loss: 7783.6641 - 2s/epoch - 3ms/step
# Epoch 236/1000
# 531/531 - 2s - loss: 7667.3633 - 2s/epoch - 4ms/step
# Epoch 237/1000
# 531/531 - 2s - loss: 7660.4106 - 2s/epoch - 3ms/step
# Epoch 238/1000
# 531/531 - 2s - loss: 7640.3003 - 2s/epoch - 4ms/step
# Epoch 239/1000
# 531/531 - 2s - loss: 8720.3984 - 2s/epoch - 3ms/step
# Epoch 240/1000
# 531/531 - 2s - loss: 8623.5986 - 2s/epoch - 3ms/step
# Epoch 241/1000
# 531/531 - 2s - loss: 8311.2441 - 2s/epoch - 3ms/step
# Epoch 242/1000
# 531/531 - 2s - loss: 9095.5742 - 2s/epoch - 3ms/step
# Epoch 243/1000
# 531/531 - 2s - loss: 8631.5830 - 2s/epoch - 3ms/step
# Epoch 244/1000
# 531/531 - 2s - loss: 8119.7261 - 2s/epoch - 3ms/step
# Epoch 245/1000
# 531/531 - 2s - loss: 8212.6992 - 2s/epoch - 3ms/step
# Epoch 246/1000
# 531/531 - 2s - loss: 7984.5376 - 2s/epoch - 3ms/step
# Epoch 247/1000
# 531/531 - 2s - loss: 8585.9883 - 2s/epoch - 4ms/step
# Epoch 248/1000
# 531/531 - 2s - loss: 8115.9595 - 2s/epoch - 4ms/step
# Epoch 249/1000
# 531/531 - 2s - loss: 8174.5972 - 2s/epoch - 3ms/step
# Epoch 250/1000
# 531/531 - 2s - loss: 8070.1763 - 2s/epoch - 3ms/step
# Epoch 251/1000
# 531/531 - 2s - loss: 8981.3926 - 2s/epoch - 3ms/step
# Epoch 252/1000
# 531/531 - 2s - loss: 8549.2236 - 2s/epoch - 3ms/step
# Epoch 253/1000
# 531/531 - 2s - loss: 8390.6650 - 2s/epoch - 3ms/step
# Epoch 254/1000
# 531/531 - 2s - loss: 7992.1206 - 2s/epoch - 3ms/step
# Epoch 255/1000
# 531/531 - 2s - loss: 8231.3340 - 2s/epoch - 3ms/step
# Epoch 256/1000
# 531/531 - 2s - loss: 8035.2588 - 2s/epoch - 3ms/step
# Epoch 257/1000
# 531/531 - 2s - loss: 8338.9678 - 2s/epoch - 4ms/step
# Epoch 258/1000
# 531/531 - 2s - loss: 7828.3276 - 2s/epoch - 3ms/step
# Epoch 259/1000
# 531/531 - 2s - loss: 8269.7236 - 2s/epoch - 3ms/step
# Epoch 260/1000
# 531/531 - 2s - loss: 7754.3350 - 2s/epoch - 3ms/step
# Epoch 261/1000
# 531/531 - 2s - loss: 7804.8706 - 2s/epoch - 3ms/step
# Epoch 262/1000
# 531/531 - 2s - loss: 7813.2935 - 2s/epoch - 3ms/step
# Epoch 263/1000
# 531/531 - 2s - loss: 7766.0176 - 2s/epoch - 3ms/step
# Epoch 264/1000
# 531/531 - 2s - loss: 7798.7378 - 2s/epoch - 3ms/step
# Epoch 265/1000
# 531/531 - 2s - loss: 7698.4067 - 2s/epoch - 3ms/step
# Epoch 266/1000
# 531/531 - 2s - loss: 7622.3701 - 2s/epoch - 3ms/step
# Epoch 267/1000
# 531/531 - 2s - loss: 7922.8354 - 2s/epoch - 3ms/step
# Epoch 268/1000
# 531/531 - 2s - loss: 7863.8955 - 2s/epoch - 3ms/step
# Epoch 269/1000
# 531/531 - 2s - loss: 7765.9731 - 2s/epoch - 3ms/step
# Epoch 270/1000
# 531/531 - 2s - loss: 7587.6450 - 2s/epoch - 3ms/step
# Epoch 271/1000
# 531/531 - 2s - loss: 7461.4355 - 2s/epoch - 3ms/step
# Epoch 272/1000
# 531/531 - 2s - loss: 7627.9336 - 2s/epoch - 3ms/step
# Epoch 273/1000
# 531/531 - 2s - loss: 8148.1157 - 2s/epoch - 3ms/step
# Epoch 274/1000
# 531/531 - 2s - loss: 7659.5708 - 2s/epoch - 3ms/step
# Epoch 275/1000
# 531/531 - 2s - loss: 7680.9272 - 2s/epoch - 3ms/step
# Epoch 276/1000
# 531/531 - 2s - loss: 7653.3745 - 2s/epoch - 3ms/step
# Epoch 277/1000
# 531/531 - 2s - loss: 7860.7847 - 2s/epoch - 3ms/step
# Epoch 278/1000
# 531/531 - 2s - loss: 7555.7856 - 2s/epoch - 3ms/step
# Epoch 279/1000
# 531/531 - 2s - loss: 7594.9219 - 2s/epoch - 3ms/step
# Epoch 280/1000
# 531/531 - 2s - loss: 7507.8325 - 2s/epoch - 3ms/step
# Epoch 281/1000
# 531/531 - 2s - loss: 7468.8584 - 2s/epoch - 3ms/step
# Epoch 282/1000
# 531/531 - 2s - loss: 7581.6538 - 2s/epoch - 3ms/step
# Epoch 283/1000
# 531/531 - 2s - loss: 7453.2861 - 2s/epoch - 3ms/step
# Epoch 284/1000
# 531/531 - 2s - loss: 7722.9219 - 2s/epoch - 4ms/step
# Epoch 285/1000
# 531/531 - 2s - loss: 7565.3027 - 2s/epoch - 3ms/step
# Epoch 286/1000
# 531/531 - 2s - loss: 7304.2695 - 2s/epoch - 4ms/step
# Epoch 287/1000
# 531/531 - 2s - loss: 8797.7959 - 2s/epoch - 3ms/step
# Epoch 288/1000
# 531/531 - 2s - loss: 7828.3145 - 2s/epoch - 4ms/step
# Epoch 289/1000
# 531/531 - 2s - loss: 7475.3452 - 2s/epoch - 4ms/step
# Epoch 290/1000
# 531/531 - 2s - loss: 7390.4521 - 2s/epoch - 4ms/step
# Epoch 291/1000
# 531/531 - 2s - loss: 7261.0171 - 2s/epoch - 4ms/step
# Epoch 292/1000
# 531/531 - 2s - loss: 7631.6138 - 2s/epoch - 3ms/step
# Epoch 293/1000
# 531/531 - 2s - loss: 7681.1333 - 2s/epoch - 3ms/step
# Epoch 294/1000
# 531/531 - 2s - loss: 7300.8804 - 2s/epoch - 4ms/step
# Epoch 295/1000
# 531/531 - 2s - loss: 7438.5044 - 2s/epoch - 4ms/step
# Epoch 296/1000
# 531/531 - 2s - loss: 7503.3633 - 2s/epoch - 3ms/step
# Epoch 297/1000
# 531/531 - 2s - loss: 7301.8232 - 2s/epoch - 4ms/step
# Epoch 298/1000
# 531/531 - 2s - loss: 7557.2788 - 2s/epoch - 4ms/step
# Epoch 299/1000
# 531/531 - 2s - loss: 7362.2378 - 2s/epoch - 3ms/step
# Epoch 300/1000
# 531/531 - 2s - loss: 7430.7305 - 2s/epoch - 4ms/step
# Epoch 301/1000
# 531/531 - 2s - loss: 7263.7266 - 2s/epoch - 4ms/step
# Epoch 302/1000
# 531/531 - 2s - loss: 7243.2505 - 2s/epoch - 4ms/step
# Epoch 303/1000
# 531/531 - 2s - loss: 7299.2646 - 2s/epoch - 4ms/step
# Epoch 304/1000
# 531/531 - 2s - loss: 7701.3926 - 2s/epoch - 4ms/step
# Epoch 305/1000
# 531/531 - 2s - loss: 8664.2637 - 2s/epoch - 4ms/step
# Epoch 306/1000
# 531/531 - 2s - loss: 7707.9897 - 2s/epoch - 4ms/step
# Epoch 307/1000
# 531/531 - 2s - loss: 7668.6758 - 2s/epoch - 4ms/step
# Epoch 308/1000
# 531/531 - 2s - loss: 7358.0015 - 2s/epoch - 4ms/step
# Epoch 309/1000
# 531/531 - 2s - loss: 7395.1528 - 2s/epoch - 4ms/step
# Epoch 310/1000
# 531/531 - 2s - loss: 7406.3325 - 2s/epoch - 4ms/step
# Epoch 311/1000
# 531/531 - 2s - loss: 7404.4653 - 2s/epoch - 4ms/step
# Epoch 312/1000
# 531/531 - 2s - loss: 7367.3418 - 2s/epoch - 4ms/step
# Epoch 313/1000
# 531/531 - 2s - loss: 7340.4951 - 2s/epoch - 4ms/step
# Epoch 314/1000
# 531/531 - 2s - loss: 8375.3252 - 2s/epoch - 4ms/step
# Epoch 315/1000
# 531/531 - 2s - loss: 7325.0825 - 2s/epoch - 4ms/step
# Epoch 316/1000
# 531/531 - 2s - loss: 7418.6494 - 2s/epoch - 4ms/step
# Epoch 317/1000
# 531/531 - 2s - loss: 7400.9653 - 2s/epoch - 4ms/step
# Epoch 318/1000
# 531/531 - 2s - loss: 7515.0459 - 2s/epoch - 4ms/step
# Epoch 319/1000
# 531/531 - 2s - loss: 7782.7422 - 2s/epoch - 3ms/step
# Epoch 320/1000
# 531/531 - 2s - loss: 7343.5020 - 2s/epoch - 3ms/step
# Epoch 321/1000
# 531/531 - 2s - loss: 7429.5840 - 2s/epoch - 4ms/step
# Epoch 322/1000
# 531/531 - 2s - loss: 7358.1870 - 2s/epoch - 3ms/step
# Epoch 323/1000
# 531/531 - 2s - loss: 7287.0396 - 2s/epoch - 4ms/step
# Epoch 324/1000
# 531/531 - 2s - loss: 7358.3545 - 2s/epoch - 4ms/step
# Epoch 325/1000
# 531/531 - 2s - loss: 7427.5161 - 2s/epoch - 4ms/step
# Epoch 326/1000
# 531/531 - 2s - loss: 7429.3643 - 2s/epoch - 4ms/step
# Epoch 327/1000
# 531/531 - 2s - loss: 7450.3369 - 2s/epoch - 4ms/step
# Epoch 328/1000
# 531/531 - 2s - loss: 7362.8281 - 2s/epoch - 4ms/step
# Epoch 329/1000
# 531/531 - 2s - loss: 7266.0615 - 2s/epoch - 4ms/step
# Epoch 330/1000
# 531/531 - 2s - loss: 7514.5078 - 2s/epoch - 4ms/step
# Epoch 331/1000
# 531/531 - 2s - loss: 7315.0576 - 2s/epoch - 4ms/step
# Epoch 332/1000
# 531/531 - 2s - loss: 7211.7656 - 2s/epoch - 3ms/step
# Epoch 333/1000
# 531/531 - 2s - loss: 7250.8521 - 2s/epoch - 3ms/step
# Epoch 334/1000
# 531/531 - 2s - loss: 7282.9863 - 2s/epoch - 3ms/step
# Epoch 335/1000
# 531/531 - 2s - loss: 7254.6489 - 2s/epoch - 3ms/step
# Epoch 336/1000
# 531/531 - 2s - loss: 7288.5337 - 2s/epoch - 4ms/step
# Epoch 337/1000
# 531/531 - 2s - loss: 7293.1885 - 2s/epoch - 3ms/step
# Epoch 338/1000
# 531/531 - 2s - loss: 7276.5459 - 2s/epoch - 3ms/step
# Epoch 339/1000
# 531/531 - 2s - loss: 7270.8208 - 2s/epoch - 3ms/step
# Epoch 340/1000
# 531/531 - 2s - loss: 7226.8618 - 2s/epoch - 3ms/step
# Epoch 341/1000
# 531/531 - 2s - loss: 7278.7114 - 2s/epoch - 3ms/step
# Epoch 342/1000
# 531/531 - 2s - loss: 7320.5205 - 2s/epoch - 3ms/step
# Epoch 343/1000
# 531/531 - 2s - loss: 7283.8530 - 2s/epoch - 4ms/step
# Epoch 344/1000
# 531/531 - 2s - loss: 7269.1860 - 2s/epoch - 3ms/step
# Epoch 345/1000
# 531/531 - 2s - loss: 7354.5312 - 2s/epoch - 3ms/step
# Epoch 346/1000
# 531/531 - 2s - loss: 7286.9834 - 2s/epoch - 3ms/step
# Epoch 347/1000
# 531/531 - 2s - loss: 7274.8281 - 2s/epoch - 4ms/step
# Epoch 348/1000
# 531/531 - 2s - loss: 7198.8350 - 2s/epoch - 3ms/step
# Epoch 349/1000
# 531/531 - 2s - loss: 7295.7896 - 2s/epoch - 3ms/step
# Epoch 350/1000
# 531/531 - 2s - loss: 7319.8135 - 2s/epoch - 3ms/step
# Epoch 351/1000
# 531/531 - 19s - loss: 7320.9292 - 19s/epoch - 37ms/step
# Epoch 352/1000
# 531/531 - 2s - loss: 7325.7769 - 2s/epoch - 3ms/step
# Epoch 353/1000
# 531/531 - 2s - loss: 7402.0117 - 2s/epoch - 3ms/step
# Epoch 354/1000
# 531/531 - 2s - loss: 7284.2944 - 2s/epoch - 3ms/step
# Epoch 355/1000
# 531/531 - 2s - loss: 7389.6436 - 2s/epoch - 3ms/step
# Epoch 356/1000
# 531/531 - 4s - loss: 7067.3223 - 4s/epoch - 7ms/step
# Epoch 357/1000
# 531/531 - 2s - loss: 7227.6294 - 2s/epoch - 3ms/step
# Epoch 358/1000
# 531/531 - 2s - loss: 7325.8496 - 2s/epoch - 3ms/step
# Epoch 359/1000
# 531/531 - 2s - loss: 7339.1777 - 2s/epoch - 3ms/step
# Epoch 360/1000
# 531/531 - 2s - loss: 7251.3330 - 2s/epoch - 3ms/step
# Epoch 361/1000
# 531/531 - 2s - loss: 7222.1650 - 2s/epoch - 3ms/step
# Epoch 362/1000
# 531/531 - 2s - loss: 7256.7686 - 2s/epoch - 3ms/step
# Epoch 363/1000
# 531/531 - 2s - loss: 7498.6787 - 2s/epoch - 3ms/step
# Epoch 364/1000
# 531/531 - 2s - loss: 7317.7759 - 2s/epoch - 3ms/step
# Epoch 365/1000
# 531/531 - 2s - loss: 7231.0361 - 2s/epoch - 3ms/step
# Epoch 366/1000
# 531/531 - 2s - loss: 7243.2837 - 2s/epoch - 3ms/step
# Epoch 367/1000
# 531/531 - 2s - loss: 7346.2163 - 2s/epoch - 3ms/step
# Epoch 368/1000
# 531/531 - 2s - loss: 7466.6792 - 2s/epoch - 3ms/step
# Epoch 369/1000
# 531/531 - 2s - loss: 7362.6455 - 2s/epoch - 3ms/step
# Epoch 370/1000
# 531/531 - 2s - loss: 7165.5679 - 2s/epoch - 3ms/step
# Epoch 371/1000
# 531/531 - 2s - loss: 7889.3174 - 2s/epoch - 3ms/step
# Epoch 372/1000
# 531/531 - 2s - loss: 7193.6201 - 2s/epoch - 3ms/step
# Epoch 373/1000
# 531/531 - 2s - loss: 7128.2783 - 2s/epoch - 3ms/step
# Epoch 374/1000
# 531/531 - 2s - loss: 7406.7925 - 2s/epoch - 3ms/step
# Epoch 375/1000
# 531/531 - 2s - loss: 7270.8936 - 2s/epoch - 3ms/step
# Epoch 376/1000
# 531/531 - 2s - loss: 7467.1895 - 2s/epoch - 3ms/step
# Epoch 377/1000
# 531/531 - 2s - loss: 7223.2002 - 2s/epoch - 3ms/step
# Epoch 378/1000
# 531/531 - 2s - loss: 7219.7344 - 2s/epoch - 3ms/step
# Epoch 379/1000
# 531/531 - 243s - loss: 7239.7793 - 243s/epoch - 458ms/step
# Epoch 380/1000
# 531/531 - 2s - loss: 7254.6021 - 2s/epoch - 3ms/step
# Epoch 381/1000
# 531/531 - 2s - loss: 7240.9941 - 2s/epoch - 3ms/step
# Epoch 382/1000
# 531/531 - 2s - loss: 7145.6694 - 2s/epoch - 3ms/step
# Epoch 383/1000
# 531/531 - 2s - loss: 7832.5962 - 2s/epoch - 3ms/step
# Epoch 384/1000
# 531/531 - 2s - loss: 9979.5811 - 2s/epoch - 3ms/step
# Epoch 385/1000
# 531/531 - 2s - loss: 9923.7861 - 2s/epoch - 3ms/step
# Epoch 386/1000
# 531/531 - 2s - loss: 9726.5088 - 2s/epoch - 3ms/step
# Epoch 387/1000
# 531/531 - 2s - loss: 9839.8359 - 2s/epoch - 3ms/step
# Epoch 388/1000
# 531/531 - 2s - loss: 9686.0029 - 2s/epoch - 3ms/step
# Epoch 389/1000
# 531/531 - 2s - loss: 9682.8848 - 2s/epoch - 3ms/step
# Epoch 390/1000
# 531/531 - 2s - loss: 9678.7666 - 2s/epoch - 3ms/step
# Epoch 391/1000
# 531/531 - 2s - loss: 9708.8857 - 2s/epoch - 3ms/step
# Epoch 392/1000
# 531/531 - 2s - loss: 9604.9170 - 2s/epoch - 3ms/step
# Epoch 393/1000
# 531/531 - 2s - loss: 9585.6201 - 2s/epoch - 3ms/step
# Epoch 394/1000
# 531/531 - 2s - loss: 9619.0508 - 2s/epoch - 3ms/step
# Epoch 395/1000
# 531/531 - 2s - loss: 9682.2471 - 2s/epoch - 3ms/step
# Epoch 396/1000
# 531/531 - 2s - loss: 9644.3027 - 2s/epoch - 3ms/step
# Epoch 397/1000
# 531/531 - 2s - loss: 9536.7002 - 2s/epoch - 3ms/step
# Epoch 398/1000
# 531/531 - 2s - loss: 9576.0195 - 2s/epoch - 3ms/step
# Epoch 399/1000
# 531/531 - 2s - loss: 9365.8936 - 2s/epoch - 3ms/step
# Epoch 400/1000
# 531/531 - 2s - loss: 9442.2363 - 2s/epoch - 3ms/step
# Epoch 401/1000
# 531/531 - 2s - loss: 9383.1533 - 2s/epoch - 3ms/step
# Epoch 402/1000
# 531/531 - 2s - loss: 9358.8535 - 2s/epoch - 3ms/step
# Epoch 403/1000
# 531/531 - 2s - loss: 9360.7334 - 2s/epoch - 3ms/step
# Epoch 404/1000
# 531/531 - 2s - loss: 9367.3232 - 2s/epoch - 3ms/step
# Epoch 405/1000
# 531/531 - 2s - loss: 9118.7441 - 2s/epoch - 3ms/step
# Epoch 406/1000
# 531/531 - 2s - loss: 9142.7920 - 2s/epoch - 3ms/step
# Epoch 407/1000
# 531/531 - 2s - loss: 8961.1055 - 2s/epoch - 3ms/step
# Epoch 408/1000
# 531/531 - 73s - loss: 8997.5371 - 73s/epoch - 137ms/step
# Epoch 409/1000
# 531/531 - 2s - loss: 9030.9482 - 2s/epoch - 3ms/step
# Epoch 410/1000
# 531/531 - 2s - loss: 8800.4990 - 2s/epoch - 3ms/step
# Epoch 411/1000
# 531/531 - 2s - loss: 8831.2930 - 2s/epoch - 3ms/step
# Epoch 412/1000
# 531/531 - 2s - loss: 8744.5459 - 2s/epoch - 3ms/step
# Epoch 413/1000
# 531/531 - 2s - loss: 8812.3232 - 2s/epoch - 3ms/step
# Epoch 414/1000
# 531/531 - 2s - loss: 8663.2803 - 2s/epoch - 3ms/step
# Epoch 415/1000
# 531/531 - 2s - loss: 8660.5723 - 2s/epoch - 3ms/step
# Epoch 416/1000
# 531/531 - 2s - loss: 8647.9941 - 2s/epoch - 3ms/step
# Epoch 417/1000
# 531/531 - 2s - loss: 8568.1270 - 2s/epoch - 3ms/step
# Epoch 418/1000
# 531/531 - 2s - loss: 8425.2783 - 2s/epoch - 3ms/step
# Epoch 419/1000
# 531/531 - 2s - loss: 8617.3945 - 2s/epoch - 3ms/step
# Epoch 420/1000
# 531/531 - 2s - loss: 8182.6938 - 2s/epoch - 3ms/step
# Epoch 421/1000
# 531/531 - 2s - loss: 8456.8584 - 2s/epoch - 3ms/step
# Epoch 422/1000
# 531/531 - 2s - loss: 8151.2778 - 2s/epoch - 3ms/step
# Epoch 423/1000
# 531/531 - 2s - loss: 7766.7852 - 2s/epoch - 3ms/step
# Epoch 424/1000
# 531/531 - 2s - loss: 7637.5576 - 2s/epoch - 3ms/step
# Epoch 425/1000
# 531/531 - 2s - loss: 7887.4688 - 2s/epoch - 3ms/step
# Epoch 426/1000
# 531/531 - 2s - loss: 7609.1025 - 2s/epoch - 3ms/step
# Epoch 427/1000
# 531/531 - 2s - loss: 7578.4971 - 2s/epoch - 3ms/step
# Epoch 428/1000
# 531/531 - 2s - loss: 7557.9893 - 2s/epoch - 3ms/step
# Epoch 429/1000
# 531/531 - 2s - loss: 7516.7451 - 2s/epoch - 3ms/step
# Epoch 430/1000
# 531/531 - 2s - loss: 7423.3901 - 2s/epoch - 3ms/step
# Epoch 431/1000
# 531/531 - 2s - loss: 7524.2397 - 2s/epoch - 3ms/step
# Epoch 432/1000
# 531/531 - 2s - loss: 7429.0718 - 2s/epoch - 3ms/step
# Epoch 433/1000
# 531/531 - 2s - loss: 7332.1582 - 2s/epoch - 3ms/step
# Epoch 434/1000
# 531/531 - 2s - loss: 7416.5723 - 2s/epoch - 3ms/step
# Epoch 435/1000
# 531/531 - 2s - loss: 7373.8965 - 2s/epoch - 3ms/step
# Epoch 436/1000
# 531/531 - 2s - loss: 7382.9351 - 2s/epoch - 3ms/step
# Epoch 437/1000
# 531/531 - 59s - loss: 7429.5713 - 59s/epoch - 112ms/step
# Epoch 438/1000
# 531/531 - 2s - loss: 7358.2349 - 2s/epoch - 3ms/step
# Epoch 439/1000
# 531/531 - 2s - loss: 7422.4863 - 2s/epoch - 3ms/step
# Epoch 440/1000
# 531/531 - 2s - loss: 7362.4805 - 2s/epoch - 3ms/step
# Epoch 441/1000
# 531/531 - 2s - loss: 7440.7422 - 2s/epoch - 3ms/step
# Epoch 442/1000
# 531/531 - 2s - loss: 7314.8125 - 2s/epoch - 3ms/step
# Epoch 443/1000
# 531/531 - 2s - loss: 7305.1704 - 2s/epoch - 3ms/step
# Epoch 444/1000
# 531/531 - 2s - loss: 7295.4292 - 2s/epoch - 3ms/step
# Epoch 445/1000
# 531/531 - 2s - loss: 7201.4658 - 2s/epoch - 3ms/step
# Epoch 446/1000
# 531/531 - 2s - loss: 7641.9380 - 2s/epoch - 3ms/step
# Epoch 447/1000
# 531/531 - 2s - loss: 7253.8862 - 2s/epoch - 3ms/step
# Epoch 448/1000
# 531/531 - 2s - loss: 7333.2251 - 2s/epoch - 3ms/step
# Epoch 449/1000
# 531/531 - 2s - loss: 7237.9033 - 2s/epoch - 3ms/step
# Epoch 450/1000
# 531/531 - 2s - loss: 7248.6465 - 2s/epoch - 3ms/step
# Epoch 451/1000
# 531/531 - 2s - loss: 7339.1592 - 2s/epoch - 3ms/step
# Epoch 452/1000
# 531/531 - 2s - loss: 7261.8564 - 2s/epoch - 3ms/step
# Epoch 453/1000
# 531/531 - 2s - loss: 7350.9458 - 2s/epoch - 3ms/step
# Epoch 454/1000
# 531/531 - 2s - loss: 7411.6987 - 2s/epoch - 3ms/step
# Epoch 455/1000
# 531/531 - 2s - loss: 7284.7876 - 2s/epoch - 3ms/step
# Epoch 456/1000
# 531/531 - 2s - loss: 7398.7832 - 2s/epoch - 3ms/step
# Epoch 457/1000
# 531/531 - 2s - loss: 7264.3125 - 2s/epoch - 3ms/step
# Epoch 458/1000
# 531/531 - 2s - loss: 7222.0366 - 2s/epoch - 3ms/step
# Epoch 459/1000
# 531/531 - 2s - loss: 7373.5273 - 2s/epoch - 3ms/step
# Epoch 460/1000
# 531/531 - 2s - loss: 7212.8418 - 2s/epoch - 3ms/step
# Epoch 461/1000
# 531/531 - 2s - loss: 7230.2388 - 2s/epoch - 3ms/step
# Epoch 462/1000
# 531/531 - 2s - loss: 7301.3979 - 2s/epoch - 3ms/step
# Epoch 463/1000
# 531/531 - 2s - loss: 7190.2588 - 2s/epoch - 3ms/step
# Epoch 464/1000
# 531/531 - 2s - loss: 7177.3345 - 2s/epoch - 3ms/step
# Epoch 465/1000
# 531/531 - 2s - loss: 7143.4204 - 2s/epoch - 3ms/step
# Epoch 466/1000
# 531/531 - 306s - loss: 7466.7354 - 306s/epoch - 577ms/step
# Epoch 467/1000
# 531/531 - 2s - loss: 7314.4087 - 2s/epoch - 3ms/step
# Epoch 468/1000
# 531/531 - 2s - loss: 7128.4321 - 2s/epoch - 3ms/step
# Epoch 469/1000
# 531/531 - 2s - loss: 7369.5264 - 2s/epoch - 3ms/step
# Epoch 470/1000
# 531/531 - 2s - loss: 7525.9106 - 2s/epoch - 3ms/step
# Epoch 471/1000
# 531/531 - 2s - loss: 7295.0962 - 2s/epoch - 3ms/step
# Epoch 472/1000
# 531/531 - 2s - loss: 7209.2153 - 2s/epoch - 3ms/step
# Epoch 473/1000
# 531/531 - 2s - loss: 7231.1865 - 2s/epoch - 3ms/step
# Epoch 474/1000
# 531/531 - 2s - loss: 7425.1616 - 2s/epoch - 3ms/step
# Epoch 475/1000
# 531/531 - 2s - loss: 7272.8091 - 2s/epoch - 3ms/step
# Epoch 476/1000
# 531/531 - 2s - loss: 7239.7153 - 2s/epoch - 3ms/step
# Epoch 477/1000
# 531/531 - 2s - loss: 7158.0400 - 2s/epoch - 4ms/step
# Epoch 478/1000
# 531/531 - 2s - loss: 7276.9912 - 2s/epoch - 4ms/step
# Epoch 479/1000
# 531/531 - 3s - loss: 7250.4131 - 3s/epoch - 5ms/step
# Epoch 480/1000
# 531/531 - 2s - loss: 7261.2349 - 2s/epoch - 4ms/step
# Epoch 481/1000
# 531/531 - 2s - loss: 7082.7739 - 2s/epoch - 4ms/step
# Epoch 482/1000
# 531/531 - 2s - loss: 7345.3896 - 2s/epoch - 4ms/step
# Epoch 483/1000
# 531/531 - 2s - loss: 7309.7129 - 2s/epoch - 4ms/step
# Epoch 484/1000
# 531/531 - 2s - loss: 7223.4575 - 2s/epoch - 4ms/step
# Epoch 485/1000
# 531/531 - 2s - loss: 7186.1699 - 2s/epoch - 3ms/step
# Epoch 486/1000
# 531/531 - 2s - loss: 7147.1616 - 2s/epoch - 3ms/step
# Epoch 487/1000
# 531/531 - 2s - loss: 7262.3892 - 2s/epoch - 3ms/step
# Epoch 488/1000
# 531/531 - 2s - loss: 7182.0625 - 2s/epoch - 3ms/step
# Epoch 489/1000
# 531/531 - 2s - loss: 7188.0151 - 2s/epoch - 3ms/step
# Epoch 490/1000
# 531/531 - 2s - loss: 7152.1284 - 2s/epoch - 3ms/step
# Epoch 491/1000
# 531/531 - 2s - loss: 7233.3965 - 2s/epoch - 3ms/step
# Epoch 492/1000
# 531/531 - 2s - loss: 7247.7339 - 2s/epoch - 3ms/step
# Epoch 493/1000
# 531/531 - 2s - loss: 7332.0063 - 2s/epoch - 3ms/step
# Epoch 494/1000
# 531/531 - 2s - loss: 7265.5093 - 2s/epoch - 3ms/step
# Epoch 495/1000
# 531/531 - 2s - loss: 7212.7378 - 2s/epoch - 3ms/step
# Epoch 496/1000
# 531/531 - 2s - loss: 7284.9258 - 2s/epoch - 3ms/step
# Epoch 497/1000
# 531/531 - 2s - loss: 7049.0288 - 2s/epoch - 3ms/step
# Epoch 498/1000
# 531/531 - 2s - loss: 7239.6489 - 2s/epoch - 3ms/step
# Epoch 499/1000
# 531/531 - 2s - loss: 7260.9424 - 2s/epoch - 3ms/step
# Epoch 500/1000
# 531/531 - 2s - loss: 7261.4634 - 2s/epoch - 3ms/step
# Epoch 501/1000
# 531/531 - 2s - loss: 7253.8203 - 2s/epoch - 3ms/step
# Epoch 502/1000
# 531/531 - 2s - loss: 7206.7041 - 2s/epoch - 3ms/step
# Epoch 503/1000
# 531/531 - 2s - loss: 7253.0171 - 2s/epoch - 3ms/step
# Epoch 504/1000
# 531/531 - 2s - loss: 7134.2202 - 2s/epoch - 3ms/step
# Epoch 505/1000
# 531/531 - 2s - loss: 7233.9062 - 2s/epoch - 3ms/step
# Epoch 506/1000
# 531/531 - 2s - loss: 7483.5454 - 2s/epoch - 3ms/step
# Epoch 507/1000
# 531/531 - 2s - loss: 7239.1289 - 2s/epoch - 3ms/step
# Epoch 508/1000
# 531/531 - 2s - loss: 7236.2422 - 2s/epoch - 3ms/step
# Epoch 509/1000
# 531/531 - 2s - loss: 7163.8315 - 2s/epoch - 3ms/step
# Epoch 510/1000
# 531/531 - 2s - loss: 7224.3760 - 2s/epoch - 3ms/step
# Epoch 511/1000
# 531/531 - 2s - loss: 7320.3032 - 2s/epoch - 4ms/step
# Epoch 512/1000
# 531/531 - 2s - loss: 7249.1831 - 2s/epoch - 3ms/step
# Epoch 513/1000
# 531/531 - 2s - loss: 7177.8164 - 2s/epoch - 3ms/step
# Epoch 514/1000
# 531/531 - 2s - loss: 7272.9209 - 2s/epoch - 3ms/step
# Epoch 515/1000
# 531/531 - 2s - loss: 7159.7612 - 2s/epoch - 3ms/step
# Epoch 516/1000
# 531/531 - 2s - loss: 7228.1514 - 2s/epoch - 3ms/step
# Epoch 517/1000
# 531/531 - 2s - loss: 7341.0908 - 2s/epoch - 3ms/step
# Epoch 518/1000
# 531/531 - 2s - loss: 7139.7173 - 2s/epoch - 3ms/step
# Epoch 519/1000
# 531/531 - 2s - loss: 7242.0249 - 2s/epoch - 3ms/step
# Epoch 520/1000
# 531/531 - 2s - loss: 7488.1108 - 2s/epoch - 3ms/step
# Epoch 521/1000
# 531/531 - 2s - loss: 7402.8193 - 2s/epoch - 3ms/step
# Epoch 522/1000
# 531/531 - 2s - loss: 7177.6909 - 2s/epoch - 3ms/step
# Epoch 523/1000
# 531/531 - 2s - loss: 7148.8813 - 2s/epoch - 3ms/step
# Epoch 524/1000
# 531/531 - 2s - loss: 7267.2969 - 2s/epoch - 3ms/step
# Epoch 525/1000
# 531/531 - 2s - loss: 7478.0361 - 2s/epoch - 3ms/step
# Epoch 526/1000
# 531/531 - 2s - loss: 7217.0884 - 2s/epoch - 3ms/step
# Epoch 527/1000
# 531/531 - 2s - loss: 7259.8203 - 2s/epoch - 3ms/step
# Epoch 528/1000
# 531/531 - 2s - loss: 7205.8730 - 2s/epoch - 3ms/step
# Epoch 529/1000
# 531/531 - 2s - loss: 7522.7046 - 2s/epoch - 3ms/step
# Epoch 530/1000
# 531/531 - 2s - loss: 7117.3574 - 2s/epoch - 3ms/step
# Epoch 531/1000
# 531/531 - 2s - loss: 7131.7461 - 2s/epoch - 3ms/step
# Epoch 532/1000
# 531/531 - 2s - loss: 7227.0454 - 2s/epoch - 3ms/step
# Epoch 533/1000
# 531/531 - 2s - loss: 7246.8130 - 2s/epoch - 3ms/step
# Epoch 534/1000
# 531/531 - 2s - loss: 7158.4829 - 2s/epoch - 3ms/step
# Epoch 535/1000
# 531/531 - 2s - loss: 7262.1909 - 2s/epoch - 3ms/step
# Epoch 536/1000
# 531/531 - 2s - loss: 7194.0186 - 2s/epoch - 3ms/step
# Epoch 537/1000
# 531/531 - 2s - loss: 7367.8521 - 2s/epoch - 3ms/step
# Epoch 538/1000
# 531/531 - 2s - loss: 7474.9409 - 2s/epoch - 3ms/step
# Epoch 539/1000
# 531/531 - 2s - loss: 7163.0586 - 2s/epoch - 3ms/step
# Epoch 540/1000
# 531/531 - 2s - loss: 7244.3062 - 2s/epoch - 3ms/step
# Epoch 541/1000
# 531/531 - 2s - loss: 7304.9941 - 2s/epoch - 3ms/step
# Epoch 542/1000
# 531/531 - 2s - loss: 7159.4209 - 2s/epoch - 3ms/step
# Epoch 543/1000
# 531/531 - 2s - loss: 7243.6172 - 2s/epoch - 3ms/step
# Epoch 544/1000
# 531/531 - 2s - loss: 7189.0854 - 2s/epoch - 3ms/step
# Epoch 545/1000
# 531/531 - 2s - loss: 7374.2271 - 2s/epoch - 3ms/step
# Epoch 546/1000
# 531/531 - 2s - loss: 7034.8101 - 2s/epoch - 4ms/step
# Epoch 547/1000
# 531/531 - 2s - loss: 7122.1904 - 2s/epoch - 3ms/step
# Epoch 548/1000
# 531/531 - 2s - loss: 7132.9468 - 2s/epoch - 3ms/step
# Epoch 549/1000
# 531/531 - 2s - loss: 7240.0010 - 2s/epoch - 3ms/step
# Epoch 550/1000
# 531/531 - 2s - loss: 7262.4688 - 2s/epoch - 3ms/step
# Epoch 551/1000
# 531/531 - 2s - loss: 7179.5972 - 2s/epoch - 3ms/step
# Epoch 552/1000
# 531/531 - 2s - loss: 7340.8105 - 2s/epoch - 3ms/step
# Epoch 553/1000
# 531/531 - 2s - loss: 7247.1519 - 2s/epoch - 3ms/step
# Epoch 554/1000
# 531/531 - 2s - loss: 7154.1226 - 2s/epoch - 4ms/step
# Epoch 555/1000
# 531/531 - 2s - loss: 7148.7700 - 2s/epoch - 3ms/step
# Epoch 556/1000
# 531/531 - 2s - loss: 7099.9351 - 2s/epoch - 3ms/step
# Epoch 557/1000
# 531/531 - 2s - loss: 7145.6973 - 2s/epoch - 3ms/step
# Epoch 558/1000
# 531/531 - 2s - loss: 7417.3096 - 2s/epoch - 3ms/step
# Epoch 559/1000
# 531/531 - 2s - loss: 7176.6445 - 2s/epoch - 3ms/step
# Epoch 560/1000
# 531/531 - 2s - loss: 7302.1328 - 2s/epoch - 3ms/step
# Epoch 561/1000
# 531/531 - 2s - loss: 7061.9722 - 2s/epoch - 3ms/step
# Epoch 562/1000
# 531/531 - 2s - loss: 7123.0825 - 2s/epoch - 3ms/step
# Epoch 563/1000
# 531/531 - 2s - loss: 7302.9087 - 2s/epoch - 3ms/step
# Epoch 564/1000
# 531/531 - 2s - loss: 7288.7788 - 2s/epoch - 3ms/step
# Epoch 565/1000
# 531/531 - 2s - loss: 7174.1084 - 2s/epoch - 3ms/step
# Epoch 566/1000
# 531/531 - 2s - loss: 7152.9014 - 2s/epoch - 3ms/step
# Epoch 567/1000
# 531/531 - 2s - loss: 7105.5679 - 2s/epoch - 3ms/step
# Epoch 568/1000
# 531/531 - 2s - loss: 7290.3833 - 2s/epoch - 3ms/step
# Epoch 569/1000
# 531/531 - 2s - loss: 7324.5371 - 2s/epoch - 3ms/step
# Epoch 570/1000
# 531/531 - 2s - loss: 7177.4409 - 2s/epoch - 3ms/step
# Epoch 571/1000
# 531/531 - 2s - loss: 7083.8062 - 2s/epoch - 3ms/step
# Epoch 572/1000
# 531/531 - 2s - loss: 7210.3643 - 2s/epoch - 3ms/step
# Epoch 573/1000
# 531/531 - 2s - loss: 7162.7197 - 2s/epoch - 3ms/step
# Epoch 574/1000
# 531/531 - 2s - loss: 7214.5342 - 2s/epoch - 3ms/step
# Epoch 575/1000
# 531/531 - 2s - loss: 7234.7715 - 2s/epoch - 3ms/step
# Epoch 576/1000
# 531/531 - 2s - loss: 7134.6001 - 2s/epoch - 4ms/step
# Epoch 577/1000
# 531/531 - 2s - loss: 7273.3721 - 2s/epoch - 4ms/step
# Epoch 578/1000
# 531/531 - 2s - loss: 7224.8350 - 2s/epoch - 3ms/step
# Epoch 579/1000
# 531/531 - 2s - loss: 7290.1616 - 2s/epoch - 3ms/step
# Epoch 580/1000
# 531/531 - 2s - loss: 7140.2729 - 2s/epoch - 3ms/step
# Epoch 581/1000
# 531/531 - 2s - loss: 7190.7056 - 2s/epoch - 3ms/step
# Epoch 582/1000
# 531/531 - 2s - loss: 7221.0034 - 2s/epoch - 3ms/step
# Epoch 583/1000
# 531/531 - 2s - loss: 7128.1636 - 2s/epoch - 3ms/step
# Epoch 584/1000
# 531/531 - 2s - loss: 7091.0005 - 2s/epoch - 3ms/step
# Epoch 585/1000
# 531/531 - 2s - loss: 7355.5635 - 2s/epoch - 3ms/step
# Epoch 586/1000
# 531/531 - 2s - loss: 7063.1011 - 2s/epoch - 3ms/step
# Epoch 587/1000
# 531/531 - 2s - loss: 7318.8105 - 2s/epoch - 3ms/step
# Epoch 588/1000
# 531/531 - 2s - loss: 7330.0962 - 2s/epoch - 3ms/step
# Epoch 589/1000
# 531/531 - 2s - loss: 7256.7051 - 2s/epoch - 3ms/step
# Epoch 590/1000
# 531/531 - 2s - loss: 7208.8262 - 2s/epoch - 3ms/step
# Epoch 591/1000
# 531/531 - 2s - loss: 7213.4287 - 2s/epoch - 3ms/step
# Epoch 592/1000
# 531/531 - 2s - loss: 7236.0986 - 2s/epoch - 3ms/step
# Epoch 593/1000
# 531/531 - 2s - loss: 7147.4692 - 2s/epoch - 3ms/step
# Epoch 594/1000
# 531/531 - 2s - loss: 7055.5273 - 2s/epoch - 3ms/step
# Epoch 595/1000
# 531/531 - 2s - loss: 7167.3838 - 2s/epoch - 3ms/step
# Epoch 596/1000
# 531/531 - 2s - loss: 7516.3281 - 2s/epoch - 3ms/step
# Epoch 597/1000
# 531/531 - 2s - loss: 7070.1211 - 2s/epoch - 3ms/step
# Epoch 598/1000
# 531/531 - 2s - loss: 7207.3350 - 2s/epoch - 3ms/step
# Epoch 599/1000
# 531/531 - 2s - loss: 7100.0879 - 2s/epoch - 3ms/step
# Epoch 600/1000
# 531/531 - 2s - loss: 7051.0620 - 2s/epoch - 3ms/step
# Epoch 601/1000
# 531/531 - 2s - loss: 7202.0532 - 2s/epoch - 3ms/step
# Epoch 602/1000
# 531/531 - 2s - loss: 7102.6587 - 2s/epoch - 3ms/step
# Epoch 603/1000
# 531/531 - 2s - loss: 7189.6357 - 2s/epoch - 3ms/step
# Epoch 604/1000
# 531/531 - 2s - loss: 7219.5830 - 2s/epoch - 3ms/step
# Epoch 605/1000
# 531/531 - 2s - loss: 7136.4556 - 2s/epoch - 3ms/step
# Epoch 606/1000
# 531/531 - 2s - loss: 7201.0762 - 2s/epoch - 3ms/step
# Epoch 607/1000
# 531/531 - 2s - loss: 7010.7207 - 2s/epoch - 3ms/step
# Epoch 608/1000
# 531/531 - 2s - loss: 7094.5928 - 2s/epoch - 3ms/step
# Epoch 609/1000
# 531/531 - 2s - loss: 7190.0771 - 2s/epoch - 3ms/step
# Epoch 610/1000
# 531/531 - 2s - loss: 7370.2437 - 2s/epoch - 3ms/step
# Epoch 611/1000
# 531/531 - 2s - loss: 7141.6973 - 2s/epoch - 3ms/step
# Epoch 612/1000
# 531/531 - 2s - loss: 7211.9497 - 2s/epoch - 3ms/step
# Epoch 613/1000
# 531/531 - 2s - loss: 7120.7539 - 2s/epoch - 3ms/step
# Epoch 614/1000
# 531/531 - 2s - loss: 7206.7539 - 2s/epoch - 3ms/step
# Epoch 615/1000
# 531/531 - 2s - loss: 7153.6128 - 2s/epoch - 3ms/step
# Epoch 616/1000
# 531/531 - 2s - loss: 7137.4731 - 2s/epoch - 3ms/step
# Epoch 617/1000
# 531/531 - 2s - loss: 7313.3608 - 2s/epoch - 3ms/step
# Epoch 618/1000
# 531/531 - 2s - loss: 7151.8354 - 2s/epoch - 3ms/step
# Epoch 619/1000
# 531/531 - 2s - loss: 7176.2471 - 2s/epoch - 3ms/step
# Epoch 620/1000
# 531/531 - 2s - loss: 7225.7720 - 2s/epoch - 3ms/step
# Epoch 621/1000
# 531/531 - 2s - loss: 7142.2344 - 2s/epoch - 3ms/step
# Epoch 622/1000
# 531/531 - 2s - loss: 7131.3237 - 2s/epoch - 3ms/step
# Epoch 623/1000
# 531/531 - 2s - loss: 7145.7847 - 2s/epoch - 3ms/step
# Epoch 624/1000
# 531/531 - 2s - loss: 7179.0215 - 2s/epoch - 3ms/step
# Epoch 625/1000
# 531/531 - 2s - loss: 7192.5361 - 2s/epoch - 3ms/step
# Epoch 626/1000
# 531/531 - 2s - loss: 7199.5044 - 2s/epoch - 3ms/step
# Epoch 627/1000
# 531/531 - 2s - loss: 7174.6211 - 2s/epoch - 3ms/step
# Epoch 628/1000
# 531/531 - 2s - loss: 7044.8774 - 2s/epoch - 3ms/step
# Epoch 629/1000
# 531/531 - 2s - loss: 7193.4146 - 2s/epoch - 3ms/step
# Epoch 630/1000
# 531/531 - 2s - loss: 7140.8232 - 2s/epoch - 3ms/step
# Epoch 631/1000
# 531/531 - 2s - loss: 7184.3306 - 2s/epoch - 3ms/step
# Epoch 632/1000
# 531/531 - 2s - loss: 7155.4521 - 2s/epoch - 3ms/step
# Epoch 633/1000
# 531/531 - 2s - loss: 7272.6245 - 2s/epoch - 3ms/step
# Epoch 634/1000
# 531/531 - 2s - loss: 7126.4854 - 2s/epoch - 3ms/step
# Epoch 635/1000
# 531/531 - 2s - loss: 7392.0967 - 2s/epoch - 3ms/step
# Epoch 636/1000
# 531/531 - 2s - loss: 7108.7046 - 2s/epoch - 3ms/step
# Epoch 637/1000
# 531/531 - 2s - loss: 7421.8945 - 2s/epoch - 3ms/step
# Epoch 638/1000
# 531/531 - 2s - loss: 7179.8433 - 2s/epoch - 3ms/step
# Epoch 639/1000
# 531/531 - 2s - loss: 7064.5947 - 2s/epoch - 3ms/step
# Epoch 640/1000
# 531/531 - 2s - loss: 7290.7300 - 2s/epoch - 3ms/step
# Epoch 641/1000
# 531/531 - 2s - loss: 7170.7158 - 2s/epoch - 3ms/step
# Epoch 642/1000
# 531/531 - 2s - loss: 7245.4141 - 2s/epoch - 3ms/step
# Epoch 643/1000
# 531/531 - 2s - loss: 7120.8965 - 2s/epoch - 3ms/step
# Epoch 644/1000
# 531/531 - 2s - loss: 7143.1509 - 2s/epoch - 3ms/step
# Epoch 645/1000
# 531/531 - 2s - loss: 7142.7593 - 2s/epoch - 3ms/step
# Epoch 646/1000
# 531/531 - 2s - loss: 7114.7280 - 2s/epoch - 3ms/step
# Epoch 647/1000
# 531/531 - 2s - loss: 7233.8975 - 2s/epoch - 3ms/step
# Epoch 648/1000
# 531/531 - 2s - loss: 7101.6250 - 2s/epoch - 3ms/step
# Epoch 649/1000
# 531/531 - 2s - loss: 7230.5176 - 2s/epoch - 3ms/step
# Epoch 650/1000
# 531/531 - 2s - loss: 7178.1250 - 2s/epoch - 3ms/step
# Epoch 651/1000
# 531/531 - 2s - loss: 7200.3159 - 2s/epoch - 3ms/step
# Epoch 652/1000
# 531/531 - 2s - loss: 7080.2720 - 2s/epoch - 3ms/step
# Epoch 653/1000
# 531/531 - 2s - loss: 7091.6270 - 2s/epoch - 3ms/step
# Epoch 654/1000
# 531/531 - 2s - loss: 7152.1646 - 2s/epoch - 3ms/step
# Epoch 655/1000
# 531/531 - 2s - loss: 7221.8281 - 2s/epoch - 3ms/step
# Epoch 656/1000
# 531/531 - 2s - loss: 7156.3794 - 2s/epoch - 3ms/step
# Epoch 657/1000
# 531/531 - 2s - loss: 7106.8564 - 2s/epoch - 3ms/step
# Epoch 658/1000
# 531/531 - 2s - loss: 7078.9805 - 2s/epoch - 3ms/step
# Epoch 659/1000
# 531/531 - 2s - loss: 7169.7397 - 2s/epoch - 3ms/step
# Epoch 660/1000
# 531/531 - 2s - loss: 7199.7197 - 2s/epoch - 3ms/step
# Epoch 661/1000
# 531/531 - 2s - loss: 7146.7695 - 2s/epoch - 3ms/step
# Epoch 662/1000
# 531/531 - 2s - loss: 7282.5713 - 2s/epoch - 3ms/step
# Epoch 663/1000
# 531/531 - 2s - loss: 7104.3540 - 2s/epoch - 3ms/step
# Epoch 664/1000
# 531/531 - 2s - loss: 7207.5454 - 2s/epoch - 3ms/step
# Epoch 665/1000
# 531/531 - 2s - loss: 7144.2080 - 2s/epoch - 3ms/step
# Epoch 666/1000
# 531/531 - 2s - loss: 7128.6499 - 2s/epoch - 3ms/step
# Epoch 667/1000
# 531/531 - 2s - loss: 7183.3359 - 2s/epoch - 3ms/step
# Epoch 668/1000
# 531/531 - 2s - loss: 6989.2266 - 2s/epoch - 3ms/step
# Epoch 669/1000
# 531/531 - 2s - loss: 7111.8354 - 2s/epoch - 3ms/step
# Epoch 670/1000
# 531/531 - 2s - loss: 7400.2876 - 2s/epoch - 3ms/step
# Epoch 671/1000
# 531/531 - 2s - loss: 7193.9756 - 2s/epoch - 3ms/step
# Epoch 672/1000
# 531/531 - 2s - loss: 7150.5122 - 2s/epoch - 3ms/step
# Epoch 673/1000
# 531/531 - 2s - loss: 7092.7437 - 2s/epoch - 3ms/step
# Epoch 674/1000
# 531/531 - 2s - loss: 7129.5635 - 2s/epoch - 3ms/step
# Epoch 675/1000
# 531/531 - 2s - loss: 7106.9595 - 2s/epoch - 3ms/step
# Epoch 676/1000
# 531/531 - 2s - loss: 7085.7480 - 2s/epoch - 3ms/step
# Epoch 677/1000
# 531/531 - 2s - loss: 7147.1499 - 2s/epoch - 3ms/step
# Epoch 678/1000
# 531/531 - 2s - loss: 7371.7632 - 2s/epoch - 3ms/step
# Epoch 679/1000
# 531/531 - 2s - loss: 7090.9707 - 2s/epoch - 3ms/step
# Epoch 680/1000
# 531/531 - 2s - loss: 7076.1938 - 2s/epoch - 3ms/step
# Epoch 681/1000
# 531/531 - 2s - loss: 7225.6006 - 2s/epoch - 3ms/step
# Epoch 682/1000
# 531/531 - 2s - loss: 7187.7378 - 2s/epoch - 3ms/step
# Epoch 683/1000
# 531/531 - 2s - loss: 7075.6611 - 2s/epoch - 3ms/step
# Epoch 684/1000
# 531/531 - 2s - loss: 7162.5840 - 2s/epoch - 3ms/step
# Epoch 685/1000
# 531/531 - 2s - loss: 7085.5947 - 2s/epoch - 3ms/step
# Epoch 686/1000
# 531/531 - 2s - loss: 7183.2041 - 2s/epoch - 3ms/step
# Epoch 687/1000
# 531/531 - 2s - loss: 7150.3599 - 2s/epoch - 3ms/step
# Epoch 688/1000
# 531/531 - 2s - loss: 7096.9414 - 2s/epoch - 3ms/step
# Epoch 689/1000
# 531/531 - 2s - loss: 7249.1821 - 2s/epoch - 3ms/step
# Epoch 690/1000
# 531/531 - 2s - loss: 7073.7983 - 2s/epoch - 3ms/step
# Epoch 691/1000
# 531/531 - 2s - loss: 7324.8765 - 2s/epoch - 3ms/step
# Epoch 692/1000
# 531/531 - 2s - loss: 7138.5176 - 2s/epoch - 3ms/step
# Epoch 693/1000
# 531/531 - 2s - loss: 7258.6211 - 2s/epoch - 3ms/step
# Epoch 694/1000
# 531/531 - 2s - loss: 7278.1558 - 2s/epoch - 3ms/step
# Epoch 695/1000
# 531/531 - 2s - loss: 7090.7578 - 2s/epoch - 3ms/step
# Epoch 696/1000
# 531/531 - 2s - loss: 7092.1104 - 2s/epoch - 3ms/step
# Epoch 697/1000
# 531/531 - 2s - loss: 7142.2241 - 2s/epoch - 3ms/step
# Epoch 698/1000
# 531/531 - 2s - loss: 7225.4341 - 2s/epoch - 3ms/step
# Epoch 699/1000
# 531/531 - 2s - loss: 7160.8105 - 2s/epoch - 3ms/step
# Epoch 700/1000
# 531/531 - 2s - loss: 7051.8213 - 2s/epoch - 3ms/step
# Epoch 701/1000
# 531/531 - 2s - loss: 7364.1680 - 2s/epoch - 3ms/step
# Epoch 702/1000
# 531/531 - 2s - loss: 7011.1641 - 2s/epoch - 3ms/step
# Epoch 703/1000
# 531/531 - 2s - loss: 7251.0859 - 2s/epoch - 3ms/step
# Epoch 704/1000
# 531/531 - 2s - loss: 7149.5571 - 2s/epoch - 3ms/step
# Epoch 705/1000
# ...
# Epoch 767/1000
# 531/531 - 2s - loss: 7001.4844 - 2s/epoch - 3ms/step
# Epoch 768/1000
# 531/531 - 2s - loss: 7193.0195 - 2s/epoch - 3ms/step
# Epoch 769/1000
# 531/531 - 2s - loss: 7158.7520 - 2s/epoch - 3ms/step
# Epoch 770/1000
# 531/531 - 2s - loss: 7102.2749 - 2s/epoch - 3ms/step
# Epoch 771/1000
# 531/531 - 2s - loss: 7037.0972 - 2s/epoch - 3ms/step
# Epoch 772/1000
# 531/531 - 2s - loss: 7178.8618 - 2s/epoch - 3ms/step
# Epoch 773/1000
# 531/531 - 2s - loss: 7272.9326 - 2s/epoch - 3ms/step
# Epoch 774/1000
# 531/531 - 2s - loss: 7186.5786 - 2s/epoch - 3ms/step
# Epoch 775/1000
# 531/531 - 2s - loss: 7137.9961 - 2s/epoch - 3ms/step
# Epoch 776/1000
# 531/531 - 2s - loss: 7025.2192 - 2s/epoch - 3ms/step
# Epoch 777/1000
# 531/531 - 2s - loss: 7170.5908 - 2s/epoch - 3ms/step
# Epoch 778/1000
# 531/531 - 2s - loss: 7055.6177 - 2s/epoch - 3ms/step
# Epoch 779/1000
# 531/531 - 2s - loss: 7194.5425 - 2s/epoch - 3ms/step
# Epoch 780/1000
# 531/531 - 2s - loss: 7504.8442 - 2s/epoch - 3ms/step
# Epoch 781/1000
# 531/531 - 2s - loss: 7074.0894 - 2s/epoch - 3ms/step
# Epoch 782/1000
# 531/531 - 2s - loss: 7134.4717 - 2s/epoch - 3ms/step
# Epoch 783/1000
# 531/531 - 2s - loss: 7145.2788 - 2s/epoch - 3ms/step
# Epoch 784/1000
# 531/531 - 2s - loss: 7161.6519 - 2s/epoch - 3ms/step
# Epoch 785/1000
# 531/531 - 2s - loss: 7137.8262 - 2s/epoch - 3ms/step
# Epoch 786/1000
# 531/531 - 2s - loss: 7027.3750 - 2s/epoch - 3ms/step
# Epoch 787/1000
# 531/531 - 2s - loss: 7537.0645 - 2s/epoch - 3ms/step
# Epoch 788/1000
# 531/531 - 2s - loss: 7228.5679 - 2s/epoch - 3ms/step
# Epoch 789/1000
# 531/531 - 2s - loss: 7053.8428 - 2s/epoch - 3ms/step
# Epoch 790/1000
# 531/531 - 2s - loss: 7088.6006 - 2s/epoch - 3ms/step
# Epoch 791/1000
# 531/531 - 2s - loss: 7035.4629 - 2s/epoch - 3ms/step
# Epoch 792/1000
# 531/531 - 2s - loss: 7102.5571 - 2s/epoch - 3ms/step
# Epoch 793/1000
# 531/531 - 2s - loss: 7040.7349 - 2s/epoch - 3ms/step
# Epoch 794/1000
# 531/531 - 2s - loss: 7222.9683 - 2s/epoch - 3ms/step
# Epoch 795/1000
# 531/531 - 2s - loss: 7049.6094 - 2s/epoch - 3ms/step
# Epoch 796/1000
# 531/531 - 2s - loss: 7195.5884 - 2s/epoch - 3ms/step
# Epoch 797/1000
# 531/531 - 2s - loss: 7203.8491 - 2s/epoch - 3ms/step
# Epoch 798/1000
# 531/531 - 2s - loss: 7310.5063 - 2s/epoch - 3ms/step
# Epoch 799/1000
# 531/531 - 2s - loss: 7052.4697 - 2s/epoch - 4ms/step
# Epoch 800/1000
# 531/531 - 2s - loss: 7163.7827 - 2s/epoch - 3ms/step
# Epoch 801/1000
# 531/531 - 2s - loss: 7126.0244 - 2s/epoch - 4ms/step
# Epoch 802/1000
# 531/531 - 2s - loss: 7233.1133 - 2s/epoch - 4ms/step
# Epoch 803/1000
# 531/531 - 2s - loss: 7418.0811 - 2s/epoch - 3ms/step
# Epoch 804/1000
# 531/531 - 2s - loss: 7078.9360 - 2s/epoch - 3ms/step
# Epoch 805/1000
# 531/531 - 2s - loss: 7273.5479 - 2s/epoch - 3ms/step
# Epoch 806/1000
# 531/531 - 2s - loss: 7124.5752 - 2s/epoch - 3ms/step
# Epoch 807/1000
# 531/531 - 2s - loss: 7051.2515 - 2s/epoch - 3ms/step
# Epoch 808/1000
# 531/531 - 2s - loss: 7273.4160 - 2s/epoch - 3ms/step
# Epoch 809/1000
# 531/531 - 2s - loss: 7061.3486 - 2s/epoch - 3ms/step
# Epoch 810/1000
# 531/531 - 2s - loss: 7134.3091 - 2s/epoch - 3ms/step
# Epoch 811/1000
# 531/531 - 2s - loss: 7334.1123 - 2s/epoch - 3ms/step
# Epoch 812/1000
# 531/531 - 2s - loss: 7062.4673 - 2s/epoch - 3ms/step
# Epoch 813/1000
# 531/531 - 2s - loss: 7062.5547 - 2s/epoch - 4ms/step
# Epoch 814/1000
# 531/531 - 2s - loss: 7191.6768 - 2s/epoch - 3ms/step
# Epoch 815/1000
# 531/531 - 2s - loss: 7182.0381 - 2s/epoch - 4ms/step
# Epoch 816/1000
# 531/531 - 2s - loss: 7117.6875 - 2s/epoch - 3ms/step
# Epoch 817/1000
# 531/531 - 2s - loss: 7022.3076 - 2s/epoch - 3ms/step
# Epoch 818/1000
# 531/531 - 2s - loss: 7345.4028 - 2s/epoch - 3ms/step
# Epoch 819/1000
# 531/531 - 2s - loss: 7210.9858 - 2s/epoch - 3ms/step
# Epoch 820/1000
# 531/531 - 2s - loss: 7235.1064 - 2s/epoch - 3ms/step
# Epoch 821/1000
# 531/531 - 2s - loss: 7096.9541 - 2s/epoch - 3ms/step
# Epoch 822/1000
# 531/531 - 2s - loss: 7080.5854 - 2s/epoch - 3ms/step
# Epoch 823/1000
# 531/531 - 2s - loss: 7074.4639 - 2s/epoch - 4ms/step
# Epoch 824/1000
# 531/531 - 2s - loss: 7232.1426 - 2s/epoch - 3ms/step
# Epoch 825/1000
# 531/531 - 2s - loss: 7198.7520 - 2s/epoch - 3ms/step
# Epoch 826/1000
# 531/531 - 2s - loss: 7295.4204 - 2s/epoch - 3ms/step
# Epoch 827/1000
# 531/531 - 2s - loss: 7090.5986 - 2s/epoch - 4ms/step
# Epoch 828/1000
# 531/531 - 2s - loss: 7374.9575 - 2s/epoch - 4ms/step
# Epoch 829/1000
# 531/531 - 2s - loss: 7784.8345 - 2s/epoch - 3ms/step
# Epoch 830/1000
# 531/531 - 2s - loss: 7125.3525 - 2s/epoch - 4ms/step
# Epoch 831/1000
# 531/531 - 2s - loss: 7195.7563 - 2s/epoch - 3ms/step
# Epoch 832/1000
# 531/531 - 2s - loss: 7049.8594 - 2s/epoch - 4ms/step
# Epoch 833/1000
# 531/531 - 2s - loss: 7056.3984 - 2s/epoch - 3ms/step
# Epoch 834/1000
# 531/531 - 2s - loss: 7199.3135 - 2s/epoch - 3ms/step
# Epoch 835/1000
# 531/531 - 2s - loss: 7087.2603 - 2s/epoch - 3ms/step
# Epoch 836/1000
# 531/531 - 2s - loss: 7225.0923 - 2s/epoch - 3ms/step
# Epoch 837/1000
# 531/531 - 2s - loss: 7400.0874 - 2s/epoch - 3ms/step
# Epoch 838/1000
# 531/531 - 2s - loss: 7050.3682 - 2s/epoch - 3ms/step
# Epoch 839/1000
# 531/531 - 2s - loss: 7217.3008 - 2s/epoch - 3ms/step
# Epoch 840/1000
# 531/531 - 2s - loss: 7084.4922 - 2s/epoch - 3ms/step
# Epoch 841/1000
# 531/531 - 2s - loss: 7055.6133 - 2s/epoch - 3ms/step
# Epoch 842/1000
# 531/531 - 2s - loss: 7217.6646 - 2s/epoch - 3ms/step
# Epoch 843/1000
# 531/531 - 2s - loss: 7172.9316 - 2s/epoch - 3ms/step
# Epoch 844/1000
# 531/531 - 2s - loss: 7072.5547 - 2s/epoch - 3ms/step
# Epoch 845/1000
# 531/531 - 2s - loss: 7018.0459 - 2s/epoch - 3ms/step
# Epoch 846/1000
# 531/531 - 2s - loss: 7145.8223 - 2s/epoch - 3ms/step
# Epoch 847/1000
# 531/531 - 2s - loss: 7047.1372 - 2s/epoch - 3ms/step
# Epoch 848/1000
# 531/531 - 2s - loss: 7152.4067 - 2s/epoch - 3ms/step
# Epoch 849/1000
# 531/531 - 2s - loss: 7196.7734 - 2s/epoch - 3ms/step
# Epoch 850/1000
# 531/531 - 2s - loss: 7181.2817 - 2s/epoch - 3ms/step
# Epoch 851/1000
# 531/531 - 2s - loss: 7139.5220 - 2s/epoch - 3ms/step
# Epoch 852/1000
# 531/531 - 2s - loss: 7082.6685 - 2s/epoch - 3ms/step
# Epoch 853/1000
# 531/531 - 2s - loss: 7264.5298 - 2s/epoch - 3ms/step
# Epoch 854/1000
# 531/531 - 2s - loss: 7123.5068 - 2s/epoch - 3ms/step
# Epoch 855/1000
# 531/531 - 2s - loss: 7049.0459 - 2s/epoch - 3ms/step
# Epoch 856/1000
# 531/531 - 2s - loss: 7024.3154 - 2s/epoch - 3ms/step
# Epoch 857/1000
# 531/531 - 2s - loss: 7027.6123 - 2s/epoch - 3ms/step
# Epoch 858/1000
# 531/531 - 2s - loss: 7089.3838 - 2s/epoch - 3ms/step
# Epoch 859/1000
# 531/531 - 2s - loss: 7098.2764 - 2s/epoch - 3ms/step
# Epoch 860/1000
# 531/531 - 2s - loss: 7052.0840 - 2s/epoch - 3ms/step
# Epoch 861/1000
# 531/531 - 2s - loss: 7208.4507 - 2s/epoch - 3ms/step
# Epoch 862/1000
# 531/531 - 2s - loss: 7051.7227 - 2s/epoch - 3ms/step
# Epoch 863/1000
# 531/531 - 2s - loss: 6994.6118 - 2s/epoch - 3ms/step
# Epoch 864/1000
# 531/531 - 2s - loss: 7104.9307 - 2s/epoch - 3ms/step
# Epoch 865/1000
# 531/531 - 2s - loss: 7120.8354 - 2s/epoch - 3ms/step
# Epoch 866/1000
# 531/531 - 2s - loss: 7114.6309 - 2s/epoch - 3ms/step
# Epoch 867/1000
# 531/531 - 2s - loss: 7278.4971 - 2s/epoch - 3ms/step
# Epoch 868/1000
# 531/531 - 2s - loss: 6981.0542 - 2s/epoch - 4ms/step
# Epoch 869/1000
# 531/531 - 2s - loss: 7015.0571 - 2s/epoch - 3ms/step
# Epoch 870/1000
# 531/531 - 2s - loss: 7129.1348 - 2s/epoch - 3ms/step
# Epoch 871/1000
# 531/531 - 2s - loss: 7109.5459 - 2s/epoch - 3ms/step
# Epoch 872/1000
# 531/531 - 2s - loss: 7083.7905 - 2s/epoch - 3ms/step
# Epoch 873/1000
# 531/531 - 2s - loss: 7158.9824 - 2s/epoch - 3ms/step
# Epoch 874/1000
# 531/531 - 2s - loss: 7098.7251 - 2s/epoch - 3ms/step
# Epoch 875/1000
# 531/531 - 2s - loss: 7001.1060 - 2s/epoch - 3ms/step
# Epoch 876/1000
# 531/531 - 2s - loss: 7092.0176 - 2s/epoch - 3ms/step
# Epoch 877/1000
# 531/531 - 2s - loss: 7110.7471 - 2s/epoch - 3ms/step
# Epoch 878/1000
# 531/531 - 2s - loss: 6928.3701 - 2s/epoch - 3ms/step
# Epoch 879/1000
# 531/531 - 2s - loss: 7052.7812 - 2s/epoch - 3ms/step
# Epoch 880/1000
# 531/531 - 2s - loss: 7136.1465 - 2s/epoch - 4ms/step
# Epoch 881/1000
# 531/531 - 2s - loss: 7132.6089 - 2s/epoch - 3ms/step
# Epoch 882/1000
# 531/531 - 2s - loss: 7022.1040 - 2s/epoch - 3ms/step
# Epoch 883/1000
# 531/531 - 2s - loss: 7230.2168 - 2s/epoch - 3ms/step
# Epoch 884/1000
# 531/531 - 2s - loss: 7315.4795 - 2s/epoch - 3ms/step
# Epoch 885/1000
# 531/531 - 2s - loss: 7040.4473 - 2s/epoch - 3ms/step
# Epoch 886/1000
# 531/531 - 2s - loss: 7058.3589 - 2s/epoch - 3ms/step
# Epoch 887/1000
# 531/531 - 2s - loss: 7023.4355 - 2s/epoch - 3ms/step
# Epoch 888/1000
# 531/531 - 2s - loss: 6985.3384 - 2s/epoch - 3ms/step
# Epoch 889/1000
# 531/531 - 2s - loss: 7042.0972 - 2s/epoch - 3ms/step
# Epoch 890/1000
# 531/531 - 2s - loss: 7074.9385 - 2s/epoch - 3ms/step
# Epoch 891/1000
# 531/531 - 2s - loss: 7054.2061 - 2s/epoch - 4ms/step
# Epoch 892/1000
# 531/531 - 2s - loss: 7113.9399 - 2s/epoch - 3ms/step
# Epoch 893/1000
# 531/531 - 2s - loss: 7219.7197 - 2s/epoch - 3ms/step
# Epoch 894/1000
# 531/531 - 2s - loss: 7085.9746 - 2s/epoch - 4ms/step
# Epoch 895/1000
# 531/531 - 2s - loss: 6964.0435 - 2s/epoch - 4ms/step
# Epoch 896/1000
# 531/531 - 2s - loss: 7155.3276 - 2s/epoch - 4ms/step
# Epoch 897/1000
# 531/531 - 2s - loss: 6982.7202 - 2s/epoch - 3ms/step
# Epoch 898/1000
# 531/531 - 2s - loss: 7123.7007 - 2s/epoch - 3ms/step
# Epoch 899/1000
# 531/531 - 2s - loss: 7102.7456 - 2s/epoch - 3ms/step
# Epoch 900/1000
# 531/531 - 2s - loss: 7100.9912 - 2s/epoch - 3ms/step
# Epoch 901/1000
# 531/531 - 2s - loss: 7268.0073 - 2s/epoch - 3ms/step
# Epoch 902/1000
# 531/531 - 2s - loss: 7325.6714 - 2s/epoch - 3ms/step
# Epoch 903/1000
# 531/531 - 2s - loss: 7227.6118 - 2s/epoch - 3ms/step
# Epoch 904/1000
# 531/531 - 2s - loss: 7007.2280 - 2s/epoch - 3ms/step
# Epoch 905/1000
# 531/531 - 2s - loss: 7082.8989 - 2s/epoch - 3ms/step
# Epoch 906/1000
# 531/531 - 2s - loss: 6938.0986 - 2s/epoch - 3ms/step
# Epoch 907/1000
# 531/531 - 2s - loss: 7061.1470 - 2s/epoch - 3ms/step
# Epoch 908/1000
# 531/531 - 2s - loss: 6939.6719 - 2s/epoch - 3ms/step
# Epoch 909/1000
# 531/531 - 2s - loss: 7208.2803 - 2s/epoch - 3ms/step
# Epoch 910/1000
# 531/531 - 2s - loss: 7010.5659 - 2s/epoch - 3ms/step
# Epoch 911/1000
# 531/531 - 2s - loss: 7066.4180 - 2s/epoch - 3ms/step
# Epoch 912/1000
# 531/531 - 2s - loss: 7188.0986 - 2s/epoch - 3ms/step
# Epoch 913/1000
# 531/531 - 2s - loss: 7135.1826 - 2s/epoch - 3ms/step
# Epoch 914/1000
# 531/531 - 2s - loss: 6979.6841 - 2s/epoch - 3ms/step
# Epoch 915/1000
# 531/531 - 2s - loss: 7151.2144 - 2s/epoch - 3ms/step
# Epoch 916/1000
# 531/531 - 2s - loss: 7135.3550 - 2s/epoch - 3ms/step
# Epoch 917/1000
# 531/531 - 2s - loss: 7214.5698 - 2s/epoch - 3ms/step
# Epoch 918/1000
# 531/531 - 2s - loss: 6955.4453 - 2s/epoch - 3ms/step
# Epoch 919/1000
# 531/531 - 2s - loss: 7183.8223 - 2s/epoch - 3ms/step
# Epoch 920/1000
# 531/531 - 2s - loss: 6980.7466 - 2s/epoch - 3ms/step
# Epoch 921/1000
# 531/531 - 2s - loss: 7146.8306 - 2s/epoch - 3ms/step
# Epoch 922/1000
# 531/531 - 2s - loss: 6985.2871 - 2s/epoch - 3ms/step
# Epoch 923/1000
# 531/531 - 2s - loss: 7061.6587 - 2s/epoch - 3ms/step
# Epoch 924/1000
# 531/531 - 2s - loss: 7468.5298 - 2s/epoch - 3ms/step
# Epoch 925/1000
# 531/531 - 2s - loss: 7082.9248 - 2s/epoch - 3ms/step
# Epoch 926/1000
# 531/531 - 2s - loss: 6902.6963 - 2s/epoch - 3ms/step
# Epoch 927/1000
# 531/531 - 2s - loss: 7029.4863 - 2s/epoch - 3ms/step
# Epoch 928/1000
# 531/531 - 2s - loss: 7110.8647 - 2s/epoch - 3ms/step
# Epoch 929/1000
# 531/531 - 2s - loss: 7105.0659 - 2s/epoch - 3ms/step
# Epoch 930/1000
# 531/531 - 2s - loss: 7342.3730 - 2s/epoch - 3ms/step
# Epoch 931/1000
# 531/531 - 2s - loss: 7171.4062 - 2s/epoch - 3ms/step
# Epoch 932/1000
# 531/531 - 2s - loss: 6928.4468 - 2s/epoch - 3ms/step
# Epoch 933/1000
# 531/531 - 2s - loss: 7138.3818 - 2s/epoch - 3ms/step
# Epoch 934/1000
# 531/531 - 2s - loss: 6985.0698 - 2s/epoch - 3ms/step
# Epoch 935/1000
# 531/531 - 2s - loss: 6985.5332 - 2s/epoch - 3ms/step
# Epoch 936/1000
# 531/531 - 2s - loss: 7078.7041 - 2s/epoch - 3ms/step
# Epoch 937/1000
# 531/531 - 2s - loss: 7038.8911 - 2s/epoch - 3ms/step
# Epoch 938/1000
# 531/531 - 2s - loss: 7181.6157 - 2s/epoch - 3ms/step
# Epoch 939/1000
# 531/531 - 2s - loss: 7265.1187 - 2s/epoch - 3ms/step
# Epoch 940/1000
# 531/531 - 2s - loss: 7165.2002 - 2s/epoch - 3ms/step
# Epoch 941/1000
# 531/531 - 2s - loss: 7026.5977 - 2s/epoch - 3ms/step
# Epoch 942/1000
# 531/531 - 2s - loss: 7002.8965 - 2s/epoch - 3ms/step
# Epoch 943/1000
# 531/531 - 2s - loss: 7023.2715 - 2s/epoch - 3ms/step
# Epoch 944/1000
# 531/531 - 2s - loss: 7041.6177 - 2s/epoch - 3ms/step
# Epoch 945/1000
# 531/531 - 2s - loss: 7055.5137 - 2s/epoch - 3ms/step
# Epoch 946/1000
# 531/531 - 2s - loss: 7027.9014 - 2s/epoch - 3ms/step
# Epoch 947/1000
# 531/531 - 2s - loss: 7172.0967 - 2s/epoch - 3ms/step
# Epoch 948/1000
# 531/531 - 2s - loss: 7082.4106 - 2s/epoch - 3ms/step
# Epoch 949/1000
# 531/531 - 2s - loss: 7008.5557 - 2s/epoch - 3ms/step
# Epoch 950/1000
# 531/531 - 2s - loss: 7021.6929 - 2s/epoch - 3ms/step
# Epoch 951/1000
# 531/531 - 2s - loss: 7034.0684 - 2s/epoch - 3ms/step
# Epoch 952/1000
# 531/531 - 2s - loss: 7216.5244 - 2s/epoch - 3ms/step
# Epoch 953/1000
# 531/531 - 2s - loss: 6957.3936 - 2s/epoch - 3ms/step
# Epoch 954/1000
# 531/531 - 2s - loss: 7044.0371 - 2s/epoch - 3ms/step
# Epoch 955/1000
# 531/531 - 2s - loss: 6995.7563 - 2s/epoch - 3ms/step
# Epoch 956/1000
# 531/531 - 2s - loss: 7129.4888 - 2s/epoch - 3ms/step
# Epoch 957/1000
# 531/531 - 2s - loss: 7084.6294 - 2s/epoch - 3ms/step
# Epoch 958/1000
# 531/531 - 2s - loss: 7071.0327 - 2s/epoch - 3ms/step
# Epoch 959/1000
# 531/531 - 2s - loss: 6897.5122 - 2s/epoch - 3ms/step
# Epoch 960/1000
# 531/531 - 2s - loss: 7088.1138 - 2s/epoch - 3ms/step
# Epoch 961/1000
# 531/531 - 2s - loss: 7124.7769 - 2s/epoch - 3ms/step
# Epoch 962/1000
# 531/531 - 2s - loss: 6979.2944 - 2s/epoch - 3ms/step
# Epoch 963/1000
# 531/531 - 2s - loss: 7051.0112 - 2s/epoch - 3ms/step
# Epoch 964/1000
# 531/531 - 2s - loss: 6995.9121 - 2s/epoch - 3ms/step
# Epoch 965/1000
# 531/531 - 2s - loss: 7158.5376 - 2s/epoch - 3ms/step
# Epoch 966/1000
# 531/531 - 2s - loss: 6958.0854 - 2s/epoch - 3ms/step
# Epoch 967/1000
# 531/531 - 2s - loss: 7030.6143 - 2s/epoch - 3ms/step
# Epoch 968/1000
# 531/531 - 2s - loss: 7224.0601 - 2s/epoch - 3ms/step
# Epoch 969/1000
# 531/531 - 2s - loss: 7059.7080 - 2s/epoch - 3ms/step
# Epoch 970/1000
# 531/531 - 2s - loss: 7125.3911 - 2s/epoch - 3ms/step
# Epoch 971/1000
# 531/531 - 2s - loss: 7361.4258 - 2s/epoch - 3ms/step
# Epoch 972/1000
# 531/531 - 2s - loss: 7093.6777 - 2s/epoch - 3ms/step
# Epoch 973/1000
# 531/531 - 2s - loss: 7015.8062 - 2s/epoch - 3ms/step
# Epoch 974/1000
# 531/531 - 2s - loss: 7382.4927 - 2s/epoch - 3ms/step
# Epoch 975/1000
# 531/531 - 2s - loss: 7143.5142 - 2s/epoch - 3ms/step
# Epoch 976/1000
# 531/531 - 2s - loss: 7183.2305 - 2s/epoch - 3ms/step
# Epoch 977/1000
# 531/531 - 2s - loss: 7092.7637 - 2s/epoch - 3ms/step
# Epoch 978/1000
# 531/531 - 2s - loss: 7158.7935 - 2s/epoch - 3ms/step
# Epoch 979/1000
# 531/531 - 2s - loss: 7570.0454 - 2s/epoch - 3ms/step
# Epoch 980/1000
# 531/531 - 2s - loss: 7101.8018 - 2s/epoch - 3ms/step
# Epoch 981/1000
# 531/531 - 2s - loss: 7078.4497 - 2s/epoch - 3ms/step
# Epoch 982/1000
# 531/531 - 2s - loss: 7059.0732 - 2s/epoch - 3ms/step
# Epoch 983/1000
# 531/531 - 2s - loss: 7235.4180 - 2s/epoch - 3ms/step
# Epoch 984/1000
# 531/531 - 2s - loss: 7154.9502 - 2s/epoch - 3ms/step
# Epoch 985/1000
# 531/531 - 2s - loss: 7152.6914 - 2s/epoch - 3ms/step
# Epoch 986/1000
# 531/531 - 2s - loss: 7074.2861 - 2s/epoch - 3ms/step
# Epoch 987/1000
# 531/531 - 2s - loss: 7018.7349 - 2s/epoch - 3ms/step
# Epoch 988/1000
# 531/531 - 2s - loss: 7114.3872 - 2s/epoch - 3ms/step
# Epoch 989/1000
# 531/531 - 2s - loss: 7166.0684 - 2s/epoch - 3ms/step
# Epoch 990/1000
# 531/531 - 2s - loss: 7027.3325 - 2s/epoch - 3ms/step
# Epoch 991/1000
# 531/531 - 2s - loss: 7114.2051 - 2s/epoch - 3ms/step
# Epoch 992/1000
# 531/531 - 2s - loss: 7112.5156 - 2s/epoch - 3ms/step
# Epoch 993/1000
# 531/531 - 2s - loss: 7109.7476 - 2s/epoch - 3ms/step
# Epoch 994/1000
# 531/531 - 2s - loss: 7135.9014 - 2s/epoch - 3ms/step
# Epoch 995/1000
# 531/531 - 2s - loss: 7041.4849 - 2s/epoch - 3ms/step
# Epoch 996/1000
# 531/531 - 2s - loss: 7037.1367 - 2s/epoch - 3ms/step
# Epoch 997/1000
# 531/531 - 2s - loss: 7151.7632 - 2s/epoch - 3ms/step
# Epoch 998/1000
# 531/531 - 2s - loss: 7062.8247 - 2s/epoch - 3ms/step
# Epoch 999/1000
# 531/531 - 2s - loss: 6954.3755 - 2s/epoch - 3ms/step
# Epoch 1000/1000
# 531/531 - 2s - loss: 7288.9038 - 2s/epoch - 3ms/step
# 3/3 [==============================] - 0s 2ms/step

# %%
c=0
for i in loss_index_L_FORECE_C:    
    L_FORCE_C[i]=pred[c]
    c+=1

# %%
import matplotlib.pyplot as plt 
plt.plot(L_FORCE_C,label='imputation_L_FORCE_C_cnnlstm')
plt.plot(L.iloc[:,0],label='original')
plt.legend()
