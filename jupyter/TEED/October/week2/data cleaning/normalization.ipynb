# %%
import pandas as pd

data=pd.read_excel("/Users/withmocha/Desktop/TEED/data/mocha/23.10.14/squart.xlsx")


data
# Out:
#      Unnamed: 0  FORCE_B(Right)  FORCE_C(Left)  FORCE_D(Heel)  \
# 0             0              67            260            750
# 1             1              68            263            735
# 2             2              71            275            745
# 3             3              73            261            767
# 4             4              80            252            772
# ..          ...             ...            ...            ...
# 608         608              48            342            214
# 609         609              23            335            208
# 610         610              45            338            244
# 611         611              38            328            247
# 612         612              33            315            290
#
#      FORCE_E(Little toe)  FORCE_F(Center)  X COORDINATE_C(Left)  \
# 0                      0               28              3.325000
# 1                      0               13              3.378327
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                0
# FORCE_B(Right)            0
# FORCE_C(Left)             0
# FORCE_D(Heel)             0
# FORCE_E(Little toe)       0
# FORCE_F(Center)           0
# X COORDINATE_C(Left)      0
# X COORDINATE_D(Heel)      0
# X COORDINATE_F(Center)    0
# Y COORDINATE_C(Left)      0
# Y COORDINATE_D(Heel)      0
# Y COORDINATE_F(Center)    0
# COPX                      0
# COPY                      0
# FSR DATA_A(Big toe)       0
# FSR DATA_B(Right)         0
# FSR DATA_C(Left)          0
# FSR DATA_D(Heel)          0
# FSR DATA_E(Little toe)    0
# FSR DATA_F(Center)        0
# dtype: int64

# %%
data.drop(columns=['Unnamed: 0','COPX','COPY'],inplace=True)

# %%
columns=data.columns

# %%
LR=data.loc[:,['FORCE_B(Right)','FORCE_C(Left)','X COORDINATE_C(Left)','Y COORDINATE_C(Left)',
               'FSR DATA_B(Right)','FSR DATA_C(Left)']]

L=data.loc[:,['FORCE_C(Left)','X COORDINATE_C(Left)','Y COORDINATE_C(Left)','FSR DATA_C(Left)']]

R=data.loc[:,['FORCE_B(Right)','FSR DATA_B(Right)']]

# %%
L.plot(figsize=(15,15))
# Out:
# <Axes: >

# %%
R.plot(figsize=(15,15))
# Out:
# <Axes: >

# %%
LR.plot(figsize=(15,15))
# Out:
# <Axes: >

# %%
L
# Out:
#      FORCE_C(Left)  X COORDINATE_C(Left)  Y COORDINATE_C(Left)  \
# 0              260              3.325000             12.434615
# 1              263              3.378327             12.311787
# 2              275              3.378182             12.383636
# 3              261              3.385057             12.306513
# 4              252              3.311508             12.388889
# ..             ...                   ...                   ...
# 608            342              3.165205             12.741228
# 609            335              3.165672             12.749254
# 610            338              3.217456             12.665680
# 611            328              3.179878             12.681402
# 612            315              3.165079             12.709524
#
#      FSR DATA_C(Left)
# 0                  53
# 1                  52
# 2                  51
# 3                  48
# 4                  47
# ..                ...
# 608                50
# ...

# %%
L_col=L.columns
LR_col=LR.columns
R_col=R.columns
print(L_col)
print(R_col)
print(LR_col)
# Out:
# Index(['FORCE_C(Left)', 'X COORDINATE_C(Left)', 'Y COORDINATE_C(Left)',
#        'FSR DATA_C(Left)'],
#       dtype='object')
# Index(['FORCE_B(Right)', 'FSR DATA_B(Right)'], dtype='object')
# Index(['FORCE_B(Right)', 'FORCE_C(Left)', 'X COORDINATE_C(Left)',
#        'Y COORDINATE_C(Left)', 'FSR DATA_B(Right)', 'FSR DATA_C(Left)'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
L_scaled=scaler.fit_transform(L)

# %%
L=pd.DataFrame(data=L_scaled)

# %%
L
# Out:
#             0         1         2         3
# 0    1.245014  1.529382 -0.886157  1.361804
# 1    1.274000  1.749337 -1.368345  1.264316
# 2    1.389941  1.748738 -1.086286  1.166829
# 3    1.254676  1.777098 -1.389048  0.874366
# 4    1.167720  1.473732 -1.065666  0.776878
# ..        ...       ...       ...       ...
# 608  2.037281  0.870283  0.317515  1.069341
# 609  1.969648  0.872209  0.349021  1.166829
# 610  1.998633  1.085799  0.020937  1.069341
# 611  1.902016  0.930805  0.082657  0.776878
# 612  1.776412  0.869766  0.193053  0.484416
#
# [613 rows x 4 columns]

# %%
L_new=L.set_axis(["FORCE_C(Left)","X COORDINATE_C(Left)","Y COORDINATE_C(Left)",
            "FSR DATA_C(Left)"],axis="columns")

L_new
# Out:
#      FORCE_C(Left)  X COORDINATE_C(Left)  Y COORDINATE_C(Left)  \
# 0         1.245014              1.529382             -0.886157
# 1         1.274000              1.749337             -1.368345
# 2         1.389941              1.748738             -1.086286
# 3         1.254676              1.777098             -1.389048
# 4         1.167720              1.473732             -1.065666
# ..             ...                   ...                   ...
# 608       2.037281              0.870283              0.317515
# 609       1.969648              0.872209              0.349021
# 610       1.998633              1.085799              0.020937
# 611       1.902016              0.930805              0.082657
# 612       1.776412              0.869766              0.193053
#
#      FSR DATA_C(Left)
# 0            1.361804
# 1            1.264316
# 2            1.166829
# 3            0.874366
# 4            0.776878
# ..                ...
# 608          1.069341
# ...

# %%
L_new.plot(figsize=(15,15))
# Out:
# <Axes: >

# %%
R_col
# Out:
# Index(['FORCE_B(Right)', 'FSR DATA_B(Right)'], dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
R_scaled=scaler.fit_transform(R)
R=pd.DataFrame(data=R_scaled)

R_new=R.set_axis(["FORCE_B(Right)","FSR DATA_B(Right)"],axis="columns")

R_new
# Out:
#      FORCE_B(Right)  FSR DATA_B(Right)
# 0          2.277552           1.757358
# 1          2.319914           1.524890
# 2          2.447001           1.524890
# 3          2.531726           1.292421
# 4          2.828263           1.292421
# ..              ...                ...
# 608        1.472665          -0.334861
# 609        0.413604          -0.102392
# 610        1.345578           0.362545
# 611        1.049041           1.059952
# 612        0.837228           1.757358
#
# [613 rows x 2 columns]

# %%
R_new.plot(figsize=(15,15))
# Out:
# <Axes: >

# %%
LR_col
# Out:
# Index(['FORCE_B(Right)', 'FORCE_C(Left)', 'X COORDINATE_C(Left)',
#        'Y COORDINATE_C(Left)', 'FSR DATA_B(Right)', 'FSR DATA_C(Left)'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
LR_scaled=scaler.fit_transform(LR)
LR=pd.DataFrame(data=LR_scaled)

LR_new=LR.set_axis(["FORCE_B(Right)","FORCE_C(Left)",
                "X COORDINATE_C(Left)","Y COORDINATE_C(Left)",
                "FSR DATA_B(Right)","FSR DATA_C(Left)"],axis="columns")

LR_new
# Out:
#      FORCE_B(Right)  FORCE_C(Left)  X COORDINATE_C(Left)  \
# 0          2.277552       1.245014              1.529382
# 1          2.319914       1.274000              1.749337
# 2          2.447001       1.389941              1.748738
# 3          2.531726       1.254676              1.777098
# 4          2.828263       1.167720              1.473732
# ..              ...            ...                   ...
# 608        1.472665       2.037281              0.870283
# 609        0.413604       1.969648              0.872209
# 610        1.345578       1.998633              1.085799
# 611        1.049041       1.902016              0.930805
# 612        0.837228       1.776412              0.869766
#
#      Y COORDINATE_C(Left)  FSR DATA_B(Right)  FSR DATA_C(Left)
# 0               -0.886157           1.757358          1.361804
# 1               -1.368345           1.524890          1.264316
# 2               -1.086286           1.524890          1.166829
# ...

# %%
LR.plot(figsize=(15,15))
# Out:
# <Axes: >

# %%
L_new.to_excel("data_L.xlsx")

# %%
R_new
# Out:
#      FORCE_B(Right)  FSR DATA_B(Right)
# 0          2.277552           1.757358
# 1          2.319914           1.524890
# 2          2.447001           1.524890
# 3          2.531726           1.292421
# 4          2.828263           1.292421
# ..              ...                ...
# 608        1.472665          -0.334861
# 609        0.413604          -0.102392
# 610        1.345578           0.362545
# 611        1.049041           1.059952
# 612        0.837228           1.757358
#
# [613 rows x 2 columns]

# %%
R_new.to_excel("data_R.xlsx")

# %%
LR_new.to_excel("data_LR.xlsx")
