# %%
import pandas as pd

data_row=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/Data(24.03.12)/data(use)/data(small)/abnormal/fishing data small.csv")

data_row
# Out:
#      Unnamed: 0 word  predict
# 0             0   본인  fishing
# 1             1   통장  fishing
# 2             2   저희  fishing
# 3             3    거  fishing
# 4             4   사건  fishing
# ..          ...  ...      ...
# 593         593   행과  fishing
# 594         594   감사  fishing
# 595         595   위반  fishing
# 596         596   한계  fishing
# 597         597   감염  fishing
#
# [598 rows x 3 columns]

# %%
data_row.drop(columns=['Unnamed: 0'],inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
A=le.fit_transform(data_row['word'])

# %%
for i in range(data_row.shape[0]):
    data_row.iloc[i,0]=A[i]

# %%
data=data_row

# %%
A=le.fit_transform(data['predict'])

# %%
for i in range(data.shape[0]):
    data.iloc[i,1]=A[i]

# %%
data
# Out:
#     word predict
# 0    238       0
# 1    548       0
# 2    436       0
# 3     17       0
# 4    254       0
# ..   ...     ...
# 593  577       0
# 594    9       0
# 595  373       0
# 596  570       0
# 597   10       0
#
# [598 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.array(data['word'])

# %%
plt.plot(x)
