# %%
import pandas as pd  

data_row=pd.read_excel('/Users/withmocha/Desktop/TEED/data/mocha/23.12.04/gait/gait_row_main.xlsx')


data_row
# Out:
#      FORCE_A(Big toe)  FORCE_B(Right)  FORCD_C(Left)  FORCE_D(Heel)  \
# 0                   0             117            254           1794
# 1                   0             163            287           1751
# 2                  14             174            326           1812
# 3                   0             204            348           1785
# 4                  35             251            368           1761
# ..                ...             ...            ...            ...
# 887                 0              84            258           2215
# 888                 0             109            293           2239
# 889                 0             108            318           2251
# 890                 0             132            352           2251
# 891                 0             155            392           2178
#
#      FORCE_E(Little toe)  FORCE_F(Center)  XCOR_A(Big toe)  XCOR_B(Right)  \
# 0                      0                0              NaN       7.081197
# ...

# %%
data_row.isnull().sum()
# Out:
# FORCE_A(Big toe)         0
# FORCE_B(Right)           0
# FORCD_C(Left)            0
# FORCE_D(Heel)            0
# FORCE_E(Little toe)      0
# FORCE_F(Center)          0
# XCOR_A(Big toe)        619
# XCOR_B(Right)          412
# XCOR_C(Left)           318
# XCOR_D(Heel)           458
# XCOR_E(Little toe)     675
# XCORF(Center)          572
# YCOR_A(Big toe)        619
# YCOR_B(Right)          412
# YCOR_C(Left)           318
# YCOR_D(Heel)           458
# YCOR_E(Little toe)     675
# YCOR_F(Center)         572
# COPX                   262
# COPY                   262
# FSR_A(Big toe)           0
# FSR_B(Right)             0
# FSR_C(Left)              0
# FSR_D(Heel)              0
# FSR_E(Little toe)        0
# FSR_F(Center)            0
# dtype: int64

# %%
data_row.fillna(method="ffill",inplace=True)
# Out:
# /var/folders/gb/hslcbzfs0bvcnj3zxtfrxt_r0000gn/T/ipykernel_95334/2738689939.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_row.fillna(method="ffill",inplace=True)

# %%
data_row.isnull().sum()
# Out:
# FORCE_A(Big toe)        0
# FORCE_B(Right)          0
# FORCD_C(Left)           0
# FORCE_D(Heel)           0
# FORCE_E(Little toe)     0
# FORCE_F(Center)         0
# XCOR_A(Big toe)         2
# XCOR_B(Right)           0
# XCOR_C(Left)            0
# XCOR_D(Heel)            0
# XCOR_E(Little toe)     13
# XCORF(Center)           1
# YCOR_A(Big toe)         2
# YCOR_B(Right)           0
# YCOR_C(Left)            0
# YCOR_D(Heel)            0
# YCOR_E(Little toe)     13
# YCOR_F(Center)          1
# COPX                    0
# COPY                    0
# FSR_A(Big toe)          0
# FSR_B(Right)            0
# FSR_C(Left)             0
# FSR_D(Heel)             0
# FSR_E(Little toe)       0
# FSR_F(Center)           0
# dtype: int64

# %%
data_row.fillna(method="bfill",inplace=True)
# Out:
# /var/folders/gb/hslcbzfs0bvcnj3zxtfrxt_r0000gn/T/ipykernel_95334/1358116098.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_row.fillna(method="bfill",inplace=True)

# %%
data_row.isnull().sum()
# Out:
# FORCE_A(Big toe)       0
# FORCE_B(Right)         0
# FORCD_C(Left)          0
# FORCE_D(Heel)          0
# FORCE_E(Little toe)    0
# FORCE_F(Center)        0
# XCOR_A(Big toe)        0
# XCOR_B(Right)          0
# XCOR_C(Left)           0
# XCOR_D(Heel)           0
# XCOR_E(Little toe)     0
# XCORF(Center)          0
# YCOR_A(Big toe)        0
# YCOR_B(Right)          0
# YCOR_C(Left)           0
# YCOR_D(Heel)           0
# YCOR_E(Little toe)     0
# YCOR_F(Center)         0
# COPX                   0
# COPY                   0
# FSR_A(Big toe)         0
# FSR_B(Right)           0
# FSR_C(Left)            0
# FSR_D(Heel)            0
# FSR_E(Little toe)      0
# FSR_F(Center)          0
# dtype: int64

# %%
data_row.to_excel("gait_data_target.xlsx")
