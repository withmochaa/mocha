# %%
import pandas as pd  

data=pd.read_excel('/Users/withmocha/Desktop/TEED/data/mocha/23.12.04/gait/gait_data_fit_feature.xlsx')


data
# Out:
#      Unnamed: 0  FORCE_B(Right)  FORCE_C(Left)  FSR_C(Left)
# 0             0             117            254           40
# 1             1             163            287           41
# 2             2             174            326           42
# 3             3             204            348           44
# 4             4             251            368           49
# ..          ...             ...            ...          ...
# 887         887              84            258           42
# 888         888             109            293           45
# 889         889             108            318           47
# 890         890             132            352           47
# 891         891             155            392           49
#
# [892 rows x 4 columns]

# %%
data.drop(columns=["Unnamed: 0"],inplace=True)

# %%
import matplotlib.pyplot as plt

columns=data.columns
count=0
for i in columns:
    print(columns[count])
    count=count+1
    plt.plot(data[i])
    plt.show()
# Out:
# FORCE_B(Right)
# FORCE_C(Left)
# FSR_C(Left)

# %%
data.columns
# Out:
# Index(['FORCE_B(Right)', 'FORCE_C(Left)', 'FSR_C(Left)'], dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
data_scaled=scaler.fit_transform(data)
data2=pd.DataFrame(data=data_scaled)
data2=data2.set_axis(["FORCE_B(Right)","FORCE_C(Left)",
                      "FSR_C(Left)"],axis="columns")

# %%
data2.to_excel("gait_norm.xlsx")
