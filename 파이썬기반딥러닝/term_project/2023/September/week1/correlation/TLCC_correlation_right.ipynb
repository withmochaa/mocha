# %%
import pandas as pd

data=pd.read_excel('/Users/withmocha/Desktop/TEED/data/mocha/23.09.02/data_sum.xlsx')

print(data)
print(data.shape)
# Out:
#      SQUAT_FORCE_L  SQUAT_X_COR_L  SQUAT_Y_COR_L  SQUAT_COPX  SQUAT_COPY  \
# 0              260       3.325000      12.434615    5.519283   21.277130
# 1              263       3.378327      12.311787    5.588154   21.189624
# 2              275       3.378182      12.383636    5.527003   21.112061
# 3              261       3.385057      12.306513    5.551982   21.260793
# 4              252       3.311508      12.388889    5.533654   21.252622
# ..             ...            ...            ...         ...         ...
# 608            342       3.165205      12.741228    4.145478   17.242464
# 609            335       3.165672      12.749254    4.034075   17.324757
# 610            338       3.217456      12.665680    4.198758   17.590062
# 611            328       3.179878      12.681402    4.174745   17.733418
# 612            315       3.165079      12.709524    4.236453   18.237685
#
#      SQUAT_FSR_L  SQUAT_FSRNONOISE_L  SQUAT_FSR_mass_L  SQUAT_FORCE_R  \
# ...

# %%
data.plot(figsize=(35,35))
# Out:
# <Axes: >

# %%
data.isnull().sum()
# Out:
# SQUAT_FORCE_L           0
# SQUAT_X_COR_L          64
# SQUAT_Y_COR_L          64
# SQUAT_COPX              0
# SQUAT_COPY              0
# SQUAT_FSR_L             0
# SQUAT_FSRNONOISE_L      0
# SQUAT_FSR_mass_L        0
# SQUAT_FORCE_R           0
# SQUAT_X_COR_R         420
# SQUAT_Y_COR_R         420
# SQUAT_COPX.1            0
# SQUAT_COPY.1            0
# SQUAT_FSR_R             0
# SQUAT_FSRNONOISE_R      0
# SQUAT_FSR_mass_R        0
# STS_FORCE_L             0
# STS_X_COR_L           149
# STS_Y_COR_L           149
# STS_COPX               20
# STS_COPY               20
# STS_FSR_L               0
# STS_FSRNONOISE_L        0
# STS_FSR_mass_L          0
# STS_FORCE_R             0
# STS_X_COR_R           366
# STS_Y_COR_R           366
# STS_COPX.1             20
# STS_COPY.1             20
# STS_FSR_R               0
# STS_FSRNONOISE_R        0
# STS_FSR_mass_R          0
# GAIT_FORCE_L            0
# GAIT_X_COR_L          329
# GAIT_Y_COR_L          329
# ...

# %%
data.drop(columns=['SQUAT_X_COR_R','SQUAT_Y_COR_R'],inplace=True)

# %%
data.isnull().sum()
# Out:
# SQUAT_FORCE_L           0
# SQUAT_X_COR_L          64
# SQUAT_Y_COR_L          64
# SQUAT_COPX              0
# SQUAT_COPY              0
# SQUAT_FSR_L             0
# SQUAT_FSRNONOISE_L      0
# SQUAT_FSR_mass_L        0
# SQUAT_FORCE_R           0
# SQUAT_COPX.1            0
# SQUAT_COPY.1            0
# SQUAT_FSR_R             0
# SQUAT_FSRNONOISE_R      0
# SQUAT_FSR_mass_R        0
# STS_FORCE_L             0
# STS_X_COR_L           149
# STS_Y_COR_L           149
# STS_COPX               20
# STS_COPY               20
# STS_FSR_L               0
# STS_FSRNONOISE_L        0
# STS_FSR_mass_L          0
# STS_FORCE_R             0
# STS_X_COR_R           366
# STS_Y_COR_R           366
# STS_COPX.1             20
# STS_COPY.1             20
# STS_FSR_R               0
# STS_FSRNONOISE_R        0
# STS_FSR_mass_R          0
# GAIT_FORCE_L            0
# GAIT_X_COR_L          329
# GAIT_Y_COR_L          329
# GAIT_COPX             186
# GAIT_COPY             186
# ...

# %%
columns=data.columns

print(columns)
# Out:
# Index(['SQUAT_FORCE_L', 'SQUAT_X_COR_L', 'SQUAT_Y_COR_L', 'SQUAT_COPX',
#        'SQUAT_COPY', 'SQUAT_FSR_L', 'SQUAT_FSRNONOISE_L', 'SQUAT_FSR_mass_L',
#        'SQUAT_FORCE_R', 'SQUAT_COPX.1', 'SQUAT_COPY.1', 'SQUAT_FSR_R',
#        'SQUAT_FSRNONOISE_R', 'SQUAT_FSR_mass_R', 'STS_FORCE_L', 'STS_X_COR_L',
#        'STS_Y_COR_L', 'STS_COPX', 'STS_COPY', 'STS_FSR_L', 'STS_FSRNONOISE_L',
#        'STS_FSR_mass_L', 'STS_FORCE_R', 'STS_X_COR_R', 'STS_Y_COR_R',
#        'STS_COPX.1', 'STS_COPY.1', 'STS_FSR_R', 'STS_FSRNONOISE_R',
#        'STS_FSR_mass_R', 'GAIT_FORCE_L', 'GAIT_X_COR_L', 'GAIT_Y_COR_L',
#        'GAIT_COPX', 'GAIT_COPY', 'GAIT_FSR_L', 'GAIT_FSRNONOISE_L',
#        'GAIT_FSR_mass_L', 'GAIT_FORCE_R', 'GAIT_X_COR_R', 'GAIT_Y_COR_R',
#        'GAIT_COPX.1', 'GAIT_COPY.1', 'GAIT_FSR_R', 'GAIT_FSRNONOISE_R',
#        'GAIT_FSR_mass_R'],
#       dtype='object')

# %%
for i in columns:
    data[i].fillna(data[i].mean(),inplace=True)
    
data.isnull().sum()
# Out:
# SQUAT_FORCE_L         0
# SQUAT_X_COR_L         0
# SQUAT_Y_COR_L         0
# SQUAT_COPX            0
# SQUAT_COPY            0
# SQUAT_FSR_L           0
# SQUAT_FSRNONOISE_L    0
# SQUAT_FSR_mass_L      0
# SQUAT_FORCE_R         0
# SQUAT_COPX.1          0
# SQUAT_COPY.1          0
# SQUAT_FSR_R           0
# SQUAT_FSRNONOISE_R    0
# SQUAT_FSR_mass_R      0
# STS_FORCE_L           0
# STS_X_COR_L           0
# STS_Y_COR_L           0
# STS_COPX              0
# STS_COPY              0
# STS_FSR_L             0
# STS_FSRNONOISE_L      0
# STS_FSR_mass_L        0
# STS_FORCE_R           0
# STS_X_COR_R           0
# STS_Y_COR_R           0
# STS_COPX.1            0
# STS_COPY.1            0
# STS_FSR_R             0
# STS_FSRNONOISE_R      0
# STS_FSR_mass_R        0
# GAIT_FORCE_L          0
# GAIT_X_COR_L          0
# GAIT_Y_COR_L          0
# GAIT_COPX             0
# GAIT_COPY             0
# GAIT_FSR_L            0
# GAIT_FSRNONOISE_L     0
# GAIT_FSR_mass_L       0
# ...

# %%
data.plot(figsize=(40,40))
# Out:
# <Axes: >

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
def crosscorr(datax, datay, lag=0, wrap=False):
    if wrap:
        shiftedy = datay.shift(lag)
        shiftedy.iloc[:lag] = datay.iloc[-lag:].values
        return datax.corr(shiftedy)
    else: 
        return datax.corr(datay.shift(lag))

# %%
squat_sts_force=pd.concat([data.SQUAT_FORCE_R,data.STS_FORCE_R],axis=1)

d1 = data['SQUAT_FORCE_R']
d2 = data['STS_FORCE_R']
seconds = 5
fps = 30
rs = [crosscorr(d1,d2, lag) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
offset = np.floor(len(rs)/2)-np.argmax(rs) # 최대 correlation 값 가지는 offset 계산

f,ax=plt.subplots(figsize=(20,3))
ax.plot(rs)
ax.axvline(np.ceil(len(rs)/2),color='k',linestyle='--',label='Center')
ax.axvline(np.argmax(rs),color='r',linestyle='--',label='Peak synchrony')
ax.set(title=f'Offset = {offset} frames\nS1 leads <> S2 leads',ylim=[-.91,.91],xlim=[0,301], xlabel='Offset_about_squat_sts_force_R',ylabel='Pearson r')
ax.set_xticks([-50,0, 50, 100, 151, 201, 251, 301])
ax.set_xticklabels([-200,-150, -100, -50, 0, 50, 100, 150]);
plt.legend()

# %%
squat_sts_fsr=pd.concat([data.SQUAT_FSR_R,data.STS_FSR_R],axis=1)

d1 = data['SQUAT_FSR_R']
d2 = data['STS_FSR_R']
seconds = 5
fps = 30
rs = [crosscorr(d1,d2, lag) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
offset = np.floor(len(rs)/2)-np.argmax(rs) # 최대 correlation 값 가지는 offset 계산

f,ax=plt.subplots(figsize=(20,3))
ax.plot(rs)
ax.axvline(np.ceil(len(rs)/2),color='k',linestyle='--',label='Center')
ax.axvline(np.argmax(rs),color='r',linestyle='--',label='Peak synchrony')
ax.set(title=f'Offset = {offset} frames\nS1 leads <> S2 leads',ylim=[-.91,.91],xlim=[0,301], xlabel='Offset_about_squat_sts_fsr_R',ylabel='Pearson r')
ax.set_xticks([0, 50, 100, 151, 201, 251, 301])
ax.set_xticklabels([-150, -100, -50, 0, 50, 100, 150]);
plt.legend()

# %%
squat_gait_force=pd.concat([data.SQUAT_FORCE_R,data.GAIT_FORCE_R],axis=1)
d1 = data['SQUAT_FORCE_R']
d2 = data['GAIT_FORCE_R']
seconds = 5
fps = 30
rs = [crosscorr(d1,d2, lag) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
offset = np.floor(len(rs)/2)-np.argmax(rs) # 최대 correlation 값 가지는 offset 계산

f,ax=plt.subplots(figsize=(20,3))
ax.plot(rs)
ax.axvline(np.ceil(len(rs)/2),color='k',linestyle='--',label='Center')
ax.axvline(np.argmax(rs),color='r',linestyle='--',label='Peak synchrony')
ax.set(title=f'Offset = {offset} frames\nS1 leads <> S2 leads',ylim=[-.91,.91],xlim=[0,301], xlabel='Offset_about_squat_gait_force_R',ylabel='Pearson r')
ax.set_xticks([0, 50, 100, 151, 201, 251, 301])
ax.set_xticklabels([-150, -100, -50, 0, 50, 100, 150]);
plt.legend()

# %%
squat_gait_force=pd.concat([data.SQUAT_FORCE_R,data.GAIT_FORCE_R],axis=1)
d1 = data['SQUAT_FORCE_R']
d2 = data['GAIT_FORCE_R']
seconds = 5
fps = 30
rs = [crosscorr(d1,d2, lag) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
offset = np.floor(len(rs)/2)-np.argmax(rs) # 최대 correlation 값 가지는 offset 계산

f,ax=plt.subplots(figsize=(20,3))
ax.plot(rs)
ax.axvline(np.ceil(len(rs)/2),color='k',linestyle='--',label='Center')
ax.axvline(np.argmax(rs),color='r',linestyle='--',label='Peak synchrony')
ax.set(title=f'Offset = {offset} frames\nS1 leads <> S2 leads',ylim=[-.91,.91],xlim=[0,301], xlabel='Offset_about_squat_gait_force_R',ylabel='Pearson r')
ax.set_xticks([0, 50, 100, 151, 201, 251, 301])
ax.set_xticklabels([-150, -100, -50, 0, 50, 100, 150]);
plt.legend()

# %%
squat_gait_fsr=pd.concat([data.SQUAT_FSR_R,data.GAIT_FSR_R],axis=1)


d1 = data['SQUAT_FSR_R']
d2 = data['GAIT_FSR_R']
seconds = 5
fps = 30
rs = [crosscorr(d1,d2, lag) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
offset = np.floor(len(rs)/2)-np.argmax(rs) # 최대 correlation 값 가지는 offset 계산

f,ax=plt.subplots(figsize=(20,3))
ax.plot(rs)
ax.axvline(np.ceil(len(rs)/2),color='k',linestyle='--',label='Center')
ax.axvline(np.argmax(rs),color='r',linestyle='--',label='Peak synchrony')
ax.set(title=f'Offset = {offset} frames\nS1 leads <> S2 leads',ylim=[-.91,.91],xlim=[0,301], xlabel='Offset_about_squat_gait_fsr_R',ylabel='Pearson r')
ax.set_xticks([0, 50, 100, 151, 201, 251, 301])
ax.set_xticklabels([-150, -100, -50, 0, 50, 100, 150]);
plt.legend()

# %%
sts_gait_force=pd.concat([data.STS_FORCE_R,data.GAIT_FORCE_R],axis=1)

d1 = data['STS_FORCE_R']
d2 = data['GAIT_FORCE_R']
seconds = 5
fps = 30
rs = [crosscorr(d1,d2, lag) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
offset = np.floor(len(rs)/2)-np.argmax(rs) # 최대 correlation 값 가지는 offset 계산

f,ax=plt.subplots(figsize=(20,3))
ax.plot(rs)
ax.axvline(np.ceil(len(rs)/2),color='k',linestyle='--',label='Center')
ax.axvline(np.argmax(rs),color='r',linestyle='--',label='Peak synchrony')
ax.set(title=f'Offset = {offset} frames\nS1 leads <> S2 leads',ylim=[-.91,.91],xlim=[0,301], xlabel='Offset_about_sts_gait_force_R',ylabel='Pearson r')
ax.set_xticks([0, 50, 100, 151, 201, 251, 301])
ax.set_xticklabels([-150, -100, -50, 0, 50, 100, 150]);
plt.legend()

# %%
sts_gait_x_cor=pd.concat([data.STS_X_COR_R,data.GAIT_X_COR_R],axis=1)

d1 = data['STS_X_COR_R']
d2 = data['GAIT_X_COR_R']
seconds = 5
fps = 30
rs = [crosscorr(d1,d2, lag) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
offset = np.floor(len(rs)/2)-np.argmax(rs) # 최대 correlation 값 가지는 offset 계산

f,ax=plt.subplots(figsize=(20,3))
ax.plot(rs)
ax.axvline(np.ceil(len(rs)/2),color='k',linestyle='--',label='Center')
ax.axvline(np.argmax(rs),color='r',linestyle='--',label='Peak synchrony')
ax.set(title=f'Offset = {offset} frames\nS1 leads <> S2 leads',ylim=[-.91,.91],xlim=[0,301], xlabel='Offset_about_sts_gait_x_cor_R',ylabel='Pearson r')
ax.set_xticks([0, 50, 100, 151, 201, 251, 301])
ax.set_xticklabels([-150, -100, -50, 0, 50, 100, 150]);
plt.legend()

# %%
sts_gait_y_cor=pd.concat([data.STS_Y_COR_R,data.GAIT_Y_COR_R],axis=1)

d1 = data['STS_Y_COR_R']
d2 = data['GAIT_Y_COR_R']
seconds = 5
fps = 30
rs = [crosscorr(d1,d2, lag) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
offset = np.floor(len(rs)/2)-np.argmax(rs) # 최대 correlation 값 가지는 offset 계산

f,ax=plt.subplots(figsize=(20,3))
ax.plot(rs)
ax.axvline(np.ceil(len(rs)/2),color='k',linestyle='--',label='Center')
ax.axvline(np.argmax(rs),color='r',linestyle='--',label='Peak synchrony')
ax.set(title=f'Offset = {offset} frames\nS1 leads <> S2 leads',ylim=[-.91,.91],xlim=[0,301], xlabel='Offset_about_sts_gait_y_cor_R',ylabel='Pearson r')
ax.set_xticks([-50,0, 50, 100, 151, 201, 251, 301])
ax.set_xticklabels([-200,-150, -100, -50, 0, 50, 100, 150]);
plt.legend()

# %%
sts_gait_fsr=pd.concat([data.STS_FSR_R,data.GAIT_FSR_R],axis=1)

d1 = data['STS_FSR_R']
d2 = data['GAIT_FSR_R']
seconds = 5
fps = 30
rs = [crosscorr(d1,d2, lag) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
offset = np.floor(len(rs)/2)-np.argmax(rs) # 최대 correlation 값 가지는 offset 계산

f,ax=plt.subplots(figsize=(20,3))
ax.plot(rs)
ax.axvline(np.ceil(len(rs)/2),color='k',linestyle='--',label='Center')
ax.axvline(np.argmax(rs),color='r',linestyle='--',label='Peak synchrony')
ax.set(title=f'Offset = {offset} frames\nS1 leads <> S2 leads',ylim=[-.91,.91],xlim=[0,301], xlabel='Offset_about_sts_gait_fsr_R',ylabel='Pearson r')
ax.set_xticks([0, 50, 100, 151, 201, 251, 301])
ax.set_xticklabels([-150, -100, -50, 0, 50, 100, 150]);
plt.legend()

# %%
sts_gait_fsr_noise=pd.concat([data.STS_FSRNONOISE_R,data.GAIT_FSRNONOISE_R],axis=1)

d1 = data['STS_FSRNONOISE_R']
d2 = data['GAIT_FSRNONOISE_R']
seconds = 5
fps = 30
rs = [crosscorr(d1,d2, lag) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
offset = np.floor(len(rs)/2)-np.argmax(rs) # 최대 correlation 값 가지는 offset 계산

f,ax=plt.subplots(figsize=(20,3))
ax.plot(rs)
ax.axvline(np.ceil(len(rs)/2),color='k',linestyle='--',label='Center')
ax.axvline(np.argmax(rs),color='r',linestyle='--',label='Peak synchrony')
ax.set(title=f'Offset = {offset} frames\nS1 leads <> S2 leads',ylim=[-.91,.91],xlim=[0,301], xlabel='Offset_about_sts_gait_fsr_noise_R',ylabel='Pearson r')
ax.set_xticks([0, 50, 100, 151, 201, 251, 301])
ax.set_xticklabels([-150, -100, -50, 0, 50, 100, 150]);
plt.legend()

# %%
sts_gait_fsr_mass=pd.concat([data.STS_FSR_mass_R,data.GAIT_FSR_mass_R],axis=1)

d1 = data['STS_FSR_mass_R']
d2 = data['GAIT_FSR_mass_R']
seconds = 5
fps = 30
rs = [crosscorr(d1,d2, lag) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
offset = np.floor(len(rs)/2)-np.argmax(rs) # 최대 correlation 값 가지는 offset 계산

f,ax=plt.subplots(figsize=(20,3))
ax.plot(rs)
ax.axvline(np.ceil(len(rs)/2),color='k',linestyle='--',label='Center')
ax.axvline(np.argmax(rs),color='r',linestyle='--',label='Peak synchrony')
ax.set(title=f'Offset = {offset} frames\nS1 leads <> S2 leads',ylim=[-.91,.91],xlim=[0,301], xlabel='Offset_about_sts_gait_fsr_mass_R',ylabel='Pearson r')
ax.set_xticks([0, 50, 100, 151, 201, 251, 301])
ax.set_xticklabels([-150, -100, -50, 0, 50, 100, 150]);
plt.legend()
