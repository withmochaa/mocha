# %%
import pandas as pd 

data=pd.read_excel("/Users/withmocha/Desktop/TEED/data/mocha/23.11.01/data_ffill_norm_drop.xlsx")

data
# Out:
#      Unnamed: 0  FORCE_B(Right)  FORCE_C(Left)  X COORDINATE_C(Left)  \
# 0             0        2.299863       1.249019              1.545615
# 1             1        2.342486       1.278073              1.767201
# 2             2        2.470357       1.394288              1.766598
# 3             3        2.555604       1.258703              1.795168
# 4             4             NaN            NaN                   NaN
# ..          ...             ...            ...                   ...
# 608         608        0.253933       2.033475              0.908013
# 609         609             NaN            NaN                   NaN
# 610         610        1.362145       2.004421              1.098743
# 611         611        1.063780       1.907574              0.942600
# 612         612        0.850663       1.781674              0.881108
#
#      X COORDINATE_D(Heel)  X COORDINATE_F(Center)  Y COORDINATE_C(Left)  \
# 0                1.477110                0.907408             -0.901622
# 1                1.805595               -1.000678             -1.390730
# 2                1.231645               -0.746267             -1.104623
# 3                1.361128                0.631795             -1.411730
# 4                     NaN                     NaN                   NaN
# ..                    ...                     ...                   ...
# 608              1.955067                1.146905              0.310464
# 609                   NaN                     NaN                   NaN
# 610              1.805396                1.265896              0.018490
# 611              1.411102                1.228955              0.081096
# 612              1.233902                1.064326              0.193077
#
#      FSR DATA_B(Right)  FSR DATA_C(Left)
# 0             1.733268          1.358621
# 1             1.503390          1.261157
# 2             1.503390          1.163692
# 3             1.273513          0.871298
# 4                  NaN               NaN
# ..                 ...               ...
# 608          -0.105751          1.066228
# 609                NaN               NaN
# 610           0.354004          1.066228
# 611           1.043636          0.773834
# 612           1.733268          0.481440
#
# [613 rows x 9 columns]

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                 0
# FORCE_B(Right)            80
# FORCE_C(Left)             80
# X COORDINATE_C(Left)      80
# X COORDINATE_D(Heel)      80
# X COORDINATE_F(Center)    80
# Y COORDINATE_C(Left)      80
# FSR DATA_B(Right)         80
# FSR DATA_C(Left)          80
# dtype: int64

# %%
data.drop(columns="Unnamed: 0",inplace=True)

# %%
import matplotlib.pyplot as plt

columns=data.columns
count=0
for i in columns:
    print(columns[count])
    count=count+1
    plt.plot(data[i])
    plt.show()
# Out:
# FORCE_B(Right)
# FORCE_C(Left)
# X COORDINATE_C(Left)
# X COORDINATE_D(Heel)
# X COORDINATE_F(Center)
# Y COORDINATE_C(Left)
# FSR DATA_B(Right)
# FSR DATA_C(Left)

# %%
data.columns
# Out:
# Index(['FORCE_B(Right)', 'FORCE_C(Left)', 'X COORDINATE_C(Left)',
#        'X COORDINATE_D(Heel)', 'X COORDINATE_F(Center)',
#        'Y COORDINATE_C(Left)', 'FSR DATA_B(Right)', 'FSR DATA_C(Left)'],
#       dtype='object')

# %%
data2=pd.read_excel("/Users/withmocha/Desktop/TEED/data/mocha/23.11.01/data_delay_ffill.xlsx")
data2.drop(columns="Unnamed: 0",inplace=True)
data2=data2.loc[:,['FORCE_C(Left)','FSR DATA_C(Left)']]

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
data_scaled=scaler.fit_transform(data2)
data2=pd.DataFrame(data=data_scaled)
data2=data2.set_axis(["FORCE_C(Left)","FSR DATA_C(Left)"],axis="columns")

# %%
data2
# Out:
#      FORCE_C(Left)  FSR DATA_C(Left)
# 0         1.249019          1.358621
# 1         1.278073          1.261157
# 2         1.394288          1.163692
# 3         1.258703          0.871298
# 4         1.258703          0.871298
# ..             ...               ...
# 608       2.033475          1.066228
# 609       2.033475          1.066228
# 610       2.004421          1.066228
# 611       1.907574          0.773834
# 612       1.781674          0.481440
#
# [613 rows x 2 columns]

# %%
R=data.loc[:,['FORCE_B(Right)','FSR DATA_B(Right)']]
L=data.loc[:,['FORCE_C(Left)','FSR DATA_C(Left)']]

# %%
R
# Out:
#      FORCE_B(Right)  FSR DATA_B(Right)
# 0          2.299863           1.733268
# 1          2.342486           1.503390
# 2          2.470357           1.503390
# 3          2.555604           1.273513
# 4               NaN                NaN
# ..              ...                ...
# 608        0.253933          -0.105751
# 609             NaN                NaN
# 610        1.362145           0.354004
# 611        1.063780           1.043636
# 612        0.850663           1.733268
#
# [613 rows x 2 columns]

# %%
L
# Out:
#      FORCE_C(Left)  FSR DATA_C(Left)
# 0         1.249019          1.358621
# 1         1.278073          1.261157
# 2         1.394288          1.163692
# 3         1.258703          0.871298
# 4              NaN               NaN
# ..             ...               ...
# 608       2.033475          1.066228
# 609            NaN               NaN
# 610       2.004421          1.066228
# 611       1.907574          0.773834
# 612       1.781674          0.481440
#
# [613 rows x 2 columns]

# %%
L.plot(figsize=(20,20))
# Out:
# <Axes: >

# %%
import numpy as np

index=R.index

loss_index_R_FORECE_B=np.array(R.index).reshape(-1,1)[R.iloc[:,0].isna()]
loss_index_R_FSR_B=np.array(R.index).reshape(-1,1)[R.iloc[:,1].isna()]

normal_index_R_FORECE_B=np.setdiff1d(index,loss_index_R_FORECE_B)
normal_index_R_FSR_B=np.setdiff1d(index,loss_index_R_FSR_B)

# %%
print(L.isnull().sum())
print(R.isnull().sum())
# Out:
# FORCE_C(Left)       80
# FSR DATA_C(Left)    80
# dtype: int64
# FORCE_B(Right)       80
# FSR DATA_B(Right)    80
# dtype: int64

# %%
index=L.index

loss_index_L_FORECE_C=np.array(L.index).reshape(-1,1)[L.iloc[:,0].isna()]
loss_index_L_FSR_C=np.array(L.index).reshape(-1,1)[L.iloc[:,1].isna()]

normal_index_L_FORECE_C=np.setdiff1d(index,loss_index_L_FORECE_C)
normal_index_L_FSR_C=np.setdiff1d(index,loss_index_L_FSR_C)

# %%
x_train_R_FORECE_B=normal_index_R_FORECE_B.reshape(-1,1)
y_train_L_FORECE_C=L.iloc[normal_index_L_FORECE_C,0]
x_test_L_FORECE_C=loss_index_L_FORECE_C

x_train_R_FSR_B=normal_index_R_FSR_B.reshape(-1,1)
y_train_L_FSR_C=L.iloc[normal_index_L_FSR_C,1]
x_test_L_FSR_C=loss_index_L_FSR_C

L_FORCE_C=L.iloc[:,0].copy()
L_FSR_C=L.iloc[:,1].copy()

# %%
print(x_train_R_FORECE_B.shape)
print(y_train_L_FORECE_C.shape)
# Out:
# (533, 1)
# (533,)

# %%
x_train_R_FORECE_B=x_train_R_FORECE_B.reshape(x_train_R_FORECE_B.shape[0],x_train_R_FORECE_B.shape[1],1)
x_train_R_FSR_B=x_train_R_FSR_B.reshape(x_train_R_FSR_B.shape[0],x_train_R_FSR_B.shape[1],1)
x_test_L_FORECE_C=x_test_L_FORECE_C.reshape(x_test_L_FORECE_C.shape[0],x_test_L_FORECE_C.shape[1],1)
x_test_L_FSR_C=x_test_L_FSR_C.reshape(x_test_L_FSR_C.shape[0],x_test_L_FSR_C.shape[1],1)

# %%
print(x_train_R_FORECE_B.shape)
print(y_train_L_FORECE_C.shape)
# Out:
# (533, 1, 1)
# (533,)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import LSTM
from tensorflow.keras import layers
from keras.layers import Activation, Dense
import tensorflow as tf 
from tensorflow.keras import Model
from keras.layers import Dropout
from keras.layers import Dense, Input, TimeDistributed, Flatten
from keras.layers.convolutional import Conv1D ,MaxPooling1D
from keras.optimizers import adam
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import LSTM



model_cnn_lstm = Sequential()
model_cnn_lstm.add(TimeDistributed(Conv1D(filters=64, kernel_size=1, activation='relu'), input_shape=(None, x_train_R_FORECE_B.shape[1], x_train_R_FORECE_B.shape[2])))
model_cnn_lstm.add(TimeDistributed(MaxPooling1D(pool_size=1)))
model_cnn_lstm.add(TimeDistributed(Flatten()))
model_cnn_lstm.add(LSTM(1000, activation='relu'))
model_cnn_lstm.add(Dense(1))
model_cnn_lstm.compile(loss='mse', optimizer='adam')
model_cnn_lstm.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_18 (TimeDi  (None, None, 1, 64)      128
#  stributed)
#
#  time_distributed_19 (TimeDi  (None, None, 1, 64)      0
#  stributed)
#
#  time_distributed_20 (TimeDi  (None, None, 64)         0
#  stributed)
#
#  lstm_5 (LSTM)               (None, 1000)              4260000
#
#  dense_5 (Dense)             (None, 1)                 1001
#
# =================================================================
# Total params: 4,261,129
# Trainable params: 4,261,129
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_cnn_lstm.fit(x_train_R_FORECE_B,y_train_L_FORECE_C,epochs=100,verbose="auto",batch_size=4,)
# Out:
# Epoch 1/100
# 134/134 [==============================] - 2s 10ms/step - loss: 9.0394
# Epoch 2/100
# 134/134 [==============================] - 1s 10ms/step - loss: 1.5015
# Epoch 3/100
# 134/134 [==============================] - 1s 10ms/step - loss: 4.4332
# Epoch 4/100
# 134/134 [==============================] - 1s 10ms/step - loss: 1.1865
# Epoch 5/100
# 134/134 [==============================] - 2s 11ms/step - loss: 1.2209
# Epoch 6/100
# 134/134 [==============================] - 2s 11ms/step - loss: 1.3596
# Epoch 7/100
# 134/134 [==============================] - 2s 11ms/step - loss: 1.1142
# Epoch 8/100
# 134/134 [==============================] - 2s 11ms/step - loss: 1.1136
# Epoch 9/100
# 134/134 [==============================] - 1s 10ms/step - loss: 1.0832
# Epoch 10/100
# 134/134 [==============================] - 1s 10ms/step - loss: 1.1391
# Epoch 11/100
# 134/134 [==============================] - 1s 10ms/step - loss: 1.0859
# Epoch 12/100
# 134/134 [==============================] - 1s 10ms/step - loss: 1.1009
# Epoch 13/100
# 134/134 [==============================] - 1s 10ms/step - loss: 1.0592
# Epoch 14/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.9626
# Epoch 15/100
# 134/134 [==============================] - 1s 10ms/step - loss: 1.0620
# Epoch 16/100
# 134/134 [==============================] - 1s 10ms/step - loss: 1.0095
# Epoch 17/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.9295
# Epoch 18/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.9512
# Epoch 19/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.9766
# Epoch 20/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.9134
# Epoch 21/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8830
# Epoch 22/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8489
# Epoch 23/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.9039
# Epoch 24/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.9110
# Epoch 25/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8601
# Epoch 26/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8556
# Epoch 27/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8376
# Epoch 28/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8599
# Epoch 29/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8554
# Epoch 30/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8501
# Epoch 31/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8356
# Epoch 32/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8462
# Epoch 33/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8266
# Epoch 34/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8313
# Epoch 35/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8262
# Epoch 36/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8275
# Epoch 37/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8673
# Epoch 38/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8331
# Epoch 39/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8266
# Epoch 40/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8304
# Epoch 41/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8277
# Epoch 42/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8246
# Epoch 43/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8208
# Epoch 44/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8254
# Epoch 45/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8259
# Epoch 46/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8192
# Epoch 47/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8219
# Epoch 48/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8272
# Epoch 49/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8221
# Epoch 50/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8162
# Epoch 51/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8216
# Epoch 52/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8142
# Epoch 53/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8244
# Epoch 54/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8245
# Epoch 55/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8291
# Epoch 56/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8287
# Epoch 57/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8192
# Epoch 58/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8158
# Epoch 59/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8193
# Epoch 60/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8183
# Epoch 61/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8250
# Epoch 62/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8133
# Epoch 63/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8133
# Epoch 64/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8210
# Epoch 65/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8170
# Epoch 66/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8089
# Epoch 67/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8172
# Epoch 68/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8146
# Epoch 69/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8137
# Epoch 70/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8108
# Epoch 71/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8121
# Epoch 72/100
# 134/134 [==============================] - 2s 11ms/step - loss: 0.8082
# Epoch 73/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8064
# Epoch 74/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8055
# Epoch 75/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8058
# Epoch 76/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8079
# Epoch 77/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8066
# Epoch 78/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8055
# Epoch 79/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8048
# Epoch 80/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8030
# Epoch 81/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8122
# Epoch 82/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8067
# Epoch 83/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8016
# Epoch 84/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8286
# Epoch 85/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8100
# Epoch 86/100
# 134/134 [==============================] - 2s 11ms/step - loss: 0.8054
# Epoch 87/100
# 134/134 [==============================] - 2s 12ms/step - loss: 0.8032
# Epoch 88/100
# 134/134 [==============================] - 2s 12ms/step - loss: 0.8017
# Epoch 89/100
# 134/134 [==============================] - 2s 11ms/step - loss: 0.8047
# Epoch 90/100
# 134/134 [==============================] - 2s 11ms/step - loss: 0.8008
# Epoch 91/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8042
# Epoch 92/100
# 134/134 [==============================] - 2s 11ms/step - loss: 0.8006
# Epoch 93/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8090
# Epoch 94/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7995
# Epoch 95/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8038
# Epoch 96/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7912
# Epoch 97/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7951
# Epoch 98/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7985
# Epoch 99/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7987
# Epoch 100/100
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7997

# %%
pred=model_cnn_lstm.predict(x_test_L_FORECE_C)
pred=pred.reshape(-1,1)
# Out:
# 3/3 [==============================] - 0s 3ms/step

# %%
c=0
for i in loss_index_L_FORECE_C:    
    L_FORCE_C[i]=pred[c]
    c+=1

# %%
import matplotlib.pyplot as plt 
plt.plot(L_FORCE_C,label='imputation_L_FORCE_C_cnnlstm')
plt.plot(L.iloc[:,0],label='original')
plt.legend()

# %%
model_cnn_lstm.fit(x_train_R_FSR_B,y_train_L_FSR_C,epochs=100,verbose="auto",batch_size=4)
pred=model_cnn_lstm.predict(x_test_L_FSR_C)
pred=pred.reshape(-1,1)
# Out:
# Epoch 1/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7987
# Epoch 2/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8001
# Epoch 3/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7960
# Epoch 4/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7950
# Epoch 5/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7921
# Epoch 6/100
# 134/134 [==============================] - 1s 9ms/step - loss: 0.8242
# Epoch 7/100
# 134/134 [==============================] - 1s 9ms/step - loss: 0.7805
# Epoch 8/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.8010
# Epoch 9/100
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7874
# Epoch 10/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7995
# Epoch 11/100
# 134/134 [==============================] - 2s 11ms/step - loss: 0.7911
# Epoch 12/100
# 134/134 [==============================] - 1s 9ms/step - loss: 0.7892
# Epoch 13/100
# 134/134 [==============================] - 1s 9ms/step - loss: 0.7890
# Epoch 14/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7868
# Epoch 15/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7837
# Epoch 16/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7831
# Epoch 17/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7862
# Epoch 18/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.8009
# Epoch 19/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7934
# Epoch 20/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7823
# Epoch 21/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7951
# Epoch 22/100
# 134/134 [==============================] - 2s 17ms/step - loss: 0.7879
# Epoch 23/100
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7826
# Epoch 24/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7792
# Epoch 25/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7885
# Epoch 26/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7903
# Epoch 27/100
# 134/134 [==============================] - 1s 9ms/step - loss: 0.7815
# Epoch 28/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7822
# Epoch 29/100
# 134/134 [==============================] - 2s 11ms/step - loss: 0.7818
# Epoch 30/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7864
# Epoch 31/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7791
# Epoch 32/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7783
# Epoch 33/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7805
# Epoch 34/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7768
# Epoch 35/100
# 134/134 [==============================] - 1s 9ms/step - loss: 0.7905
# Epoch 36/100
# 134/134 [==============================] - 1s 9ms/step - loss: 0.7736
# Epoch 37/100
# 134/134 [==============================] - 1s 9ms/step - loss: 0.7752
# Epoch 38/100
# 134/134 [==============================] - 1s 9ms/step - loss: 0.7905
# Epoch 39/100
# 134/134 [==============================] - 1s 9ms/step - loss: 0.7850
# Epoch 40/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7884
# Epoch 41/100
# 134/134 [==============================] - 2s 11ms/step - loss: 0.7783
# Epoch 42/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7858
# Epoch 43/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7815
# Epoch 44/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7833
# Epoch 45/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7861
# Epoch 46/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7894
# Epoch 47/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7824
# Epoch 48/100
# 134/134 [==============================] - 2s 13ms/step - loss: 0.7821
# Epoch 49/100
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7840
# Epoch 50/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7818
# Epoch 51/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7761
# Epoch 52/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7813
# Epoch 53/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7858
# Epoch 54/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7794
# Epoch 55/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7860
# Epoch 56/100
# 134/134 [==============================] - 2s 14ms/step - loss: 0.7748
# Epoch 57/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7829
# Epoch 58/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7757
# Epoch 59/100
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7865
# Epoch 60/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7778
# Epoch 61/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7781
# Epoch 62/100
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7813
# Epoch 63/100
# 134/134 [==============================] - 2s 13ms/step - loss: 0.7807
# Epoch 64/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7813
# Epoch 65/100
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7819
# Epoch 66/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7775
# Epoch 67/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7807
# Epoch 68/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7775
# Epoch 69/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7789
# Epoch 70/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7783
# Epoch 71/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7788
# Epoch 72/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7752
# Epoch 73/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7939
# Epoch 74/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7825
# Epoch 75/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7788
# Epoch 76/100
# 134/134 [==============================] - 1s 10ms/step - loss: 0.7788
# Epoch 77/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7801
# Epoch 78/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7830
# Epoch 79/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7812
# Epoch 80/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7790
# Epoch 81/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7779
# Epoch 82/100
# 134/134 [==============================] - 2s 11ms/step - loss: 0.7760
# Epoch 83/100
# 134/134 [==============================] - 2s 11ms/step - loss: 0.7698
# Epoch 84/100
# 134/134 [==============================] - 2s 11ms/step - loss: 0.7752
# Epoch 85/100
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7788
# Epoch 86/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7769
# Epoch 87/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7729
# Epoch 88/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7787
# Epoch 89/100
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7744
# Epoch 90/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.7809
# Epoch 91/100
# 134/134 [==============================] - 2s 11ms/step - loss: 0.7756
# Epoch 92/100
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7782
# Epoch 93/100
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7811
# Epoch 94/100
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7816
# Epoch 95/100
# 134/134 [==============================] - 2s 13ms/step - loss: 0.7738
# Epoch 96/100
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7760
# Epoch 97/100
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7731
# Epoch 98/100
# 134/134 [==============================] - 2s 13ms/step - loss: 0.7783
# Epoch 99/100
# 134/134 [==============================] - 2s 13ms/step - loss: 0.7765
# Epoch 100/100
# 134/134 [==============================] - 2s 13ms/step - loss: 0.7809
# 3/3 [==============================] - 0s 4ms/step

# %%
c=0
for i in loss_index_L_FSR_C:    
    L_FSR_C[i]=pred[c]
    c+=1

# %%
plt.plot(L_FSR_C,label='imputation_L_FSR_C_cnnlstm')
plt.plot(L.iloc[:,1],label='original')
plt.legend()

# %%
L.isnull().sum()
# Out:
# FORCE_C(Left)       80
# FSR DATA_C(Left)    80
# dtype: int64

# %%
for i in loss_index_L_FORECE_C:    
    L['FORCE_C(Left)'][i]=L_FORCE_C[i]
    
for i in loss_index_L_FSR_C:    
    L['FSR DATA_C(Left)'][i]=L_FSR_C[i]

# %%
L.plot(figsize=(20,20))
# Out:
# <Axes: >

# %%
answer=pd.read_excel("/Users/withmocha/Desktop/TEED/data/mocha/23.11.01/data_ffill_norm.xlsx")

# %%
answer
# Out:
#      Unnamed: 0  FORCE_B(Right)  FORCE_C(Left)  X COORDINATE_C(Left)  \
# 0             0        2.299863       1.249019              1.545615
# 1             1        2.342486       1.278073              1.767201
# 2             2        2.470357       1.394288              1.766598
# 3             3        2.555604       1.258703              1.795168
# 4             4        2.555604       1.258703              1.795168
# ..          ...             ...            ...                   ...
# 608         608        0.253933       2.033475              0.908013
# 609         609        0.253933       2.033475              0.908013
# 610         610        1.362145       2.004421              1.098743
# 611         611        1.063780       1.907574              0.942600
# 612         612        0.850663       1.781674              0.881108
#
#      X COORDINATE_D(Heel)  X COORDINATE_F(Center)  Y COORDINATE_C(Left)  \
# 0                1.477110                0.907408             -0.901622
# 1                1.805595               -1.000678             -1.390730
# 2                1.231645               -0.746267             -1.104623
# 3                1.361128                0.631795             -1.411730
# 4                1.361128                0.631795             -1.411730
# ..                    ...                     ...                   ...
# 608              1.955067                1.146905              0.310464
# 609              1.955067                1.146905              0.310464
# 610              1.805396                1.265896              0.018490
# 611              1.411102                1.228955              0.081096
# 612              1.233902                1.064326              0.193077
#
#      FSR DATA_B(Right)  FSR DATA_C(Left)
# 0             1.733268          1.358621
# 1             1.503390          1.261157
# 2             1.503390          1.163692
# 3             1.273513          0.871298
# 4             1.273513          0.871298
# ..                 ...               ...
# 608          -0.105751          1.066228
# 609          -0.105751          1.066228
# 610           0.354004          1.066228
# 611           1.043636          0.773834
# 612           1.733268          0.481440
#
# [613 rows x 9 columns]

# %%
answer.columns
# Out:
# Index(['Unnamed: 0', 'FORCE_B(Right)', 'FORCE_C(Left)', 'X COORDINATE_C(Left)',
#        'X COORDINATE_D(Heel)', 'X COORDINATE_F(Center)',
#        'Y COORDINATE_C(Left)', 'FSR DATA_B(Right)', 'FSR DATA_C(Left)'],
#       dtype='object')

# %%
import numpy as np

def RMSE(data,pred):
    n=len(data)
    return np.sqrt((np.sum((data-pred)**2))/n)

print(RMSE(answer['FORCE_C(Left)'],L_FORCE_C))
print(RMSE(answer['FSR DATA_C(Left)'],L_FSR_C))
# Out:
# 0.33644321766877505
# 0.3178211089696026

# %%
L.plot(figsize=(20,20))
# Out:
# <Axes: >

# %%
L = pd.DataFrame(scaler.inverse_transform(L))
L_sca=L.set_axis(["FORCE_C(Left)","FSR DATA_C(Left)"],axis="columns")
L_sca.plot(figsize=(20,20))
# Out:
# <Axes: >
