# %%
import pandas as pd


data_row=pd.read_excel("/Users/withmocha/Desktop/TEED/data/mocha/23.11.14/gait_row.xlsx")

data_row
# Out:
#      Force_A(Big toe)  Force_B(Right)  Force_C(Left)  Force_D(Heel)  \
# 0                   0               0              0             14
# 1                   0               0              0            109
# 2                   0               0              0            240
# 3                   0               0              0            324
# 4                   0               0              0            412
# ..                ...             ...            ...            ...
# 596               385              96             36              0
# 597               278              53             22              0
# 598               170              16              0              0
# 599               105               6              0              0
# 600                40               0              0              0
#
#      E(LittleForce_ toe)  Force_F(Center)  X_COR_A(Big toe)  Force_B(Right).1  \
# ...

# %%
data_row.isnull().sum()
# Out:
# Force_A(Big toe)         0
# Force_B(Right)           0
# Force_C(Left)            0
# Force_D(Heel)            0
# E(LittleForce_ toe)      0
# Force_F(Center)          0
# X_COR_A(Big toe)       285
# Force_B(Right).1       287
# Force_C(Left).1        245
# Force_D(Heel).1        310
# Force_E(Little toe)    379
# Force_F(Center).1      300
# Y_COR_A(Big toe)       285
# Y_COR_B(Right)         287
# Y_COR_C(Left)          245
# Y_COR_D(Heel)          310
# Y_COR_E(Little toe)    379
# Y_COR_F(Center)        300
# dtype: int64

# %%
data_row.fillna(method='bfill',inplace=True)
# Out:
# /var/folders/gb/hslcbzfs0bvcnj3zxtfrxt_r0000gn/T/ipykernel_10700/1142086997.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_row.fillna(method='bfill',inplace=True)

# %%
data_row.isnull().sum()
# Out:
# Force_A(Big toe)        0
# Force_B(Right)          0
# Force_C(Left)           0
# Force_D(Heel)           0
# E(LittleForce_ toe)     0
# Force_F(Center)         0
# X_COR_A(Big toe)        0
# Force_B(Right).1        1
# Force_C(Left).1         3
# Force_D(Heel).1        28
# Force_E(Little toe)     0
# Force_F(Center).1       0
# Y_COR_A(Big toe)        0
# Y_COR_B(Right)          1
# Y_COR_C(Left)           3
# Y_COR_D(Heel)          28
# Y_COR_E(Little toe)     0
# Y_COR_F(Center)         0
# dtype: int64

# %%
data_row.fillna(method='ffill',inplace=True)
# Out:
# /var/folders/gb/hslcbzfs0bvcnj3zxtfrxt_r0000gn/T/ipykernel_10700/252126780.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_row.fillna(method='ffill',inplace=True)

# %%
data_row.isnull().sum()
# Out:
# Force_A(Big toe)       0
# Force_B(Right)         0
# Force_C(Left)          0
# Force_D(Heel)          0
# E(LittleForce_ toe)    0
# Force_F(Center)        0
# X_COR_A(Big toe)       0
# Force_B(Right).1       0
# Force_C(Left).1        0
# Force_D(Heel).1        0
# Force_E(Little toe)    0
# Force_F(Center).1      0
# Y_COR_A(Big toe)       0
# Y_COR_B(Right)         0
# Y_COR_C(Left)          0
# Y_COR_D(Heel)          0
# Y_COR_E(Little toe)    0
# Y_COR_F(Center)        0
# dtype: int64

# %%
data_row.to_excel("gait_row_bfill.xlsx")
